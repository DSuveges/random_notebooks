# %% [markdown]
# # Valiadation lab data
#
# This is in the readme:
#
# ```
# Description for the first set of Open Targets Validation Lab Oncology screen results.
#
# This release contains only Cell Titre Glow (CTG) results for Colorectal cancer (CO) target genes.
#
# The file CTG_CO_Partner-Preview-Matrix_v6a.txt is a tab delimited file with rows corresponding to targeted genes and the following columns:
#
# gene, cell-line, effect-size, pass-fail, expected-to-pass
#
# pass-fail is based on the effect-size score with, in this case a threshold of >= 38 being a pass. Effect-size may be used to order the entries as a proxy for "significance", but the pass-fail column should be used to determine Status (in future releases, pass-fail may not be determine solely using the effect size).
#
# Expected-to-pass corresponds to whether or not this gene & cell-line combination was expected to validate based on the original selection criteria.
#
# Bio-marker/meta-data annotation can be found in the file COlines.txt (the CO prefix indicating these are the annotations for Colorectal cell lines). Rows in this file correspond to cell-lines and each subsequent column corresponds to a biomarker/meta-data annotation which we would like to be presented (somehow!) for each of the rows in the CTG_CO_Partner-Preview-Matrix_v6a.txt file.
# ```

# %%
import pandas as pd

colo_cells = pd.read_csv('/Users/dsuveges/project_data/validation_lab/COlines.txt', sep='\t')

colo_cells
# Out:
#   CO_line MS_status CRIS_subtype KRAS_status TP53_status APC_status
# 0   SW626       MSS            ?         mut         mut        mut
# 1    HT29       MSS            B          wt         mut        mut
# 2   SW837       MSS            B         mut         mut        mut
# 3   MDST8       MSS            D          wt          wt        mut
# 4  HCT116       MSI            D         mut          wt         wt
# 5    KM12       MSI            A          wt         mut         wt
# 6     RKO       MSI            ?          wt          wt         wt
# 7   LS180       MSI            A         mut          wt        mut

# %%
result = pd.read_csv('/Users/dsuveges/project_data/validation_lab/CTG_CO_Partner-Preview-Matrix_v6a.txt', sep='\t')
result.head()
# Out:
#       gene cell-line  effect-size  pass-fail  expected-to-pass
# 0  ARHGEF7     SW626        59.90       True              True
# 1  ARHGEF7      HT29         1.79      False             False
# 2  ARHGEF7     SW837        17.31      False             False
# 3  ARHGEF7     MDST8        -6.49      False              True
# 4  ARHGEF7    HCT116        36.31      False             False

# %%
print(f'Unique genes: {len(result.gene.unique())}')
print(f'Lengther of results dataset: {len(result)}')
print(f"Number of experiments reaching significance: {len(result.loc[result['effect-size'] >= 38])}")
print(f"Number of genes reaching significance: {len(result.loc[result['effect-size'] >= 38].gene.unique())}")
print('Gene with no replication: ' + result.loc[result['effect-size'] < 38].gene.value_counts().loc[lambda x: x == 8].index[0])
# Out:
# Unique genes: 25
# Lengther of results dataset: 200
# Number of experiments reaching significance: 95
# Number of genes reaching significance: 24
# Gene with no replication: HSP90B1

# %%
# Using exclusively pyspark:
import pandas as pd
import json
import requests

from pyspark.conf import SparkConf
from pyspark.sql.types import ArrayType, StringType, IntegerType
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, struct, lit, when, udf, array

sparkConf = (
    SparkConf()
    .set('spark.driver.memory', '15g')
    .set('spark.executor.memory', '15g')
    .set('spark.driver.maxResultSize', '0')
    .set('spark.debug.maxToStringFields', '2000')
    .set('spark.sql.execution.arrow.maxRecordsPerBatch', '500000')
)
spark = (
    SparkSession.builder
    .config(conf=sparkConf)
    .master('local[*]')
    .getOrCreate()
)


cell_lines_file = '/Users/dsuveges/project_data/validation_lab/COlines.txt'
cell_lines_annotation_file = '/Users/dsuveges/project_data/validation_lab/model_list_20211124.csv'
cell_cancer_driver_mutation = '/Users/dsuveges/project_data/validation_lab/mutations_summary_20211124.csv'
validation_file = '/Users/dsuveges/project_data/validation_lab/CTG_CO_Partner-Preview-Matrix_v6a.txt'

# %%
annot = (
    spark.read
    .option("multiline",True)
    .csv(cell_lines_annotation_file, header=True, sep=',', quote='"')
    .persist()
)

print(annot.columns)
annot.show(1, vertical=True)
# Out:
# ['model_id', 'model_name', 'synonyms', 'model_type', 'growth_properties', 'doi', 'pmed', 'model_treatment', 'model_comments', 'msi_status', 'mutational_burden', 'ploidy', 'parent_id', 'crispr_ko_data', 'sample_id', 'tissue', 'tissue_status', 'cancer_type', 'cancer_type_detail', 'cancer_type_ncit_id', 'age_at_sampling', 'sampling_day', 'sampling_month', 'sampling_year', 'sample_treatment', 'sample_treatment_details', 'sample_site', 'tnm_t', 'tnm_n', 'tnm_m', 'tnm_integrated', 'tumour_grade', 'patient_id', 'species', 'gender', 'ethnicity', 'smoking_status', 'model_relations_comment', 'COSMIC_ID', 'BROAD_ID', 'CCLE_ID', 'RRID', 'HCMI', 'suppliers', 'supplier', 'cat_number']
# -RECORD 0----------------------------------------
#  model_id                 | SIDM01274
#  model_name               | HCM-SANG-0314-C15
#  synonyms                 | OESO_167
#  model_type               | Organoid
#  growth_properties        | NA
#  doi                      | null
#  pmed                     | null
#  model_treatment          | None
#  model_comments           | null
#  msi_status               | MSS
#  mutational_burden        | null
#  ploidy                   | null
#  parent_id                | null
#  crispr_ko_data           | False
#  sample_id                | SIDS01216
#  tissue                   | Esophagus
#  tissue_status            | Tumour
#  cancer_type              | Esophageal Carcinoma
#  cancer_type_detail       | Esophageal Adenoc...
#  cancer_type_ncit_id      | C4025
#  age_at_sampling          | 72.0
#  sampling_day             | 1.0
#  sampling_month           | 9.0
#  sampling_year            | 2017.0
#  sample_treatment         | Chemotherapy
#  sample_treatment_details | Capecitabine
# Cis...
#  sample_site              | Esophagus
#  tnm_t                    | T4
#  tnm_n                    | N0
#  tnm_m                    | M0
#  tnm_integrated           | IIIA
#  tumour_grade             | Moderately differ...
#  patient_id               | SIDP01107
#  species                  | Homo Sapiens
#  gender                   | Male
#  ethnicity                | Unknown
#  smoking_status           | Ex-Smoker
#  model_relations_comment  | null
#  COSMIC_ID                | null
#  BROAD_ID                 | null
#  CCLE_ID                  | null
#  RRID                     | null
#  HCMI                     | null
#  suppliers                | null
#  supplier                 | null
#  cat_number               | null
# only showing top 1 row

# %%
# diseaseCellLines_model = (
#     annot
#     .withColumn(
#         'diseaseCellLines',
#         struct(
#             col('model_name').alias('name'), 
#             col('model_id').alias('id'), 
#             col('tissue')
#         )
#     )
#     .select(
#         col('model_name').alias('cellLine'),
#         'diseaseCellLines')
#     .persist()
# )

diseaseCellLines_model = (
    annot
    .select(
        col('model_name').alias('name'), 
        col('model_id').alias('id'), 
        col('tissue')
    )
)


diseaseCellLines_model.show()
# Out:
# +-----------------+---------+--------------------+
# |             name|       id|              tissue|
# +-----------------+---------+--------------------+
# |HCM-SANG-0314-C15|SIDM01274|           Esophagus|
# |HCM-SANG-0272-C20|SIDM01276|     Large Intestine|
# |HCM-SANG-0310-C15|SIDM01280|           Esophagus|
# |              HLF|SIDM00065|               Liver|
# |             TE-7|SIDM00066|           Esophagus|
# |HCM-SANG-0278-C20|SIDM01282|     Large Intestine|
# |HCM-SANG-0277-C18|SIDM01284|     Large Intestine|
# |            TE-13|SIDM00076|           Esophagus|
# |      NCI-ADR-RES|SIDM00089|               Ovary|
# |        ONCO-DG-1|SIDM00093|               Ovary|
# |         NCI-H125|SIDM00106|                Lung|
# |            SNB19|SIDM00109|Central Nervous S...|
# |            B2-17|SIDM00110|Central Nervous S...|
# |HCM-SANG-0276-C18|SIDM01278|     Large Intestine|
# |         COLO-320|SIDM00071|     Large Intestine|
# |             DiFi|SIDM00049|     Large Intestine|
# |            HCE-4|SIDM00052|           Esophagus|
# |           MZ1-PC|SIDM00053|            Pancreas|
# |             PL18|SIDM00054|            Pancreas|
# |               K5|SIDM00056|             Thyroid|
# +-----------------+---------+--------------------+
# only showing top 20 rows

# %% [markdown]
# ## Aggregating data:

# %%
validation_lab_cell_lines = (
    # Reading cell metadata from validation lab:
    spark.read.csv(cell_lines_file, sep='\t', header=True)
    
    # Renaming columns:
    .withColumnRenamed('CO_line', 'name')
    .withColumnRenamed('MS_status', 'microsatelliteStabilityStatus')
    
    # Updating some of the cell lines' name:
    .withColumn('name',
         when(col('name') == 'HT29', 'HT-29')
        .when(col('name') == 'HCT116', 'HCT-116')
        .when(col('name') == 'LS180', 'LS-180')
        .otherwise(col('name'))
    )
    
    # Updating some of the subtype:
    .withColumn('diseaseSubtype',
        when(col('CRIS_subtype') == '?', None)
        .otherwise(col('CRIS_subtype'))
    )
    
    # Joining dataset with cell model data read downloaded from Sanger website:
    .join(diseaseCellLines_model, on='name', how='left')
    
    # Adding UBERON code to tissues (it's constant colon)
    .withColumn('tissueID', lit('UBERON_0000059'))
    
    # generating disease cell lines object:
    .withColumn(
        'diseaseCellLines',
        array(struct(col('name'), col('id'), col('tissue'), col('tissueId')))
    )
    .drop(*['id', 'tissue', 'tissueId', 'CRIS_subtype'])
    .persist()
)


validation_lab_cell_lines.show()
# Out:
# +-------+-----------------------------+-----------+-----------+----------+--------------+--------------------+
# |   name|microsatelliteStabilityStatus|KRAS_status|TP53_status|APC_status|diseaseSubtype|    diseaseCellLines|
# +-------+-----------------------------+-----------+-----------+----------+--------------+--------------------+
# |  SW626|                          MSS|        mut|        mut|       mut|          null|[{SW626, SIDM0116...|
# |  HT-29|                          MSS|         wt|        mut|       mut|             B|[{HT-29, SIDM0013...|
# |  SW837|                          MSS|        mut|        mut|       mut|             B|[{SW837, SIDM0083...|
# |  MDST8|                          MSS|         wt|         wt|       mut|             D|[{MDST8, SIDM0052...|
# |HCT-116|                          MSI|        mut|         wt|        wt|             D|[{HCT-116, SIDM00...|
# |   KM12|                          MSI|         wt|        mut|        wt|             A|[{KM12, SIDM00150...|
# |    RKO|                          MSI|         wt|         wt|        wt|          null|[{RKO, SIDM01090,...|
# | LS-180|                          MSI|        mut|         wt|       mut|             A|[{LS-180, SIDM006...|
# +-------+-----------------------------+-----------+-----------+----------+--------------+--------------------+

# %%
consequences_map = {
    'ess_splice': 'SO_0001629',
    'frameshift': 'SO_0000865',
    'missense': 'SO_0001583',
    'inframe': 'SO_0001817',
    'stop_lost': 'SO_0001578',
    'nonsense': 'SO:0001587'
}

map_udf = udf(lambda x: consequences_map.get(x), StringType())

generate_name_udf = udf(lambda gene, variant: f'{gene}:{variant.split(".")[1]}' if variant else None, StringType())


# Parsing cancer driver mutations:
cancer_drivers = (
    spark
    .read.csv(cell_cancer_driver_mutation, sep=',', header=True)
    .select(
        col('model_name'),
        col('gene_symbol'), col('protein_mutation'), col('effect')
    )
    
    # Filtering for relevant genes:
    .filter(
        col('gene_symbol').isNotNull() &
        col('gene_symbol').isin(['KRAS','TP53', 'APC'])
    )
    
    # Map functional consequences to SO terms:
    .withColumn('functionalConsequenceId', map_udf(col('effect')))
    
    # Generate mutaion names:
    .withColumn(
        'variant', 
        struct(
            generate_name_udf(col('gene_symbol'), col('protein_mutation')).alias('name'),
            col('functionalConsequenceId')
        ))
    
    # Grouping by model name and gene_symbol:
    .groupby(['model_name'])
    .agg(
        collect_set(col('variant')).alias('variants')
    )
    .withColumnRenamed('model_name', 'name')
)

# %%
validation_lab_cell_lines = (
    validation_lab_cell_lines
    
    # Joining cancer driver mutations with cell lines:
    .join(cancer_drivers, on='name', how='left')
    
    # Dropping unused columns:
    .drop(*['KRAS_status', 'TP53_status', 'APC_status'])
)

# %%
# Out:
# +-------+-----------------------------+--------------+--------------------+--------------------+
# |   name|microsatelliteStabilityStatus|diseaseSubtype|    diseaseCellLines|            variants|
# +-------+-----------------------------+--------------+--------------------+--------------------+
# |  SW626|                          MSS|          null|[{SW626, SIDM0116...|[{TP53:G262V, SO_...|
# |  HT-29|                          MSS|             B|[{HT-29, SIDM0013...|[{TP53:R273H, SO_...|
# |  SW837|                          MSS|             B|[{SW837, SIDM0083...|[{APC:R213*, SO:0...|
# |  MDST8|                          MSS|             D|[{MDST8, SIDM0052...|[{APC:T1556fs*3, ...|
# |HCT-116|                          MSI|             D|[{HCT-116, SIDM00...|[{KRAS:G13D, SO_0...|
# |   KM12|                          MSI|             A|[{KM12, SIDM00150...|[{TP53:H179R, SO_...|
# |    RKO|                          MSI|          null|[{RKO, SIDM01090,...|                null|
# | LS-180|                          MSI|             A|[{LS-180, SIDM006...|[{KRAS:G12D, SO_0...|
# +-------+-----------------------------+--------------+--------------------+--------------------+

# %%
evidence = (
    spark.read.csv(validation_file, sep='\t', header=True)
    .withColumnRenamed('gene', 'targetFromSource')
    .withColumnRenamed('cell-line', 'name')
    .withColumnRenamed('effect-size', 'resourceScore')
    .withColumn(
        'confidence',
        when(col('resourceScore') >= 38, lit('Passed validation'))
        .otherwise(lit('Failed validation'))
    )
    .join(validation_lab_cell_lines, on='name', how='left')
    .drop(*['name', 'pass-fail', 'expected-to-pass'])
)

# %%
evidence.coalesce(1).write.format('json').mode('overwrite').option('compression', 'gzip').save('validation.json')

# %%
# %%bash
#
# gzcat validation.json/*gz | jq
# Out:
# {
#   "targetFromSource": "ARHGEF7",
#   "resourceScore": "6.95",
#   "confidence": "Failed validation",
#   "microsatelliteStabilityStatus": "MSI",
#   "diseaseSubtype": "A",
#   "diseaseCellLines": [
#     {
#       "name": "KM12",
#       "id": "SIDM00150",
#       "tissue": "Large Intestine",
#       "tissueId": "UBERON_0000059"
#     }
#   ],
#   "variants": [
#     {
#       "name": "TP53:H179R",
#       "functionalConsequenceId": "SO_0001583"
#     },
#     {
#       "name": "APC:N1818fs*2",
#       "functionalConsequenceId": "SO_0000865"
#     },
#     {
#       "name": "TP53:V73fs*50",
#       "functionalConsequenceId": "SO_0000865"
#     }
#   ]
# }
# {
#   "targetFromSource": "BRCA2",
#   "resourceScore": "59.68",
#   "confidence": "Passed validation",
#   "microsatelliteStabilityStatus": "MSI",
#   "diseaseSubtype": "A",
#   "diseaseCellLines": [
#     {
#       "name": "KM12",
#       "id": "SIDM00150",
#       "tissue": "Large Intestine",
#       "tissueId": "UBERON_0000059"
#     }
#   ],
#   "variants": [
#     {
#       "name": "TP53:H179R",
#       "functionalConsequenceId": "SO_0001583"
#     },
#     {
#       "name": "APC:N1818fs*2",
#       "functionalConsequenceId": "SO_0000865"
#     },
#     {
#       "name": "TP53:V73fs*50",
#       "functionalConsequenceId": "SO_0000865"
#     }
#   ]
# }
# {
#   "targetFromSource": "CCND1",
#   "resourceScore": "8.66",
#   "confidence": "Failed validation",
#   "microsatelliteStabilityStatus": "MSI",
#   "diseaseSubtype": "A",
#   "diseaseCellLines": [
#     {
#       "name": "KM12",
#       "id": "SIDM00150",
#       "tissue": "Large Intestine",
#       "tissueId": "UBERON_0000059"
#     }
#   ],
#   "variants": [
#     {
#       "name": "TP53:H179R",
#       "functionalConsequenceId": "SO_0001583"
#     },
#     {
#       "name": "APC:N1818fs*2",
#       "functionalConsequenceId": "SO_0000865"
#     },
#     {
#       "name": "TP53:V73fs*50",
#       "functionalConsequenceId": "SO_0000865"
#     }
#   ]
# }
# {
#   "targetFromSource": "CFLAR",
#   "resourceScore": "3.37",
#   "confidence": "Failed validation",
#   "microsatelliteStabilityStatus": "MSI",
#   "diseaseSubtype": "A",
#   "diseaseCellLines": [
#     {
#       "name": "KM12",
#       "id": "SIDM00150",
#       "tissue": "Large Intestine",
#       "tissueId": "UBERON_0000059"
#     }
#   ],
#   "variants": [
#     {
#       "name": "TP53:H179R",
#       "functionalConsequenceId": "SO_0001583"
#     },
#     {
#       "name": "APC:N1818fs*2",
#       "functionalConsequenceId": "SO_0000865"
#     },
#     {
#       "name": "TP53:V73fs*50",
#       "functionalConsequenceId": "SO_0000865"
#     }
#   ]
# }
# {
#   "targetFromSource": "CHD4",
#   "resourceScore": "65.62",
#   "confidence": "Passed validation",
#   "microsatelliteStabilityStatus": "MSI",
#   "diseaseSubtype": "A",
#   "diseaseCellLines": [
#     {
#       "name": "KM12",
#       "id": "SIDM00150",
#       "tissue": "Large Intestine",
#       "tissueId": "UBERON_0000059"
#     }
#   ],
#   "variants": [
#     {
#       "name": "TP53:H179R",
#       "functionalConsequenceId": "SO_0001583"
#     },
#     {
#       "name": "APC:N1818fs*2",
#       "functionalConsequenceId": "SO_0000865"
#     },
#     {
#       "name": "TP53:V73fs*50",
#       "functionalConsequenceId": "SO_0000865"
#     }
#   ]
# }
# {
#   "targetFromSource": "CYB5R4",
#   "resourceScore": "-0.97",
#   "confidence": "Failed validation",
#   "microsatelliteStabilityStatus": "MSI",
#   "diseaseSubtype": "A",
#   "diseaseCellLines": [
#     {
#       "name": "KM12",
#       "id": "SIDM00150",
#       "tissue": "Large Intestine",
#       "tissueId": "UBERON_0000059"
#     }
#   ],
#   "variants": [
#     {
#       "name": "TP53:H179R",
#       "functionalConsequenceId": "SO_0001583"
#     },
#     {
#       "name": "APC:N1818fs*2",
#       "functionalConsequenceId": "SO_0000865"
#     },
#     {
#       "name": "TP53:V73fs*50",
#       "functionalConsequenceId": "SO_0000865"
#     }
#   ]
# }
# {
#   "targetFromSource": "DNAJC11",
#   "resourceScore": "41.35",
#   "confidence": "Passed validation",
#   "microsatelliteStabilityStatus": "MSI",
#   "diseaseSubtype": "A",
#   "diseaseCellLines": [
#     {
#       "name": "KM12",
#       "id": "SIDM00150",
#       "tissue": "Large Intestine",
#       "tissueId": "UBERON_0000059"
#     }
#   ],
#   "variants": [
#     {
#       "name": "TP53:H179R",
#       "functionalConsequenceId": "SO_0001583"
#     },
#     {
#       "name": "APC:N1818fs*2",
#       "functionalConsequenceId": "SO_0000865"
#     },
#     {
#       "name": "TP53:V73fs*50",
#       "functionalConsequenceId": "SO_0000865"
#     }
#   ]
# }
# {
#   "targetFromSource": "DYNLL1",
#   "resourceScore": "12.97",
#   "confidence": "Failed validation",
#   "microsatelliteStabilityStatus": "MSI",
#   "diseaseSubtype": "A",
#   "diseaseCellLines": [
#     {
#       "name": "KM12",
#       "id": "SIDM00150",
#       "tissue": "Large Intestine",
#       "tissueId": "UBERON_0000059"
#     }
#   ],
#   "variants": [
#     {
#       "name": "TP53:H179R",
#       "functionalConsequenceId": "SO_0001583"
#     },
#     {
#       "name": "APC:N1818fs*2",
#       "functionalConsequenceId": "SO_0000865"
#     },
#     {
#       "name": "TP53:V73fs*50",
#       "functionalConsequenceId": "SO_0000865"
#     }
#   ]
# }
# {
#   "targetFromSource": "HSP90B1",
#   "resourceScore": "5.11",
#   "confidence": "Failed validation",
#   "microsatelliteStabilityStatus": "MSI",
#   "diseaseSubtype": "A",
#   "diseaseCellLines": [
#     {
#       "name": "KM12",
#       "id": "SIDM00150",
#       "tissue": "Large Intestine",
#       "tissueId": "UBERON_0000059"
#     }
#   ],
#   "variants": [
#     {
#       "name": "TP53:H179R",
#       "functionalConsequenceId": "SO_0001583"
#     },
#     {
#       "name": "APC:N1818fs*2",
#       "functionalConsequenceId": "SO_0000865"
#     },
#     {
#       "name": "TP53:V73fs*50",
#       "functionalConsequenceId": "SO_0000865"
#     }
#   ]
# }
# {
#   "targetFromSource": "IRF2BP2",
#   "resourceScore": "6.26",
#   "confidence": "Failed validation",
#   "microsatelliteStabilityStatus": "MSI",
#   "diseaseSubtype": "A",
#   "diseaseCellLines": [
#     {
#       "name": "KM12",
#       "id": "SIDM00150",
#       "tissue": "Large Intestine",
#       "tissueId": "UBERON_0000059"
#     }
#   ],
#   "variants": [
#     {
#       "name": "TP53:H179R",
#       "functionalConsequenceId": "SO_0001583"
#     },
#     {
#       "name": "APC:N1818fs*2",
#       "functionalConsequenceId": "SO_0000865"
#     },
#     {
#       "name": "TP53:V73fs*50",
#       "functionalConsequenceId": "SO_0000865"
#     }
#   ]
# }
# {
#   "targetFromSource": "KDM2A",
#   "resourceScore": "35.94",
#   "confidence": "Failed validation",
#   "microsatelliteStabilityStatus": "MSI",
#   "diseaseSubtype": "A",
#   "diseaseCellLines": [
#     {
#       "name": "KM12",
#       "id": "SIDM00150",
#       "tissue": "Large Intestine",
#       "tissueId": "UBERON_0000059"
#     }
#   ],
#   "variants": [
#     {
#       "name": "TP53:H179R",
#       "functionalConsequenceId": "SO_0001583"
#     },
#     {
#       "name": "APC:N1818fs*2",
#       "functionalConsequenceId": "SO_0000865"
#     },
#     {
#       "name": "TP53:V73fs*50",
#       "functionalConsequenceId": "SO_0000865"
#     }
#   ]
# }
# {
#   "targetFromSource": "KRAS",
#   "resourceScore": "11.29",
#   "confidence": "Failed validation",
#   "microsatelliteStabilityStatus": "MSI",
#   "diseaseSubtype": "A",
#   "diseaseCellLines": [
#     {
#       "name": "KM12",
#       "id": "SIDM00150",
#       "tissue": "Large Intestine",
#       "tissueId": "UBERON_0000059"
#     }
#   ],
#   "variants": [
#     {
#       "name": "TP53:H179R",
#       "functionalConsequenceId": "SO_0001583"
#     },
#     {
#       "name": "APC:N1818fs*2",
#       "functionalConsequenceId": "SO_0000865"
#     },
#     {
#       "name": "TP53:V73fs*50",
#       "functionalConsequenceId": "SO_0000865"
#     }
#   ]
# }
# {
#   "targetFromSource": "MTA2",
#   "resourceScore": "14.28",
#   "confidence": "Failed validation",
#   "microsatelliteStabilityStatus": "MSI",
#   "diseaseSubtype": "A",
#   "diseaseCellLines": [
#     {
#       "name": "KM12",
#       "id": "SIDM00150",
#       "tissue": "Large Intestine",
#       "tissueId": "UBERON_0000059"
#     }
#   ],
#   "variants": [
#     {
#       "name": "TP53:H179R",
#       "functionalConsequenceId": "SO_0001583"
#     },
#     {
#       "name": "APC:N1818fs*2",
#       "functionalConsequenceId": "SO_0000865"
#     },
#     {
#       "name": "TP53:V73fs*50",
#       "functionalConsequenceId": "SO_0000865"
#     }
#   ]
# }
# {
#   "targetFromSource": "MTX2",
#   "resourceScore": "15.09",
#   "confidence": "Failed validation",
#   "microsatelliteStabilityStatus": "MSI",
#   "diseaseSubtype": "A",
#   "diseaseCellLines": [
#     {
#       "name": "KM12",
#       "id": "SIDM00150",
#       "tissue": "Large Intestine",
#       "tissueId": "UBERON_0000059"
#     }
#   ],
#   "variants": [
#     {
#       "name": "TP53:H179R",
#       "functionalConsequenceId": "SO_0001583"
#     },
#     {
#       "name": "APC:N1818fs*2",
#       "functionalConsequenceId": "SO_0000865"
#     },
#     {
#       "name": "TP53:V73fs*50",
#       "functionalConsequenceId": "SO_0000865"
#     }
#   ]
# }
# {
#   "targetFromSource": "PAK2",
#   "resourceScore": "16.22",
#   "confidence": "Failed validation",
#   "microsatelliteStabilityStatus": "MSI",
#   "diseaseSubtype": "A",
#   "diseaseCellLines": [
#     {
#       "name": "KM12",
#       "id": "SIDM00150",
#       "tissue": "Large Intestine",
#       "tissueId": "UBERON_0000059"
#     }
#   ],
#   "variants": [
#     {
#       "name": "TP53:H179R",
#       "functionalConsequenceId": "SO_0001583"
#     },
#     {
#       "name": "APC:N1818fs*2",
#       "functionalConsequenceId": "SO_0000865"
#     },
#     {
#       "name": "TP53:V73fs*50",
#       "functionalConsequenceId": "SO_0000865"
#     }
#   ]
# }
# {
#   "targetFromSource": "PPP2CA",
#   "resourceScore": "8.22",
#   "confidence": "Failed validation",
#   "microsatelliteStabilityStatus": "MSI",
#   "diseaseSubtype": "A",
#   "diseaseCellLines": [
#     {
#       "name": "KM12",
#       "id": "SIDM00150",
#       "tissue": "Large Intestine",
#       "tissueId": "UBERON_0000059"
#     }
#   ],
#   "variants": [
#     {
#       "name": "TP53:H179R",
#       "functionalConsequenceId": "SO_0001583"
#     },
#     {
#       "name": "APC:N1818fs*2",
#       "functionalConsequenceId": "SO_0000865"
#     },
#     {
#       "name": "TP53:V73fs*50",
#       "functionalConsequenceId": "SO_0000865"
#     }
#   ]
# }
# {
#   "targetFromSource": "PRPF4B",
#   "resourceScore": "70.77",
#   "confidence": "Passed validation",
#   "microsatelliteStabilityStatus": "MSI",
#   "diseaseSubtype": "A",
#   "diseaseCellLines": [
#     {
#       "name": "KM12",
#       "id": "SIDM00150",
#       "tissue": "Large Intestine",
#       "tissueId": "UBERON_0000059"
#     }
#   ],
#   "variants": [
#     {
#       "name": "TP53:H179R",
#       "functionalConsequenceId": "SO_0001583"
#     },
#     {
#       "name": "APC:N1818fs*2",
#       "functionalConsequenceId": "SO_0000865"
#     },
#     {
#       "name": "TP53:V73fs*50",
#       "functionalConsequenceId": "SO_0000865"
#     }
#   ]
# }
# {
#   "targetFromSource": "RHOA",
#   "resourceScore": "7.94",
#   "confidence": "Failed validation",
#   "microsatelliteStabilityStatus": "MSI",
#   "diseaseSubtype": "A",
#   "diseaseCellLines": [
#     {
#       "name": "KM12",
#       "id": "SIDM00150",
#       "tissue": "Large Intestine",
#       "tissueId": "UBERON_0000059"
#     }
#   ],
#   "variants": [
#     {
#       "name": "TP53:H179R",
#       "functionalConsequenceId": "SO_0001583"
#     },
#     {
#       "name": "APC:N1818fs*2",
#       "functionalConsequenceId": "SO_0000865"
#     },
#     {
#       "name": "TP53:V73fs*50",
#       "functionalConsequenceId": "SO_0000865"
#     }
#   ]
# }
# {
#   "targetFromSource": "TCF7L2",
#   "resourceScore": "4.9",
#   "confidence": "Failed validation",
#   "microsatelliteStabilityStatus": "MSI",
#   "diseaseSubtype": "A",
#   "diseaseCellLines": [
#     {
#       "name": "KM12",
#       "id": "SIDM00150",
#       "tissue": "Large Intestine",
#       "tissueId": "UBERON_0000059"
#     }
#   ],
#   "variants": [
#     {
#       "name": "TP53:H179R",
#       "functionalConsequenceId": "SO_0001583"
#     },
#     {
#       "name": "APC:N1818fs*2",
#       "functionalConsequenceId": "SO_0000865"
#     },
#     {
#       "name": "TP53:V73fs*50",
#       "functionalConsequenceId": "SO_0000865"
#     }
#   ]
# }
# {
#   "targetFromSource": "UBE2C",
#   "resourceScore": "4.02",
#   "confidence": "Failed validation",
#   "microsatelliteStabilityStatus": "MSI",
#   "diseaseSubtype": "A",
#   "diseaseCellLines": [
#     {
#       "name": "KM12",
#       "id": "SIDM00150",
#       "tissue": "Large Intestine",
#       "tissueId": "UBERON_0000059"
#     }
#   ],
#   "variants": [
#     {
#       "name": "TP53:H179R",
#       "functionalConsequenceId": "SO_0001583"
#     },
#     {
#       "name": "APC:N1818fs*2",
#       "functionalConsequenceId": "SO_0000865"
#     },
#     {
#       "name": "TP53:V73fs*50",
#       "functionalConsequenceId": "SO_0000865"
#     }
#   ]
# }
# {
#   "targetFromSource": "UBR4",
#   "resourceScore": "14.15",
#   "confidence": "Failed validation",
#   "microsatelliteStabilityStatus": "MSI",
#   "diseaseSubtype": "A",
#   "diseaseCellLines": [
#     {
#       "name": "KM12",
#       "id": "SIDM00150",
#       "tissue": "Large Intestine",
#       "tissueId": "UBERON_0000059"
#     }
#   ],
#   "variants": [
#     {
#       "name": "TP53:H179R",
#       "functionalConsequenceId": "SO_0001583"
#     },
#     {
#       "name": "APC:N1818fs*2",
#       "functionalConsequenceId": "SO_0000865"
#     },
#     {
#       "name": "TP53:V73fs*50",
#       "functionalConsequenceId": "SO_0000865"
#     }
#   ]
# }
# {
#   "targetFromSource": "USP10",
#   "resourceScore": "71.96",
#   "confidence": "Passed validation",
#   "microsatelliteStabilityStatus": "MSI",
#   "diseaseSubtype": "A",
#   "diseaseCellLines": [
#     {
#       "name": "KM12",
#       "id": "SIDM00150",
#       "tissue": "Large Intestine",
#       "tissueId": "UBERON_0000059"
#     }
#   ],
#   "variants": [
#     {
#       "name": "TP53:H179R",
#       "functionalConsequenceId": "SO_0001583"
#     },
#     {
#       "name": "APC:N1818fs*2",
#       "functionalConsequenceId": "SO_0000865"
#     },
#     {
#       "name": "TP53:V73fs*50",
#       "functionalConsequenceId": "SO_0000865"
#     }
#   ]
# }
# {
#   "targetFromSource": "USP7",
#   "resourceScore": "27.48",
#   "confidence": "Failed validation",
#   "microsatelliteStabilityStatus": "MSI",
#   "diseaseSubtype": "A",
#   "diseaseCellLines": [
#     {
#       "name": "KM12",
#       "id": "SIDM00150",
#       "tissue": "Large Intestine",
#       "tissueId": "UBERON_0000059"
#     }
#   ],
#   "variants": [
#     {
#       "name": "TP53:H179R",
#       "functionalConsequenceId": "SO_0001583"
#     },
#     {
#       "name": "APC:N1818fs*2",
#       "functionalConsequenceId": "SO_0000865"
#     },
#     {
#       "name": "TP53:V73fs*50",
#       "functionalConsequenceId": "SO_0000865"
#     }
#   ]
# }
# {
#   "targetFromSource": "WRN",
#   "resourceScore": "77.5",
#   "confidence": "Passed validation",
#   "microsatelliteStabilityStatus": "MSI",
#   "diseaseSubtype": "A",
#   "diseaseCellLines": [
#     {
#       "name": "KM12",
#       "id": "SIDM00150",
#       "tissue": "Large Intestine",
#       "tissueId": "UBERON_0000059"
#     }
#   ],
#   "variants": [
#     {
#       "name": "TP53:H179R",
#       "functionalConsequenceId": "SO_0001583"
#     },
#     {
#       "name": "APC:N1818fs*2",
#       "functionalConsequenceId": "SO_0000865"
#     },
#     {
#       "name": "TP53:V73fs*50",
#       "functionalConsequenceId": "SO_0000865"
#     }
#   ]
# }
# {
#   "targetFromSource": "ZFP36L1",
#   "resourceScore": "1.62",
#   "confidence": "Failed validation",
#   "microsatelliteStabilityStatus": "MSI",
#   "diseaseSubtype": "A",
#   "diseaseCellLines": [
#     {
#       "name": "KM12",
#       "id": "SIDM00150",
#       "tissue": "Large Intestine",
#       "tissueId": "UBERON_0000059"
#     }
#   ],
#   "variants": [
#     {
#       "name": "TP53:H179R",
#       "functionalConsequenceId": "SO_0001583"
#     },
#     {
#       "name": "APC:N1818fs*2",
#       "functionalConsequenceId": "SO_0000865"
#     },
#     {
#       "name": "TP53:V73fs*50",
#       "functionalConsequenceId": "SO_0000865"
#     }
#   ]
# }
# {
#   "targetFromSource": "ARHGEF7",
#   "resourceScore": "42.06",
#   "confidence": "Passed validation",
#   "microsatelliteStabilityStatus": "MSI",
#   "diseaseCellLines": [
#     {
#       "name": "RKO",
#       "id": "SIDM01090",
#       "tissue": "Large Intestine",
#       "tissueId": "UBERON_0000059"
#     }
#   ]
# }
# {
#   "targetFromSource": "BRCA2",
#   "resourceScore": "59.94",
#   "confidence": "Passed validation",
#   "microsatelliteStabilityStatus": "MSI",
#   "diseaseCellLines": [
#     {
#       "name": "RKO",
#       "id": "SIDM01090",
#       "tissue": "Large Intestine",
#       "tissueId": "UBERON_0000059"
#     }
#   ]
# }
# {
#   "targetFromSource": "CCND1",
#   "resourceScore": "31.28",
#   "confidence": "Failed validation",
#   "microsatelliteStabilityStatus": "MSI",
#   "diseaseCellLines": [
#     {
#       "name": "RKO",
#       "id": "SIDM01090",
#       "tissue": "Large Intestine",
#       "tissueId": "UBERON_0000059"
#     }
#   ]
# }
# {
#   "targetFromSource": "CFLAR",
#   "resourceScore": "27.23",
#   "confidence": "Failed validation",
#   "microsatelliteStabilityStatus": "MSI",
#   "diseaseCellLines": [
#     {
#       "name": "RKO",
#       "id": "SIDM01090",
#       "tissue": "Large Intestine",
#       "tissueId": "UBERON_0000059"
#     }
#   ]
# }
# {
#   "targetFromSource": "CHD4",
#   "resourceScore": "72.33",
#   "confidence": "Passed validation",
#   "microsatelliteStabilityStatus": "MSI",
#   "diseaseCellLines": [
#     {
#       "name": "RKO",
#       "id": "SIDM01090",
#       "tissue": "Large Intestine",
#       "tissueId": "UBERON_0000059"
#     }
#   ]
# }
# {
#   "targetFromSource": "CYB5R4",
#   "resourceScore": "19.94",
#   "confidence": "Failed validation",
#   "microsatelliteStabilityStatus": "MSI",
#   "diseaseCellLines": [
#     {
#       "name": "RKO",
#       "id": "SIDM01090",
#       "tissue": "Large Intestine",
#       "tissueId": "UBERON_0000059"
#     }
#   ]
# }
# {
#   "targetFromSource": "DNAJC11",
#   "resourceScore": "63.93",
#   "confidence": "Passed validation",
#   "microsatelliteStabilityStatus": "MSI",
#   "diseaseCellLines": [
#     {
#       "name": "RKO",
#       "id": "SIDM01090",
#       "tissue": "Large Intestine",
#       "tissueId": "UBERON_0000059"
#     }
#   ]
# }
# {
#   "targetFromSource": "DYNLL1",
#   "resourceScore": "42.65",
#   "confidence": "Passed validation",
#   "microsatelliteStabilityStatus": "MSI",
#   "diseaseCellLines": [
#     {
#       "name": "RKO",
#       "id": "SIDM01090",
#       "tissue": "Large Intestine",
#       "tissueId": "UBERON_0000059"
#     }
#   ]
# }
# {
#   "targetFromSource": "HSP90B1",
#   "resourceScore": "23.58",
#   "confidence": "Failed validation",
#   "microsatelliteStabilityStatus": "MSI",
#   "diseaseCellLines": [
#     {
#       "name": "RKO",
#       "id": "SIDM01090",
#       "tissue": "Large Intestine",
#       "tissueId": "UBERON_0000059"
#     }
#   ]
# }
# {
#   "targetFromSource": "IRF2BP2",
#   "resourceScore": "28.5",
#   "confidence": "Failed validation",
#   "microsatelliteStabilityStatus": "MSI",
#   "diseaseCellLines": [
#     {
#       "name": "RKO",
#       "id": "SIDM01090",
#       "tissue": "Large Intestine",
#       "tissueId": "UBERON_0000059"
#     }
#   ]
# }
# {
#   "targetFromSource": "KDM2A",
#   "resourceScore": "32.09",
#   "confidence": "Failed validation",
#   "microsatelliteStabilityStatus": "MSI",
#   "diseaseCellLines": [
#     {
#       "name": "RKO",
#       "id": "SIDM01090",
#       "tissue": "Large Intestine",
#       "tissueId": "UBERON_0000059"
#     }
#   ]
# }
# {
#   "targetFromSource": "KRAS",
#   "resourceScore": "15.13",
#   "confidence": "Failed validation",
#   "microsatelliteStabilityStatus": "MSI",
#   "diseaseCellLines": [
#     {
#       "name": "RKO",
#       "id": "SIDM01090",
#       "tissue": "Large Intestine",
#       "tissueId": "UBERON_0000059"
#     }
#   ]
# }
# {
#   "targetFromSource": "MTA2",
#   "resourceScore": "21.14",
#   "confidence": "Failed validation",
#   "microsatelliteStabilityStatus": "MSI",
#   "diseaseCellLines": [
#     {
#       "name": "RKO",
#       "id": "SIDM01090",
#       "tissue": "Large Intestine",
#       "tissueId": "UBERON_0000059"
#     }
#   ]
# }
# {
#   "targetFromSource": "MTX2",
#   "resourceScore": "45.94",
#   "confidence": "Passed validation",
#   "microsatelliteStabilityStatus": "MSI",
#   "diseaseCellLines": [
#     {
#       "name": "RKO",
#       "id": "SIDM01090",
#       "tissue": "Large Intestine",
#       "tissueId": "UBERON_0000059"
#     }
#   ]
# }
# {
#   "targetFromSource": "PAK2",
#   "resourceScore": "34.35",
#   "confidence": "Failed validation",
#   "microsatelliteStabilityStatus": "MSI",
#   "diseaseCellLines": [
#     {
#       "name": "RKO",
#       "id": "SIDM01090",
#       "tissue": "Large Intestine",
#       "tissueId": "UBERON_0000059"
#     }
#   ]
# }
# {
#   "targetFromSource": "PPP2CA",
#   "resourceScore": "26.79",
#   "confidence": "Failed validation",
#   "microsatelliteStabilityStatus": "MSI",
#   "diseaseCellLines": [
#     {
#       "name": "RKO",
#       "id": "SIDM01090",
#       "tissue": "Large Intestine",
#       "tissueId": "UBERON_0000059"
#     }
#   ]
# }
# {
#   "targetFromSource": "PRPF4B",
#   "resourceScore": "72.76",
#   "confidence": "Passed validation",
#   "microsatelliteStabilityStatus": "MSI",
#   "diseaseCellLines": [
#     {
#       "name": "RKO",
#       "id": "SIDM01090",
#       "tissue": "Large Intestine",
#       "tissueId": "UBERON_0000059"
#     }
#   ]
# }
# {
#   "targetFromSource": "RHOA",
#   "resourceScore": "53.42",
#   "confidence": "Passed validation",
#   "microsatelliteStabilityStatus": "MSI",
#   "diseaseCellLines": [
#     {
#       "name": "RKO",
#       "id": "SIDM01090",
#       "tissue": "Large Intestine",
#       "tissueId": "UBERON_0000059"
#     }
#   ]
# }
# {
#   "targetFromSource": "TCF7L2",
#   "resourceScore": "11.03",
#   "confidence": "Failed validation",
#   "microsatelliteStabilityStatus": "MSI",
#   "diseaseCellLines": [
#     {
#       "name": "RKO",
#       "id": "SIDM01090",
#       "tissue": "Large Intestine",
#       "tissueId": "UBERON_0000059"
#     }
#   ]
# }
# {
#   "targetFromSource": "UBE2C",
#   "resourceScore": "45.93",
#   "confidence": "Passed validation",
#   "microsatelliteStabilityStatus": "MSI",
#   "diseaseCellLines": [
#     {
#       "name": "RKO",
#       "id": "SIDM01090",
#       "tissue": "Large Intestine",
#       "tissueId": "UBERON_0000059"
#     }
#   ]
# }
# {
#   "targetFromSource": "UBR4",
#   "resourceScore": "25.56",
#   "confidence": "Failed validation",
#   "microsatelliteStabilityStatus": "MSI",
#   "diseaseCellLines": [
#     {
#       "name": "RKO",
#       "id": "SIDM01090",
#       "tissue": "Large Intestine",
#       "tissueId": "UBERON_0000059"
#     }
#   ]
# }
# {
#   "targetFromSource": "USP10",
#   "resourceScore": "73.85",
#   "confidence": "Passed validation",
#   "microsatelliteStabilityStatus": "MSI",
#   "diseaseCellLines": [
#     {
#       "name": "RKO",
#       "id": "SIDM01090",
#       "tissue": "Large Intestine",
#       "tissueId": "UBERON_0000059"
#     }
#   ]
# }
# {
#   "targetFromSource": "USP7",
#   "resourceScore": "83.06",
#   "confidence": "Passed validation",
#   "microsatelliteStabilityStatus": "MSI",
#   "diseaseCellLines": [
#     {
#       "name": "RKO",
#       "id": "SIDM01090",
#       "tissue": "Large Intestine",
#       "tissueId": "UBERON_0000059"
#     }
#   ]
# }
# {
#   "targetFromSource": "WRN",
#   "resourceScore": "67.81",
#   "confidence": "Passed validation",
#   "microsatelliteStabilityStatus": "MSI",
#   "diseaseCellLines": [
#     {
#       "name": "RKO",
#       "id": "SIDM01090",
#       "tissue": "Large Intestine",
#       "tissueId": "UBERON_0000059"
#     }
#   ]
# }
# {
#   "targetFromSource": "ZFP36L1",
#   "resourceScore": "72.45",
#   "confidence": "Passed validation",
#   "microsatelliteStabilityStatus": "MSI",
#   "diseaseCellLines": [
#     {
#       "name": "RKO",
#       "id": "SIDM01090",
#       "tissue": "Large Intestine",
#       "tissueId": "UBERON_0000059"
#     }
#   ]
# }
# {
#   "targetFromSource": "ARHGEF7",
#   "resourceScore": "58.5",
#   "confidence": "Passed validation"
# }
# {
#   "targetFromSource": "BRCA2",
#   "resourceScore": "68.79",
#   "confidence": "Passed validation"
# }
# {
#   "targetFromSource": "CCND1",
#   "resourceScore": "65.02",
#   "confidence": "Passed validation"
# }
# {
#   "targetFromSource": "CFLAR",
#   "resourceScore": "76.44",
#   "confidence": "Passed validation"
# }
# {
#   "targetFromSource": "CHD4",
#   "resourceScore": "88.43",
#   "confidence": "Passed validation"
# }
# {
#   "targetFromSource": "CYB5R4",
#   "resourceScore": "48.36",
#   "confidence": "Passed validation"
# }
# {
#   "targetFromSource": "DNAJC11",
#   "resourceScore": "45.69",
#   "confidence": "Passed validation"
# }
# {
#   "targetFromSource": "DYNLL1",
#   "resourceScore": "49.22",
#   "confidence": "Passed validation"
# }
# {
#   "targetFromSource": "HSP90B1",
#   "resourceScore": "21.13",
#   "confidence": "Failed validation"
# }
# {
#   "targetFromSource": "IRF2BP2",
#   "resourceScore": "77.23",
#   "confidence": "Passed validation"
# }
# {
#   "targetFromSource": "KDM2A",
#   "resourceScore": "59.42",
#   "confidence": "Passed validation"
# }
# {
#   "targetFromSource": "KRAS",
#   "resourceScore": "96.57",
#   "confidence": "Passed validation"
# }
# {
#   "targetFromSource": "MTA2",
#   "resourceScore": "61.68",
#   "confidence": "Passed validation"
# }
# {
#   "targetFromSource": "MTX2",
#   "resourceScore": "25.27",
#   "confidence": "Failed validation"
# }
# {
#   "targetFromSource": "PAK2",
#   "resourceScore": "47.37",
#   "confidence": "Passed validation"
# }
# {
#   "targetFromSource": "PPP2CA",
#   "resourceScore": "76.29",
#   "confidence": "Passed validation"
# }
# {
#   "targetFromSource": "PRPF4B",
#   "resourceScore": "59.95",
#   "confidence": "Passed validation"
# }
# {
#   "targetFromSource": "RHOA",
#   "resourceScore": "78.82",
#   "confidence": "Passed validation"
# }
# {
#   "targetFromSource": "TCF7L2",
#   "resourceScore": "68.88",
#   "confidence": "Passed validation"
# }
# {
#   "targetFromSource": "UBE2C",
#   "resourceScore": "61.55",
#   "confidence": "Passed validation"
# }
# {
#   "targetFromSource": "UBR4",
#   "resourceScore": "39.31",
#   "confidence": "Passed validation"
# }
# {
#   "targetFromSource": "USP10",
#   "resourceScore": "96.12",
#   "confidence": "Passed validation"
# }
# {
#   "targetFromSource": "USP7",
#   "resourceScore": "80.51",
#   "confidence": "Passed validation"
# }
# {
#   "targetFromSource": "WRN",
#   "resourceScore": "77.79",
#   "confidence": "Passed validation"
# }
# {
#   "targetFromSource": "ZFP36L1",
#   "resourceScore": "42.08",
#   "confidence": "Passed validation"
# }
# {
#   "targetFromSource": "ARHGEF7",
#   "resourceScore": "17.31",
#   "confidence": "Failed validation",
#   "microsatelliteStabilityStatus": "MSS",
#   "diseaseSubtype": "B",
#   "diseaseCellLines": [
#     {
#       "name": "SW837",
#       "id": "SIDM00833",
#       "tissue": "Large Intestine",
#       "tissueId": "UBERON_0000059"
#     }
#   ],
#   "variants": [
#     {
#       "name": "APC:R213*",
#       "functionalConsequenceId": "SO:0001587"
#     },
#     {
#       "name": "APC:R1450*",
#       "functionalConsequenceId": "SO:0001587"
#     },
#     {
#       "name": "KRAS:G12C",
#       "functionalConsequenceId": "SO_0001583"
#     },
#     {
#       "name": "TP53:R248W",
#       "functionalConsequenceId": "SO_0001583"
#     }
#   ]
# }
# {
#   "targetFromSource": "BRCA2",
#   "resourceScore": "15.28",
#   "confidence": "Failed validation",
#   "microsatelliteStabilityStatus": "MSS",
#   "diseaseSubtype": "B",
#   "diseaseCellLines": [
#     {
#       "name": "SW837",
#       "id": "SIDM00833",
#       "tissue": "Large Intestine",
#       "tissueId": "UBERON_0000059"
#     }
#   ],
#   "variants": [
#     {
#       "name": "APC:R213*",
#       "functionalConsequenceId": "SO:0001587"
#     },
#     {
#       "name": "APC:R1450*",
#       "functionalConsequenceId": "SO:0001587"
#     },
#     {
#       "name": "KRAS:G12C",
#       "functionalConsequenceId": "SO_0001583"
#     },
#     {
#       "name": "TP53:R248W",
#       "functionalConsequenceId": "SO_0001583"
#     }
#   ]
# }
# {
#   "targetFromSource": "CCND1",
#   "resourceScore": "21.39",
#   "confidence": "Failed validation",
#   "microsatelliteStabilityStatus": "MSS",
#   "diseaseSubtype": "B",
#   "diseaseCellLines": [
#     {
#       "name": "SW837",
#       "id": "SIDM00833",
#       "tissue": "Large Intestine",
#       "tissueId": "UBERON_0000059"
#     }
#   ],
#   "variants": [
#     {
#       "name": "APC:R213*",
#       "functionalConsequenceId": "SO:0001587"
#     },
#     {
#       "name": "APC:R1450*",
#       "functionalConsequenceId": "SO:0001587"
#     },
#     {
#       "name": "KRAS:G12C",
#       "functionalConsequenceId": "SO_0001583"
#     },
#     {
#       "name": "TP53:R248W",
#       "functionalConsequenceId": "SO_0001583"
#     }
#   ]
# }
# {
#   "targetFromSource": "CFLAR",
#   "resourceScore": "35.71",
#   "confidence": "Failed validation",
#   "microsatelliteStabilityStatus": "MSS",
#   "diseaseSubtype": "B",
#   "diseaseCellLines": [
#     {
#       "name": "SW837",
#       "id": "SIDM00833",
#       "tissue": "Large Intestine",
#       "tissueId": "UBERON_0000059"
#     }
#   ],
#   "variants": [
#     {
#       "name": "APC:R213*",
#       "functionalConsequenceId": "SO:0001587"
#     },
#     {
#       "name": "APC:R1450*",
#       "functionalConsequenceId": "SO:0001587"
#     },
#     {
#       "name": "KRAS:G12C",
#       "functionalConsequenceId": "SO_0001583"
#     },
#     {
#       "name": "TP53:R248W",
#       "functionalConsequenceId": "SO_0001583"
#     }
#   ]
# }
# {
#   "targetFromSource": "CHD4",
#   "resourceScore": "119.09",
#   "confidence": "Passed validation",
#   "microsatelliteStabilityStatus": "MSS",
#   "diseaseSubtype": "B",
#   "diseaseCellLines": [
#     {
#       "name": "SW837",
#       "id": "SIDM00833",
#       "tissue": "Large Intestine",
#       "tissueId": "UBERON_0000059"
#     }
#   ],
#   "variants": [
#     {
#       "name": "APC:R213*",
#       "functionalConsequenceId": "SO:0001587"
#     },
#     {
#       "name": "APC:R1450*",
#       "functionalConsequenceId": "SO:0001587"
#     },
#     {
#       "name": "KRAS:G12C",
#       "functionalConsequenceId": "SO_0001583"
#     },
#     {
#       "name": "TP53:R248W",
#       "functionalConsequenceId": "SO_0001583"
#     }
#   ]
# }
# {
#   "targetFromSource": "CYB5R4",
#   "resourceScore": "14.32",
#   "confidence": "Failed validation",
#   "microsatelliteStabilityStatus": "MSS",
#   "diseaseSubtype": "B",
#   "diseaseCellLines": [
#     {
#       "name": "SW837",
#       "id": "SIDM00833",
#       "tissue": "Large Intestine",
#       "tissueId": "UBERON_0000059"
#     }
#   ],
#   "variants": [
#     {
#       "name": "APC:R213*",
#       "functionalConsequenceId": "SO:0001587"
#     },
#     {
#       "name": "APC:R1450*",
#       "functionalConsequenceId": "SO:0001587"
#     },
#     {
#       "name": "KRAS:G12C",
#       "functionalConsequenceId": "SO_0001583"
#     },
#     {
#       "name": "TP53:R248W",
#       "functionalConsequenceId": "SO_0001583"
#     }
#   ]
# }
# {
#   "targetFromSource": "DNAJC11",
#   "resourceScore": "23.28",
#   "confidence": "Failed validation",
#   "microsatelliteStabilityStatus": "MSS",
#   "diseaseSubtype": "B",
#   "diseaseCellLines": [
#     {
#       "name": "SW837",
#       "id": "SIDM00833",
#       "tissue": "Large Intestine",
#       "tissueId": "UBERON_0000059"
#     }
#   ],
#   "variants": [
#     {
#       "name": "APC:R213*",
#       "functionalConsequenceId": "SO:0001587"
#     },
#     {
#       "name": "APC:R1450*",
#       "functionalConsequenceId": "SO:0001587"
#     },
#     {
#       "name": "KRAS:G12C",
#       "functionalConsequenceId": "SO_0001583"
#     },
#     {
#       "name": "TP53:R248W",
#       "functionalConsequenceId": "SO_0001583"
#     }
#   ]
# }
# {
#   "targetFromSource": "DYNLL1",
#   "resourceScore": "23.4",
#   "confidence": "Failed validation",
#   "microsatelliteStabilityStatus": "MSS",
#   "diseaseSubtype": "B",
#   "diseaseCellLines": [
#     {
#       "name": "SW837",
#       "id": "SIDM00833",
#       "tissue": "Large Intestine",
#       "tissueId": "UBERON_0000059"
#     }
#   ],
#   "variants": [
#     {
#       "name": "APC:R213*",
#       "functionalConsequenceId": "SO:0001587"
#     },
#     {
#       "name": "APC:R1450*",
#       "functionalConsequenceId": "SO:0001587"
#     },
#     {
#       "name": "KRAS:G12C",
#       "functionalConsequenceId": "SO_0001583"
#     },
#     {
#       "name": "TP53:R248W",
#       "functionalConsequenceId": "SO_0001583"
#     }
#   ]
# }
# {
#   "targetFromSource": "HSP90B1",
#   "resourceScore": "10.76",
#   "confidence": "Failed validation",
#   "microsatelliteStabilityStatus": "MSS",
#   "diseaseSubtype": "B",
#   "diseaseCellLines": [
#     {
#       "name": "SW837",
#       "id": "SIDM00833",
#       "tissue": "Large Intestine",
#       "tissueId": "UBERON_0000059"
#     }
#   ],
#   "variants": [
#     {
#       "name": "APC:R213*",
#       "functionalConsequenceId": "SO:0001587"
#     },
#     {
#       "name": "APC:R1450*",
#       "functionalConsequenceId": "SO:0001587"
#     },
#     {
#       "name": "KRAS:G12C",
#       "functionalConsequenceId": "SO_0001583"
#     },
#     {
#       "name": "TP53:R248W",
#       "functionalConsequenceId": "SO_0001583"
#     }
#   ]
# }
# {
#   "targetFromSource": "IRF2BP2",
#   "resourceScore": "26.41",
#   "confidence": "Failed validation",
#   "microsatelliteStabilityStatus": "MSS",
#   "diseaseSubtype": "B",
#   "diseaseCellLines": [
#     {
#       "name": "SW837",
#       "id": "SIDM00833",
#       "tissue": "Large Intestine",
#       "tissueId": "UBERON_0000059"
#     }
#   ],
#   "variants": [
#     {
#       "name": "APC:R213*",
#       "functionalConsequenceId": "SO:0001587"
#     },
#     {
#       "name": "APC:R1450*",
#       "functionalConsequenceId": "SO:0001587"
#     },
#     {
#       "name": "KRAS:G12C",
#       "functionalConsequenceId": "SO_0001583"
#     },
#     {
#       "name": "TP53:R248W",
#       "functionalConsequenceId": "SO_0001583"
#     }
#   ]
# }
# {
#   "targetFromSource": "KDM2A",
#   "resourceScore": "49.36",
#   "confidence": "Passed validation",
#   "microsatelliteStabilityStatus": "MSS",
#   "diseaseSubtype": "B",
#   "diseaseCellLines": [
#     {
#       "name": "SW837",
#       "id": "SIDM00833",
#       "tissue": "Large Intestine",
#       "tissueId": "UBERON_0000059"
#     }
#   ],
#   "variants": [
#     {
#       "name": "APC:R213*",
#       "functionalConsequenceId": "SO:0001587"
#     },
#     {
#       "name": "APC:R1450*",
#       "functionalConsequenceId": "SO:0001587"
#     },
#     {
#       "name": "KRAS:G12C",
#       "functionalConsequenceId": "SO_0001583"
#     },
#     {
#       "name": "TP53:R248W",
#       "functionalConsequenceId": "SO_0001583"
#     }
#   ]
# }
# {
#   "targetFromSource": "KRAS",
#   "resourceScore": "73.26",
#   "confidence": "Passed validation",
#   "microsatelliteStabilityStatus": "MSS",
#   "diseaseSubtype": "B",
#   "diseaseCellLines": [
#     {
#       "name": "SW837",
#       "id": "SIDM00833",
#       "tissue": "Large Intestine",
#       "tissueId": "UBERON_0000059"
#     }
#   ],
#   "variants": [
#     {
#       "name": "APC:R213*",
#       "functionalConsequenceId": "SO:0001587"
#     },
#     {
#       "name": "APC:R1450*",
#       "functionalConsequenceId": "SO:0001587"
#     },
#     {
#       "name": "KRAS:G12C",
#       "functionalConsequenceId": "SO_0001583"
#     },
#     {
#       "name": "TP53:R248W",
#       "functionalConsequenceId": "SO_0001583"
#     }
#   ]
# }
# {
#   "targetFromSource": "MTA2",
#   "resourceScore": "38.65",
#   "confidence": "Passed validation",
#   "microsatelliteStabilityStatus": "MSS",
#   "diseaseSubtype": "B",
#   "diseaseCellLines": [
#     {
#       "name": "SW837",
#       "id": "SIDM00833",
#       "tissue": "Large Intestine",
#       "tissueId": "UBERON_0000059"
#     }
#   ],
#   "variants": [
#     {
#       "name": "APC:R213*",
#       "functionalConsequenceId": "SO:0001587"
#     },
#     {
#       "name": "APC:R1450*",
#       "functionalConsequenceId": "SO:0001587"
#     },
#     {
#       "name": "KRAS:G12C",
#       "functionalConsequenceId": "SO_0001583"
#     },
#     {
#       "name": "TP53:R248W",
#       "functionalConsequenceId": "SO_0001583"
#     }
#   ]
# }
# {
#   "targetFromSource": "MTX2",
#   "resourceScore": "24.65",
#   "confidence": "Failed validation",
#   "microsatelliteStabilityStatus": "MSS",
#   "diseaseSubtype": "B",
#   "diseaseCellLines": [
#     {
#       "name": "SW837",
#       "id": "SIDM00833",
#       "tissue": "Large Intestine",
#       "tissueId": "UBERON_0000059"
#     }
#   ],
#   "variants": [
#     {
#       "name": "APC:R213*",
#       "functionalConsequenceId": "SO:0001587"
#     },
#     {
#       "name": "APC:R1450*",
#       "functionalConsequenceId": "SO:0001587"
#     },
#     {
#       "name": "KRAS:G12C",
#       "functionalConsequenceId": "SO_0001583"
#     },
#     {
#       "name": "TP53:R248W",
#       "functionalConsequenceId": "SO_0001583"
#     }
#   ]
# }
# {
#   "targetFromSource": "PAK2",
#   "resourceScore": "13.05",
#   "confidence": "Failed validation",
#   "microsatelliteStabilityStatus": "MSS",
#   "diseaseSubtype": "B",
#   "diseaseCellLines": [
#     {
#       "name": "SW837",
#       "id": "SIDM00833",
#       "tissue": "Large Intestine",
#       "tissueId": "UBERON_0000059"
#     }
#   ],
#   "variants": [
#     {
#       "name": "APC:R213*",
#       "functionalConsequenceId": "SO:0001587"
#     },
#     {
#       "name": "APC:R1450*",
#       "functionalConsequenceId": "SO:0001587"
#     },
#     {
#       "name": "KRAS:G12C",
#       "functionalConsequenceId": "SO_0001583"
#     },
#     {
#       "name": "TP53:R248W",
#       "functionalConsequenceId": "SO_0001583"
#     }
#   ]
# }
# {
#   "targetFromSource": "PPP2CA",
#   "resourceScore": "63.85",
#   "confidence": "Passed validation",
#   "microsatelliteStabilityStatus": "MSS",
#   "diseaseSubtype": "B",
#   "diseaseCellLines": [
#     {
#       "name": "SW837",
#       "id": "SIDM00833",
#       "tissue": "Large Intestine",
#       "tissueId": "UBERON_0000059"
#     }
#   ],
#   "variants": [
#     {
#       "name": "APC:R213*",
#       "functionalConsequenceId": "SO:0001587"
#     },
#     {
#       "name": "APC:R1450*",
#       "functionalConsequenceId": "SO:0001587"
#     },
#     {
#       "name": "KRAS:G12C",
#       "functionalConsequenceId": "SO_0001583"
#     },
#     {
#       "name": "TP53:R248W",
#       "functionalConsequenceId": "SO_0001583"
#     }
#   ]
# }
# {
#   "targetFromSource": "PRPF4B",
#   "resourceScore": "54.02",
#   "confidence": "Passed validation",
#   "microsatelliteStabilityStatus": "MSS",
#   "diseaseSubtype": "B",
#   "diseaseCellLines": [
#     {
#       "name": "SW837",
#       "id": "SIDM00833",
#       "tissue": "Large Intestine",
#       "tissueId": "UBERON_0000059"
#     }
#   ],
#   "variants": [
#     {
#       "name": "APC:R213*",
#       "functionalConsequenceId": "SO:0001587"
#     },
#     {
#       "name": "APC:R1450*",
#       "functionalConsequenceId": "SO:0001587"
#     },
#     {
#       "name": "KRAS:G12C",
#       "functionalConsequenceId": "SO_0001583"
#     },
#     {
#       "name": "TP53:R248W",
#       "functionalConsequenceId": "SO_0001583"
#     }
#   ]
# }
# {
#   "targetFromSource": "RHOA",
#   "resourceScore": "51.68",
#   "confidence": "Passed validation",
#   "microsatelliteStabilityStatus": "MSS",
#   "diseaseSubtype": "B",
#   "diseaseCellLines": [
#     {
#       "name": "SW837",
#       "id": "SIDM00833",
#       "tissue": "Large Intestine",
#       "tissueId": "UBERON_0000059"
#     }
#   ],
#   "variants": [
#     {
#       "name": "APC:R213*",
#       "functionalConsequenceId": "SO:0001587"
#     },
#     {
#       "name": "APC:R1450*",
#       "functionalConsequenceId": "SO:0001587"
#     },
#     {
#       "name": "KRAS:G12C",
#       "functionalConsequenceId": "SO_0001583"
#     },
#     {
#       "name": "TP53:R248W",
#       "functionalConsequenceId": "SO_0001583"
#     }
#   ]
# }
# {
#   "targetFromSource": "TCF7L2",
#   "resourceScore": "16.29",
#   "confidence": "Failed validation",
#   "microsatelliteStabilityStatus": "MSS",
#   "diseaseSubtype": "B",
#   "diseaseCellLines": [
#     {
#       "name": "SW837",
#       "id": "SIDM00833",
#       "tissue": "Large Intestine",
#       "tissueId": "UBERON_0000059"
#     }
#   ],
#   "variants": [
#     {
#       "name": "APC:R213*",
#       "functionalConsequenceId": "SO:0001587"
#     },
#     {
#       "name": "APC:R1450*",
#       "functionalConsequenceId": "SO:0001587"
#     },
#     {
#       "name": "KRAS:G12C",
#       "functionalConsequenceId": "SO_0001583"
#     },
#     {
#       "name": "TP53:R248W",
#       "functionalConsequenceId": "SO_0001583"
#     }
#   ]
# }
# {
#   "targetFromSource": "UBE2C",
#   "resourceScore": "19.43",
#   "confidence": "Failed validation",
#   "microsatelliteStabilityStatus": "MSS",
#   "diseaseSubtype": "B",
#   "diseaseCellLines": [
#     {
#       "name": "SW837",
#       "id": "SIDM00833",
#       "tissue": "Large Intestine",
#       "tissueId": "UBERON_0000059"
#     }
#   ],
#   "variants": [
#     {
#       "name": "APC:R213*",
#       "functionalConsequenceId": "SO:0001587"
#     },
#     {
#       "name": "APC:R1450*",
#       "functionalConsequenceId": "SO:0001587"
#     },
#     {
#       "name": "KRAS:G12C",
#       "functionalConsequenceId": "SO_0001583"
#     },
#     {
#       "name": "TP53:R248W",
#       "functionalConsequenceId": "SO_0001583"
#     }
#   ]
# }
# {
#   "targetFromSource": "UBR4",
#   "resourceScore": "26",
#   "confidence": "Failed validation",
#   "microsatelliteStabilityStatus": "MSS",
#   "diseaseSubtype": "B",
#   "diseaseCellLines": [
#     {
#       "name": "SW837",
#       "id": "SIDM00833",
#       "tissue": "Large Intestine",
#       "tissueId": "UBERON_0000059"
#     }
#   ],
#   "variants": [
#     {
#       "name": "APC:R213*",
#       "functionalConsequenceId": "SO:0001587"
#     },
#     {
#       "name": "APC:R1450*",
#       "functionalConsequenceId": "SO:0001587"
#     },
#     {
#       "name": "KRAS:G12C",
#       "functionalConsequenceId": "SO_0001583"
#     },
#     {
#       "name": "TP53:R248W",
#       "functionalConsequenceId": "SO_0001583"
#     }
#   ]
# }
# {
#   "targetFromSource": "USP10",
#   "resourceScore": "45.8",
#   "confidence": "Passed validation",
#   "microsatelliteStabilityStatus": "MSS",
#   "diseaseSubtype": "B",
#   "diseaseCellLines": [
#     {
#       "name": "SW837",
#       "id": "SIDM00833",
#       "tissue": "Large Intestine",
#       "tissueId": "UBERON_0000059"
#     }
#   ],
#   "variants": [
#     {
#       "name": "APC:R213*",
#       "functionalConsequenceId": "SO:0001587"
#     },
#     {
#       "name": "APC:R1450*",
#       "functionalConsequenceId": "SO:0001587"
#     },
#     {
#       "name": "KRAS:G12C",
#       "functionalConsequenceId": "SO_0001583"
#     },
#     {
#       "name": "TP53:R248W",
#       "functionalConsequenceId": "SO_0001583"
#     }
#   ]
# }
# {
#   "targetFromSource": "USP7",
#   "resourceScore": "33.66",
#   "confidence": "Failed validation",
#   "microsatelliteStabilityStatus": "MSS",
#   "diseaseSubtype": "B",
#   "diseaseCellLines": [
#     {
#       "name": "SW837",
#       "id": "SIDM00833",
#       "tissue": "Large Intestine",
#       "tissueId": "UBERON_0000059"
#     }
#   ],
#   "variants": [
#     {
#       "name": "APC:R213*",
#       "functionalConsequenceId": "SO:0001587"
#     },
#     {
#       "name": "APC:R1450*",
#       "functionalConsequenceId": "SO:0001587"
#     },
#     {
#       "name": "KRAS:G12C",
#       "functionalConsequenceId": "SO_0001583"
#     },
#     {
#       "name": "TP53:R248W",
#       "functionalConsequenceId": "SO_0001583"
#     }
#   ]
# }
# {
#   "targetFromSource": "WRN",
#   "resourceScore": "25.81",
#   "confidence": "Failed validation",
#   "microsatelliteStabilityStatus": "MSS",
#   "diseaseSubtype": "B",
#   "diseaseCellLines": [
#     {
#       "name": "SW837",
#       "id": "SIDM00833",
#       "tissue": "Large Intestine",
#       "tissueId": "UBERON_0000059"
#     }
#   ],
#   "variants": [
#     {
#       "name": "APC:R213*",
#       "functionalConsequenceId": "SO:0001587"
#     },
#     {
#       "name": "APC:R1450*",
#       "functionalConsequenceId": "SO:0001587"
#     },
#     {
#       "name": "KRAS:G12C",
#       "functionalConsequenceId": "SO_0001583"
#     },
#     {
#       "name": "TP53:R248W",
#       "functionalConsequenceId": "SO_0001583"
#     }
#   ]
# }
# {
#   "targetFromSource": "ZFP36L1",
#   "resourceScore": "26.73",
#   "confidence": "Failed validation",
#   "microsatelliteStabilityStatus": "MSS",
#   "diseaseSubtype": "B",
#   "diseaseCellLines": [
#     {
#       "name": "SW837",
#       "id": "SIDM00833",
#       "tissue": "Large Intestine",
#       "tissueId": "UBERON_0000059"
#     }
#   ],
#   "variants": [
#     {
#       "name": "APC:R213*",
#       "functionalConsequenceId": "SO:0001587"
#     },
#     {
#       "name": "APC:R1450*",
#       "functionalConsequenceId": "SO:0001587"
#     },
#     {
#       "name": "KRAS:G12C",
#       "functionalConsequenceId": "SO_0001583"
#     },
#     {
#       "name": "TP53:R248W",
#       "functionalConsequenceId": "SO_0001583"
#     }
#   ]
# }
# {
#   "targetFromSource": "ARHGEF7",
#   "resourceScore": "1.79",
#   "confidence": "Failed validation"
# }
# {
#   "targetFromSource": "BRCA2",
#   "resourceScore": "8.71",
#   "confidence": "Failed validation"
# }
# {
#   "targetFromSource": "CCND1",
#   "resourceScore": "-2.13",
#   "confidence": "Failed validation"
# }
# {
#   "targetFromSource": "CFLAR",
#   "resourceScore": "71.3",
#   "confidence": "Passed validation"
# }
# {
#   "targetFromSource": "CHD4",
#   "resourceScore": "51.18",
#   "confidence": "Passed validation"
# }
# {
#   "targetFromSource": "CYB5R4",
#   "resourceScore": "1.63",
#   "confidence": "Failed validation"
# }
# {
#   "targetFromSource": "DNAJC11",
#   "resourceScore": "16.96",
#   "confidence": "Failed validation"
# }
# {
#   "targetFromSource": "DYNLL1",
#   "resourceScore": "-7.34",
#   "confidence": "Failed validation"
# }
# {
#   "targetFromSource": "HSP90B1",
#   "resourceScore": "6.47",
#   "confidence": "Failed validation"
# }
# {
#   "targetFromSource": "IRF2BP2",
#   "resourceScore": "15.51",
#   "confidence": "Failed validation"
# }
# {
#   "targetFromSource": "KDM2A",
#   "resourceScore": "37.6",
#   "confidence": "Failed validation"
# }
# {
#   "targetFromSource": "KRAS",
#   "resourceScore": "-1.63",
#   "confidence": "Failed validation"
# }
# {
#   "targetFromSource": "MTA2",
#   "resourceScore": "13.23",
#   "confidence": "Failed validation"
# }
# {
#   "targetFromSource": "MTX2",
#   "resourceScore": "10.3",
#   "confidence": "Failed validation"
# }
# {
#   "targetFromSource": "PAK2",
#   "resourceScore": "9.25",
#   "confidence": "Failed validation"
# }
# {
#   "targetFromSource": "PPP2CA",
#   "resourceScore": "23.35",
#   "confidence": "Failed validation"
# }
# {
#   "targetFromSource": "PRPF4B",
#   "resourceScore": "62.37",
#   "confidence": "Passed validation"
# }
# {
#   "targetFromSource": "RHOA",
#   "resourceScore": "11.03",
#   "confidence": "Failed validation"
# }
# {
#   "targetFromSource": "TCF7L2",
#   "resourceScore": "34.76",
#   "confidence": "Failed validation"
# }
# {
#   "targetFromSource": "UBE2C",
#   "resourceScore": "21.47",
#   "confidence": "Failed validation"
# }
# {
#   "targetFromSource": "UBR4",
#   "resourceScore": "9.38",
#   "confidence": "Failed validation"
# }
# {
#   "targetFromSource": "USP10",
#   "resourceScore": "14.26",
#   "confidence": "Failed validation"
# }
# {
#   "targetFromSource": "USP7",
#   "resourceScore": "16.2",
#   "confidence": "Failed validation"
# }
# {
#   "targetFromSource": "WRN",
#   "resourceScore": "9.87",
#   "confidence": "Failed validation"
# }
# {
#   "targetFromSource": "ZFP36L1",
#   "resourceScore": "22",
#   "confidence": "Failed validation"
# }
# {
#   "targetFromSource": "ARHGEF7",
#   "resourceScore": "-6.49",
#   "confidence": "Failed validation",
#   "microsatelliteStabilityStatus": "MSS",
#   "diseaseSubtype": "D",
#   "diseaseCellLines": [
#     {
#       "name": "MDST8",
#       "id": "SIDM00527",
#       "tissue": "Large Intestine",
#       "tissueId": "UBERON_0000059"
#     }
#   ],
#   "variants": [
#     {
#       "name": "APC:T1556fs*3",
#       "functionalConsequenceId": "SO_0000865"
#     }
#   ]
# }
# {
#   "targetFromSource": "BRCA2",
#   "resourceScore": "17.38",
#   "confidence": "Failed validation",
#   "microsatelliteStabilityStatus": "MSS",
#   "diseaseSubtype": "D",
#   "diseaseCellLines": [
#     {
#       "name": "MDST8",
#       "id": "SIDM00527",
#       "tissue": "Large Intestine",
#       "tissueId": "UBERON_0000059"
#     }
#   ],
#   "variants": [
#     {
#       "name": "APC:T1556fs*3",
#       "functionalConsequenceId": "SO_0000865"
#     }
#   ]
# }
# {
#   "targetFromSource": "CCND1",
#   "resourceScore": "76.22",
#   "confidence": "Passed validation",
#   "microsatelliteStabilityStatus": "MSS",
#   "diseaseSubtype": "D",
#   "diseaseCellLines": [
#     {
#       "name": "MDST8",
#       "id": "SIDM00527",
#       "tissue": "Large Intestine",
#       "tissueId": "UBERON_0000059"
#     }
#   ],
#   "variants": [
#     {
#       "name": "APC:T1556fs*3",
#       "functionalConsequenceId": "SO_0000865"
#     }
#   ]
# }
# {
#   "targetFromSource": "CFLAR",
#   "resourceScore": "19.31",
#   "confidence": "Failed validation",
#   "microsatelliteStabilityStatus": "MSS",
#   "diseaseSubtype": "D",
#   "diseaseCellLines": [
#     {
#       "name": "MDST8",
#       "id": "SIDM00527",
#       "tissue": "Large Intestine",
#       "tissueId": "UBERON_0000059"
#     }
#   ],
#   "variants": [
#     {
#       "name": "APC:T1556fs*3",
#       "functionalConsequenceId": "SO_0000865"
#     }
#   ]
# }
# {
#   "targetFromSource": "CHD4",
#   "resourceScore": "109.53",
#   "confidence": "Passed validation",
#   "microsatelliteStabilityStatus": "MSS",
#   "diseaseSubtype": "D",
#   "diseaseCellLines": [
#     {
#       "name": "MDST8",
#       "id": "SIDM00527",
#       "tissue": "Large Intestine",
#       "tissueId": "UBERON_0000059"
#     }
#   ],
#   "variants": [
#     {
#       "name": "APC:T1556fs*3",
#       "functionalConsequenceId": "SO_0000865"
#     }
#   ]
# }
# {
#   "targetFromSource": "CYB5R4",
#   "resourceScore": "-47.86",
#   "confidence": "Failed validation",
#   "microsatelliteStabilityStatus": "MSS",
#   "diseaseSubtype": "D",
#   "diseaseCellLines": [
#     {
#       "name": "MDST8",
#       "id": "SIDM00527",
#       "tissue": "Large Intestine",
#       "tissueId": "UBERON_0000059"
#     }
#   ],
#   "variants": [
#     {
#       "name": "APC:T1556fs*3",
#       "functionalConsequenceId": "SO_0000865"
#     }
#   ]
# }
# {
#   "targetFromSource": "DNAJC11",
#   "resourceScore": "42.94",
#   "confidence": "Passed validation",
#   "microsatelliteStabilityStatus": "MSS",
#   "diseaseSubtype": "D",
#   "diseaseCellLines": [
#     {
#       "name": "MDST8",
#       "id": "SIDM00527",
#       "tissue": "Large Intestine",
#       "tissueId": "UBERON_0000059"
#     }
#   ],
#   "variants": [
#     {
#       "name": "APC:T1556fs*3",
#       "functionalConsequenceId": "SO_0000865"
#     }
#   ]
# }
# {
# ...
#   "resourceScore": "47.92",
#   "confidence": "Passed validation"
# }
# {
#   "targetFromSource": "KRAS",
#   "resourceScore": "66.2",
#   "confidence": "Passed validation"
# }
# {
#   "targetFromSource": "MTA2",
#   "resourceScore": "34.95",
#   "confidence": "Failed validation"
# }
# {
#   "targetFromSource": "MTX2",
#   "resourceScore": "25.93",
#   "confidence": "Failed validation"
# }
# {
#   "targetFromSource": "PAK2",
#   "resourceScore": "51.3",
#   "confidence": "Passed validation"
# }
# {
#   "targetFromSource": "PPP2CA",
#   "resourceScore": "48.38",
#   "confidence": "Passed validation"
# }
# {
#   "targetFromSource": "PRPF4B",
#   "resourceScore": "61.66",
#   "confidence": "Passed validation"
# }
# {
#   "targetFromSource": "RHOA",
#   "resourceScore": "41.39",
#   "confidence": "Passed validation"
# }
# {
#   "targetFromSource": "TCF7L2",
#   "resourceScore": "50.85",
#   "confidence": "Passed validation"
# }
# {
#   "targetFromSource": "UBE2C",
#   "resourceScore": "17.14",
#   "confidence": "Failed validation"
# }
# {
#   "targetFromSource": "UBR4",
#   "resourceScore": "72",
#   "confidence": "Passed validation"
# }
# {
#   "targetFromSource": "USP10",
#   "resourceScore": "73.21",
#   "confidence": "Passed validation"
# }
# {
#   "targetFromSource": "USP7",
#   "resourceScore": "82.3",
#   "confidence": "Passed validation"
# }
# {
#   "targetFromSource": "WRN",
#   "resourceScore": "81.22",
#   "confidence": "Passed validation"
# }
# {
#   "targetFromSource": "ZFP36L1",
#   "resourceScore": "50.6",
#   "confidence": "Passed validation"
# }
# {
#   "targetFromSource": "ARHGEF7",
#   "resourceScore": "59.9",
#   "confidence": "Passed validation",
#   "microsatelliteStabilityStatus": "MSS",
#   "diseaseCellLines": [
#     {
#       "name": "SW626",
#       "id": "SIDM01168",
#       "tissue": "Large Intestine",
#       "tissueId": "UBERON_0000059"
#     }
#   ],
#   "variants": [
#     {
#       "name": "TP53:G262V",
#       "functionalConsequenceId": "SO_0001583"
#     },
#     {
#       "name": "APC:R976fs*9",
#       "functionalConsequenceId": "SO_0000865"
#     },
#     {
#       "name": "KRAS:G12V",
#       "functionalConsequenceId": "SO_0001583"
#     }
#   ]
# }
# {
#   "targetFromSource": "BRCA2",
#   "resourceScore": "31.89",
#   "confidence": "Failed validation",
#   "microsatelliteStabilityStatus": "MSS",
#   "diseaseCellLines": [
#     {
#       "name": "SW626",
#       "id": "SIDM01168",
#       "tissue": "Large Intestine",
#       "tissueId": "UBERON_0000059"
#     }
#   ],
#   "variants": [
#     {
#       "name": "TP53:G262V",
#       "functionalConsequenceId": "SO_0001583"
#     },
#     {
#       "name": "APC:R976fs*9",
#       "functionalConsequenceId": "SO_0000865"
#     },
#     {
#       "name": "KRAS:G12V",
#       "functionalConsequenceId": "SO_0001583"
#     }
#   ]
# }
# {
#   "targetFromSource": "CCND1",
#   "resourceScore": "30.6",
#   "confidence": "Failed validation",
#   "microsatelliteStabilityStatus": "MSS",
#   "diseaseCellLines": [
#     {
#       "name": "SW626",
#       "id": "SIDM01168",
#       "tissue": "Large Intestine",
#       "tissueId": "UBERON_0000059"
#     }
#   ],
#   "variants": [
#     {
#       "name": "TP53:G262V",
#       "functionalConsequenceId": "SO_0001583"
#     },
#     {
#       "name": "APC:R976fs*9",
#       "functionalConsequenceId": "SO_0000865"
#     },
#     {
#       "name": "KRAS:G12V",
#       "functionalConsequenceId": "SO_0001583"
#     }
#   ]
# }
# {
#   "targetFromSource": "CFLAR",
#   "resourceScore": "50.62",
#   "confidence": "Passed validation",
#   "microsatelliteStabilityStatus": "MSS",
#   "diseaseCellLines": [
#     {
#       "name": "SW626",
#       "id": "SIDM01168",
#       "tissue": "Large Intestine",
#       "tissueId": "UBERON_0000059"
#     }
#   ],
#   "variants": [
#     {
#       "name": "TP53:G262V",
#       "functionalConsequenceId": "SO_0001583"
#     },
#     {
#       "name": "APC:R976fs*9",
#       "functionalConsequenceId": "SO_0000865"
#     },
#     {
#       "name": "KRAS:G12V",
#       "functionalConsequenceId": "SO_0001583"
#     }
#   ]
# }
# {
#   "targetFromSource": "CHD4",
#   "resourceScore": "136.18",
#   "confidence": "Passed validation",
#   "microsatelliteStabilityStatus": "MSS",
#   "diseaseCellLines": [
#     {
#       "name": "SW626",
#       "id": "SIDM01168",
#       "tissue": "Large Intestine",
#       "tissueId": "UBERON_0000059"
#     }
#   ],
#   "variants": [
#     {
#       "name": "TP53:G262V",
#       "functionalConsequenceId": "SO_0001583"
#     },
#     {
#       "name": "APC:R976fs*9",
#       "functionalConsequenceId": "SO_0000865"
#     },
#     {
#       "name": "KRAS:G12V",
#       "functionalConsequenceId": "SO_0001583"
#     }
#   ]
# }
# {
#   "targetFromSource": "CYB5R4",
#   "resourceScore": "40.58",
#   "confidence": "Passed validation",
#   "microsatelliteStabilityStatus": "MSS",
#   "diseaseCellLines": [
#     {
#       "name": "SW626",
#       "id": "SIDM01168",
#       "tissue": "Large Intestine",
#       "tissueId": "UBERON_0000059"
#     }
#   ],
#   "variants": [
#     {
#       "name": "TP53:G262V",
#       "functionalConsequenceId": "SO_0001583"
#     },
#     {
#       "name": "APC:R976fs*9",
#       "functionalConsequenceId": "SO_0000865"
#     },
#     {
#       "name": "KRAS:G12V",
#       "functionalConsequenceId": "SO_0001583"
#     }
#   ]
# }
# {
#   "targetFromSource": "DNAJC11",
#   "resourceScore": "50.37",
#   "confidence": "Passed validation",
#   "microsatelliteStabilityStatus": "MSS",
#   "diseaseCellLines": [
#     {
#       "name": "SW626",
#       "id": "SIDM01168",
#       "tissue": "Large Intestine",
#       "tissueId": "UBERON_0000059"
#     }
#   ],
#   "variants": [
#     {
#       "name": "TP53:G262V",
#       "functionalConsequenceId": "SO_0001583"
#     },
#     {
#       "name": "APC:R976fs*9",
#       "functionalConsequenceId": "SO_0000865"
#     },
#     {
#       "name": "KRAS:G12V",
#       "functionalConsequenceId": "SO_0001583"
#     }
#   ]
# }
# {
#   "targetFromSource": "DYNLL1",
#   "resourceScore": "54.24",
#   "confidence": "Passed validation",
#   "microsatelliteStabilityStatus": "MSS",
#   "diseaseCellLines": [
#     {
#       "name": "SW626",
#       "id": "SIDM01168",
#       "tissue": "Large Intestine",
#       "tissueId": "UBERON_0000059"
#     }
#   ],
#   "variants": [
#     {
#       "name": "TP53:G262V",
#       "functionalConsequenceId": "SO_0001583"
#     },
#     {
#       "name": "APC:R976fs*9",
#       "functionalConsequenceId": "SO_0000865"
#     },
#     {
#       "name": "KRAS:G12V",
#       "functionalConsequenceId": "SO_0001583"
#     }
#   ]
# }
# {
#   "targetFromSource": "HSP90B1",
#   "resourceScore": "29.19",
#   "confidence": "Failed validation",
#   "microsatelliteStabilityStatus": "MSS",
#   "diseaseCellLines": [
#     {
#       "name": "SW626",
#       "id": "SIDM01168",
#       "tissue": "Large Intestine",
#       "tissueId": "UBERON_0000059"
#     }
#   ],
#   "variants": [
#     {
#       "name": "TP53:G262V",
#       "functionalConsequenceId": "SO_0001583"
#     },
#     {
#       "name": "APC:R976fs*9",
#       "functionalConsequenceId": "SO_0000865"
#     },
#     {
#       "name": "KRAS:G12V",
#       "functionalConsequenceId": "SO_0001583"
#     }
#   ]
# }
# {
#   "targetFromSource": "IRF2BP2",
#   "resourceScore": "35.97",
#   "confidence": "Failed validation",
#   "microsatelliteStabilityStatus": "MSS",
#   "diseaseCellLines": [
#     {
#       "name": "SW626",
#       "id": "SIDM01168",
#       "tissue": "Large Intestine",
#       "tissueId": "UBERON_0000059"
#     }
#   ],
#   "variants": [
#     {
#       "name": "TP53:G262V",
#       "functionalConsequenceId": "SO_0001583"
#     },
#     {
#       "name": "APC:R976fs*9",
#       "functionalConsequenceId": "SO_0000865"
#     },
#     {
#       "name": "KRAS:G12V",
#       "functionalConsequenceId": "SO_0001583"
#     }
#   ]
# }
# {
#   "targetFromSource": "KDM2A",
#   "resourceScore": "46.78",
#   "confidence": "Passed validation",
#   "microsatelliteStabilityStatus": "MSS",
#   "diseaseCellLines": [
#     {
#       "name": "SW626",
#       "id": "SIDM01168",
#       "tissue": "Large Intestine",
#       "tissueId": "UBERON_0000059"
#     }
#   ],
#   "variants": [
#     {
#       "name": "TP53:G262V",
#       "functionalConsequenceId": "SO_0001583"
#     },
#     {
#       "name": "APC:R976fs*9",
#       "functionalConsequenceId": "SO_0000865"
#     },
#     {
#       "name": "KRAS:G12V",
#       "functionalConsequenceId": "SO_0001583"
#     }
#   ]
# }
# {
#   "targetFromSource": "KRAS",
#   "resourceScore": "135.68",
#   "confidence": "Passed validation",
#   "microsatelliteStabilityStatus": "MSS",
#   "diseaseCellLines": [
#     {
#       "name": "SW626",
#       "id": "SIDM01168",
#       "tissue": "Large Intestine",
#       "tissueId": "UBERON_0000059"
#     }
#   ],
#   "variants": [
#     {
#       "name": "TP53:G262V",
#       "functionalConsequenceId": "SO_0001583"
#     },
#     {
#       "name": "APC:R976fs*9",
#       "functionalConsequenceId": "SO_0000865"
#     },
#     {
#       "name": "KRAS:G12V",
#       "functionalConsequenceId": "SO_0001583"
#     }
#   ]
# }
# {
#   "targetFromSource": "MTA2",
#   "resourceScore": "34.44",
#   "confidence": "Failed validation",
#   "microsatelliteStabilityStatus": "MSS",
#   "diseaseCellLines": [
#     {
#       "name": "SW626",
#       "id": "SIDM01168",
#       "tissue": "Large Intestine",
#       "tissueId": "UBERON_0000059"
#     }
#   ],
#   "variants": [
#     {
#       "name": "TP53:G262V",
#       "functionalConsequenceId": "SO_0001583"
#     },
#     {
#       "name": "APC:R976fs*9",
#       "functionalConsequenceId": "SO_0000865"
#     },
#     {
#       "name": "KRAS:G12V",
#       "functionalConsequenceId": "SO_0001583"
#     }
#   ]
# }
# {
#   "targetFromSource": "MTX2",
#   "resourceScore": "27.66",
#   "confidence": "Failed validation",
#   "microsatelliteStabilityStatus": "MSS",
#   "diseaseCellLines": [
#     {
#       "name": "SW626",
#       "id": "SIDM01168",
#       "tissue": "Large Intestine",
#       "tissueId": "UBERON_0000059"
#     }
#   ],
#   "variants": [
#     {
#       "name": "TP53:G262V",
#       "functionalConsequenceId": "SO_0001583"
#     },
#     {
#       "name": "APC:R976fs*9",
#       "functionalConsequenceId": "SO_0000865"
#     },
#     {
#       "name": "KRAS:G12V",
#       "functionalConsequenceId": "SO_0001583"
#     }
#   ]
# }
# {
#   "targetFromSource": "PAK2",
#   "resourceScore": "100.66",
#   "confidence": "Passed validation",
#   "microsatelliteStabilityStatus": "MSS",
#   "diseaseCellLines": [
#     {
#       "name": "SW626",
#       "id": "SIDM01168",
#       "tissue": "Large Intestine",
#       "tissueId": "UBERON_0000059"
#     }
#   ],
#   "variants": [
#     {
#       "name": "TP53:G262V",
#       "functionalConsequenceId": "SO_0001583"
#     },
#     {
#       "name": "APC:R976fs*9",
#       "functionalConsequenceId": "SO_0000865"
#     },
#     {
#       "name": "KRAS:G12V",
#       "functionalConsequenceId": "SO_0001583"
#     }
#   ]
# }
# {
#   "targetFromSource": "PPP2CA",
#   "resourceScore": "88.1",
#   "confidence": "Passed validation",
#   "microsatelliteStabilityStatus": "MSS",
#   "diseaseCellLines": [
#     {
#       "name": "SW626",
#       "id": "SIDM01168",
#       "tissue": "Large Intestine",
#       "tissueId": "UBERON_0000059"
#     }
#   ],
#   "variants": [
#     {
#       "name": "TP53:G262V",
#       "functionalConsequenceId": "SO_0001583"
#     },
#     {
#       "name": "APC:R976fs*9",
#       "functionalConsequenceId": "SO_0000865"
#     },
#     {
#       "name": "KRAS:G12V",
#       "functionalConsequenceId": "SO_0001583"
#     }
#   ]
# }
# {
#   "targetFromSource": "PRPF4B",
#   "resourceScore": "89.5",
#   "confidence": "Passed validation",
#   "microsatelliteStabilityStatus": "MSS",
#   "diseaseCellLines": [
#     {
#       "name": "SW626",
#       "id": "SIDM01168",
#       "tissue": "Large Intestine",
#       "tissueId": "UBERON_0000059"
#     }
#   ],
#   "variants": [
#     {
#       "name": "TP53:G262V",
#       "functionalConsequenceId": "SO_0001583"
#     },
#     {
#       "name": "APC:R976fs*9",
#       "functionalConsequenceId": "SO_0000865"
#     },
#     {
#       "name": "KRAS:G12V",
#       "functionalConsequenceId": "SO_0001583"
#     }
#   ]
# }
# {
#   "targetFromSource": "RHOA",
#   "resourceScore": "93.63",
#   "confidence": "Passed validation",
#   "microsatelliteStabilityStatus": "MSS",
#   "diseaseCellLines": [
#     {
#       "name": "SW626",
#       "id": "SIDM01168",
#       "tissue": "Large Intestine",
#       "tissueId": "UBERON_0000059"
#     }
#   ],
#   "variants": [
#     {
#       "name": "TP53:G262V",
#       "functionalConsequenceId": "SO_0001583"
#     },
#     {
#       "name": "APC:R976fs*9",
#       "functionalConsequenceId": "SO_0000865"
#     },
#     {
#       "name": "KRAS:G12V",
#       "functionalConsequenceId": "SO_0001583"
#     }
#   ]
# }
# {
#   "targetFromSource": "TCF7L2",
#   "resourceScore": "19.97",
#   "confidence": "Failed validation",
#   "microsatelliteStabilityStatus": "MSS",
#   "diseaseCellLines": [
#     {
#       "name": "SW626",
#       "id": "SIDM01168",
#       "tissue": "Large Intestine",
#       "tissueId": "UBERON_0000059"
#     }
#   ],
#   "variants": [
#     {
#       "name": "TP53:G262V",
#       "functionalConsequenceId": "SO_0001583"
#     },
#     {
#       "name": "APC:R976fs*9",
#       "functionalConsequenceId": "SO_0000865"
#     },
#     {
#       "name": "KRAS:G12V",
#       "functionalConsequenceId": "SO_0001583"
#     }
#   ]
# }
# {
#   "targetFromSource": "UBE2C",
#   "resourceScore": "63.75",
#   "confidence": "Passed validation",
#   "microsatelliteStabilityStatus": "MSS",
#   "diseaseCellLines": [
#     {
#       "name": "SW626",
#       "id": "SIDM01168",
#       "tissue": "Large Intestine",
#       "tissueId": "UBERON_0000059"
#     }
#   ],
#   "variants": [
#     {
#       "name": "TP53:G262V",
#       "functionalConsequenceId": "SO_0001583"
#     },
#     {
#       "name": "APC:R976fs*9",
#       "functionalConsequenceId": "SO_0000865"
#     },
#     {
#       "name": "KRAS:G12V",
#       "functionalConsequenceId": "SO_0001583"
#     }
#   ]
# }
# {
#   "targetFromSource": "UBR4",
#   "resourceScore": "37.11",
#   "confidence": "Failed validation",
#   "microsatelliteStabilityStatus": "MSS",
#   "diseaseCellLines": [
#     {
#       "name": "SW626",
#       "id": "SIDM01168",
#       "tissue": "Large Intestine",
#       "tissueId": "UBERON_0000059"
#     }
#   ],
#   "variants": [
#     {
#       "name": "TP53:G262V",
#       "functionalConsequenceId": "SO_0001583"
#     },
#     {
#       "name": "APC:R976fs*9",
#       "functionalConsequenceId": "SO_0000865"
#     },
#     {
#       "name": "KRAS:G12V",
#       "functionalConsequenceId": "SO_0001583"
#     }
#   ]
# }
# {
#   "targetFromSource": "USP10",
#   "resourceScore": "58.46",
#   "confidence": "Passed validation",
#   "microsatelliteStabilityStatus": "MSS",
#   "diseaseCellLines": [
#     {
#       "name": "SW626",
#       "id": "SIDM01168",
#       "tissue": "Large Intestine",
#       "tissueId": "UBERON_0000059"
#     }
#   ],
#   "variants": [
#     {
#       "name": "TP53:G262V",
#       "functionalConsequenceId": "SO_0001583"
#     },
#     {
#       "name": "APC:R976fs*9",
#       "functionalConsequenceId": "SO_0000865"
#     },
#     {
#       "name": "KRAS:G12V",
#       "functionalConsequenceId": "SO_0001583"
#     }
#   ]
# }
# {
#   "targetFromSource": "USP7",
#   "resourceScore": "53.16",
#   "confidence": "Passed validation",
#   "microsatelliteStabilityStatus": "MSS",
#   "diseaseCellLines": [
#     {
#       "name": "SW626",
#       "id": "SIDM01168",
#       "tissue": "Large Intestine",
#       "tissueId": "UBERON_0000059"
#     }
#   ],
#   "variants": [
#     {
#       "name": "TP53:G262V",
#       "functionalConsequenceId": "SO_0001583"
#     },
#     {
#       "name": "APC:R976fs*9",
#       "functionalConsequenceId": "SO_0000865"
#     },
#     {
#       "name": "KRAS:G12V",
#       "functionalConsequenceId": "SO_0001583"
#     }
#   ]
# }
# {
#   "targetFromSource": "WRN",
#   "resourceScore": "12.63",
#   "confidence": "Failed validation",
#   "microsatelliteStabilityStatus": "MSS",
#   "diseaseCellLines": [
#     {
#       "name": "SW626",
#       "id": "SIDM01168",
#       "tissue": "Large Intestine",
#       "tissueId": "UBERON_0000059"
#     }
#   ],
#   "variants": [
#     {
#       "name": "TP53:G262V",
#       "functionalConsequenceId": "SO_0001583"
#     },
#     {
#       "name": "APC:R976fs*9",
#       "functionalConsequenceId": "SO_0000865"
#     },
#     {
#       "name": "KRAS:G12V",
#       "functionalConsequenceId": "SO_0001583"
#     }
#   ]
# }
# {
#   "targetFromSource": "ZFP36L1",
#   "resourceScore": "27.89",
#   "confidence": "Failed validation",
#   "microsatelliteStabilityStatus": "MSS",
#   "diseaseCellLines": [
#     {
#       "name": "SW626",
#       "id": "SIDM01168",
#       "tissue": "Large Intestine",
#       "tissueId": "UBERON_0000059"
#     }
#   ],
#   "variants": [
#     {
#       "name": "TP53:G262V",
#       "functionalConsequenceId": "SO_0001583"
#     },
#     {
#       "name": "APC:R976fs*9",
#       "functionalConsequenceId": "SO_0000865"
#     },
#     {
#       "name": "KRAS:G12V",
#       "functionalConsequenceId": "SO_0001583"
#     }
#   ]
# }

# %% [markdown]
# ```json
# {
#   "targetFromSource": "UBE2C",
#   "resourceScore": 4.02,
#   "confidence": "Failed validation",
#   "microsatelliteStabilityStatus": "MSI",
#   "diseaseSubtype": "A",
#   "diseaseCellLines": [
#     {
#       "name": "KM12",
#       "id": "SIDM00150",
#       "tissue": "Large Intestine",
#       "tissueId": "UBERON_0000059"
#     }
#   ],
#   "biomarkers": [
#     {
#       "name": "TP53mut",
#       "variants": [
#         {
#           "name": "TP53:H179R",
#           "functionalConsequenceId": "SO_0001583"
#         },
#         {
#           "name": "TP53:V73fs*50",
#           "functionalConsequenceId": "SO_0000865"
#         }
#       ]
#     },
#     {
#       "name": "APCwt",
#       "variants": [
#         {
#           "name": "APC:N1818fs*2",
#           "functionalConsequenceId": "SO_0000865"
#         }
#       ]
#     },
#     {
#       "name": "KRASwt"
#     }
#   ]
# }
# ```
