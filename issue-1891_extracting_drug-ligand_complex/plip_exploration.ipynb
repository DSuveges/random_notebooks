# %% [markdown]
# # Exploring PLIP application
#
#
# **Source data**: annotated drugs, where the drug id (`chembl_id`) is annotated with pdb structure and compound id + the corresponding target identifier based on the SIFTS dataset.
#
# **Schema**:
#
# ```
# root
#  |-- pdb_structure_id: string (nullable = true)
#  |-- chembl_id: string (nullable = true)
#  |-- name: string (nullable = true)
#  |-- pdb_compound_id: string (nullable = true)
#  |-- ensembl_gene_id: string (nullable = true)
#  |-- pdb_chain_id: string (nullable = true)
# ```

# %%
import argparse
import json
import logging
from json import JSONDecodeError
import urllib

import requests
from functools import reduce
import pandas as pd
from pyspark.sql.functions import (
    col, udf, struct, lit, split, expr, collect_set,
    regexp_replace, min as pyspark_min, explode, when,
    array_contains, count, first, element_at, size, sum as pyspark_sum
)
from pyspark.sql.types import FloatType, ArrayType, StructType, StructField, BooleanType, StringType
from pyspark.sql import SparkSession
from pyspark.sql import DataFrame
from collections import defaultdict

def fetch_pdb(pdb_strcture_id: str, folder: str) -> None:
    """This function fetches a single PDB structure from PDBEurope
    
    Args:
        pdb_strcture_id: string, a single PDB structure identifier
        folder: string, a folder to save the structure
    """
    try:
        urllib.request.urlretrieve(f'https://www.ebi.ac.uk/pdbe/entry-files/download/pdb{pdb_strcture_id}.ent', f'{folder}/{pdb_strcture_id}.pdb')
    except:
        # logging.warning(f'Failed to fetch PDB structure: {pdb_strcture_id}')
        print(f'Failed to fetch PDB structure: {pdb_strcture_id}')


spark = (
    SparkSession.builder
    .master('local[*]')
    .getOrCreate()
)

source_data = 'molecules_w_targets'

# Reading data:
annotated_molecules = (
    spark.read.parquet(source_data)
    .filter(col('ensembl_gene_id').isNotNull())
    .sample(False, 0.01)
    .distinct()
    .persist()
)

# Extracting a list of strcutures:
pdbs = [row.pdb_structure_id for row in annotated_molecules.select(col('pdb_structure_id')).distinct().collect()]
len(pdbs)

# Dowlading the structures:
folder = './pdb_structures'
[fetch_pdb(pdb, folder) for pdb in pdbs]
# Out:
# Failed to fetch PDB structure: 4u51
# Failed to fetch PDB structure: 7l20
# Failed to fetch PDB structure: 6zsg
# Failed to fetch PDB structure: 6tpy
# Failed to fetch PDB structure: 6ftj
# Failed to fetch PDB structure: 5tga
# Failed to fetch PDB structure: 7pd3
# Failed to fetch PDB structure: 6lqv
# Failed to fetch PDB structure: 7a5g
# Failed to fetch PDB structure: 7d5s
# Failed to fetch PDB structure: 7nqh
# Failed to fetch PDB structure: 7jgl
# Failed to fetch PDB structure: 7ajt
# Failed to fetch PDB structure: 7of4
# Failed to fetch PDB structure: 6qc7
# Failed to fetch PDB structure: 6zsb
# Failed to fetch PDB structure: 4u4n
# Failed to fetch PDB structure: 6zvj
# Failed to fetch PDB structure: 5mrc
# Failed to fetch PDB structure: 7ohu
# Failed to fetch PDB structure: 5tgm
# Failed to fetch PDB structure: 6zsc
# Failed to fetch PDB structure: 6zmi
# Failed to fetch PDB structure: 5xti
# Failed to fetch PDB structure: 6o2s
# Failed to fetch PDB structure: 6vlz
# Failed to fetch PDB structure: 6msg
# Failed to fetch PDB structure: 7abg
# Failed to fetch PDB structure: 5lzt
# Failed to fetch PDB structure: 4u56
# Failed to fetch PDB structure: 7a5f
# Failed to fetch PDB structure: 4v88
# Failed to fetch PDB structure: 5mei
# Failed to fetch PDB structure: 5vyc
# Failed to fetch PDB structure: 5juu
# Failed to fetch PDB structure: 6w2s
# Failed to fetch PDB structure: 5dgf
# Failed to fetch PDB structure: 6z8p
# Failed to fetch PDB structure: 5ndg
# Failed to fetch PDB structure: 7mq9
# Failed to fetch PDB structure: 7lbm
# Failed to fetch PDB structure: 7ohx
# Failed to fetch PDB structure: 5t0c
# Failed to fetch PDB structure: 6hhq
# Failed to fetch PDB structure: 5lzx
# Failed to fetch PDB structure: 6qc3
# Failed to fetch PDB structure: 6mte
# Failed to fetch PDB structure: 3jai
# Failed to fetch PDB structure: 6ekc
# Failed to fetch PDB structure: 6drc
# Failed to fetch PDB structure: 4wsn
# Failed to fetch PDB structure: 4u4o
# Failed to fetch PDB structure: 6z6k
# Failed to fetch PDB structure: 4u4r
# Failed to fetch PDB structure: 4ym7
# Failed to fetch PDB structure: 4v8t
# Failed to fetch PDB structure: 6z6m
# Failed to fetch PDB structure: 5dge
# Failed to fetch PDB structure: 7odr
# Failed to fetch PDB structure: 7ajb
# Failed to fetch PDB structure: 6gqv
# Failed to fetch PDB structure: 7nwg
# Failed to fetch PDB structure: 6fvy
# Failed to fetch PDB structure: 6zqc
# Failed to fetch PDB structure: 5wlc
# Failed to fetch PDB structure: 7mq8
# Failed to fetch PDB structure: 5apn
# Failed to fetch PDB structure: 6mtb
# Failed to fetch PDB structure: 6ke6
# Failed to fetch PDB structure: 7d5t
# Failed to fetch PDB structure: 5taq
# Failed to fetch PDB structure: 6lqs
# Failed to fetch PDB structure: 6zqg
# Failed to fetch PDB structure: 5gpn
# Failed to fetch PDB structure: 6ylg
# Failed to fetch PDB structure: 6i7o
# Failed to fetch PDB structure: 6dqj
# Failed to fetch PDB structure: 5lyb
# Failed to fetch PDB structure: 6lss
# Failed to fetch PDB structure: 7of3
# Failed to fetch PDB structure: 4u4y
# Failed to fetch PDB structure: 5gak
# Failed to fetch PDB structure: 6d9j
# Failed to fetch PDB structure: 5juo
# Failed to fetch PDB structure: 6gb2
# Failed to fetch PDB structure: 6msd
# Failed to fetch PDB structure: 6r86
# Failed to fetch PDB structure: 6gaz
# Failed to fetch PDB structure: 7ls2
# Failed to fetch PDB structure: 6olf
# Failed to fetch PDB structure: 6ydp
# Failed to fetch PDB structure: 5vfq
# Failed to fetch PDB structure: 7og4
# Failed to fetch PDB structure: 6t4q
# Failed to fetch PDB structure: 6zse
# Failed to fetch PDB structure: 5aj0
# Failed to fetch PDB structure: 4u52
# Failed to fetch PDB structure: 4u3u
# Failed to fetch PDB structure: 6zqb
# Failed to fetch PDB structure: 5dc3
# Failed to fetch PDB structure: 3j9m
# Failed to fetch PDB structure: 6y2l
# Failed to fetch PDB structure: 3jah
# Failed to fetch PDB structure: 6rw4
# Failed to fetch PDB structure: 6r5q
# Failed to fetch PDB structure: 6zsa
# Failed to fetch PDB structure: 6om0
# Failed to fetch PDB structure: 7osm
# Failed to fetch PDB structure: 6zs9
# Failed to fetch PDB structure: 5dat
# Failed to fetch PDB structure: 7o7z
# Failed to fetch PDB structure: 5jus
# Failed to fetch PDB structure: 6xir
# Failed to fetch PDB structure: 6tb3
# Failed to fetch PDB structure: 7nql
# Failed to fetch PDB structure: 4u4q
# Failed to fetch PDB structure: 7d4i
# Failed to fetch PDB structure: 5on6
# Failed to fetch PDB structure: 7nsj
# Failed to fetch PDB structure: 7a09
# Failed to fetch PDB structure: 5lzy
# Failed to fetch PDB structure: 6jiy
# Failed to fetch PDB structure: 6msk
# Failed to fetch PDB structure: 5apo
# Failed to fetch PDB structure: 5ndv
# Failed to fetch PDB structure: 6zp4
# Failed to fetch PDB structure: 3j7p
# Failed to fetch PDB structure: 6msj
# Failed to fetch PDB structure: 6m62
# Failed to fetch PDB structure: 3j6b
# Failed to fetch PDB structure: 5i4l
# Failed to fetch PDB structure: 5l4g
# Failed to fetch PDB structure: 7ls1
# Failed to fetch PDB structure: 5fci
# Failed to fetch PDB structure: 5tb1
# Failed to fetch PDB structure: 6z6n
# Failed to fetch PDB structure: 6vmi
# Failed to fetch PDB structure: 7of5
# Failed to fetch PDB structure: 7a5i
# Failed to fetch PDB structure: 6pto
# Failed to fetch PDB structure: 5z57
# Failed to fetch PDB structure: 6hd7
# Failed to fetch PDB structure: 5m1j
# Failed to fetch PDB structure: 6qc2
# Failed to fetch PDB structure: 6qcf
# Failed to fetch PDB structure: 6rw5
# Failed to fetch PDB structure: 6qc9
# Failed to fetch PDB structure: 6tnu
# Failed to fetch PDB structure: 5vfs
# Failed to fetch PDB structure: 6gaw
# Failed to fetch PDB structure: 6qa9
# Failed to fetch PDB structure: 4v4l
# Failed to fetch PDB structure: 6r84
# Failed to fetch PDB structure: 5lzs
# Failed to fetch PDB structure: 6qdv
# Failed to fetch PDB structure: 6lqq
# Failed to fetch PDB structure: 6fti
# Failed to fetch PDB structure: 4u3n
# Failed to fetch PDB structure: 5vfp
# Failed to fetch PDB structure: 6qc5
# Failed to fetch PDB structure: 6qzp
# Failed to fetch PDB structure: 4u4z
# Failed to fetch PDB structure: 7o9k
# Failed to fetch PDB structure: 7cpu
# Failed to fetch PDB structure: 6z6j
# Failed to fetch PDB structure: 6ydw
# Failed to fetch PDB structure: 7ohv
# Failed to fetch PDB structure: 7a5k
# Failed to fetch PDB structure: 5zwm
# Failed to fetch PDB structure: 5lks
# Failed to fetch PDB structure: 7of6
# Failed to fetch PDB structure: 7f9o
# Failed to fetch PDB structure: 6z6l
# Failed to fetch PDB structure: 6lqr
# Failed to fetch PDB structure: 7ajh
# Failed to fetch PDB structure: 6lqu
# Failed to fetch PDB structure: 6zqe
# Failed to fetch PDB structure: 5aj4
# Failed to fetch PDB structure: 6zqa
# Failed to fetch PDB structure: 6m8p
# Failed to fetch PDB structure: 6z5o
# Failed to fetch PDB structure: 6xa1
# Failed to fetch PDB structure: 7old
# Failed to fetch PDB structure: 7mqa
# Failed to fetch PDB structure: 7nfx
# Failed to fetch PDB structure: 7ena
# Failed to fetch PDB structure: 5dgv
# Failed to fetch PDB structure: 7o81
# Failed to fetch PDB structure: 7nwi
# Failed to fetch PDB structure: 7pbd
# Failed to fetch PDB structure: 6qx9
# Failed to fetch PDB structure: 7ajj
# Failed to fetch PDB structure: 7b7d
# Failed to fetch PDB structure: 6ql9
# Failed to fetch PDB structure: 6j5k
# Failed to fetch PDB structure: 7nsi
# Failed to fetch PDB structure: 6ole
# Failed to fetch PDB structure: 7rro
# Failed to fetch PDB structure: 7jk9
# Failed to fetch PDB structure: 6ylh
# Failed to fetch PDB structure: 6y57
# Failed to fetch PDB structure: 7oic
# Failed to fetch PDB structure: 4u3m
# Failed to fetch PDB structure: 3j7q
# Failed to fetch PDB structure: 7nbd
# Failed to fetch PDB structure: 6t59
# Failed to fetch PDB structure: 7o7y
# Failed to fetch PDB structure: 6zmo
# Failed to fetch PDB structure: 6qik
# Failed to fetch PDB structure: 5mpc
# Failed to fetch PDB structure: 6lsr
# Failed to fetch PDB structure: 7nsh
# Failed to fetch PDB structure: 7aju
# Failed to fetch PDB structure: 5obm
# Failed to fetch PDB structure: 6i9r
# Failed to fetch PDB structure: 7abf
# Failed to fetch PDB structure: 6woo
# Failed to fetch PDB structure: 6mse
# Failed to fetch PDB structure: 5gm6
# Failed to fetch PDB structure: 7o80
# Failed to fetch PDB structure: 5z56
# Failed to fetch PDB structure: 7egb
# Failed to fetch PDB structure: 6fvv
# Failed to fetch PDB structure: 6snt
# Failed to fetch PDB structure: 5mre
# Failed to fetch PDB structure: 4u53
# Failed to fetch PDB structure: 3j7r
# Failed to fetch PDB structure: 5yzg
# Failed to fetch PDB structure: 7jmh
# Failed to fetch PDB structure: 6tq1
# Failed to fetch PDB structure: 5tan
# Failed to fetch PDB structure: 5ndw
# Failed to fetch PDB structure: 6qc6
# Failed to fetch PDB structure: 6zsd
# Failed to fetch PDB structure: 6ftg
# Failed to fetch PDB structure: 6r6g
# Failed to fetch PDB structure: 6zon
# Failed to fetch PDB structure: 7ods
# Failed to fetch PDB structure: 4u6f
# Failed to fetch PDB structure: 6r6p
# Failed to fetch PDB structure: 6lu8
# Failed to fetch PDB structure: 6lqm
# Failed to fetch PDB structure: 6qc4
# Failed to fetch PDB structure: 6sgc
# Failed to fetch PDB structure: 6hcq
# Failed to fetch PDB structure: 7btb
# Failed to fetch PDB structure: 7o9m
# Failed to fetch PDB structure: 5xjc
# Failed to fetch PDB structure: 7bhp
# Failed to fetch PDB structure: 5xth
# Failed to fetch PDB structure: 6zm5
# Failed to fetch PDB structure: 6mtd
# Failed to fetch PDB structure: 6zmw
# Failed to fetch PDB structure: 5fcj
# Failed to fetch PDB structure: 7d63
# Failed to fetch PDB structure: 6om7
# Failed to fetch PDB structure: 5lzu
# Failed to fetch PDB structure: 6oli
# Failed to fetch PDB structure: 6qca
# Failed to fetch PDB structure: 7ohp
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  ...]

# %% [markdown]
# Conclusions:
# * ~100 structures: 1minute,
# * the test contained 1.7k structures out of which only 1.4k could be downloaded
# * Some larger compexes has no pdb, but tar.gz files. -> no, we don't go that directino
# * It seems we still need to pre-filter some ligands that are not relevant.
# * Timewise estimated time constraint: ~6hours. We need to find simpler way to get the data.
# * Also the full dataset is around 55GB

# %%
spark.read.parquet(source_data).printSchema()
# Out:
# root
#  |-- pdb_structure_id: string (nullable = true)
#  |-- chembl_id: string (nullable = true)
#  |-- name: string (nullable = true)
#  |-- pdb_compound_id: string (nullable = true)
#  |-- ensembl_gene_id: string (nullable = true)
#  |-- pdb_chain_id: string (nullable = true)

# %%
2.6 * 36000 / 1700
# Out:
# 55.05882352941177
