# %%
# %%bash
#
# # Fetching pre-release data.
# gsutil cp -r gs://open-targets-pre-data-releases/22.04/output/etl/parquet/errors/evidence  ~/project_data/

# %%
import pandas as pd
import json
import requests

from pyspark.sql.types import ArrayType, StringType, IntegerType
from pyspark.sql import SparkSession
import pyspark.sql.functions as f

# establish spark connection
spark = (
    SparkSession.builder
    .master('local[*]')
    .getOrCreate()
)

# %%
(
    spark.read.parquet('/Users/dsuveges/project_data/evidence')
    .printSchema()
)
# Out:
# root
#  |-- datasourceId: string (nullable = true)
#  |-- targetId: string (nullable = true)
#  |-- alleleOrigins: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- allelicRequirements: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- ancestry: string (nullable = true)
#  |-- ancestryId: string (nullable = true)
#  |-- beta: double (nullable = true)
#  |-- betaConfidenceIntervalLower: double (nullable = true)
#  |-- betaConfidenceIntervalUpper: double (nullable = true)
#  |-- biologicalModelAllelicComposition: string (nullable = true)
#  |-- biologicalModelGeneticBackground: string (nullable = true)
#  |-- biologicalModelId: string (nullable = true)
#  |-- biomarkerName: string (nullable = true)
#  |-- biomarkers: struct (nullable = true)
#  |    |-- geneExpression: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- id: string (nullable = true)
#  |    |    |    |-- name: string (nullable = true)
#  |    |-- variant: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- functionalConsequenceId: string (nullable = true)
#  |    |    |    |-- id: string (nullable = true)
#  |    |    |    |-- name: string (nullable = true)
#  |-- biosamplesFromSource: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- clinicalPhase: long (nullable = true)
#  |-- clinicalSignificances: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- clinicalStatus: string (nullable = true)
#  |-- cohortDescription: string (nullable = true)
#  |-- cohortId: string (nullable = true)
#  |-- cohortPhenotypes: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- cohortShortName: string (nullable = true)
#  |-- confidence: string (nullable = true)
#  |-- contrast: string (nullable = true)
#  |-- datatypeId: string (nullable = true)
#  |-- diseaseCellLines: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- name: string (nullable = true)
#  |    |    |-- tissue: string (nullable = true)
#  |    |    |-- tissueId: string (nullable = true)
#  |-- diseaseFromSource: string (nullable = true)
#  |-- diseaseFromSourceId: string (nullable = true)
#  |-- diseaseFromSourceMappedId: string (nullable = true)
#  |-- diseaseModelAssociatedHumanPhenotypes: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- label: string (nullable = true)
#  |-- diseaseModelAssociatedModelPhenotypes: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- label: string (nullable = true)
#  |-- drugFromSource: string (nullable = true)
#  |-- drugId: string (nullable = true)
#  |-- drugResponse: string (nullable = true)
#  |-- literature: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- log2FoldChangePercentileRank: long (nullable = true)
#  |-- log2FoldChangeValue: double (nullable = true)
#  |-- mutatedSamples: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- functionalConsequenceId: string (nullable = true)
#  |    |    |-- numberMutatedSamples: long (nullable = true)
#  |    |    |-- numberSamplesTested: long (nullable = true)
#  |    |    |-- numberSamplesWithMutationType: long (nullable = true)
#  |-- oddsRatio: double (nullable = true)
#  |-- oddsRatioConfidenceIntervalLower: double (nullable = true)
#  |-- oddsRatioConfidenceIntervalUpper: double (nullable = true)
#  |-- pValueExponent: long (nullable = true)
#  |-- pValueMantissa: double (nullable = true)
#  |-- pathways: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- name: string (nullable = true)
#  |-- pmcIds: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- projectId: string (nullable = true)
#  |-- publicationFirstAuthor: string (nullable = true)
#  |-- publicationYear: long (nullable = true)
#  |-- reactionId: string (nullable = true)
#  |-- reactionName: string (nullable = true)
#  |-- resourceScore: double (nullable = true)
#  |-- significantDriverMethods: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- statisticalMethod: string (nullable = true)
#  |-- statisticalMethodOverview: string (nullable = true)
#  |-- studyCases: long (nullable = true)
#  |-- studyCasesWithQualifyingVariants: long (nullable = true)
#  |-- studyId: string (nullable = true)
#  |-- studyOverview: string (nullable = true)
#  |-- studySampleSize: long (nullable = true)
#  |-- studyStartDate: string (nullable = true)
#  |-- studyStopReason: string (nullable = true)
#  |-- studyStopReasonCategories: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- targetFromSource: string (nullable = true)
#  |-- targetFromSourceId: string (nullable = true)
#  |-- targetInModel: string (nullable = true)
#  |-- targetInModelEnsemblId: string (nullable = true)
#  |-- targetInModelMgiId: string (nullable = true)
#  |-- targetModulation: string (nullable = true)
#  |-- textMiningSentences: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- dEnd: long (nullable = true)
#  |    |    |-- dStart: long (nullable = true)
#  |    |    |-- section: string (nullable = true)
#  |    |    |-- tEnd: long (nullable = true)
#  |    |    |-- tStart: long (nullable = true)
#  |    |    |-- text: string (nullable = true)
#  |-- urls: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- niceName: string (nullable = true)
#  |    |    |-- url: string (nullable = true)
#  |-- variantAminoacidDescriptions: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- variantFunctionalConsequenceId: string (nullable = true)
#  |-- variantHgvsId: string (nullable = true)
#  |-- variantId: string (nullable = true)
#  |-- variantRsId: string (nullable = true)
#  |-- resolvedTarget: boolean (nullable = true)
#  |-- resolvedDisease: boolean (nullable = true)
#  |-- diseaseId: string (nullable = true)
#  |-- excludedBiotype: boolean (nullable = true)
#  |-- id: string (nullable = true)
#  |-- score: double (nullable = true)
#  |-- nullifiedScore: boolean (nullable = true)
#  |-- markedDuplicate: boolean (nullable = true)
#  |-- sourceId: string (nullable = true)

# %%
failed_evidence = (
    spark.read.parquet('/Users/dsuveges/project_data/evidence')
    .persist()
)

print(f'Number of failed evidence: {failed_evidence.count()}')
# Out:
# Number of failed evidence: 354943

# %%
resolved_reason = (
    spark.read.parquet('/Users/dsuveges/project_data/evidence')
    .groupby('datasourceId', 'resolvedTarget', 'resolvedDisease', 'nullifiedScore', 'markedDuplicate')
    .count()
    .orderBy('datasourceId')
#     .show(150)
    .persist()
)

resolved_reason.show(250)
# Out:
# +------------------+--------------+---------------+--------------+---------------+------+
# |      datasourceId|resolvedTarget|resolvedDisease|nullifiedScore|markedDuplicate| count|
# +------------------+--------------+---------------+--------------+---------------+------+
# | cancer_biomarkers|          true|          false|         false|          false|    19|
# | cancer_biomarkers|          true|           true|         false|           true|    29|
# |cancer_gene_census|          true|          false|         false|           true|  7018|
# |cancer_gene_census|          true|          false|         false|          false|   897|
# |            chembl|         false|           true|         false|          false|     9|
# |            chembl|          true|           true|         false|           true| 67656|
# |            chembl|          true|          false|         false|           true|   265|
# |            chembl|          true|          false|         false|          false|  3983|
# |           clingen|          true|          false|         false|          false|    41|
# |               eva|          true|          false|         false|          false| 26144|
# |               eva|          true|           true|         false|           true|   386|
# |               eva|          true|          false|         false|           true|   502|
# |       eva_somatic|          true|          false|         false|          false|  1893|
# |       eva_somatic|          true|          false|         false|           true|     6|
# |       eva_somatic|          true|           true|         false|           true|     5|
# |  expression_atlas|          true|           true|         false|           true|     1|
# |  expression_atlas|          true|          false|         false|          false|   389|
# |  expression_atlas|          true|           true|         false|          false|   778|
# |  expression_atlas|         false|           true|         false|          false|    15|
# |    gene2phenotype|          true|           true|          true|          false|  1278|
# |    gene2phenotype|         false|          false|         false|          false|     2|
# |    gene2phenotype|         false|           true|         false|          false|     4|
# |    gene2phenotype|         false|           true|          true|          false|     2|
# |    gene2phenotype|          true|          false|          true|          false|   243|
# |    gene2phenotype|          true|          false|         false|          false|   705|
# |       gene_burden|         false|          false|         false|          false|    13|
# |       gene_burden|          true|          false|         false|          false|  6735|
# |       gene_burden|         false|           true|         false|          false|    83|
# |  genomics_england|          true|          false|         false|          false| 13419|
# |  genomics_england|         false|           true|         false|          false|   534|
# |  genomics_england|         false|          false|         false|           true|     1|
# |  genomics_england|          true|           true|         false|           true|   315|
# |  genomics_england|          true|          false|         false|           true|    41|
# |  genomics_england|         false|           true|         false|           true|    11|
# |  genomics_england|         false|          false|         false|          false|   259|
# |              impc|          true|          false|         false|          false|168580|
# |              impc|          true|           true|         false|           true| 15156|
# |              impc|         false|           true|         false|          false|   399|
# |              impc|         false|          false|         false|          false|    86|
# |              impc|         false|           true|         false|           true|     4|
# |              impc|          true|          false|         false|           true|   126|
# |           intogen|         false|          false|         false|          false|     2|
# |           intogen|         false|           true|         false|          false|    10|
# |           intogen|          true|          false|         false|          false|    22|
# |          orphanet|          true|           true|         false|           true|    15|
# |          orphanet|          true|          false|         false|          false|   372|
# |ot_genetics_portal|          true|          false|         false|          false| 31614|
# |           progeny|          true|           true|         false|           true|    14|
# |           progeny|         false|           true|         false|          false|    14|
# |          reactome|         false|           true|         false|          false|   442|
# |          reactome|          true|          false|         false|          false|    91|
# |          reactome|          true|           true|         false|           true|   123|
# |        slapenrich|         false|           true|         false|          false|  2232|
# |            sysbio|         false|           true|         false|          false|    21|
# |            sysbio|          true|           true|         false|           true|     1|
# |uniprot_literature|          true|          false|         false|          false|   279|
# |uniprot_literature|         false|           true|         false|          false|     1|
# |  uniprot_variants|          true|           true|         false|           true|  1061|
# |  uniprot_variants|          true|          false|         false|           true|    10|
# |  uniprot_variants|          true|          false|         false|          false|   587|
# +------------------+--------------+---------------+--------------+---------------+------+

# %%
resolved_reason.filter(f.col('resolvedTarget') == False).show(250)
# Out:
# +------------------+--------------+---------------+--------------+---------------+-----+
# |      datasourceId|resolvedTarget|resolvedDisease|nullifiedScore|markedDuplicate|count|
# +------------------+--------------+---------------+--------------+---------------+-----+
# |            chembl|         false|           true|         false|          false|    9|
# |  expression_atlas|         false|           true|         false|          false|   15|
# |    gene2phenotype|         false|          false|         false|          false|    2|
# |    gene2phenotype|         false|           true|         false|          false|    4|
# |    gene2phenotype|         false|           true|          true|          false|    2|
# |       gene_burden|         false|          false|         false|          false|   13|
# |       gene_burden|         false|           true|         false|          false|   83|
# |  genomics_england|         false|           true|         false|          false|  534|
# |  genomics_england|         false|          false|         false|           true|    1|
# |  genomics_england|         false|           true|         false|           true|   11|
# |  genomics_england|         false|          false|         false|          false|  259|
# |              impc|         false|           true|         false|          false|  399|
# |              impc|         false|          false|         false|          false|   86|
# |              impc|         false|           true|         false|           true|    4|
# |           intogen|         false|          false|         false|          false|    2|
# |           intogen|         false|           true|         false|          false|   10|
# |           progeny|         false|           true|         false|          false|   14|
# |          reactome|         false|           true|         false|          false|  442|
# |        slapenrich|         false|           true|         false|          false| 2232|
# |            sysbio|         false|           true|         false|          false|   21|
# |uniprot_literature|         false|           true|         false|          false|    1|
# +------------------+--------------+---------------+--------------+---------------+-----+

# %%
(
    failed_evidence
    .filter(f.col('resolvedTarget') == False)
    .groupby(
        'datasourceId', 'targetFromSource', 'targetFromSourceId'
    )
    .count()
    .orderBy(['datasourceId', 'count'], ascending=False)
    .show(300)
)
# Out:
# +------------------+----------------+------------------+-----+
# |      datasourceId|targetFromSource|targetFromSourceId|count|
# +------------------+----------------+------------------+-----+
# |uniprot_literature|            null|            Q156A1|    1|
# |            sysbio|            null|               FYB|    2|
# |            sysbio|            null|              WARS|    1|
# |            sysbio|            null|          PPAPDC1B|    1|
# |            sysbio|            null|           STATIP1|    1|
# |            sysbio|            null|          C1orf143|    1|
# |            sysbio|            null|           MOBKL2B|    1|
# |            sysbio|            null|            TMEPAI|    1|
# |            sysbio|            null|         C20orf133|    1|
# |            sysbio|            null|            FAM49A|    1|
# |            sysbio|            null|             LARGE|    1|
# |            sysbio|            null|              CTGF|    1|
# |            sysbio|            null|             MLL3S|    1|
# |            sysbio|            null|            FAM26F|    1|
# |            sysbio|            null|            DOPEY1|    1|
# |            sysbio|            null|          AK025613|    1|
# |            sysbio|            null|             PCTK2|    1|
# |            sysbio|            null|              EMR2|    1|
# |            sysbio|            null|             TUBB4|    1|
# |            sysbio|            null|             SFRS3|    1|
# |            sysbio|            null|              BLR1|    1|
# |        slapenrich|            null|         HIST1H2BH|  103|
# |        slapenrich|            null|         HIST2H2BE|   93|
# |        slapenrich|            null|         HIST2H2AC|   92|
# |        slapenrich|            null|         HIST1H2BD|   88|
# |        slapenrich|            null|         HIST1H2BL|   83|
# |        slapenrich|            null|            MRE11A|   83|
# |        slapenrich|            null|         HIST1H2AC|   75|
# |        slapenrich|            null|         HIST1H2BM|   73|
# |        slapenrich|            null|         HIST1H2BJ|   72|
# |        slapenrich|            null|         HIST1H2AJ|   64|
# |        slapenrich|            null|         HIST1H2BB|   63|
# |        slapenrich|            null|             SHFM1|   62|
# |        slapenrich|            null|         HIST1H2BO|   60|
# |        slapenrich|            null|          HIST1H3A|   59|
# |        slapenrich|            null|         HIST1H2AB|   58|
# |        slapenrich|            null|         HIST1H2BN|   57|
# |        slapenrich|            null|         HIST1H2BC|   55|
# |        slapenrich|            null|             WHSC1|   52|
# |        slapenrich|            null|             H2AFZ|   50|
# |        slapenrich|            null|         HIST1H2BK|   49|
# |        slapenrich|            null|             H2AFX|   49|
# |        slapenrich|            null|               BRE|   47|
# |        slapenrich|            null|         HIST1H2BA|   45|
# |        slapenrich|            null|             RFWD2|   43|
# |        slapenrich|            null|          HIST1H1C|   42|
# |        slapenrich|            null|          HIST1H1E|   37|
# |        slapenrich|            null|           HIST3H3|   36|
# |        slapenrich|            null|          HIST1H1B|   32|
# |        slapenrich|            null|           FAM175A|   29|
# |        slapenrich|            null|             H3F3A|   27|
# |        slapenrich|            null|             H2AFV|   24|
# |        slapenrich|            null|          HIST1H1D|   23|
# |        slapenrich|            null|         HIST3H2BB|   23|
# |        slapenrich|            null|             NUPL2|   18|
# |        slapenrich|            null|            TCEB3B|   18|
# |        slapenrich|            null|         HIST1H2AG|   15|
# |        slapenrich|            null|          HIST1H1A|   15|
# |        slapenrich|            null|             H2AFJ|   14|
# |        slapenrich|            null|              FIGF|   14|
# |        slapenrich|            null|         HIST1H2AH|   13|
# |        slapenrich|            null|             TCEB3|   12|
# |        slapenrich|            null|             TCEB1|   12|
# |        slapenrich|            null|           TMEM55B|   11|
# |        slapenrich|            null|               GIF|   11|
# |        slapenrich|            null|             RQCD1|   10|
# |        slapenrich|            null|            TCEB3C|   10|
# |        slapenrich|            null|         HIST1H2AA|   10|
# |        slapenrich|            null|           FGFR1OP|   10|
# |        slapenrich|            null|             INADL|    9|
# |        slapenrich|            null|         HIST2H2AB|    9|
# |        slapenrich|            null|            ADRBK1|    8|
# |        slapenrich|            null|              H1F0|    7|
# |        slapenrich|            null|              MPP5|    7|
# |        slapenrich|            null|           ERBB2IP|    7|
# |        slapenrich|            null|             OR5R1|    7|
# |        slapenrich|            null|             TCEB2|    7|
# |        slapenrich|            null|           DEFB131|    7|
# |        slapenrich|            null|            KIRREL|    6|
# |        slapenrich|            null|         HIST2H2BF|    6|
# |        slapenrich|            null|            FAM49B|    6|
# |        slapenrich|            null|               MUT|    5|
# |        slapenrich|            null|            CD3EAP|    5|
# |        slapenrich|            null|           TWISTNB|    5|
# |        slapenrich|            null|               PHB|    5|
# |        slapenrich|            null|             CASC5|    4|
# |        slapenrich|            null|             PAPD7|    4|
# |        slapenrich|            null|           TCEB3CL|    4|
# |        slapenrich|            null|             SEPP1|    4|
# |        slapenrich|            null|           WHSC1L1|    4|
# |        slapenrich|            null|            TROVE2|    4|
# |        slapenrich|            null|           WBSCR17|    4|
# |        slapenrich|            null|            ADRBK2|    3|
# |        slapenrich|            null|           FAM175B|    3|
# |        slapenrich|            null|             UFD1L|    3|
# |        slapenrich|            null|            CTAGE5|    3|
# |        slapenrich|            null|           TMEM173|    3|
# |        slapenrich|            null|            C9orf3|    3|
# |        slapenrich|            null|           PLA2G16|    2|
# |        slapenrich|            null|           CSRP2BP|    2|
# |        slapenrich|            null|              HFE2|    2|
# |        slapenrich|            null|          HIST3H2A|    2|
# |        slapenrich|            null|              MINA|    2|
# |        slapenrich|            null|              SARS|    2|
# |        slapenrich|            null|               FYB|    2|
# |        slapenrich|            null|            IKBKAP|    2|
# |        slapenrich|            null|             TSTA3|    2|
# |        slapenrich|            null|              ARSE|    2|
# |        slapenrich|            null|             PARK2|    2|
# |        slapenrich|            null|           GUCY1A3|    1|
# |        slapenrich|            null|              PTRF|    1|
# |        slapenrich|            null|          KIAA0101|    1|
# |        slapenrich|            null|              MKL1|    1|
# |        slapenrich|            null|             SEPT7|    1|
# |        slapenrich|            null|               TAZ|    1|
# |        slapenrich|            null|            HRASLS|    1|
# |        slapenrich|            null|           GUCY1B3|    1|
# |        slapenrich|            null|             MYLPF|    1|
# |        slapenrich|            null|             CECR1|    1|
# |        slapenrich|            null|             VPRBP|    1|
# |        slapenrich|            null|             MARC2|    1|
# |        slapenrich|            null|            TMEM27|    1|
# |        slapenrich|            null|              HKR1|    1|
# |        slapenrich|            null|           NGFRAP1|    1|
# |        slapenrich|            null|           HRASLS5|    1|
# |        slapenrich|            null|               LOR|    1|
# |          reactome|            null|            Q5NV65|   17|
# |          reactome|            null|            Q5NV82|   17|
# |          reactome|            null|            Q5NV64|   17|
# |          reactome|            null|            Q5NV90|   17|
# |          reactome|            null|            Q5NV80|   17|
# |          reactome|            null|            Q5NV92|   17|
# |          reactome|            null|            Q5NV87|   17|
# |          reactome|            null|            Q5NV86|   17|
# |          reactome|            null|            Q5NV79|   17|
# |          reactome|            null|            Q5NV91|   17|
# |          reactome|            null|            Q5NV75|   17|
# |          reactome|            null|            Q5NV83|   17|
# |          reactome|            null|            Q5NV85|   17|
# |          reactome|            null|            Q5NV69|   17|
# |          reactome|            null|            Q5NV84|   17|
# |          reactome|            null|            Q5NV81|   17|
# |          reactome|            null|            P01782|   17|
# |          reactome|            null|            Q5NV67|   17|
# |          reactome|            null|            A2KUC3|   17|
# |          reactome|            null|            Q5NV68|   17|
# |          reactome|            null|            Q5NV66|   17|
# |          reactome|            null|            A2NXD2|   17|
# |          reactome|            null|            Q5NV61|   17|
# |          reactome|            null|            Q5NV62|   17|
# |          reactome|            null|            Q6PIL0|   17|
# |          reactome|            null|            Q5NV89|   17|
# |           progeny|            null|            PRKMK1|   14|
# |           intogen|            null|             H3F3A|    3|
# |           intogen|            null|          HIST1H3B|    3|
# |           intogen|            null|            FAM46C|    3|
# |           intogen|            null|          HIST1H4I|    1|
# |           intogen|            null|             SEPT9|    1|
# |           intogen|            null|              CARS|    1|
# |              impc|            null|   ENSG00000276816|  287|
# |              impc|            null|   ENSG00000274847|   82|
# |              impc|            null|   ENSG00000277796|   61|
# |              impc|            null|   ENSG00000225932|   28|
# |              impc|            null|   ENSG00000244693|   28|
# |              impc|            null|   ENSG00000286228|    3|
# |  genomics_england|            null|              ISPD|   46|
# |  genomics_england|            null|               TAZ|   40|
# |  genomics_england|            null|             WDR60|   29|
# |  genomics_england|            null|              G6PC|   29|
# |  genomics_england|            null|          C12orf65|   27|
# |  genomics_england|            null|             WDR34|   26|
# |  genomics_england|            null|              KARS|   26|
# |  genomics_england|            null|              ARSE|   24|
# |  genomics_england|            null|             TMEM5|   23|
# |  genomics_england|            null|               MUT|   23|
# |  genomics_england|            null|               ICK|   23|
# |  genomics_england|            null|           C21orf2|   21|
# |  genomics_england|            null|           C5orf42|   21|
# |  genomics_england|            null|              YARS|   20|
# |  genomics_england|            null|              DARS|   18|
# |  genomics_england|            null|              GARS|   17|
# |  genomics_england|            null|              AARS|   16|
# |  genomics_england|            null|           C4orf26|   16|
# |  genomics_england|            null|           C8orf37|   16|
# |  genomics_england|            null|               FUK|   14|
# |  genomics_england|            null|           TMEM173|   13|
# |  genomics_england|            null|              RARS|   12|
# |  genomics_england|            null|          C15orf41|   12|
# |  genomics_england|            null|            KIF1BP|   11|
# |  genomics_england|            null|              HFE2|   11|
# |  genomics_england|            null|          KIAA1161|   11|
# |  genomics_england|            null|            APOPT1|   11|
# |  genomics_england|            null|          TCTEX1D2|   10|
# |  genomics_england|            null|           ADPRHL2|    9|
# |  genomics_england|            null|              IARS|    9|
# |  genomics_england|            null|             LRRC6|    9|
# |  genomics_england|            null|              CARS|    9|
# |  genomics_england|            null|              QARS|    9|
# |  genomics_england|            null|            FAM58A|    9|
# |  genomics_england|            null|          C16orf62|    8|
# |  genomics_england|            null|               GIF|    8|
# |  genomics_england|            null|             ATP5D|    7|
# |  genomics_england|            null|          HIST1H1E|    7|
# |  genomics_england|            null|           CCDC114|    7|
# |  genomics_england|            null|              HARS|    7|
# |  genomics_england|            null|           C2orf71|    7|
# |  genomics_england|            null|             ARMC4|    7|
# |  genomics_england|            null|              MKL1|    6|
# |  genomics_england|            null|            PIH1D3|    6|
# |  genomics_england|            null|            IMPAD1|    6|
# |  genomics_england|            null|            DFNB59|    5|
# |  genomics_england|            null|              VARS|    5|
# |  genomics_england|            null|           CCDC151|    5|
# |  genomics_england|            null|          C11orf70|    5|
# |  genomics_england|            null|          C17orf62|    5|
# |  genomics_england|            null|          C21orf59|    5|
# |  genomics_england|            null|             TTC25|    4|
# |  genomics_england|            null|                 T|    4|
# |  genomics_england|            null|             WISP3|    4|
# |  genomics_england|            null|             DFNA5|    4|
# |  genomics_england|            null|          HIST1H4J|    4|
# |  genomics_england|            null|          COL4A3BP|    4|
# |  genomics_england|            null|          C19orf70|    4|
# |  genomics_england|            null|            ATP5J2|    3|
# |  genomics_england|            null|             ATP5L|    3|
# |  genomics_england|            null|             ATP5H|    3|
# |  genomics_england|            null|            ATP5F1|    3|
# |  genomics_england|            null|            ATP5L2|    3|
# |  genomics_england|            null|          HIST1H4C|    3|
# |  genomics_england|            null|            ATP5A1|    2|
# |  genomics_england|            null|            ATP5G2|    2|
# |  genomics_england|            null|             ATP5I|    2|
# |  genomics_england|            null|             ATP5J|    2|
# |  genomics_england|            null|             ATP5O|    2|
# |  genomics_england|            null|            FAM46A|    2|
# |  genomics_england|            null|            ADSSL1|    2|
# |  genomics_england|            null|           GUCY1A3|    2|
# |  genomics_england|            null|              EPRS|    2|
# |  genomics_england|            null|              WARS|    2|
# |  genomics_england|            null|            ATP5G3|    2|
# |  genomics_england|            null|            ATP5C1|    2|
# |  genomics_england|            null|             ATP5B|    2|
# |  genomics_england|            null|            ATP5G1|    2|
# |  genomics_england|            null|              MARS|    1|
# |  genomics_england|            null|               LOR|    1|
# |  genomics_england|            null|            FAM92A|    1|
# |  genomics_england|            null|              TARS|    1|
# |  genomics_england|            null|          C1orf194|    1|
# |       gene_burden|            null|              G6PC|   44|
# |       gene_burden|            null|     RP11-545J16.1|   10|
# |       gene_burden|            null|             ADCK3|    9|
# |       gene_burden|            null|              SDPR|    5|
# |       gene_burden|            null|           TMEM206|    5|
# |       gene_burden|            null|              ACPP|    5|
# |       gene_burden|            null|             CYR61|    5|
# |       gene_burden|            null|            GRAMD2|    4|
# |       gene_burden|            null|            FAM65C|    3|
# |       gene_burden|            null|         HIST1H2BE|    2|
# |       gene_burden|            null|            FAM21C|    2|
# |       gene_burden|            null|             WDR66|    1|
# |       gene_burden|            null|               BRE|    1|
# |    gene2phenotype|            null|           C8orf37|    2|
# |    gene2phenotype|            null|             MYLPF|    2|
# |    gene2phenotype|            null|          C12orf65|    2|
# |    gene2phenotype|            null|             LRRC6|    1|
# |    gene2phenotype|            null|               TAZ|    1|
# |  expression_atlas|            null|   ENSG00000224745|    4|
# |  expression_atlas|            null|   ENSG00000237513|    4|
# |  expression_atlas|            null|   ENSG00000203812|    2|
# |  expression_atlas|            null|   ENSG00000259444|    1|
# |  expression_atlas|            null|   ENSG00000226403|    1|
# |  expression_atlas|            null|   ENSG00000272196|    1|
# |  expression_atlas|            null|   ENSG00000272354|    1|
# |  expression_atlas|            null|   ENSG00000237133|    1|
# |            chembl|   CHEMBL4630576|  ENSG000001127154|    5|
# |            chembl|   CHEMBL4627244|   ENSG00000276536|    3|
# |            chembl|   CHEMBL4523374|            Q86V67|    1|
# +------------------+----------------+------------------+-----+

# %%
failed_disease = (
    failed_evidence
    .filter(f.col('resolvedDisease') == False)
    .groupby(
        'datasourceId', 'diseaseFromSource', 'diseaseFromSourceId', 'diseaseFromSourceMappedId'
    )
    .count()
    .orderBy(['datasourceId', 'count'], ascending=False)
    .persist()
)

print(f'Number of disease failed: {failed_disease.count()}')
failed_disease.show(300)
# Out:
# Number of disease failed: 15860
# +------------------+--------------------+-------------------+-------------------------+-----+
# |      datasourceId|   diseaseFromSource|diseaseFromSourceId|diseaseFromSourceMappedId|count|
# +------------------+--------------------+-------------------+-------------------------+-----+
# |  uniprot_variants|Polycystic kidney...|        OMIM:173900|                     null|   60|
# |  uniprot_variants|Ataxia telangiect...|        OMIM:208900|              EFO_0004922|   41|
# |  uniprot_variants|              Glioma|        OMIM:137800|            MONDO_0100242|   20|
# |  uniprot_variants|              Glioma|        OMIM:137800|            MONDO_0024498|   20|
# |  uniprot_variants| Neural tube defects|        OMIM:182940|            MONDO_0020705|   20|
# |  uniprot_variants|Glanzmann thromba...|        OMIM:619267|                     null|   19|
# |  uniprot_variants|Stuttering, famil...|        OMIM:184450|                     null|   15|
# |  uniprot_variants|     Neuroblastoma 3|        OMIM:613014|            MONDO_0013083|   14|
# |  uniprot_variants|Mismatch repair c...|        OMIM:619101|                     null|   13|
# |  uniprot_variants|Encephalopathy, p...|        OMIM:617193|                     null|   13|
# |  uniprot_variants|Hemolytic uremic ...|        OMIM:235400|            MONDO_0009335|   13|
# |  uniprot_variants|Nystagmus congeni...|        OMIM:310700|                     null|   10|
# |  uniprot_variants|Familial male pre...|        OMIM:176410|                     null|   10|
# |  uniprot_variants|Frontotemporal de...|        OMIM:619141|                     null|   10|
# |  uniprot_variants|Hypotonia, ataxia...|        OMIM:617330|                     null|    9|
# |  uniprot_variants|Intellectual deve...|        OMIM:617061|                     null|    8|
# |  uniprot_variants| Coumarin resistance|        OMIM:122700|                     null|    8|
# |  uniprot_variants|Combined osteogen...|        OMIM:619115|                     null|    7|
# |  uniprot_variants|     Schizophrenia 4|        OMIM:600850|                     null|    7|
# |  uniprot_variants| Colorectal cancer 1|        OMIM:608812|            MONDO_0012132|    6|
# |  uniprot_variants|Amyotrophic later...|        OMIM:617839|                     null|    6|
# |  uniprot_variants|Hematuria, benign...|        OMIM:141200|                     null|    6|
# |  uniprot_variants|Amyotrophic later...|        OMIM:617921|                     null|    5|
# |  uniprot_variants|Amyotrophic later...|        OMIM:619133|                     null|    5|
# |  uniprot_variants|    Elliptocytosis 3|        OMIM:617948|                     null|    5|
# |  uniprot_variants|Bleeding disorder...|        OMIM:617443|                     null|    5|
# |  uniprot_variants|Growth hormone de...|        OMIM:618157|                     null|    5|
# |  uniprot_variants|Pituitary adenoma...|        OMIM:617540|                     null|    4|
# |  uniprot_variants|Neurodevelopmenta...|        OMIM:618547|                     null|    4|
# |  uniprot_variants|Macrocephaly, acq...|        OMIM:618286|                     null|    4|
# |  uniprot_variants|Lower urinary tra...|        OMIM:618612|                     null|    4|
# |  uniprot_variants|Cardiac, facial, ...|        OMIM:618164|                     null|    4|
# |  uniprot_variants|Leukoencephalopat...|        OMIM:619147|                     null|    3|
# |  uniprot_variants|Spermatogenic fai...|        OMIM:619095|                     null|    3|
# |  uniprot_variants|Mega-corpus-callo...|        OMIM:618273|                     null|    3|
# |  uniprot_variants|Short stature, am...|        OMIM:618363|                     null|    3|
# |  uniprot_variants|Microcephaly, con...|        OMIM:616834|                     null|    3|
# |  uniprot_variants|Cerebellar atroph...|        OMIM:616875|                     null|    3|
# |  uniprot_variants|Ectodermal dyspla...|        OMIM:618180|                     null|    3|
# |  uniprot_variants|Rhizomelic chondr...|        OMIM:222765|                     null|    3|
# |  uniprot_variants|Cleft palate, psy...|        OMIM:616728|                     null|    3|
# |  uniprot_variants|Gonadal dysgenesi...|        OMIM:618419|                     null|    3|
# |  uniprot_variants|Hypermanganesemia...|        OMIM:617013|                     null|    3|
# |  uniprot_variants|Khan-Khan-Katsani...|        OMIM:618460|                     null|    3|
# |  uniprot_variants|Myopia 25, autoso...|        OMIM:617238|                     null|    3|
# |  uniprot_variants|Cerebellar atroph...|        OMIM:618501|                     null|    3|
# |  uniprot_variants|Congenital disord...|        OMIM:618324|                     null|    3|
# |  uniprot_variants|Encephalopathy, n...|        OMIM:617668|                     null|    3|
# |  uniprot_variants|Neurodevelopmenta...|        OMIM:618292|                     null|    3|
# |  uniprot_variants|  GNAS hyperfunction|        OMIM:139320|                     null|    3|
# |  uniprot_variants|Encephalopathy, a...|        OMIM:618426|                     null|    3|
# |  uniprot_variants|Combined oxidativ...|        OMIM:616794|                     null|    3|
# |  uniprot_variants|Abdominal obesity...|        OMIM:618620|                     null|    3|
# |  uniprot_variants|Platelet glycopro...|        OMIM:608404|                     null|    3|
# |  uniprot_variants|Hypotonia, infant...|        OMIM:616801|                     null|    2|
# |  uniprot_variants|Arthrogryposis, d...|        OMIM:619110|                     null|    2|
# |  uniprot_variants|      HELIX syndrome|        OMIM:617671|                     null|    2|
# |  uniprot_variants|Tn polyagglutinat...|        OMIM:300622|                     null|    2|
# |  uniprot_variants|Rhizomelic chondr...|        OMIM:215100|                     null|    2|
# |  uniprot_variants|Vertebral anomali...|        OMIM:618223|                     null|    2|
# |  uniprot_variants|Neuronopathy, dis...|        OMIM:619112|                     null|    2|
# |  uniprot_variants|        Yao syndrome|        OMIM:617321|                     null|    2|
# |  uniprot_variants|Neurodevelopmenta...|        OMIM:617903|                     null|    2|
# |  uniprot_variants|Platelet-activati...|        OMIM:614278|                     null|    2|
# |  uniprot_variants|Inflammatory bowe...|        OMIM:619079|                     null|    2|
# |  uniprot_variants|Deafness, congeni...|        OMIM:619196|                     null|    2|
# |  uniprot_variants|Lung disease, imm...|        OMIM:617241|                     null|    2|
# |  uniprot_variants|Mitochondrial com...|        OMIM:619166|                     null|    2|
# |  uniprot_variants|Infantile liver f...|        OMIM:618641|                     null|    2|
# |  uniprot_variants|Oocyte maturation...|        OMIM:618550|                     null|    2|
# |  uniprot_variants|Deafness, autosom...|        OMIM:619081|                     null|    2|
# |  uniprot_variants|Mitochondrial com...|        OMIM:619167|                     null|    2|
# |  uniprot_variants|Autoinflammation,...|        OMIM:617099|                     null|    2|
# |  uniprot_variants|Hydrops, lactic a...|        OMIM:617021|                     null|    2|
# |  uniprot_variants|Arthrogryposis, c...|        OMIM:618265|                     null|    2|
# |  uniprot_variants|Cardiac-urogenita...|        OMIM:618280|                     null|    2|
# |  uniprot_variants|Brachycephaly, tr...|        OMIM:617412|                     null|    2|
# |  uniprot_variants|Tubulointerstitia...|        OMIM:617056|                     null|    2|
# |  uniprot_variants|Ovarian dysgenesis 7|        OMIM:618117|                     null|    2|
# |  uniprot_variants|ACTH-independent ...|        OMIM:219080|                     null|    2|
# |  uniprot_variants|Combined oxidativ...|        OMIM:618397|                     null|    2|
# |  uniprot_variants| Immunodeficiency 49|        OMIM:617237|                     null|    2|
# |  uniprot_variants|Uridine-cytidineuria|        OMIM:618477|                     null|    2|
# |  uniprot_variants| Estrogen resistance|        OMIM:615363|                     null|    2|
# |  uniprot_variants|    Trichotillomania|        OMIM:613229|                     null|    2|
# |  uniprot_variants|Short stature, he...|        OMIM:617763|                     null|    2|
# |  uniprot_variants|Mitral valve prol...|        OMIM:607829|                     null|    2|
# |  uniprot_variants|Neurodevelopmenta...|        OMIM:618367|                     null|    2|
# |  uniprot_variants|Developmental del...|        OMIM:616901|                     null|    2|
# |  uniprot_variants|Premature ovarian...|        OMIM:617442|                     null|    2|
# |  uniprot_variants|Bone marrow failu...|        OMIM:618116|                     null|    1|
# |  uniprot_variants|Deafness, autosom...|        OMIM:618481|                     null|    1|
# |  uniprot_variants|Ovarian dysgenesis 6|        OMIM:618078|                     null|    1|
# |  uniprot_variants|Cancer, alopecia,...|        OMIM:618373|                     null|    1|
# |  uniprot_variants|Adiponectin defic...|        OMIM:612556|                     null|    1|
# |  uniprot_variants|Hypotonia, hyperv...|        OMIM:618493|                     null|    1|
# |  uniprot_variants|Anhidrosis, isola...|        OMIM:106190|                     null|    1|
# |  uniprot_variants|Cerebellar, ocula...|        OMIM:618479|                     null|    1|
# |  uniprot_variants|Deafness, autosom...|        OMIM:618422|                     null|    1|
# |  uniprot_variants|Dominant nonimmun...|        OMIM:607847|                     null|    1|
# |  uniprot_variants|Deafness, autosom...|        OMIM:618434|                     null|    1|
# |  uniprot_variants|Visual impairment...|        OMIM:618283|                     null|    1|
# |  uniprot_variants|Growth hormone de...|        OMIM:618160|                     null|    1|
# |  uniprot_variants|Spondyloepimetaph...|        OMIM:616723|                     null|    1|
# |  uniprot_variants|            Glioma 2|        OMIM:613028|            MONDO_0013092|    1|
# |  uniprot_variants|Bleeding disorder...|        OMIM:619271|                     null|    1|
# |  uniprot_variants|Deafness, autosom...|        OMIM:618456|                     null|    1|
# |  uniprot_variants|Cardioacrofacial ...|        OMIM:619143|                     null|    1|
# |  uniprot_variants|Split-foot malfor...|        OMIM:616890|                     null|    1|
# |  uniprot_variants|Ophthalmoplegia, ...|        OMIM:618155|                     null|    1|
# |  uniprot_variants|Osteopetrosis, au...|        OMIM:618107|                     null|    1|
# |  uniprot_variants|Mucopolysaccharid...|        OMIM:617303|                     null|    1|
# |  uniprot_variants|Pontocerebellar h...|        OMIM:619301|                     null|    1|
# |  uniprot_variants|Mitochondrial com...|        OMIM:619272|                     null|    1|
# |  uniprot_variants|Neurodevelopmenta...|        OMIM:618425|                     null|    1|
# |  uniprot_variants|Short stature, de...|        OMIM:617044|                     null|    1|
# |  uniprot_variants|Frontotemporal de...|        OMIM:619132|                     null|    1|
# |  uniprot_variants|Mononeuropathy of...|        OMIM:613353|            MONDO_0013237|    1|
# |  uniprot_variants|Bone marrow failu...|        OMIM:617052|                     null|    1|
# |  uniprot_variants|Left-right axis m...|        OMIM:601877|                     null|    1|
# |  uniprot_variants|Ritscher-Schinzel...|        OMIM:619135|                     null|    1|
# |  uniprot_variants|Neurodevelopmenta...|        OMIM:619072|                     null|    1|
# |  uniprot_variants|Infantile catarac...|        OMIM:618339|                     null|    1|
# |  uniprot_variants|Vitreoretinopathy...|        OMIM:619248|                     null|    1|
# |  uniprot_variants|Ventricular arryt...|        OMIM:115000|                     null|    1|
# |  uniprot_variants|         Dystonia 30|        OMIM:619291|                     null|    1|
# |  uniprot_variants|Neurodegeneration...|        OMIM:617672|                     null|    1|
# |  uniprot_variants|Megaloblastic ane...|        OMIM:601775|                     null|    1|
# |  uniprot_variants|Non-syndromic oro...|        OMIM:608864|            MONDO_0012141|    1|
# |  uniprot_variants|Microcephaly, cat...|        OMIM:618284|                     null|    1|
# |  uniprot_variants|Neurologic, endoc...|        OMIM:616263|                     null|    1|
# |  uniprot_variants|Ovarian dysgenesis 8|        OMIM:618187|                     null|    1|
# |  uniprot_variants|Hypotonia, infant...|        OMIM:616900|                     null|    1|
# |  uniprot_variants|Fibrosis, neurode...|        OMIM:618278|                     null|    1|
# |  uniprot_variants|Ataxia, sensory, ...|        OMIM:608984|                     null|    1|
# |  uniprot_variants|     Hyperglycinuria|        OMIM:138500|                     null|    1|
# |  uniprot_variants|Ectodermal dyspla...|        OMIM:617337|                     null|    1|
# |  uniprot_variants|Neurodevelopmenta...|        OMIM:618480|                     null|    1|
# |  uniprot_variants|Delpire-McNeill s...|        OMIM:619083|                     null|    1|
# |  uniprot_variants|Combined oxidativ...|        OMIM:618378|                     null|    1|
# |  uniprot_variants|Deafness, autosom...|        OMIM:618457|                     null|    1|
# |  uniprot_variants|            Glioma 2|        OMIM:613028|            MONDO_0100242|    1|
# |  uniprot_variants|Ectodermal dyspla...|        OMIM:617392|                     null|    1|
# |  uniprot_variants|Geleophysic dyspl...|        OMIM:617809|                     null|    1|
# |  uniprot_variants|Hypercholanemia, ...|        OMIM:619256|                     null|    1|
# |  uniprot_variants|Deafness, autosom...|        OMIM:619086|                     null|    1|
# |  uniprot_variants|    Schizophrenia 15|        OMIM:613950|                     null|    1|
# |  uniprot_variants|Bile acid conjuga...|        OMIM:619232|                     null|    1|
# |  uniprot_variants|Carpal tunnel syn...|        OMIM:619161|                     null|    1|
# |  uniprot_variants|Developmental del...|        OMIM:619090|                     null|    1|
# |  uniprot_variants|Hypopigmentation,...|        OMIM:618541|                     null|    1|
# |  uniprot_variants| Immunodeficiency 42|        OMIM:616622|                     null|    1|
# |  uniprot_variants|Intrauterine grow...|        OMIM:618336|                     null|    1|
# |  uniprot_variants|Complement hypera...|        OMIM:226300|                     null|    1|
# |  uniprot_variants|Encephalopathy, p...|        OMIM:617669|                     null|    1|
# |  uniprot_variants|Myopathy, scapulo...|        OMIM:616852|                     null|    1|
# |  uniprot_variants|Intellectual deve...|        OMIM:606220|                     null|    1|
# |  uniprot_variants|Vitiligo-associat...|        OMIM:606579|                     null|    1|
# |  uniprot_variants| Immunodeficiency 60|        OMIM:618394|                     null|    1|
# |  uniprot_variants|   Orofacial cleft 8|        OMIM:618149|                     null|    1|
# |  uniprot_variants|Monosomy 7 myelod...|        OMIM:252270|                     null|    1|
# |  uniprot_variants|High bone mass trait|        OMIM:601884|                     null|    1|
# |  uniprot_variants| Immunodeficiency 64|        OMIM:618534|                     null|    1|
# |  uniprot_variants|Diarrhea 10, prot...|        OMIM:618183|                     null|    1|
# |  uniprot_variants|Carboxypeptidase ...|        OMIM:212070|                     null|    1|
# |  uniprot_variants|Mitochondrial com...|        OMIM:500015|                     null|    1|
# |  uniprot_variants|Combined osteogen...|        OMIM:619120|                     null|    1|
# |  uniprot_variants|Multiple system a...|        OMIM:146500|                     null|    1|
# |  uniprot_variants|Psychomotor retar...|        OMIM:614501|                     null|    1|
# |uniprot_literature|ACTH-independent ...|        OMIM:219080|                     null|    4|
# |uniprot_literature| Neural tube defects|        OMIM:182940|            MONDO_0020705|    3|
# |uniprot_literature|  Multiple sclerosis|        OMIM:126200|            MONDO_0007462|    3|
# |uniprot_literature|              Glioma|        OMIM:137800|            MONDO_0100242|    3|
# |uniprot_literature|              Glioma|        OMIM:137800|            MONDO_0024498|    3|
# |uniprot_literature|Hemolytic uremic ...|        OMIM:235400|            MONDO_0009335|    3|
# |uniprot_literature|Budd-Chiari syndrome|        OMIM:600880|                     null|    2|
# |uniprot_literature|     Hyperglycinuria|        OMIM:138500|                     null|    2|
# |uniprot_literature|Encephalopathy, a...|        OMIM:618426|                     null|    1|
# |uniprot_literature|Cleft palate, pro...|        OMIM:619074|                     null|    1|
# |uniprot_literature|Mitral valve prol...|        OMIM:610840|                     null|    1|
# |uniprot_literature|    Trichotillomania|        OMIM:613229|                     null|    1|
# |uniprot_literature|Turnpenny-Fry syn...|        OMIM:618371|                     null|    1|
# |uniprot_literature|Diarrhea 10, prot...|        OMIM:618183|                     null|    1|
# |uniprot_literature|Oculomotor-abduce...|        OMIM:619215|                     null|    1|
# |uniprot_literature|Uridine-cytidineuria|        OMIM:618477|                     null|    1|
# |uniprot_literature|Mitochondrial com...|        OMIM:619170|                     null|    1|
# |uniprot_literature|Mitochondrial com...|        OMIM:619167|                     null|    1|
# |uniprot_literature|Leukodystrophy, h...|        OMIM:619310|                     null|    1|
# |uniprot_literature|Hypotaurinemic re...|        OMIM:145350|                     null|    1|
# |uniprot_literature|Lessel-Kreienkamp...|        OMIM:619149|                     null|    1|
# |uniprot_literature|Deafness, autosom...|        OMIM:619274|                     null|    1|
# |uniprot_literature|Bone marrow failu...|        OMIM:618116|                     null|    1|
# |uniprot_literature|Hypotonia, infant...|        OMIM:616816|                     null|    1|
# |uniprot_literature|Megacystis-microc...|        OMIM:619351|                     null|    1|
# |uniprot_literature|Carpal tunnel syn...|        OMIM:619161|                     null|    1|
# |uniprot_literature|     CIMDAG syndrome|        OMIM:619273|                     null|    1|
# |uniprot_literature|Hermansky-Pudlak ...|        OMIM:619172|                     null|    1|
# |uniprot_literature|Mitochondrial com...|        OMIM:619355|                     null|    1|
# |uniprot_literature|Spermatogenic fai...|        OMIM:619095|                     null|    1|
# |uniprot_literature|Nephrotic syndrom...|        OMIM:619155|                     null|    1|
# |uniprot_literature|Bartsocas-Papas s...|        OMIM:619339|                     null|    1|
# |uniprot_literature|Spermatogenic fai...|        OMIM:619202|                     null|    1|
# |uniprot_literature|Acetyl-CoA carbox...|        OMIM:613933|                     null|    1|
# |uniprot_literature|Neurologic, endoc...|        OMIM:616263|                     null|    1|
# |uniprot_literature|Neurodegeneration...|        OMIM:619173|                     null|    1|
# |uniprot_literature|Combined oxidativ...|        OMIM:618329|                     null|    1|
# |uniprot_literature|Microcephaly, gro...|        OMIM:618346|                     null|    1|
# |uniprot_literature|Hypothyroidism, c...|        OMIM:618573|                     null|    1|
# |uniprot_literature|Hypothyroidism, c...|        OMIM:301035|                     null|    1|
# |uniprot_literature|Rhizomelic chondr...|        OMIM:222765|                     null|    1|
# |uniprot_literature|Azoospermia, obst...|        OMIM:301060|                     null|    1|
# |uniprot_literature|Cardiofacioneurod...|        OMIM:619123|                     null|    1|
# |uniprot_literature|Bachmann-Bupp syn...|        OMIM:619075|                     null|    1|
# |uniprot_literature|Cortical dysplasi...|        OMIM:618174|                     null|    1|
# |uniprot_literature|Monosomy 7 myelod...|        OMIM:252270|                     null|    1|
# |uniprot_literature|Vitiligo-associat...|        OMIM:606579|                     null|    1|
# |uniprot_literature|Mismatch repair c...|        OMIM:619101|                     null|    1|
# |uniprot_literature| Joubert syndrome 37|        OMIM:619185|                     null|    1|
# |uniprot_literature|         Cataract 48|        OMIM:618415|                     null|    1|
# |uniprot_literature|Combined oxidativ...|        OMIM:616811|                     null|    1|
# |uniprot_literature|Immunodeficiency ...|        OMIM:618108|                     null|    1|
# |uniprot_literature|Bleeding disorder...|        OMIM:617443|                     null|    1|
# |uniprot_literature|Peeling skin with...|        OMIM:616295|                     null|    1|
# |uniprot_literature|      HELIX syndrome|        OMIM:617671|                     null|    1|
# |uniprot_literature|Deafness, autosom...|        OMIM:618533|                     null|    1|
# |uniprot_literature|Premature ovarian...|        OMIM:619245|                     null|    1|
# |uniprot_literature|Frontotemporal de...|        OMIM:619132|                     null|    1|
# |uniprot_literature|Short stature, am...|        OMIM:618363|                     null|    1|
# |uniprot_literature|Microcephaly, con...|        OMIM:616834|                     null|    1|
# |uniprot_literature|Neurodevelopmenta...|        OMIM:619286|                     null|    1|
# |uniprot_literature|Structural heart ...|        OMIM:617478|                     null|    1|
# |uniprot_literature| Immunodeficiency 77|        OMIM:619223|                     null|    1|
# |uniprot_literature|Neurodevelopmenta...|        OMIM:619264|                     null|    1|
# |uniprot_literature|Intellectual deve...|        OMIM:618316|                     null|    1|
# |uniprot_literature|Cerebellar, ocula...|        OMIM:618479|                     null|    1|
# |uniprot_literature|Familial adenomat...|        OMIM:617100|                     null|    1|
# |uniprot_literature|Blistering, acant...|        OMIM:619226|                     null|    1|
# |uniprot_literature|    Schizophrenia 19|        OMIM:617629|                     null|    1|
# |uniprot_literature|Non-syndromic oro...|        OMIM:616788|                     null|    1|
# |uniprot_literature|Dysostosis multip...|        OMIM:619345|                     null|    1|
# |uniprot_literature|     Schizophrenia 9|        OMIM:604906|                     null|    1|
# |uniprot_literature|Neurodevelopmenta...|        OMIM:619306|                     null|    1|
# |uniprot_literature|Neurodevelopmenta...|        OMIM:618292|                     null|    1|
# |uniprot_literature|Odontochondrodysp...|        OMIM:619269|                     null|    1|
# |uniprot_literature|Myopathy, myofibr...|        OMIM:619178|                     null|    1|
# |uniprot_literature|Oocyte maturation...|        OMIM:619176|                     null|    1|
# |uniprot_literature|Complement hypera...|        OMIM:226300|                     null|    1|
# |uniprot_literature|Hyperlipidemia, f...|        OMIM:602491|                     null|    1|
# |uniprot_literature|Non-syndromic oro...|        OMIM:608864|            MONDO_0012141|    1|
# |uniprot_literature| Immunodeficiency 44|        OMIM:616636|                     null|    1|
# |uniprot_literature|Developmental and...|        OMIM:301058|                     null|    1|
# |uniprot_literature|Mismatch repair c...|        OMIM:619096|                     null|    1|
# |uniprot_literature|Neurodevelopmenta...|        OMIM:619056|                     null|    1|
# |uniprot_literature|        Yao syndrome|        OMIM:617321|                     null|    1|
# |uniprot_literature|Cardioacrofacial ...|        OMIM:619142|                     null|    1|
# |uniprot_literature|Nephrotic syndrom...|        OMIM:619263|                     null|    1|
# |uniprot_literature|Sedoheptulokinase...|        OMIM:617213|                     null|    1|
# |uniprot_literature|Aicardi-Goutieres...|        OMIM:619486|                     null|    1|
# |uniprot_literature|  Thrombocytopenia 7|        OMIM:619130|                     null|    1|
# |uniprot_literature|Neurodevelopmenta...|        OMIM:619103|                     null|    1|
# |uniprot_literature|Deafness, autosom...|        OMIM:618145|                     null|    1|
# |uniprot_literature|Immunodeficiency 32B|        OMIM:226990|                     null|    1|
# |uniprot_literature|Nystagmus congeni...|        OMIM:310700|                     null|    1|
# |uniprot_literature| Immunodeficiency 49|        OMIM:617237|                     null|    1|
# |uniprot_literature|Vitamin D-depende...|        OMIM:619073|                     null|    1|
# |uniprot_literature|            Glioma 1|        OMIM:137800|            MONDO_0100242|    1|
# |uniprot_literature|Cortical dysplasi...|        OMIM:618677|                     null|    1|
# |uniprot_literature|Hypothyroidism, c...|        OMIM:301033|                     null|    1|
# |uniprot_literature|Erythrokeratoderm...|        OMIM:619209|                     null|    1|
# |uniprot_literature|High bone mass trait|        OMIM:601884|                     null|    1|
# |uniprot_literature|   KINSSHIP syndrome|        OMIM:619297|                     null|    1|
# |uniprot_literature|Deafness, autosom...|        OMIM:618410|                     null|    1|
# |uniprot_literature|Intellectual deve...|        OMIM:617061|                     null|    1|
# |uniprot_literature|Hypercholanemia, ...|        OMIM:619256|                     null|    1|
# |uniprot_literature|Coffin-Siris synd...|        OMIM:617808|                     null|    1|
# |uniprot_literature|Platelet glycopro...|        OMIM:608404|                     null|    1|
# |uniprot_literature|Neurodevelopmenta...|        OMIM:617171|                     null|    1|
# |uniprot_literature|Deafness, autosom...|        OMIM:618257|                     null|    1|
# |uniprot_literature|Muscular dystroph...|        OMIM:617066|                     null|    1|
# |uniprot_literature|Oocyte maturation...|        OMIM:618353|                     null|    1|
# |uniprot_literature|Marbach-Rustad pr...|        OMIM:619322|                     null|    1|
# |uniprot_literature|Baralle-Macken sy...|        OMIM:619255|                     null|    1|
# |uniprot_literature|Developmental del...|        OMIM:616901|                     null|    1|
# |uniprot_literature| Coumarin resistance|        OMIM:122700|                     null|    1|
# |uniprot_literature|Proteasome-associ...|        OMIM:619175|                     null|    1|
# |uniprot_literature|Platelet-activati...|        OMIM:614278|                     null|    1|
# |uniprot_literature|        Otitis media|        OMIM:166760|            MONDO_0008162|    1|
# |uniprot_literature|Mental retardatio...|        OMIM:616977|                     null|    1|
# |uniprot_literature|  Olmsted syndrome 2|        OMIM:619208|                     null|    1|
# |uniprot_literature|Neurodevelopmenta...|        OMIM:619244|                     null|    1|
# |uniprot_literature|Ectodermal dyspla...|        OMIM:618535|                     null|    1|
# |uniprot_literature|Developmental and...|        OMIM:619340|                     null|    1|
# |uniprot_literature|  Autism, X-linked 3|        OMIM:300496|                     null|    1|
# |uniprot_literature|Adiponectin defic...|        OMIM:612556|                     null|    1|
# |uniprot_literature| Immunodeficiency 45|        OMIM:616669|                     null|    1|
# |uniprot_literature|Mitochondrial com...|        OMIM:619224|                     null|    1|
# |uniprot_literature|Neurodevelopmenta...|        OMIM:619092|                     null|    1|
# |uniprot_literature| Immunodeficiency 64|        OMIM:618534|                     null|    1|
# |uniprot_literature|Microangiopathy a...|        OMIM:618564|                     null|    1|
# |uniprot_literature|Mitochondrial com...|        OMIM:619272|                     null|    1|
# +------------------+--------------------+-------------------+-------------------------+-----+
# only showing top 300 rows

# %%
failed_disease.show(truncate=False)
# Out:
# +----------------+-------------------------------------------------------------------------------------+-------------------+-------------------------+-----+
# |datasourceId    |diseaseFromSource                                                                    |diseaseFromSourceId|diseaseFromSourceMappedId|count|
# +----------------+-------------------------------------------------------------------------------------+-------------------+-------------------------+-----+
# |uniprot_variants|Polycystic kidney disease 1 with or without polycystic liver disease                 |OMIM:173900        |null                     |60   |
# |uniprot_variants|Ataxia telangiectasia                                                                |OMIM:208900        |EFO_0004922              |41   |
# |uniprot_variants|Glioma                                                                               |OMIM:137800        |MONDO_0100242            |20   |
# |uniprot_variants|Glioma                                                                               |OMIM:137800        |MONDO_0024498            |20   |
# |uniprot_variants|Neural tube defects                                                                  |OMIM:182940        |MONDO_0020705            |20   |
# |uniprot_variants|Glanzmann thrombasthenia 2                                                           |OMIM:619267        |null                     |19   |
# |uniprot_variants|Stuttering, familial persistent 1                                                    |OMIM:184450        |null                     |15   |
# |uniprot_variants|Neuroblastoma 3                                                                      |OMIM:613014        |MONDO_0013083            |14   |
# |uniprot_variants|Mismatch repair cancer syndrome 4                                                    |OMIM:619101        |null                     |13   |
# |uniprot_variants|Encephalopathy, progressive, early-onset, with brain atrophy and thin corpus callosum|OMIM:617193        |null                     |13   |
# |uniprot_variants|Hemolytic uremic syndrome atypical 1                                                 |OMIM:235400        |MONDO_0009335            |13   |
# |uniprot_variants|Nystagmus congenital X-linked 1                                                      |OMIM:310700        |null                     |10   |
# |uniprot_variants|Familial male precocious puberty                                                     |OMIM:176410        |null                     |10   |
# |uniprot_variants|Frontotemporal dementia and/or amyotrophic lateral sclerosis 5                       |OMIM:619141        |null                     |10   |
# |uniprot_variants|Hypotonia, ataxia, and delayed development syndrome                                  |OMIM:617330        |null                     |9    |
# |uniprot_variants|Intellectual developmental disorder, autosomal dominant 44, with microcephaly        |OMIM:617061        |null                     |8    |
# |uniprot_variants|Coumarin resistance                                                                  |OMIM:122700        |null                     |8    |
# |uniprot_variants|Combined osteogenesis imperfecta and Ehlers-Danlos syndrome 1                        |OMIM:619115        |null                     |7    |
# |uniprot_variants|Schizophrenia 4                                                                      |OMIM:600850        |null                     |7    |
# |uniprot_variants|Colorectal cancer 1                                                                  |OMIM:608812        |MONDO_0012132            |6    |
# +----------------+-------------------------------------------------------------------------------------+-------------------+-------------------------+-----+
# only showing top 20 rows
