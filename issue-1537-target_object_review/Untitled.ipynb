# %% [markdown]
# # Checking target object
#
# * **Date:** 2021.05.18
# * **Version:** v8

# %% [markdown]
# ## Fetching data
#
# The V8 release of the target object is downloaded from the google bucket.

# %%
# %%bash
#
#
# gsutil cp -r gs://ot-team/jarrod/target-outputs/v8 /Users/dsuveges/project_data/target_index/

# %%
from pyspark.sql import SparkSession
import pyspark.sql.functions as F
from pyspark.sql.types import StringType, IntegerType, TimestampType, StructType

# establish spark connection
spark = (
    SparkSession.builder
    .getOrCreate()
)


new_target = (
    spark.read.json('/Users/dsuveges/project_data/target_index/v8/target-beta')
    .persist()
)

new_target.show()
# Out:
# +----------------+--------------------+--------------+--------------+--------------------+--------------------+--------------------+--------------------+----+--------------------+--------------------+---------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+--------------------+--------------------+
# |alternativeGenes|        approvedName|approvedSymbol|       biotype|          constraint|             dbXrefs|functionDescriptions|     genomicLocation|  go|           hallmarks|          homologues|             id|          proteinIds|   safetyLiabilities|subcellularLocations|            synonyms|         targetClass| tep|        tractability|       transcriptIds|
# +----------------+--------------------+--------------+--------------+--------------------+--------------------+--------------------+--------------------+----+--------------------+--------------------+---------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+--------------------+--------------------+
# |            null|SCY1 like pseudok...|         SCYL3|protein_coding|[[syn, 146.92, 13...|[[19285, HGNC], [...|[May play a role ...|[1, 169894267, 16...|null|                null|[[ortholog_one2on...|ENSG00000000457|[[Q8IZE3, uniprot...|                null|[[Golgi apparatus...|[[Protein-associa...|                  []|null|[[Database Ubiqui...|[ENST00000367771,...|
# |            null| complement factor H|           CFH|protein_coding|[[syn, 222.53, 25...|[[4883, HGNC], [2...|[Glycoprotein tha...|[1, 196747504, 19...|null|                null|[[ortholog_one2on...|ENSG00000000971|[[P08603, uniprot...|                null|[[Secreted, unipr...|[[Complement fact...|[[3, Secreted pro...|null|[[UniProt SigP or...|[ENST00000359637,...|
# |            null|CASP8 and FADD li...|         CFLAR|protein_coding|[[syn, 96.864, 84...|[[1876, HGNC], [R...|[Apoptosis regula...|[2, 201176687, 20...|null|                null|[[ortholog_one2on...|ENSG00000003402|[[O15519, uniprot...|                null|[[Cytosol, HPA_ma...|[[Caspase-eight-r...|[[601, Unclassifi...|null|[[Human Protein A...|[ENST00000341222,...|
# |            null|         galectin 14|       LGALS14|protein_coding|[[syn, 36.654, 36...|[[30054, HGNC], [...|[Binds beta-galac...|[19, 39709444, 39...|null|                null|[[ortholog_one2on...|ENSG00000006659|[[Q8TCE9, uniprot...|                null|[[Nucleus, unipro...|[[Charcot-Leyden ...|                  []|null|                null|[ENST00000601802,...|
# |            null|elaC ribonuclease...|         ELAC2|protein_coding|[[syn, 180.47, 21...|[[14198, HGNC], [...|[Zinc phosphodies...|[17, 13018065, 12...|null|                null|[[ortholog_one2on...|ENSG00000006744|[[Q9BQ52, uniprot...|                null|[[Mitochondrion m...|[[Zinc phosphodie...|                  []|null|[[Database Ubiqui...|[ENST00000580504,...|
# |            null|uridine phosphory...|          UPP2|protein_coding|[[syn, 75.126, 70...|[[23061, HGNC], [...|[Catalyzes the re...|[2, 158136154, 15...|null|                null|[[ortholog_one2on...|ENSG00000007001|[[O95045, uniprot...|                null|[[Nucleoplasm, HP...|[[Uridine phospho...|                  []|null|[[High-Quality Po...|[ENST00000605860,...|
# |            null|lysine demethylas...|         KDM5D|protein_coding|[[syn, 85.033, 11...|[[11115, HGNC], [...|[Histone demethyl...|[Y, 19744939, 197...|null|                null|[[ortholog_one2on...|ENSG00000012817|[[Q9BY66, uniprot...|                null|[[Nucleus, unipro...|[[[histone H3]-tr...|                  []|null|[[UniProt Ubiquit...|[ENST00000485154,...|
# |            null|       CD74 molecule|          CD74|protein_coding|[[syn, 71.933, 67...|[[1697, HGNC], [I...|[Plays a critical...|[5, 150412929, 15...|null|                null|[[ortholog_one2on...|ENSG00000019582|[[P04233, uniprot...|                null|[[Endosome, unipr...|[[HLA class II hi...|[[9, Surface anti...|null|[[High-Quality Po...|[ENST00000518797,...|
# |            null|solute carrier fa...|        SLC7A9|protein_coding|[[syn, 127.26, 12...|[[11067, HGNC], [...|[Involved in the ...|[19, 32869767, 32...|null|                null|[[ortholog_one2on...|ENSG00000021488|[[P82251, uniprot...|                null|[[Apical cell mem...|[[b(0,+)-type ami...|                  []|null|[[UniProt SigP or...|[ENST00000589659,...|
# |            null|oxysterol binding...|        OSBPL5|protein_coding|[[syn, 248.64, 23...|[[16392, HGNC], [...|[Lipid transporte...|[11, 3166739, 308...|null|                null|[[ortholog_one2on...|ENSG00000021762|[[Q9H0X9, uniprot...|                null|[[Endoplasmic ret...|[[Oxysterol-bindi...|                  []|null|[[UniProt SigP or...|[ENST00000528124,...|
# |            null|endoplasmic retic...|         ERP44|protein_coding|[[syn, 73.807, 75...|[[18311, HGNC], [...|[Mediates thiol-d...|[9, 100099000, 99...|null|                null|[[ortholog_one2on...|ENSG00000023318|[[Q9BS26, uniprot...|                null|[[Endoplasmic ret...|[[Thioredoxin dom...|                  []|null|[[UniProt SigP or...|   [ENST00000262455]|
# |            null|ubiquitin protein...|          UBR2|protein_coding|[[syn, 311.65, 30...|[[21289, HGNC], [...|[E3 ubiquitin-pro...|[6, 42693505, 425...|null|                null|[[ortholog_one2on...|ENSG00000024048|[[Q8IWV8, uniprot...|                null|[[Nucleus, unipro...|[[E3 ubiquitin-pr...|                  []|null|[[Human Protein A...|[ENST00000372901,...|
# +----------------+--------------------+--------------+--------------+--------------------+--------------------+--------------------+--------------------+----+--------------------+--------------------+---------------+--------------------+--------------------+--------------------+--------------------+--------------------+----+--------------------+--------------------+
# only showing top 20 rows

# %%
new_target.printSchema()
# Out:
# root
#  |-- alternativeGenes: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- approvedName: string (nullable = true)
#  |-- approvedSymbol: string (nullable = true)
#  |-- biotype: string (nullable = true)
#  |-- constraint: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- constraintType: string (nullable = true)
#  |    |    |-- exp: double (nullable = true)
#  |    |    |-- obs: long (nullable = true)
#  |    |    |-- oe: double (nullable = true)
#  |    |    |-- oeLower: double (nullable = true)
#  |    |    |-- oeUpper: double (nullable = true)
#  |    |    |-- score: double (nullable = true)
#  |    |    |-- upperBin: long (nullable = true)
#  |    |    |-- upperBin6: long (nullable = true)
#  |    |    |-- upperRank: long (nullable = true)
#  |-- dbXrefs: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- source: string (nullable = true)
#  |-- functionDescriptions: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- genomicLocation: struct (nullable = true)
#  |    |-- chromosome: string (nullable = true)
#  |    |-- end: long (nullable = true)
#  |    |-- start: long (nullable = true)
#  |    |-- strand: long (nullable = true)
#  |-- go: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- aspect: string (nullable = true)
#  |    |    |-- evidence: string (nullable = true)
#  |    |    |-- geneProduct: string (nullable = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- source: string (nullable = true)
#  |-- hallmarks: struct (nullable = true)
#  |    |-- attributes: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- attribute_name: string (nullable = true)
#  |    |    |    |-- description: string (nullable = true)
#  |    |    |    |-- pmid: long (nullable = true)
#  |    |-- cancerHallmarks: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- description: string (nullable = true)
#  |    |    |    |-- impact: string (nullable = true)
#  |    |    |    |-- label: string (nullable = true)
#  |    |    |    |-- pmid: long (nullable = true)
#  |-- homologues: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- homologyType: string (nullable = true)
#  |    |    |-- queryPercentageIdentity: double (nullable = true)
#  |    |    |-- speciesId: string (nullable = true)
#  |    |    |-- speciesName: string (nullable = true)
#  |    |    |-- targetGeneId: string (nullable = true)
#  |    |    |-- targetGeneSymbol: string (nullable = true)
#  |    |    |-- targetPercentageIdentity: double (nullable = true)
#  |-- id: string (nullable = true)
#  |-- proteinIds: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- source: string (nullable = true)
#  |-- safetyLiabilities: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- assayDescription: string (nullable = true)
#  |    |    |-- assayFormat: string (nullable = true)
#  |    |    |-- assayType: string (nullable = true)
#  |    |    |-- datasource: string (nullable = true)
#  |    |    |-- effects: struct (nullable = true)
#  |    |    |    |-- dosing: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- type: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- event: string (nullable = true)
#  |    |    |-- eventId: string (nullable = true)
#  |    |    |-- pmid: string (nullable = true)
#  |    |    |-- tissue: struct (nullable = true)
#  |    |    |    |-- efoId: string (nullable = true)
#  |    |    |    |-- label: string (nullable = true)
#  |    |    |    |-- modelName: string (nullable = true)
#  |    |    |-- url: string (nullable = true)
#  |-- subcellularLocations: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- location: string (nullable = true)
#  |    |    |-- source: string (nullable = true)
#  |-- synonyms: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- label: string (nullable = true)
#  |    |    |-- source: string (nullable = true)
#  |-- targetClass: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- id: long (nullable = true)
#  |    |    |-- label: string (nullable = true)
#  |    |    |-- level: string (nullable = true)
#  |-- tep: struct (nullable = true)
#  |    |-- name: string (nullable = true)
#  |    |-- uri: string (nullable = true)
#  |-- tractability: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- modality: string (nullable = true)
#  |    |    |-- value: boolean (nullable = true)
#  |-- transcriptIds: array (nullable = true)
#  |    |-- element: string (containsNull = true)

# %% [markdown]
# ## Conclusions
#
# number of target in the target object: 17,643
#
# 1. The `alternativeGenes` is a good idea to have all gene ID for the same location, but different builds kept together. (Only 50 such genes exists)
# 2. Interestingly there are ambiguous `approvedSymbol` (one symbol is shared by multiple targets) and
#  * There are 40 such symbols
#  * there are 14 symbols, where one symbol is shared by more than 2 targets.
#  * When one symbol is shared by two targets, one of the targets are mapped to conventional location, while the rest are mapped to alternative scaffolds. Interestingly, these entries are not linked via the `alternativeGenes` column.

# %%
(
    new_target
    .filter(F.col('alternativeGenes').isNotNull())
    .select('alternativeGenes')
    .count()
)
# Out:
# 50

# %%
dataset_size = new_target.count()

colname = 'approvedSymbol'
multi_symbol = (
    new_target
    .groupby(colname)
    .agg(
        F.count(F.col('approvedSymbol')).alias('count'),
        F.first(F.col('approvedName'))
    )
    .filter(F.col('count')>2)
    .persist()
)
print(multi_symbol.count())
multi_symbol.show()
(
    new_target
    .filter(F.col('alternativeGenes').isNotNull())
    .select('id', 'alternativeGenes', 'approvedName', 'approvedSymbol', 'genomicLocation')
    .show(100)
)


(
    new_target
    .filter(F.col('approvedSymbol')=='U2')
    .select('id', 'alternativeGenes', 'approvedName', 'approvedSymbol', 'genomicLocation')
    .show()
)
# Out:
# 14
# +--------------+-----+--------------------------+
# |approvedSymbol|count|first(approvedName, false)|
# +--------------+-----+--------------------------+
# |            U2|    4|      U2 spliceosomal RNA |
# |       5S_rRNA|    3|         5S ribosomal RNA |
# |            U4|    3|      U4 spliceosomal RNA |
# |           7SK|    3|                  7SK RNA |
# |            U3|   20|      Small nucleolar R...|
# |            U6|   11|      U6 spliceosomal RNA |
# |     5_8S_rRNA|    3|       5.8S ribosomal RNA |
# |   Metazoa_SRP|   54|      Metazoan signal r...|
# |       SNORA70|    8|      small nucleolar R...|
# |            U8|   12|      U8 small nucleola...|
# |       SNORA63|    5|      Small nucleolar R...|
# |       SNORA72|    3|      Small nucleolar R...|
# |       SNORA75|    3|      Small nucleolar R...|
# |         Y_RNA|  239|                    Y RNA |
# +--------------+-----+--------------------------+
#
# +---------------+--------------------+--------------------+--------------+--------------------+
# |             id|    alternativeGenes|        approvedName|approvedSymbol|     genomicLocation|
# +---------------+--------------------+--------------------+--------------+--------------------+
# |ENSG00000226165|[ENSG00000196610,...|major histocompat...|      HLA-DQB2|[CHR_HSCHR6_MHC_S...|
# |ENSG00000227861|[ENSG00000234951,...|suppressor APC do...|        SAPCD1|[CHR_HSCHR6_MHC_A...|
# |ENSG00000228405|[ENSG00000183574,...|ring finger prote...|          RNF5|[CHR_HSCHR6_MHC_C...|
# |ENSG00000233831|[ENSG00000169260,...|zinc finger prote...|        ZNF311|[CHR_HSCHR6_MHC_S...|
# |ENSG00000276263|[ENSG00000275086,...|TCF3 fusion partner |          TFPT|[CHR_HSCHR19LRC_L...|
# |ENSG00000277092|[ENSG00000276798,...|leukocyte immunog...|        LILRA4|[CHR_HSCHR19_4_CT...|
# |ENSG00000228116|[ENSG00000231618,...|palmitoyl-protein...|          PPT2|[CHR_HSCHR6_MHC_D...|
# |ENSG00000242361|[ENSG00000242685,...|major histocompat...|       HLA-DMA|[CHR_HSCHR6_MHC_A...|
# |ENSG00000277317|[ENSG00000275623,...|killer cell immun...|       KIR2DL3|[CHR_HSCHR19KIR_A...|
# |ENSG00000226788|[ENSG00000206287,...|ring finger prote...|         RING1|[CHR_HSCHR6_MHC_C...|
# |ENSG00000231823|[ENSG00000225103,...|major histocompat...|      HLA-DQA2|[CHR_HSCHR6_MHC_M...|
# |ENSG00000234114|[ENSG00000206355,...|coiled-coil alpha...|        CCHCR1|[CHR_HSCHR6_MHC_C...|
# |ENSG00000240433|[ENSG00000244672,...|lymphocyte antige...|        LY6G5B|[CHR_HSCHR6_MHC_M...|
# |ENSG00000275404|[ENSG00000274113,...|leukocyte immunog...|        LILRA5|[CHR_HSCHR19LRC_P...|
# |ENSG00000275463|[ENSG00000274513,...|leukocyte immunog...|        LILRB2|[CHR_HSCHR19_4_CT...|
# |ENSG00000275841|[ENSG00000276175,...|leukocyte immunog...|        LILRA3|[CHR_HSCHR19_4_CT...|
# |ENSG00000277600|[ENSG00000274941,...|CCR4-NOT transcri...|         CNOT3|[CHR_HSCHR19_4_CT...|
# |ENSG00000278605|[ENSG00000274078,...|tRNA splicing end...|        TSEN34|[CHR_HSCHR19_4_CT...|
# |ENSG00000206480|[ENSG00000232280,...|        flotillin 1 |         FLOT1|[CHR_HSCHR6_MHC_Q...|
# |ENSG00000224234|[ENSG00000204689,...|olfactory recepto...|        OR10C1|[CHR_HSCHR6_MHC_C...|
# |ENSG00
# |ENSG00000229698|[ENSG00000206509,...|major histocompat...|         HLA-F|[CHR_HSCHR6_MHC_S...|
# |ENSG00000232099|[ENSG00000223858,...|ZFP57 zinc finger...|         ZFP57|[CHR_HSCHR6_MHC_M...|
# |ENSG00000276423|[ENSG00000284342,...|killer cell immun...|       KIR3DL1|[CHR_HSCHR19KIR_F...|
# +---------------+--------------------+--------------------+--------------+--------------------+
#
# +---------------+----------------+--------------------+--------------+--------------------+
# |             id|alternativeGenes|        approvedName|approvedSymbol|     genomicLocation|
# +---------------+----------------+--------------------+--------------+--------------------+
# |ENSG00000278774|            null|U2 spliceosomal RNA |            U2|[17, 43273292, 43...|
# |ENSG00000274062|            null|U2 spliceosomal RNA |            U2|[17, 43284329, 43...|
# |ENSG00000283519|            null|U2 spliceosomal RNA |            U2|[14, 75270780, 75...|
# |ENSG00000278048|            null|U2 spliceosomal RNA |            U2|[17, 43252019, 43...|
# +---------------+----------------+--------------------+--------------+--------------------+

# %%
(
    new_target
    .filter(F.col('approvedSymbol') == 'CCL4L2')
    .select('id', 'alternativeGenes', 'approvedName', 'approvedSymbol', 'genomicLocation')
    .show(truncate=False)
)

(
    new_target
    .filter(F.col('alternativeGenes').isNotNull())
    .select('id', 'alternativeGenes', 'approvedName', 'approvedSymbol', 'genomicLocation')
    .show(100)
)
# Out:
# +---------------+----------------------------------+------------------------------------+--------------+--------------------------------------------+
# |id             |alternativeGenes                  |approvedName                        |approvedSymbol|genomicLocation                             |
# +---------------+----------------------------------+------------------------------------+--------------+--------------------------------------------+
# |ENSG00000275313|[ENSG00000276125, ENSG00000282604]|C-C motif chemokine ligand 4 like 2 |CCL4L2        |[CHR_HSCHR17_10_CTG4, 36314484, 36312669, 1]|
# |ENSG00000276070|null                              |C-C motif chemokine ligand 4 like 2 |CCL4L2        |[17, 36212878, 36210924, 1]                 |
# +---------------+----------------------------------+------------------------------------+--------------+--------------------------------------------+
#
# +---------------+--------------------+--------------------+--------------+--------------------+
# |             id|    alternativeGenes|        approvedName|approvedSymbol|     genomicLocation|
# +---------------+--------------------+--------------------+--------------+--------------------+
# |ENSG00000226165|[ENSG00000196610,...|major histocompat...|      HLA-DQB2|[CHR_HSCHR6_MHC_S...|
# |ENSG00000227861|[ENSG00000234951,...|suppressor APC do...|        SAPCD1|[CHR_HSCHR6_MHC_A...|
# |ENSG00000228405|[ENSG00000183574,...|ring finger prote...|          RNF5|[CHR_HSCHR6_MHC_C...|
# |ENSG00000233831|[ENSG00000169260,...|zinc finger prote...|        ZNF311|[CHR_HSCHR6_MHC_S...|
# |ENSG00000276263|[ENSG00000275086,...|TCF3 fusion partner |          TFPT|[CHR_HSCHR19LRC_L...|
# |ENSG00000277092|[ENSG00000276798,...|leukocyte immunog...|        LILRA4|[CHR_HSCHR19_4_CT...|
# |ENSG00000228116|[ENSG00000231618,...|palmitoyl-protein...|          PPT2|[CHR_HSCHR6_MHC_D...|
# |ENSG00000242361|[ENSG00000242685,...|major histocompat...|       HLA-DMA|[CHR_HSCHR6_MHC_A...|
# |ENSG00000277317|[ENSG00000275623,...|killer cell immun...|       KIR2DL3|[CHR_HSCHR19KIR_A...|
# |ENSG00000226788|[ENSG00000206287,...|ring finger prote...|         RING1|[CHR_HSCHR6_MHC_C...|
# |ENSG00
# |ENSG00000235680|[ENSG00000233095,...|major histocompat...|         HLA-G|[CHR_HSCHR6_MHC_M...|
# |ENSG00000237724|[ENSG00000234475,...|heat shock protei...|        HSPA1A|[CHR_HSCHR6_MHC_C...|
# |ENSG00000239754|[ENSG00000241534,...|complement factor B |           CFB|[CHR_HSCHR6_MHC_C...|
# |ENSG00000223775|[ENSG00000227420,...|mitochondrial rib...|       MRPS18B|[CHR_HSCHR6_MHC_S...|
# |ENSG00000236222|[ENSG00000226916,...|WD repeat domain 46 |         WDR46|[CHR_HSCHR6_MHC_M...|
# |ENSG00000239329|[ENSG00000242092,...|major histocompat...|       HLA-DMB|[CHR_HSCHR6_MHC_M...|
# |ENSG00000226882|[ENSG00000232143,...|G protein nucleol...|          GNL1|[CHR_HSCHR6_MHC_S...|
# |ENSG00000206404|[ENSG00000226404,...|lymphocyte antige...|        LY6G5C|[CHR_HSCHR6_MHC_Q...|
# |ENSG00000235360|[ENSG00000226531,...|chromosome 6 open...|       C6orf47|[CHR_HSCHR6_MHC_C...|
# |ENSG00000237192|[ENSG00000227472,...|tripartite motif ...|        TRIM10|[CHR_HSCHR6_MHC_C...|
# |ENSG00000273875|[ENSG00000275384,...|T cell-interactin...|         TARM1|[CHR_HSCHR19LRC_P...|
# |ENSG00000206459|[ENSG00000234605,...|psoriasis suscept...|      PSORS1C2|[CHR_HSCHR6_MHC_Q...|
# |ENSG00000229698|[ENSG00000206509,...|major histocompat...|         HLA-F|[CHR_HSCHR6_MHC_S...|
# |ENSG00000232099|[ENSG00000223858,...|ZFP57 zinc finger...|         ZFP57|[CHR_HSCHR6_MHC_M...|
# |ENSG00000276423|[ENSG00000284342,...|killer cell immun...|       KIR3DL1|[CHR_HSCHR19KIR_F...|
# +---------------+--------------------+--------------------+--------------+--------------------+

# %% [markdown]
# * biotype is always set
# * there are 286 targets with empty biotype. Why? - probably missing annotation.
# *

# %%
column = 'biotype'

(
    new_target
    .groupby(column)
    .count()
    .show(30)
)


(
    new_target
    .filter(F.col(column) == '')
    .select('id', 'biotype','alternativeGenes', 'approvedName', 'approvedSymbol', 'genomicLocation')
    .show(100)
)
# Out:
# +--------------------+-----+
# |             biotype|count|
# +--------------------+-----+
# |polymorphic_pseud...|   15|
# |transcribed_unita...|   41|
# |     IG_C_pseudogene|    1|
# |                rRNA|   12|
# |                sRNA|    1|
# |              lncRNA| 4870|
# |     TR_V_pseudogene|    8|
# |               snRNA|  575|
# |transcribed_proce...|  149|
# |           IG_C_gene|    3|
# |     TR_J_pseudogene|    1|
# |           IG_J_gene|    6|
# |  unitary_pseudogene|   29|
# |           TR_V_gene|   23|
# |      protein_coding| 5850|
# |processed_pseudogene| 2947|
# |               miRNA|  535|
# |           TR_J_gene|   22|
# |     IG_J_pseudogene|    1|
# |transcribed_unpro...|  278|
# |           TR_C_gene|    2|
# |              snoRNA|  297|
# |     rRNA_pseudogene|  136|
# |          pseudogene|    4|
# |     IG_V_pseudogene|   52|
# |             Mt_tRNA|    6|
# |           IG_V_gene|   34|
# |unprocessed_pseud...|  781|
# |            misc_RNA|  651|
# |                    |  286|
# +--------------------+-----+
# only showing top 30 rows
#
# +---------------+-------+----------------+--------------------+--------------+--------------------+
# |             id|biotype|alternativeGenes|        approvedName|approvedSymbol|     genomicLocation|
# +---------------+-------+----------------+--------------------+--------------+--------------------+
# |ENSG00000266918|       |            null|                    |    AC091132.3|[17, 45533838, 45...|
# |ENSG00000278933|       |            null|                    |    AC022743.1|[18, 43499836, 43...|
# |ENSG00000278952|       |            null|                    |    AP003068.4|[11, 65119111, 65...|
# |ENSG00000279030|       |            null|    novel transcript|    AC007336.3|[16, 55488777, 55...|
# |ENSG00000279042|       |            null|                    |    AP005242.4|[18, 14993235, 14...|
# |ENSG00000279119|       |            null|                    |    AC006449.7|[17, 38728198, 38...|
# |ENSG00000279174|       |            null|                    |    AC104581.3|[17, 8016378, 801...|
# |ENSG00000279207|       |            null|    novel transcript|    AC015813.6|[17, 58101479, 58...|
# |ENSG00000279235|       |            null|                    |    AC011944.2|[15, 78906809, 78...|
# |ENSG00000279265|       |            null|                    |    AC000123.2|[7, 127350293, 12...|
# |ENSG00000279353|       |            null|                    |    AP001324.3|[11, 74699658, 74...|
# |ENSG00000279370|       |            null|                    |    AC004777.1|[5, 131261607, 13...|
# |ENSG00000279419|       |            null|                    |    AC004925.1|[7, 124745017, 12...|
# |ENSG00000279429|       |            null|                    |    AC004009.2|[7, 27412891, 274...|
# |ENSG00000279904|       |            null|                    |    AC068057.2|[2, 104707506, 10...|
# |ENSG00000279931|       |            null|    novel transcript|    AC073593.1|[12, 124725934, 1...|
# |ENSG00000279962|       |            null|                    |    AP001525.1|[18, 13710484, 13...|
# |ENSG00000279979|       |            null|                    |    AC012629.4|[5, 10675575, 106...|
# |ENSG00000279981|       |            null|                    |    AC018445.4|[18, 79498348, 79...|
# |ENSG00000280033|       |            null|                    |    AC116407.4|[17, 32160371, 32...|
# |ENSG00000280047|       |            null|                    |    AC091825.3|[5, 142168387, 14...|
# |ENSG00000280098|       |            null|                    |    AC011155.1|[18, 52409257, 52...|
# |ENSG00000280154|       |            null|                    |    AC073255.1|[2, 30408346, 304...|
# |ENSG00000280185|       |            null|                    |    AC091932.3|[5, 8794197, 8793...|
# |ENSG00000280225|       |            null|                    |    AC237221.2|[7, 57404717, 574...|
# |ENSG00000280278|       |            null|uncharacterized p...|      FLJ30679|[16, 86557299, 86...|
# |ENSG00000280310|       |            null|                    |    AC092437.1|[4, 4821452, 4820...|
# |ENSG00000280359|       |            null|    novel transcript|    AC105133.2|[15, 77785070, 77...|
# |ENSG00000280364|       |            null|    novel transcript|    AC005858.2|[12, 126107047, 1...|
# |ENSG00000280443|       |            null|                    |    AL136313.1|[6, 21822737, 218...|
# |ENSG00000278949|       |            null|    novel transcript|    AC127070.4|[12, 132867958, 1...|
# |ENSG00000279046|       |            null|    novel transcript|    AP003062.1|[11, 134986799, 1...|
# |ENSG00000279108|       |            null|                    |    AC008537.3|[19, 40842039, 40...|
# |ENSG00000279142|       |            null|    novel transcript|    AC009108.4|[16, 86597639, 86...|
# |ENSG00000279146|       |            null|    novel transcript|    AC063926.2|[12, 130466315, 1...|
# |ENSG00000279433|       |            null|                    |    AC018529.3|[18, 77110537, 77...|
# |ENSG00000279629|       |            null|                    |    AC048380.3|[18, 48662635, 48...|
# |ENSG00000279675|       |            null|                    |    AC080100.1|[11, 40112599, 40...|
# |ENSG00000279681|       |            null|    novel transcript|    AC092135.2|[16, 81617543, 81...|
# |ENSG00000279770|       |            null|long intergenic n...|     LINC00552|[13, 113751089, 1...|
# |ENSG00000279798|       |            null|                    |    AC018659.8|[12, 97563971, 97...|
# |ENSG00000279989|       |            null|                    |    AC011815.3|[18, 35257512, 35...|
# |ENSG00000280038|       |            null|dynamin 1 pseudog...|       DNM1P41|[15, 84169896, 84...|
# |ENSG00000280068|       |            null|                    |    AC138965.2|[5, 175904371, 17...|
# |ENSG00000280078|       |            null|                    |    AC016526.3|[14, 76283103, 76...|
# |ENSG00000280093|       |            null|    novel transcript|    AP002791.1|[11, 91383289, 91...|
# |ENSG00000280104|       |            null|                    |    AC010608.3|[5, 133458331, 13...|
# |ENSG00000280149|       |            null|                    |    AC004877.2|[7, 149852170, 14...|
# |ENSG00000280307|       |            null|    novel transcript|    AP000676.4|[11, 87880095, 87...|
# |ENSG00000280332|       |            null|                    |    AC020917.4|[19, 16358327, 16...|
# |ENSG00000280335|       |            null|                    |    AC016866.3|[18, 49013819, 49...|
# |ENSG00000280429|       |            null|    novel transcript|    AF001548.3|[16, 15792717, 15...|
# |ENSG00000280440|       |            null|                    |    AC002064.3|[7, 90346218, 903...|
# |ENSG00000279041|       |            null|                    |    AC102945.2|[8, 30553766, 305...|
# |ENSG00000279113|       |            null|    novel transcript|    AC148477.7|[12, 132332432, 1...|
# |ENSG00000279339|       |            null|                    |    AC100788.2|[17, 78900152, 78...|
# |ENSG00000279387|       |            null|                    |    AC011474.4|[19, 29509041, 29...|
# |ENSG00000279598|       |            null|novel transcript,...|    AC009948.3|[2, 178558966, 17...|
# |ENSG00000279632|       |            null|    novel transcript|    AP003108.4|[11, 61427325, 61...|
# |ENSG00000279659|       |            null|                    |    AL451064.2|[6, 79575530, 795...|
# |ENSG00000279717|       |            null|                    |    AC005336.3|[19, 15907234, 15...|
# |ENSG00000279733|       |            null|    novel transcript|    AP001642.1|[11, 88167691, 88...|
# |ENSG00000279806|       |            null|                    |    AC018629.1|[17, 40475289, 40...|
# |ENSG00000279807|       |            null|                    |    AC011472.5|[19, 11208702, 11...|
# |ENSG00000279818|       |            null|    novel transcript|    AP002991.1|[11, 115734742, 1...|
# |ENSG00000279841|       |            null|    novel transcript|    AC092135.3|[16, 81632038, 81...|
# |ENSG00000279917|       |            null|                    |    AC079331.2|[17, 67613822, 67...|
# |ENSG00000279935|       |            null|                    |    AL353611.2|[9, 134995854, 13...|
# |ENSG00000279945|       |            null|    novel transcript|    AC013489.3|[15, 88478387, 88...|
# |ENSG00000280120|       |            null|    novel transcript|    AC073857.1|[12, 123153377, 1...|
# |ENSG00000280139|       |            null|                    |    AC010297.1|[5, 176439238, 17...|
# |ENSG00000280211|       |            null|novel transcript,...|    AC106886.4|[16, 30776033, 30...|
# |ENSG00000280238|       |            null|                    |    AC022400.8|[10, 73791490, 73...|
# |ENSG00000280269|       |            null|                    |    AP000577.2|[11, 74205746, 74...|
# |ENSG00000280309|       |            null|                    |    AC023300.3|[15, 74304527, 74...|
# |ENSG00000280321|       |            null|                    |    AC129502.1|[11, 36197901, 36...|
# |ENSG00000280322|       |            null|                    |    AL035425.4|[X, 108726948, 10...|
# |ENSG00000282865|       |            null|                    |    AL157815.1|[13, 92241951, 92...|
# |ENSG00000286148|       |            null|                    |   FP236383.10|[21, 8468631, 846...|
# |ENSG00000225931|       |            null|    novel transcript|    AL139246.2|[1, 2569888, 2566...|
# |ENSG00000249852|       |            null|                    |    AC145676.1|[7, 229557, 22755...|
# |ENSG00000278992|       |            null|                    |    AC012048.1|[10, 76270800, 76...|
# |ENSG00000278993|       |            null|    novel transcript|    AC002350.2|[12, 110503441, 1...|
# |ENSG00000279023|       |            null|    novel transcript|    AC148477.6|[12, 132361198, 1...|
# |ENSG00000279114|       |            null|                    |      Z99129.3|[6, 122484161, 12...|
# |ENSG00000279133|       |            null|                    |    AC018628.1|[17, 62007518, 62...|
# |ENSG00000279221|       |            null|                    |    AC068254.2|[18, 69663413, 69...|
# |ENSG00000279264|       |            null|                    |    AC091953.5|[5, 8614696, 8614...|
# |ENSG00000279334|       |            null|    novel transcript|    AC073592.6|[12, 124562283, 1...|
# |ENSG00000279405|       |            null|    novel transcript|    AC004696.2|[19, 56483977, 56...|
# |ENSG00000279406|       |            null|                    |    AL359183.1|[10, 71366374, 71...|
# |ENSG00000279407|       |            null|                    |    AC007191.1|[19, 45717381, 45...|
# |ENSG00000279466|       |            null|    novel transcript|    AC073911.1|[12, 133073983, 1...|
# |ENSG00000279476|       |            null|    novel transcript|    AC092139.2|[16, 81520617, 81...|
# |ENSG00000279478|       |            null|    novel transcript|    AC127071.3|[12, 130383890, 1...|
# |ENSG00000279502|       |            null|                    |    AC016542.2|[10, 72757016, 72...|
# |ENSG00000279532|       |            null|    novel transcript|    AC002094.5|[17, 28374301, 28...|
# |ENSG00000279648|       |            null|                    |    AP000432.2|[21, 17707455, 17...|
# |ENSG00000279653|       |            null|                    |    AC004678.2|[19, 2003581, 200...|
# |ENSG00000279769|       |            null|                    |    CU639417.2|[21, 6036093, 603...|
# +---------------+-------+----------------+--------------------+--------------+--------------------+
# only showing top 100 rows

# %% [markdown]
# * constraint is set for 5.4k targets.

# %%
column = 'constraint'


(
    new_target
    .filter(F.col(column).isNotNull())
    .count()
)

(
    new_target
    .filter(F.col(column).isNotNull())
    .show(1, vertical=True, truncate=False)
)

(
    new_target
    .filter(F.col(column).isNotNull())
    .select('approvedSymbol', F.explode(F.col("constraint")))
    .printSchema()
#     .show(1, vertical=True, truncate=False)
)

(
    new_target
    .filter(F.col(column).isNotNull())
    .select('approvedSymbol', F.explode(F.col("constraint")).alias('constraint'))
    .select('approvedSymbol', 'constraint.constraintType')
    .show()
)
# Out:
# -RECORD 0-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  alternativeGenes     | null
#  approvedName         | SCY1 like pseudokinase 3
#  approvedSymbol       | SCYL3
#  biotype              | protein_coding
#  constraint           | [[syn, 146.92, 136, 0.92567, 0.804, 1.067, 0.70818,,,], [mis, 386.49, 332, 0.85902, 0.784, 0.941, 0.98492,,,], [lof, 34.32, 8, 0.2331, 0.136, 0.421, 0.28151, 2, 1, 3857]]
#  dbXrefs              | [[19285, HGNC], [IPR011989, InterPro], [IPR021133, InterPro], [IPR000719, InterPro], [IPR011009, InterPro], [IPR016024, InterPro], [SIDG33879, ProjectScore]]
#  functionDescriptions | [May play a role in regulating cell adhesion/migration complexes in migrating cells. {ECO:0000269|PubMed:12651155}.]
#  genomicLocation      | [1, 169894267, 169849631, -1]
#  go                   | null
#  hallmarks            | null
#  homologues           | [[ortholog_one2one, 98.9218, 9598, Chimpanzee, ENSPTRG00000001665, SCYL3, 98.9218], [ortholog_one2one, 94.7439, 9544, Macaque, ENSMMUG00000016583, SCYL3, 95.5163], [ortholog_one2one, 80.9973, 10116, Rat, ENSRNOG00000025318, Scyl3, 81.7687], [ortholog_one2one, 80.0539, 10090, Mouse, ENSMUSG00000026584, Scyl3, 80.8163], [ortholog_one2one, 84.6361, 9823, Pig, ENSSSCG00000006283, SCYL3, 85.5586], [ortholog_one2one, 85.1752, 9615, Dog, ENSCAFG00000015126, SCYL3, 85.0606], [ortholog_one2one, 50.6739, 8364, Tropical clawed frog, ENSXETG00000004735, scyl3, 52.514], [ortholog_one2one, 50.9434, 7955, Zebrafish, ENSDARG00000027046, scyl3, 49.2188]]
#  id                   | ENSG00000000457
#  proteinIds           | [[Q8IZE3, uniprot_swissprot], [X6RHX1, uniprot_trembl], [A8K8Z2, uniprot_obsolete], [Q5THA6, uniprot_obsolete], [Q5THA8, uniprot_obsolete], [Q8IZN9, uniprot_obsolete], [Q96C56, uniprot_obsolete], [Q9UBK6, uniprot_obsolete]]
#  safetyLiabilities    | null
#  subcellularLocations | [[Golgi apparatus, uniprot], [Cytoplasm, uniprot], [Cell projection, lamellipodium, uniprot], [Microtubules, HPA_main], [Nuclear bodies, HPA_additional]]
#  synonyms             | [[Protein-associating with the carboxyl-terminal domain of ezrin, uniprot], [SCY1-like protein 3, uniprot], [Ezrin-binding protein PACE-1, uniprot], [PACE-1, HGNC], [ezrin-binding partner PACE-1, HGNC], [PACE1, HGNC], [ezrin-binding protein PACE-1, NCBI_entrez], [ezrin-binding partner PACE-1 (PACE-1), NCBI_entrez], [SCY1-like 3, NCBI_entrez], [protein-associating with the carboxyl-terminal domain of ezrin, NCBI_entrez], [SCY1-like protein 3, NCBI_entrez], [SCY1-like, kinase-like 3, NCBI_entrez], [PACE-1, NCBI_entrez], [PACE1, NCBI_entrez]]
#  targetClass          | []
#  tep                  | null
#  tractability         | [[Database Ubiquitination, PR, true]]
#  transcriptIds        | [ENST00000367771, ENST00000423670, ENST00000470238, ENST00000367770, ENST00000367772]
# only showing top 1 row
#
# root
#  |-- approvedSymbol: string (nullable = true)
#  |-- col: struct (nullable = true)
#  |    |-- constraintType: string (nullable = true)
#  |    |-- exp: double (nullable = true)
#  |    |-- obs: long (nullable = true)
#  |    |-- oe: double (nullable = true)
#  |    |-- oeLower: double (nullable = true)
#  |    |-- oeUpper: double (nullable = true)
#  |    |-- score: double (nullable = true)
#  |    |-- upperBin: long (nullable = true)
#  |    |-- upperBin6: long (nullable = true)
#  |    |-- upperRank: long (nullable = true)
#
# +--------------+--------------+
# |approvedSymbol|constraintType|
# +--------------+--------------+
# |         SCYL3|           syn|
# |         SCYL3|           mis|
# |         SCYL3|           lof|
# |           CFH|           syn|
# |           CFH|           mis|
# |           CFH|           lof|
# |         CFLAR|           syn|
# |         CFLAR|           mis|
# |         CFLAR|           lof|
# |       LGALS14|           syn|
# |       LGALS14|           mis|
# |       LGALS14|           lof|
# |         ELAC2|           syn|
# |         ELAC2|           mis|
# |         ELAC2|           lof|
# |          UPP2|           syn|
# |          UPP2|           mis|
# |          UPP2|           lof|
# |          NOS2|           syn|
# |          NOS2|           mis|
# +--------------+--------------+
# only showing top 20 rows

# %%
column = 'targetClass'

(
    new_target
    .filter(F.col(column).isNotNull())
    .select('approvedSymbol', F.explode(column).alias(column))
    .select('approvedSymbol', F.col('targetClass.id'), F.col('targetClass.label'), F.col('targetClass.level'))
    .show(truncate=False)
)
# Out:
# +--------------+----+------------------------------------------+-----+
# |approvedSymbol|id  |label                                     |level|
# +--------------+----+------------------------------------------+-----+
# |CFH           |3   |Secreted protein                          |l1   |
# |CFLAR         |601 |Unclassified protein                      |l1   |
# |NOS2          |1   |Enzyme                                    |l1   |
# |MMP25         |82  |Metallo protease                          |l3   |
# |MMP25         |82  |Metallo protease M10A subfamily           |l5   |
# |MMP25         |82  |Metallo protease MAM clan                 |l4   |
# |MMP25         |82  |Protease                                  |l2   |
# |MMP25         |82  |Enzyme                                    |l1   |
# |LYPLA2        |646 |Enzyme                                    |l1   |
# |LYPLA2        |646 |Hydrolase                                 |l2   |
# |GABRA3        |1173|Ion channel                               |l1   |
# |GABRA3        |1173|GABA-A receptor                           |l3   |
# |GABRA3        |1173|Ligand-gated ion channel                  |l2   |
# |CD74          |9   |Surface antigen                           |l1   |
# |SH2D2A        |601 |Unclassified protein                      |l1   |
# |ARID4A        |601 |Unclassified protein                      |l1   |
# |LPAR2         |549 |EDG receptor                              |l5   |
# |LPAR2         |549 |Family A G protein-coupled receptor       |l2   |
# |LPAR2         |549 |Lipid-like ligand receptor (family A GPCR)|l4   |
# |LPAR2         |549 |Membrane receptor                         |l1   |
# +--------------+----+------------------------------------------+-----+
# only showing top 20 rows
