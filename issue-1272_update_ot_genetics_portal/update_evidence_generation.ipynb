# %%
import pandas as pd
import json
import gzip
import python_jsonschema_objects as pjo 
from collections import OrderedDict

ot_genetics_file = '/Users/dsuveges/project/issue-817_Create_genetics_evidence_json/l2g_joined_exploded.2020.03.04.parquet/'

df = pd.read_parquet(ot_genetics_file)
df.head()
# Out:
#   chrom      pos ref alt          gene_id           study_id  \
# 0     1  4544044   T   A  ENSG00000196581         GCST003128
# 1     1  7606620   C   T  ENSG00000049246  NEALE2_20002_1623
# 2     1  7606620   C   T  ENSG00000049247  NEALE2_20002_1623
# 3     1  7606620   C   T  ENSG00000116285  NEALE2_20002_1623
# 4     1  7606620   C   T  ENSG00000049249  NEALE2_20002_1623
#
#    y_proba_full_model  pval_mantissa  pval_exponent  odds_ratio  ...  \
# 0            0.757268        3.00000             -9         NaN  ...
# 1            0.051663        1.39165             -8    5.784572  ...
# 2            0.036761        1.39165             -8    5.784572  ...
# 3            0.054864        1.39165             -8    5.784572  ...
# 4            0.026479        1.39165             -8    5.784572  ...
#
#      pub_date    pub_author  \
# 0  2015-09-22         Zhu Z
# 1  2018-08-01  UKB Neale v2
# 2  2018-08-01  UKB Neale v2
# 3  2018-08-01  UKB Neale v2
# 4  2018-08-01  UKB Neale v2
#
#                                       trait_reported sample_size          efo  \
# 0                    Adolescent idiopathic scoliosis        2459  EFO_0005423
# 1  Tennis elbow / lateral epicondylitis | non-can...      361141  EFO_1001896
# 2  Tennis elbow / lateral epicondylitis | non-can...      361141  EFO_1001896
# 3  Tennis elbow / lateral epicondylitis | non-can...      361141  EFO_1001896
# 4  Tennis elbow / lateral epicondylitis | non-can...      361141  EFO_1001896
#
#   most_severe_csq  csq_arr most_severe_gene_csq  \
# 0            None     None   intergenic_variant
# 1            None     None   intergenic_variant
# 2            None     None   intergenic_variant
# 3            None     None   intergenic_variant
# 4            None     None   intergenic_variant
#
#                             consequence_link         rsid
# 0  http://purl.obolibrary.org/obo/SO_0001628     rs241215
# 1  http://purl.obolibrary.org/obo/SO_0001628  rs115071930
# 2  http://purl.obolibrary.org/obo/SO_0001628  rs115071930
# 3  http://purl.obolibrary.org/obo/SO_0001628  rs115071930
# 4  http://purl.obolibrary.org/obo/SO_0001628  rs115071930
#
# [5 rows x 23 columns]

# %%
row = df.iloc[1]
row
# Out:
# chrom                                                                   1
# pos                                                               7606620
# ref                                                                     C
# alt                                                                     T
# gene_id                                                   ENSG00000049246
# study_id                                                NEALE2_20002_1623
# y_proba_full_model                                              0.0516626
# pval_mantissa                                                     1.39165
# pval_exponent                                                          -8
# odds_ratio                                                        5.78457
# oddsr_ci_lower                                                    3.15483
# oddsr_ci_upper                                                    10.6063
# pmid
# pub_date                                                       2018-08-01
# pub_author                                                   UKB Neale v2
# trait_reported          Tennis elbow / lateral epicondylitis | non-can...
# sample_size                                                        361141
# efo                                                           EFO_1001896
# most_severe_csq                                                      None
# csq_arr                                                              None
# most_severe_gene_csq                                   intergenic_variant
# consequence_link                http://purl.obolibrary.org/obo/SO_0001628
# rsid                                                          rs115071930
# Name: 1, dtype: object

# %% [markdown]
# How the json schema looks like:
#
# ```json
# {
#   "properties": {
#     "datasourceId": {
#       "const": "ot_genetics_portal"
#     },
#     "confidenceIntervalLower": {
#       "$ref": "#/definitions/confidenceIntervalLower"
#     },
#     "confidenceIntervalUpper": {
#       "$ref": "#/definitions/confidenceIntervalUpper"
#     },
#     "datatypeId": {
#       "$ref": "#/definitions/datatypeId"
#     },
#     "diseaseFromSource": {
#       "$ref": "#/definitions/diseaseFromSource"
#     },
#     "diseaseFromSourceId": {
#       "$ref": "#/definitions/diseaseFromSourceId"
#     },
#     "diseaseId": {
#       "$ref": "#/definitions/diseaseId"
#     },
#     "literature": {
#       "$ref": "#/definitions/literature"
#     },
#     "oddsRatio": {
#       "$ref": "#/definitions/oddsRatio"
#     },
#     "pValueExponent": {
#       "$ref": "#/definitions/pValueExponent"
#     },
#     "pValueMantissa": {
#       "$ref": "#/definitions/pValueMantissa"
#     },
#     "publicationFirstAuthor": {
#       "$ref": "#/definitions/publicationFirstAuthor"
#     },
#     "publicationYear": {
#       "$ref": "#/definitions/publicationYear"
#     },
#     "resourceScore": {
#       "$ref": "#/definitions/resourceScore"
#     },
#     "studyId": {
#       "$ref": "#/definitions/studyId"
#     },
#     "studySampleSize": {
#       "$ref": "#/definitions/studySampleSize"
#     },
#     "targetFromSourceId": {
#       "$ref": "#/definitions/targetFromSourceId"
#     },
#     "variantFunctionalConsequenceId": {
#       "$ref": "#/definitions/variantFunctionalConsequenceId"
#     },
#     "variantId": {
#       "$ref": "#/definitions/variantId"
#     },
#     "variantRsId": {
#       "$ref": "#/definitions/variantRsId"
#     }
#   },
#   "required": [
#     "datasourceId",
#     "targetFromSourceId",
#     "diseaseId"
#   ],
#   "additionalProperties": false
# }
# ```
#
# The following fields are required for `ot_genetics_portal`:
# * `targetFromSourceId`: `gene_id`
# * `diseaseId`: `efo`
# * `datasourceId`: `ot_genetics_portal`
#
# The following fields are also provided:
# * `variantRsId`: `rsid`
# * `variantId`: `chrom`, `pos`, `alt`, `ref` concatenated into a single sting
# * etc.etc.

# %%
from datetime import datetime
import argparse
import os
import sys
import pyspark.sql
from pyspark.sql.types import *
from pyspark.sql.functions import *

global spark
spark = (pyspark.sql.SparkSession.builder.getOrCreate())
print('Spark version: ', spark.version)
# Out:
# Spark version:  3.0.0

# %%
df = (
    spark.read.parquet(ot_genetics_file)
    .withColumn('literature', when(col('pmid')!='', array(regexp_extract(col('pmid'), "PMID:(\d+)$",1))).otherwise(None))
    .select(
        lit('ot_genetics_portal').alias('datasourceId'),
        lit('genetic_association').alias('datatypeId'),
        col('gene_id').alias('targetFromSourceId'),
        col('efo').alias('diseaseFromSourceMappedId'),
        col('literature'),
        col('pub_author').alias('publicationFirstAuthor'),
        substring(col('pub_date'), 1, 4).cast(IntegerType()).alias('publicationYear'),
        col('trait_reported').alias('diseaseFromSource'),
        col('study_id').alias('studyId'),
        col('sample_size').alias('studySampleSize'),
        col('pval_mantissa').alias('pValueMantissa'),
        col('pval_exponent').alias('pValueExponent'),
        col('odds_ratio').alias('oddsRatio'),
        col('oddsr_ci_lower').alias('confidenceIntervalLower'),
        col('oddsr_ci_upper').alias('confidenceIntervalUpper'),
        col('y_proba_full_model').alias('resourceScore'),
        col('rsid').alias('variantRsId'),
        concat_ws('_', col('chrom'),col('pos'),col('alt'),col('ref')).alias('variantId'),
        regexp_extract(col('consequence_link'), "\/(SO.+)$",1).alias('variantFunctionalConsequenceId')
    )
    .orderBy(rand())
    .limit(500)
    .write.format('json').mode('overwrite').option("compression", "org.apache.hadoop.io.compress.GzipCodec")
    .save('cicaful3.json.gz')
)
#     .
# .write.format('json').save('cicaful2.json')

# %%
import warlock
import json

# %%
with open('/Users/dsuveges/repositories/json_schema/opentargets.json', 'r') as f:
    schema = json.load(f)

# %%
schema =   {"$schema": "http://json-schema.org/draft-07/schema#",
  "title": "OpenTargets",
  "type": "object",
  "oneOf": [
      {
          'properties':{
              
          }
      },
      {
          
      }
  ]
}

# %%
evidence = warlock.model_factory(schema)

# %%
sweden = evidence(datasourceId='ot_genetics_portal')
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# ~/opt/anaconda3/envs/jupyter/lib/python3.6/site-packages/warlock/model.py in validate(self, obj)
#     139             else:
# --> 140                 jsonschema.validate(obj, self.schema)
#     141         except jsonschema.ValidationError as exc:
#
# ~/opt/anaconda3/envs/jupyter/lib/python3.6/site-packages/jsonschema/validators.py in validate(instance, schema, cls, *args, **kwargs)
#     933     if error is not None:
# --> 934         raise error
#     935
#
# ValidationError: 'cancer_gene_census' was expected
#
# Failed validating 'const' in schema[0]['properties']['datasourceId']:
#     {'const': 'cancer_gene_census'}
#
# On instance['datasourceId']:
#     'ot_genetics_portal'
#
# During handling of the above exception, another exception occurred:
#
# ValidationError                           Traceback (most recent call last)
# ~/opt/anaconda3/envs/jupyter/lib/python3.6/site-packages/warlock/model.py in __init__(self, *args, **kwargs)
#      32         try:
# ---> 33             self.validate(d)
#      34         except exceptions.ValidationError as exc:
#
# ~/opt/anaconda3/envs/jupyter/lib/python3.6/site-packages/warlock/model.py in validate(self, obj)
#     141         except jsonschema.ValidationError as exc:
# --> 142             raise exceptions.ValidationError(str(exc))
#
# ValidationError: 'cancer_gene_census' was expected
#
# Failed validating 'const' in schema[0]['properties']['datasourceId']:
#     {'const': 'cancer_gene_census'}
#
# On instance['datasourceId']:
#     'ot_genetics_portal'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-145-664c298e3447> in <module>
# ----> 1 sweden = evidence(datasourceId='ot_genetics_portal')
#
# ~/opt/anaconda3/envs/jupyter/lib/python3.6/site-packages/warlock/core.py in __init__(self, *args, **kwargs)
#      33             self.__dict__["schema"] = schema
#      34             self.__dict__["resolver"] = resolver
# ---> 35             base_class.__init__(self, *args, **kwargs)
#      36
#      37     if resolver is not None:
#
# ~/opt/anaconda3/envs/jupyter/lib/python3.6/site-packages/warlock/model.py in __init__(self, *args, **kwargs)
#      33             self.validate(d)
#      34         except exceptions.ValidationError as exc:
# ---> 35             raise ValueError(str(exc))
#      36         else:
#      37             dict.__init__(self, d)
#
# ValueError: 'cancer_gene_census' was expected
#
# Failed validating 'const' in schema[0]['properties']['datasourceId']:
#     {'const': 'cancer_gene_census'}
#
# On instance['datasourceId']:
#     'ot_genetics_portal'
