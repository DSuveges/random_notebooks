# %% [markdown]
# # Fetch data

# %%
# %%bash
#
# wget https://archive.monarchinitiative.org/latest/tsv/gene_associations/gene_disease.9606.tsv.gz
# Out:
# --2021-05-18 17:57:19--  https://archive.monarchinitiative.org/latest/tsv/gene_associations/gene_disease.9606.tsv.gz
# Resolving archive.monarchinitiative.org (archive.monarchinitiative.org)... 128.193.83.101
# Connecting to archive.monarchinitiative.org (archive.monarchinitiative.org)|128.193.83.101|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 311041 (304K) [application/octet-stream]
# Saving to: ‘gene_disease.9606.tsv.gz’
#
#      0K .......... .......... .......... .......... .......... 16%  293K 1s
#     50K .......... .......... .......... .......... .......... 32%  320K 1s
#    100K .......... .......... .......... .......... .......... 49% 3.60M 0s
#    150K .......... .......... .......... .......... .......... 65%  549K 0s
#    200K .......... .......... .......... .......... .......... 82%  724K 0s
#    250K .......... .......... .......... .......... .......... 98% 5.68M 0s
#    300K ...                                                   100% 19.6M=0.5s
#
# 2021-05-18 17:57:20 (596 KB/s) - ‘gene_disease.9606.tsv.gz’ saved [311041/311041]

# %%
from pyspark.sql import SparkSession
import pyspark.sql.functions as F
from pyspark.sql.types import StringType, IntegerType, TimestampType, StructType, ArrayType

# establish spark connection
spark = (
    SparkSession.builder
    .getOrCreate()
)

orphanet_file = 'gene_disease.9606.tsv.gz'


orphanet_df = (
    spark.read.csv(orphanet_file,sep='\t', header=True)
    
    .withColumnRenamed('object', 'diseaseFromSourceId')
    .withColumnRenamed('object_label', 'diseaseFromSource')
    
    .withColumn('source', F.explode(F.split(F.col('is_defined_by'), '\|')))
    .withColumn('targetIdSource', F.split(F.col('subject'), ':').getItem(0))
    .withColumn('targetFromSourceId', F.split(F.col('subject'), ':').getItem(1))
    .withColumn('sourceId', F.lit('orphanet'))
    .withColumn('test_sources', get_sources(F.col('is_defined_by')))
    .filter(
        (F.col('source') == 'https://archive.monarchinitiative.org/#orphanet')
        & (F.col('subject_taxon_label') == 'Homo sapiens')
    )
    
    .drop(*['subject_taxon_label', 'subject', 'subject_taxon'])
    .persist()
)

orphanet_df.show(2, truncate=False, vertical=True)
# Out:
# -RECORD 0-----------------------------------------------------------------------------------------------------------
#  subject_label       | LOC111365204
#  diseaseFromSourceId | MONDO:0007630
#  diseaseFromSource   | North Carolina macular dystrophy
#  relation            | RO:0003303
#  relation_label      | causes condition
#  evidence            | ECO:0000322|ECO:0000220
#  evidence_label      | imported manually asserted information used in automatic assertion|sequencing assay evidence
#  source              | https://archive.monarchinitiative.org/#orphanet
#  is_defined_by       | https://archive.monarchinitiative.org/#omim|https://archive.monarchinitiative.org/#orphanet
#  qualifier           | direct
#  targetIdSource      | NCBIGene
#  targetFromSourceId  | 111365204
#  sourceId            | orphanet
#  test_sources        | [omim, orphanet]
# -RECORD 1-----------------------------------------------------------------------------------------------------------
#  subject_label       | ZBTB24
#  diseaseFromSourceId | MONDO:0000133
#  diseaseFromSource   | immunodeficiency-centromeric instability-facial anomalies syndrome
#  relation            | RO:0003304
#  relation_label      | contributes to condition
#  evidence            | ECO:0000322
#  evidence_label      | imported manually asserted information used in automatic assertion
#  source              | https://archive.monarchinitiative.org/#orphanet
#  is_defined_by       | https://archive.monarchinitiative.org/#omim|https://archive.monarchinitiative.org/#orphanet
#  qualifier           | direct
#  targetIdSource      | HGNC
#  targetFromSourceId  | 21143
#  sourceId            | orphanet
#  test_sources        | [omim, orphanet]
# only showing top 2 rows

# %%
orphanet_df.select('targetIdSource').distinct().show(30, truncate=False)
# Out:
# +--------------+
# |targetIdSource|
# +--------------+
# |NCBIGene      |
# |HGNC          |
# +--------------+

# %%
string = 'https://archive.monarchinitiative.org/#omim|https://archive.monarchinitiative.org/#orphanet'

get_sources = F.udf(
    lambda source: [ url.split('#')[1] if len(url.split('#')) > 1 else url for url in source.split('|')], 
    ArrayType(StringType())
)

# %%
get_link = F.udf(
    lambda x: eco_dicts.value[1][x],
    StringType()
)

# %% [markdown]
# # Changing strategy - get file from Orphanet directly

# %%
# %%bash
#
# wget http://www.orphadata.org/data/xml/en_product6.xml
# Out:
# --2021-05-19 18:46:35--  http://www.orphadata.org/data/xml/en_product6.xml
# Resolving www.orphadata.org (www.orphadata.org)... 194.167.41.5
# Connecting to www.orphadata.org (www.orphadata.org)|194.167.41.5|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 19436974 (19M) [text/xml]
# Saving to: ‘en_product6.xml’
#
#      0K .......... .......... .......... .......... ..........  0%  172K 1m50s
#     50K .......... .......... .......... .......... ..........  0%  280K 89s
#    100K .......... .......... .......... .......... ..........  0%  281K 81s
#    150K .......... .......... .......... .......... ..........  1%  332K 75s
#    200K .......... .......... .......... .......... ..........  1% 1.30M 63s
#    250K .......... .......... .......... .......... ..........  1%  355K 61s
#    300K .......... .......... .......... .......... ..........  1% 1.23M 54s
#    350K .......... .......... .......... .......... ..........  2%  363K 54s
#    400K .......... .......... .......... .......... ..........  2%  335K 54s
#    450K .......... .......... .......... .......... ..........  2% 2.08M 49s
#    500K .......... .......... .......... .......... ..........  2% 2.85M 45s
#    550K .......... .......... .......... .......... ..........  3%  359K 45s
#    600K .......... .......... .......... .......... ..........  3% 59.6M 42s
#    650K .......... .......... .......... .......... ..........  3% 1.18M 40s
#    700K .......... .......... .......... .......... ..........  3%  348K 41s
#    750K .......... .......... .......... .......... ..........  4% 65.8M 38s
#    800K .......... .......... .......... .......... ..........  4%  351K 39s
#    850K .......... .......... .......... .......... ..........  4% 25.5M 36s
#    900K .......... .......... .......... .......... ..........  5% 34.7M 34s
#    950K .......... .......... .......... .......... ..........  5%  138M 33s
#   1000K .......... .......... .......... .......... ..........  5%  282K 34s
#   1050K .......... .......... .......... .......... ..........  5% 17.8M 32s
#   1100K .......... .......... .......... .......... ..........  6%  680K 32s
#   1150K .......... .......... .......... .......... ..........  6% 1.03M 31s
#   1200K .......... .......... .......... .......... ..........  6%  179M 30s
#   1250K .......... .......... .......... .......... ..........  6%  195M 29s
#   1300K .......... .......... .......... .......... ..........  7% 10.0M 28s
#   1350K .......... .......... .......... .......... ..........  7%  163M 27s
#   1400K .......... .......... .......... .......... ..........  7%  159M 26s
#   1450K .......... .......... .......... .......... ..........  7% 1.13M 25s
#   1500K .......... .......... .......... .......... ..........  8% 1.13M 25s
#   1550K .......... .......... .......... .......... ..........  8% 3.42M 24s
#  18700K .......... .......... .......... .......... .......... 98% 2.41M 0s
#  18750K .......... .......... .......... .......... .......... 99% 3.47M 0s
#  18800K .......... .......... .......... .......... .......... 99% 1.83M 0s
#  18850K .......... .......... .......... .......... .......... 99% 3.08M 0s
#  18900K .......... .......... .......... .......... .......... 99% 2.36M 0s
#  18950K .......... .......... .......... .                    100% 3.94M=9.9s
#
# 2021-05-19 18:46:45 (1.88 MB/s) - ‘en_product6.xml’ saved [19436974/19436974]

# %%
import xml.etree.ElementTree as ET
tree = ET.parse('en_product6.xml')
root = tree.getroot()

# %%
orphanet_disorders = []

for disorder in root.find('DisorderList').findall('Disorder'):
    value = disorder.find('OrphaCode')
    
    parsed_disorder = {
        "diseaseFromSource": disorder.find('Name').text,
        "diseaseFromSourceId": disorder.find('OrphaCode').text,
        "type": disorder.find('DisorderType/Name').text,
    }
    
    for association in disorder.find('DisorderGeneAssociationList'):
        
        evidence = parsed_disorder.copy()
        try:
            evidence['literature'] = [pmid.replace('[PMID]','') for pmid in association.find('SourceOfValidation').text.split('_') if '[PMID]' in pmid]
        except AttributeError:
            evidence['literature'] = []
            
        evidence['associationType'] = association.find('DisorderGeneAssociationType/Name').text
        evidence['associationStatus'] = association.find('DisorderGeneAssociationStatus/Name').text
        
        # Parse gene name and id:
        gene = association.find('Gene')
        evidence['targetFromSource'] = gene.find('Name').text
        evidence['targetFromSourceIds'] = [xref.find('Reference').text for xref in gene.find('ExternalReferenceList') if 'ENSG' in xref.find('Reference').text]
        
        orphanet_disorders.append(evidence)
    
orphanet_df = pd.DataFrame(orphanet_disorders)
orphanet_df.head()
# Out:
#                                    diseaseFromSource diseaseFromSourceId  \
# 0      Multiple epiphyseal dysplasia, Al-Gazali type              166024
# 1                             Aspartylglucosaminuria                  93
# 2  Brachydactyly-short stature-retinitis pigmento...              166035
# 3                      Multiple sulfatase deficiency                 585
# 4                                  Beta-mannosidosis                 118
#
#                     type  literature                          associationType  \
# 0                Disease  [22587682]  Disease-causing germline mutation(s) in
# 1                Disease  [11309371]  Disease-causing germline mutation(s) in
# 2  Malformation syndrome  [28285769]  Disease-causing germline mutation(s) in
# 3                Disease  [17657823]  Disease-causing germline mutation(s) in
# 4                Disease  [18980795]  Disease-causing germline mutation(s) in
#
#   associationStatus                              targetFromSource  \
# 0          Assessed                       kinesin family member 7
# 1          Assessed                       aspartylglucosaminidase
# 2          Assessed  CWC27 spliceosome associated protein homolog
# 3          Assessed                  sulfatase modifying factor 1
# 4          Assessed                              mannosidase beta
#
#   targetFromSourceIds
# 0   [ENSG00000166813]
# 1   [ENSG00000038002]
# 2                  []
# 3   [ENSG00000144455]
# 4   [ENSG00000109323]

# %%
orphanet_df['type'].unique()
# Out:
# array(['Disease', 'Malformation syndrome', 'Clinical subtype',
#        'Etiological subtype', 'Morphological anomaly',
#        'Biological anomaly', 'Clinical syndrome',
#        'Particular clinical situation in a disease or syndrome',
#        'Histopathological subtype', 'Clinical group', 'Category'],
#       dtype=object)

# %%
orphanet_df.associationType.unique()
# Out:
# array(['Disease-causing germline mutation(s) in',
#        'Modifying germline mutation in', 'Major susceptibility factor in',
#        'Candidate gene tested in',
#        'Disease-causing germline mutation(s) (loss of function) in',
#        'Disease-causing somatic mutation(s) in',
#        'Disease-causing germline mutation(s) (gain of function) in',
#        'Role in the phenotype of', 'Part of a fusion gene in',
#        'Biomarker tested in'], dtype=object)

# %%
orphanet_df.associationStatus.value_counts()
# Out:
# Assessed            7377
# Not yet assessed     479
# Name: associationStatus, dtype: int64

# %%
orphanet_df.targetFromSourceIds.apply(lambda x: len(x)).value_counts()
# Out:
# 1    7803
# 0      53
# Name: targetFromSourceIds, dtype: int64

# %%
orphanet_df.literature.apply(lambda x: len(x)).value_counts()
# Out:
# 1    5199
# 2    1412
# 0     821
# 3     301
# 4      71
# 5      28
# 6      16
# 7       8
# Name: literature, dtype: int64

# %%
assert isinstance(root, ET.Element)

# %%
root.find('DisorderList').get('count')
# Out:
# '3845'

# %%
len(orphanet_df.diseaseFromSourceId.unique())
# Out:
# 3845

# %%
len(orphanet_df.loc[lambda df: df['targetFromSourceIds'].apply(lambda x: len(x)==0)])
# Out:
# 53

# %%
orphanet_df['targetFromSourceIds']
# Out:
# 0       [ENSG00000166813]
# 1       [ENSG00000038002]
# 2                      []
# 3       [ENSG00000144455]
# 4       [ENSG00000109323]
#               ...
# 7851    [ENSG00000152591]
# 7852    [ENSG00000158055]
# 7853    [ENSG00000170315]
# 7854    [ENSG00000170315]
# 7855    [ENSG00000158055]
# Name: targetFromSourceIds, Length: 7856, dtype: object

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://c02zq14flvdn:4045">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.0.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>pyspark-shell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
from pyspark import SparkContext

orphanet_json = SparkContext.parallelize(orphanet_disorders)
# orphanet_df = sqlContext.read.json(orphanet_json)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-162-063702dd434f> in <module>
#       1 from pyspark import SparkContext
#       2
# ----> 3 orphanet_json = SparkContext.parallelize(orphanet_disorders)
#       4 # orphanet_df = sqlContext.read.json(orphanet_json)
#
# TypeError: parallelize() missing 1 required positional argument: 'c'

# %%
from pyspark.sql import Row
spark.createDataFrame(Row(**x) for x in orphanet_disorders).show(2, truncate=False, vertical=True)
# Out:
# -RECORD 0------------------------------------------------------------
#  diseaseFromSource   | Multiple epiphyseal dysplasia, Al-Gazali type
#  diseaseFromSourceId | 166024
#  type                | Disease
#  literature          | [22587682]
#  associationType     | Disease-causing germline mutation(s) in
#  associationStatus   | Assessed
#  targetFromSource    | kinesin family member 7
#  targetFromSourceIds | [ENSG00000166813]
# -RECORD 1------------------------------------------------------------
#  diseaseFromSource   | Aspartylglucosaminuria
#  diseaseFromSourceId | 93
#  type                | Disease
#  literature          | [11309371]
#  associationType     | Disease-causing germline mutation(s) in
#  associationStatus   | Assessed
#  targetFromSource    | aspartylglucosaminidase
#  targetFromSourceIds | [ENSG00000038002]
# only showing top 2 rows

# %%
cicaful = [
    {
        "pocok": 31,
        "kutya": "csicseriborso",
        "bablencse": ['ingyom', 'bingyom']
    },
    {
        "pocok": 2324,
        "kutya": "fsdklmsdfkl",
        "bablencse": []
    }
]

(
    spark.createDataFrame(Row(**x) for x in cicaful)
#     .withColumn('cicaful', F.explode(F.col('bablencse')))
    .select('pocok','kutya', F.explode_outer(F.col('bablencse')))
    .show()
)
# Out:
# +-----+-------------+-------+
# |pocok|        kutya|    col|
# +-----+-------------+-------+
# |   31|csicseriborso| ingyom|
# |   31|csicseriborso|bingyom|
# | 2324|  fsdklmsdfkl|   null|
# +-----+-------------+-------+

# %%
import logging 

def parserOrphanetXml(orphanet_file: str) -> list:
    '''
    Function to parse Orphanet xml dump and return the parsed
    data as a pandas dataframe.

    Args:
        orphanet_file (str): Orphanet XML filename

    Returns:
        parsed data as a list of dictionary
    '''

    # Reading + validating xml:
    tree = ET.parse(orphanet_file)
    assert isinstance(tree, ET.ElementTree)

    root = tree.getroot()
    assert isinstance(root, ET.Element)

    # Checking if the basic nodes are in the xml structure:

    logging.info(f"There are {root.find('DisorderList').get('count')} disease in the Orphanet xml file.")

    orphanet_disorders = []

    for disorder in root.find('DisorderList').findall('Disorder'):

        # Extracting disease information:
        parsed_disorder = {
            "diseaseFromSource": disorder.find('Name').text,
            "diseaseFromSourceId": 'Orphanet_' + disorder.find('OrphaCode').text,
            "type": disorder.find('DisorderType/Name').text,
        }

        # One disease might be mapped to multiple genes:
        for association in disorder.find('DisorderGeneAssociationList'):

            # For each mapped genes, an evidence is created:
            evidence = parsed_disorder.copy()

            # Not all gene/disease association is backed up by publication:
            try:
                evidence['literature'] = [pmid.replace('[PMID]', '') for pmid in association.find('SourceOfValidation').text.split('_') if '[PMID]' in pmid]
            except AttributeError:
                evidence['literature'] = None

            evidence['associationType'] = association.find('DisorderGeneAssociationType/Name').text
            evidence['associationStatus'] = association.find('DisorderGeneAssociationStatus/Name').text

            # Parse gene name and id - going for Ensembl gene id only:
            gene = association.find('Gene')
            evidence['targetFromSource'] = gene.find('Name').text
            
            # Extracting ensembl gene id from cross references:
            ensembl_gene_id = [xref.find('Reference').text for xref in gene.find('ExternalReferenceList') if 'ENSG' in xref.find('Reference').text]
            evidence['targetFromSourceId'] = ensembl_gene_id[0] if len(ensembl_gene_id) > 0 else None

            # Collect evidence:
            orphanet_disorders.append(evidence)

    return orphanet_disorders


pod = parserOrphanetXml('en_product6.xml')
len(pod)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-609d150e1b72> in <module>
#      64
#      65
# ---> 66 pod = parserOrphanetXml('en_product6.xml')
#      67 len(pod)
#
# <ipython-input-2-609d150e1b72> in parserOrphanetXml(orphanet_file)
#      14
#      15     # Reading + validating xml:
# ---> 16     tree = ET.parse(orphanet_file)
#      17     assert isinstance(tree, ET.ElementTree)
#      18
#
# NameError: name 'ET' is not defined

# %%
import argparse
import logging
import sys
import time

import xml.etree.ElementTree as ET
from pyspark.conf import SparkConf
from pyspark.sql import SparkSession, Row
from pyspark.sql.types import StringType
import pyspark.sql.functions as F

from ontoma import OnToma

# establish spark connection
spark = (
    SparkSession.builder
    .getOrCreate()
)


input_file = 'en_product6.xml'
orphanet_disorders = parserOrphanetXml(input_file)
orphanet_df = (
    spark.createDataFrame(Row(**x) for x in orphanet_disorders)
    # Exploding
    .withColumn('dataSourceId', F.lit('orphanet'))
    .withColumn('datatypeId', F.lit('genetic_association'))
    .persist()
)

# %%
class ontoma_efo_lookup():
    '''
    Simple class to map orphanet ids to efo
    '''
    def __init__(self):
        self.otmap = OnToma()

    def get_mapping(self, disease_lable, disease_id):

        mappings = self.query_ontoma(disease_id)

        if mappings and 'EFO' in mappings['source']:
            return mappings['term'].split('/')[-1]
        else:
            mappings = self.query_ontoma(disease_id)

        if mappings and 'EFO' in mappings['source']:
            return mappings['term'].split('/')[-1]
        else:
            return None

    def query_ontoma(self, term):

        try:
            mappings = self.otmap.find_term(term, verbose=True)
        except Exception:
            time.sleep(3)
            mappings = self.otmap.find_term(term, verbose=True)

        return mappings

ol = ontoma_efo_lookup()
ont_udf = F.udf(ol.get_mapping, StringType())
# Out:
# INFO     - ontoma.downloaders - ZOOMA to EFO mappings - Parsed 3663 rows
# INFO:ontoma.downloaders:ZOOMA to EFO mappings - Parsed 3663 rows
# INFO     - ontoma.downloaders - OMIM to EFO mappings - Parsed 8561 rows
# INFO:ontoma.downloaders:OMIM to EFO mappings - Parsed 8561 rows

# %%
# (
#     orphanet_df
#     .select('diseaseFromSourceId', 'diseaseFromSource')
#     .limit(100)
#     .withColumn('test_mapping', ont_udf(F.col('diseaseFromSourceId')))
#     .show(truncate=False)
# )

ol.get_mapping('Multiple epiphyseal dysplasia, Al-Gazali type', 'Orphanet_166024')
# Out:
# INFO     - ontoma.interface - EFO OBO parsed. Size: 26965 nodes
# INFO:ontoma.interface:EFO OBO parsed. Size: 26965 nodes
# INFO     - ontoma.interface - Parsed 125228 Name to EFO mapping
# INFO:ontoma.interface:Parsed 125228 Name to EFO mapping
# INFO     - ontoma.interface - Found http://www.orpha.net/ORDO/Orphanet_166024 for Orphanet_166024 from OLS API EFO lookup - match - None
# INFO:ontoma.interface:Found http://www.orpha.net/ORDO/Orphanet_166024 for Orphanet_166024 from OLS API EFO lookup - match - None
# 'Orphanet_166024'

# %%
(
    orphanet_df
    .select('diseaseFromSourceId')
    .distinct()
    .limit(10)
    .withColumn('test_mapping', ont_udf(F.col('diseaseFromSourceId')))
    .show(truncate=False)
)
# Out:
# +-------------------+---------------+
# |diseaseFromSourceId|test_mapping   |
# +-------------------+---------------+
# |Orphanet_640       |Orphanet_640   |
# |Orphanet_157716    |Orphanet_157716|
# |Orphanet_1766      |Orphanet_1766  |
# |Orphanet_2067      |Orphanet_2067  |
# |Orphanet_251663    |null           |
# |Orphanet_250977    |Orphanet_250977|
# |Orphanet_221046    |Orphanet_221046|
# |Orphanet_320401    |Orphanet_320401|
# |Orphanet_369852    |Orphanet_369852|
# |Orphanet_363540    |Orphanet_363540|
# +-------------------+---------------+

# %%
orphanet_df.groupby('type').count().sort('count').show(truncate=False)
# Out:
# +------------------------------------------------------+-----+
# |type                                                  |count|
# +------------------------------------------------------+-----+
# |Category                                              |1    |
# |Particular clinical situation in a disease or syndrome|4    |
# |Biological anomaly                                    |11   |
# |Clinical group                                        |12   |
# |Clinical syndrome                                     |39   |
# |Histopathological subtype                             |69   |
# |Morphological anomaly                                 |233  |
# |Etiological subtype                                   |504  |
# |Clinical subtype                                      |1058 |
# |Malformation syndrome                                 |1286 |
# |Disease                                               |4639 |
# +------------------------------------------------------+-----+

# %%
orphanet_df.groupby('associationType').count().sort('count').show(truncate=False)
# Out:
# +----------------------------------------------------------+-----+
# |associationType                                           |count|
# +----------------------------------------------------------+-----+
# |Modifying germline mutation in                            |44   |
# |Biomarker tested in                                       |47   |
# |Disease-causing somatic mutation(s) in                    |197  |
# |Disease-causing germline mutation(s) (gain of function) in|210  |
# |Part of a fusion gene in                                  |232  |
# |Role in the phenotype of                                  |233  |
# |Candidate gene tested in                                  |372  |
# |Major susceptibility factor in                            |572  |
# |Disease-causing germline mutation(s) (loss of function) in|1141 |
# |Disease-causing germline mutation(s) in                   |4808 |
# +----------------------------------------------------------+-----+

# %% [markdown]
# ## Cicaful
#
#
# |types                                    |
# |:------------------------------------------------------|
# |Biological anomaly                                    |
# |Particular clinical situation in a disease or syndrome|
# |Disease                                               |
# |Category                                              |
# |Malformation syndrome                                 |
# |Clinical group                                        |
# |Clinical syndrome                                     |
# |Histopathological subtype                             |
# |Clinical subtype                                      |
# |Etiological subtype                                   |
# |Morphological anomaly                                 |

# %%
(
    orphanet_df
    .groupby('targetFromSourceId', 'diseaseFromSourceId')
    .agg(
        F.count('targetFromSourceId').alias('count'),
        F.collect_set(F.col('associationType')).alias('associationType'),
        F.collect_set(F.col('associationStatus')).alias('associationType'),
        F.collect_set(F.col('type')).alias('type'),
        F.collect_set(F.col('diseaseFromSource')).alias('diseaseFromSource'),
    )
    .filter(F.col('count') > 1)
    .show(40, vertical=True, truncate=False)
)
# Out:
# -RECORD 0---------------------------------------------------------------------------------------------------------------------------------------
#  targetFromSourceId  | ENSG00000170175
#  diseaseFromSourceId | Orphanet_98913
#  count               | 2
#  associationType     | [Disease-causing germline mutation(s) (gain of function) in, Disease-causing germline mutation(s) (loss of function) in]
#  associationType     | [Assessed]
#  type                | [Etiological subtype]
#  diseaseFromSource   | [Postsynaptic congenital myasthenic syndromes]
# -RECORD 1---------------------------------------------------------------------------------------------------------------------------------------
#  targetFromSourceId  | ENSG00000184058
#  diseaseFromSourceId | Orphanet_567
#  count               | 2
#  associationType     | [Role in the phenotype of, Disease-causing germline mutation(s) in]
#  associationType     | [Assessed]
#  type                | [Malformation syndrome]
#  diseaseFromSource   | [22q11.2 deletion syndrome]
# -RECORD 2---------------------------------------------------------------------------------------------------------------------------------------
#  targetFromSourceId  | ENSG00000101935
#  diseaseFromSourceId | Orphanet_86818
#  count               | 2
#  associationType     | [Role in the phenotype of, Disease-causing germline mutation(s) in]
#  associationType     | [Assessed]
#  type                | [Disease]
#  diseaseFromSource   | [Alport syndrome-intellectual disability-midface hypoplasia-elliptocytosis syndrome]
# -RECORD 3---------------------------------------------------------------------------------------------------------------------------------------
#  targetFromSourceId  | ENSG00000137745
#  diseaseFromSourceId | Orphanet_1040
#  count               | 2
#  associationType     | [Disease-causing germline mutation(s) (gain of function) in, Disease-causing germline mutation(s) (loss of function) in]
#  associationType     | [Assessed]
#  type                | [Disease]
#  diseaseFromSource   | [Metaphyseal anadysplasia]
# -RECORD 4---------------------------------------------------------------------------------------------------------------------------------------
#  targetFromSourceId  | ENSG00000164093
#  diseaseFromSourceId | Orphanet_782
#  count               | 2
#  associationType     | [Disease-causing germline mutation(s) (gain of function) in, Disease-causing germline mutation(s) (loss of function) in]
#  associationType     | [Assessed]
#  type                | [Malformation syndrome]
#  diseaseFromSource   | [Axenfeld-Rieger syndrome]
# -RECORD 5---------------------------------------------------------------------------------------------------------------------------------------
#  targetFromSourceId  | ENSG00000157764
#  diseaseFromSourceId | Orphanet_251615
#  count               | 2
#  associationType     | [Part of a fusion gene in, Disease-causing somatic mutation(s) in]
#  associationType     | [Assessed]
#  type                | [Histopathological subtype]
#  diseaseFromSource   | [Pilomyxoid astrocytoma]
# -RECORD 6---------------------------------------------------------------------------------------------------------------------------------------
#  targetFromSourceId  | ENSG00000090006
#  diseaseFromSourceId | Orphanet_221145
#  count               | 2
#  associationType     | [Disease-causing germline mutation(s) (gain of function) in, Disease-causing germline mutation(s) (loss of function) in]
#  associationType     | [Assessed]
#  type                | [Malformation syndrome]
#  diseaseFromSource   | [Cutis laxa with severe pulmonary, gastrointestinal and urinary anomalies]
# -RECORD 7---------------------------------------------------------------------------------------------------------------------------------------
#  targetFromSourceId  | ENSG00000026103
#  diseaseFromSourceId | Orphanet_3261
#  count               | 2
#  associationType     | [Disease-causing somatic mutation(s) in, Disease-causing germline mutation(s) in]
#  associationType     | [Assessed]
#  type                | [Disease]
#  diseaseFromSource   | [Autoimmune lymphoproliferative syndrome]
# -RECORD 8---------------------------------------------------------------------------------------------------------------------------------------
#  targetFromSourceId  | ENSG00000138449
#  diseaseFromSourceId | Orphanet_139491
#  count               | 2
#  associationType     | [Disease-causing germline mutation(s) (gain of function) in, Disease-causing germline mutation(s) (loss of function) in]
#  associationType     | [Assessed]
#  type                | [Disease]
#  diseaseFromSource   | [Hemochromatosis type 4]
# -RECORD 9---------------------------------------------------------------------------------------------------------------------------------------
#  targetFromSourceId  | ENSG00000164532
#  diseaseFromSourceId | Orphanet_99103
#  count               | 2
#  associationType     | [Disease-causing germline mutation(s) (gain of function) in, Disease-causing germline mutation(s) (loss of function) in]
#  associationType     | [Assessed]
#  type                | [Clinical subtype]
#  diseaseFromSource   | [Atrial septal defect, ostium secundum type]
# -RECORD 10--------------------------------------------------------------------------------------------------------------------------------------
#  targetFromSourceId  | ENSG00000108556
#  diseaseFromSourceId | Orphanet_98913
#  count               | 2
#  associationType     | [Disease-causing germline mutation(s) (gain of function) in, Disease-causing germline mutation(s) (loss of function) in]
#  associationType     | [Assessed]
#  type                | [Etiological subtype]
#  diseaseFromSource   | [Postsynaptic congenital myasthenic syndromes]
# -RECORD 11--------------------------------------------------------------------------------------------------------------------------------------
#  targetFromSourceId  | ENSG00000196092
#  diseaseFromSourceId | Orphanet_99860
#  count               | 2
#  associationType     | [Major susceptibility factor in, Part of a fusion gene in]
#  associationType     | [Assessed]
#  type                | [Disease]
#  diseaseFromSource   | [Precursor B-cell acute lymphoblastic leukemia]
# -RECORD 12--------------------------------------------------------------------------------------------------------------------------------------
#  targetFromSourceId  | ENSG00000163492
#  diseaseFromSourceId | Orphanet_478
#  count               | 2
#  associationType     | [Major susceptibility factor in, Disease-causing germline mutation(s) in]
#  associationType     | [Assessed]
#  type                | [Clinical subtype]
#  diseaseFromSource   | [Kallmann syndrome]
# -RECORD 13--------------------------------------------------------------------------------------------------------------------------------------
#  targetFromSourceId  | ENSG00000239697
#  diseaseFromSourceId | Orphanet_1572
#  count               | 2
#  associationType     | [Disease-causing germline mutation(s) (gain of function) in, Disease-causing germline mutation(s) (loss of function) in]
#  associationType     | [Assessed]
#  type                | [Disease]
#  diseaseFromSource   | [Common variable immunodeficiency]
# -RECORD 14--------------------------------------------------------------------------------------------------------------------------------------
#  targetFromSourceId  | ENSG00000186487
#  diseaseFromSourceId | Orphanet_528084
#  count               | 2
#  associationType     | [Role in the phenotype of, Disease-causing germline mutation(s) in]
#  associationType     | [Assessed]
#  type                | [Disease]
#  diseaseFromSource   | [Non-specific syndromic intellectual disability]
# -RECORD 15--------------------------------------------------------------------------------------------------------------------------------------
#  targetFromSourceId  | ENSG00000116001
#  diseaseFromSourceId | Orphanet_603
#  count               | 2
#  associationType     | [Disease-causing germline mutation(s) (gain of function) in, Modifying germline mutation in]
#  associationType     | [Assessed]
#  type                | [Disease]
#  diseaseFromSource   | [Distal myopathy, Welander type]
# -RECORD 16--------------------------------------------------------------------------------------------------------------------------------------
#  targetFromSourceId  | ENSG00000196628
#  diseaseFromSourceId | Orphanet_2896
#  count               | 2
#  associationType     | [Disease-causing germline mutation(s) (loss of function) in, Role in the phenotype of]
#  associationType     | [Assessed]
#  type                | [Malformation syndrome]
#  diseaseFromSource   | [Pitt-Hopkins syndrome]
# -RECORD 17--------------------------------------------------------------------------------------------------------------------------------------
#  targetFromSourceId  | ENSG00000138435
#  diseaseFromSourceId | Orphanet_98913
#  count               | 2
#  associationType     | [Disease-causing germline mutation(s) (gain of function) in, Disease-causing germline mutation(s) (loss of function) in]
#  associationType     | [Assessed]
#  type                | [Etiological subtype]
#  diseaseFromSource   | [Postsynaptic congenital myasthenic syndromes]
# -RECORD 18--------------------------------------------------------------------------------------------------------------------------------------
#  targetFromSourceId  | ENSG00000108557
#  diseaseFromSourceId | Orphanet_819
#  count               | 2
#  associationType     | [Role in the phenotype of, Disease-causing germline mutation(s) in]
#  associationType     | [Assessed]
#  type                | [Malformation syndrome]
#  diseaseFromSource   | [Smith-Magenis syndrome]
# -RECORD 19--------------------------------------------------------------------------------------------------------------------------------------
#  targetFromSourceId  | ENSG00000177301
#  diseaseFromSourceId | Orphanet_442835
#  count               | 2
#  associationType     | [Disease-causing germline mutation(s) (gain of function) in, Disease-causing germline mutation(s) (loss of function) in]
#  associationType     | [Assessed]
#  type                | [Disease]
#  diseaseFromSource   | [Non-specific early-onset epileptic encephalopathy]
# -RECORD 20--------------------------------------------------------------------------------------------------------------------------------------
#  targetFromSourceId  | ENSG00000184937
#  diseaseFromSourceId | Orphanet_654
#  count               | 2
#  associationType     | [Major susceptibility factor in, Disease-causing somatic mutation(s) in]
#  associationType     | [Assessed]
#  type                | [Disease]
#  diseaseFromSource   | [Nephroblastoma]
# -RECORD 21--------------------------------------------------------------------------------------------------------------------------------------
#  targetFromSourceId  | ENSG00000157404
#  diseaseFromSourceId | Orphanet_44890
#  count               | 2
#  associationType     | [Disease-causing germline mutation(s) (gain of function) in, Disease-causing somatic mutation(s) in]
#  associationType     | [Assessed]
#  type                | [Disease]
#  diseaseFromSource   | [Gastrointestinal stromal tumor]
# -RECORD 22--------------------------------------------------------------------------------------------------------------------------------------
#  targetFromSourceId  | ENSG00000162337
#  diseaseFromSourceId | Orphanet_498481
#  count               | 2
#  associationType     | [Major susceptibility factor in, Disease-causing germline mutation(s) in]
#  associationType     | [Assessed]
#  type                | [Malformation syndrome]
#  diseaseFromSource   | [LRP5-related primary osteoporosis]
# -RECORD 23--------------------------------------------------------------------------------------------------------------------------------------
#  targetFromSourceId  | ENSG00000163930
#  diseaseFromSourceId | Orphanet_2495
#  count               | 2
#  associationType     | [Disease-causing somatic mutation(s) in, Disease-causing germline mutation(s) in]
#  associationType     | [Assessed]
#  type                | [Disease]
#  diseaseFromSource   | [Meningioma]
# -RECORD 24--------------------------------------------------------------------------------------------------------------------------------------
#  targetFromSourceId  | ENSG00000135902
#  diseaseFromSourceId | Orphanet_98913
#  count               | 2
#  associationType     | [Disease-causing germline mutation(s) (gain of function) in, Disease-causing germline mutation(s) (loss of function) in]
#  associationType     | [Assessed]
#  type                | [Etiological subtype]
#  diseaseFromSource   | [Postsynaptic congenital myasthenic syndromes]
# -RECORD 25--------------------------------------------------------------------------------------------------------------------------------------
#  targetFromSourceId  | ENSG00000134323
#  diseaseFromSourceId | Orphanet_391641
#  count               | 2
#  associationType     | [Role in the phenotype of, Disease-causing germline mutation(s) in]
#  associationType     | [Assessed]
#  type                | [Clinical subtype]
#  diseaseFromSource   | [Feingold syndrome type 1]
# -RECORD 26--------------------------------------------------------------------------------------------------------------------------------------
#  targetFromSourceId  | ENSG00000130726
#  diseaseFromSourceId | Orphanet_654
#  count               | 2
#  associationType     | [Disease-causing somatic mutation(s) in, Disease-causing germline mutation(s) in]
#  associationType     | [Assessed]
#  type                | [Disease]
#  diseaseFromSource   | [Nephroblastoma]
# -RECORD 27--------------------------------------------------------------------------------------------------------------------------------------
#  targetFromSourceId  | ENSG00000105647
#  diseaseFromSourceId | Orphanet_83473
#  count               | 2
#  associationType     | [Disease-causing somatic mutation(s) in, Disease-causing germline mutation(s) in]
#  associationType     | [Assessed]
#  type                | [Malformation syndrome]
#  diseaseFromSource   | [Megalencephaly-polymicrogyria-postaxial polydactyly-hydrocephalus syndrome]
# -RECORD 28--------------------------------------------------------------------------------------------------------------------------------------
#  targetFromSourceId  | ENSG00000109099
#  diseaseFromSourceId | Orphanet_640
#  count               | 2
#  associationType     | [Role in the phenotype of, Disease-causing germline mutation(s) in]
#  associationType     | [Assessed]
#  type                | [Malformation syndrome]
#  diseaseFromSource   | [Hereditary neuropathy with liability to pressure palsies]
# -RECORD 29--------------------------------------------------------------------------------------------------------------------------------------
#  targetFromSourceId  | ENSG00000171094
#  diseaseFromSourceId | Orphanet_635
#  count               | 2
#  associationType     | [Major susceptibility factor in, Disease-causing somatic mutation(s) in]
#  associationType     | [Assessed]
#  type                | [Disease]
#  diseaseFromSource   | [Neuroblastoma]
# -RECORD 30--------------------------------------------------------------------------------------------------------------------------------------
#  targetFromSourceId  | ENSG00000101596
#  diseaseFromSourceId | Orphanet_269
#  count               | 2
#  associationType     | [Modifying germline mutation in, Disease-causing germline mutation(s) in]
#  associationType     | [Assessed]
#  type                | [Disease]
#  diseaseFromSource   | [Facioscapulohumeral dystrophy]
# -RECORD 31--------------------------------------------------------------------------------------------------------------------------------------
#  targetFromSourceId  | ENSG00000141510
#  diseaseFromSourceId | Orphanet_668
#  count               | 2
#  associationType     | [Disease-causing somatic mutation(s) in, Disease-causing germline mutation(s) in]
#  associationType     | [Assessed]
#  type                | [Disease]
#  diseaseFromSource   | [Osteosarcoma]
# -RECORD 32--------------------------------------------------------------------------------------------------------------------------------------
#  targetFromSourceId  | ENSG00000087086
#  diseaseFromSourceId | Orphanet_440731
#  count               | 2
#  associationType     | [Disease-causing germline mutation(s) (gain of function) in, Disease-causing germline mutation(s) (loss of function) in]
#  associationType     | [Assessed]
#  type                | [Biological anomaly]
#  diseaseFromSource   | [L-ferritin deficiency]
# -RECORD 33--------------------------------------------------------------------------------------------------------------------------------------
#  targetFromSourceId  | ENSG00000055208
#  diseaseFromSourceId | Orphanet_228410
#  count               | 2
#  associationType     | [Role in the phenotype of, Disease-causing germline mutation(s) in]
#  associationType     | [Assessed]
#  type                | [Malformation syndrome]
#  diseaseFromSource   | [Polyvalvular heart disease syndrome]
# -RECORD 34--------------------------------------------------------------------------------------------------------------------------------------
#  targetFromSourceId  | ENSG00000163930
#  diseaseFromSourceId | Orphanet_39044
#  count               | 2
#  associationType     | [Disease-causing somatic mutation(s) in, Disease-causing germline mutation(s) in]
#  associationType     | [Assessed]
#  type                | [Disease]
#  diseaseFromSource   | [Uveal melanoma]

# %%
orphanet_df.printSchema()
# Out:
# root
#  |-- diseaseFromSource: string (nullable = true)
#  |-- diseaseFromSourceId: string (nullable = true)
#  |-- type: string (nullable = true)
#  |-- literature: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- associationType: string (nullable = true)
#  |-- associationStatus: string (nullable = true)
#  |-- targetFromSource: string (nullable = true)
#  |-- targetFromSourceId: string (nullable = true)
#  |-- dataSourceId: string (nullable = false)
#  |-- datatypeId: string (nullable = false)

# %%
orphanet_df.select('associationType').distinct().show(truncate=False)
# Out:
# +----------------------------------------------------------+
# |associationType                                           |
# +----------------------------------------------------------+
# |Major susceptibility factor in                            |
# |Disease-causing germline mutation(s) (loss of function) in|
# |Part of a fusion gene in                                  |
# |Candidate gene tested in                                  |
# |Role in the phenotype of                                  |
# |Biomarker tested in                                       |
# |Disease-causing germline mutation(s) in                   |
# |Modifying germline mutation in                            |
# |Disease-causing somatic mutation(s) in                    |
# |Disease-causing germline mutation(s) (gain of function) in|
# +----------------------------------------------------------+
