# %% [markdown]
# # HUMSAVAR
#
#
# **Exploring the HUMSAVAR dataset**
#
# * Getting basic stats: evidence count, association count, target count, disease count
# * Comparing with the existing Uniprot evidence set: overlap by association.
#
# #### Acquiring dataset:
#
# * Downloading humsavar from `https://www.uniprot.org/docs/humsavar.txt` load as pyspark dataframe.
# * Downloading the original uniprot evidence set from:
#
# ### Basic stats
#
# * Number of evidence: 80,129
# * Number of evidence with no uniprot identifier: 0
# * Number of evidence with no genes: 27 (discrepancy between gene and uniprot annotation)
#
# * Number of evidence with no disease annotation: 41,354 (with 11,855 genes)
# * Number of evidence disease annotation: 38775
#
# * Number of associations: 6318. genes: 4190, diseases: 4529
# * Number of associations with MIM : 4002. genes: 2914, diseases: 3843
#
# ## Humsavar vs uniprot evidence
#
# #### Acquiring dataset:
#
# Dataset downloaded from `gs://otar011-uniprot/cttv011-11-10-2021.json.gz`
#
# ### Comparison
#
#
# #### Approach 1:
#
# To compare the two datasets, I only considered associations. The humsavar dataset was filtered for entries with OMIM identifiers, I made no attempt to map the dieseases to EFO. The uniprot evidence set was joined with humsavar dataset by `omim` disease identifier AND `uniprot` target identifiers (the uniprot evidence set has OMIM identifier in the `diseaseFromSourceId` field).
#
# Out of the 4002 unique association from humsavar 3815 was found in the Uniprot dataset. It suggests humsavar is a subset of the uniprot dataset. The 187 missing associations are comprised of 123 distinct diseases (from which 3 was not found in Uniprot dataset), and 182 distinct targets (from which 159 was not found in the uniprot dataset.)
#
# **Conclusion**:
#
# I think the humsavar dataset is likely a subset of the curated evidence set curated by Uniprot due to the large overlap. However some of the evidence in the humsavar dataset has no disease annotation at all, indicating it might be generated automatically by parsing Uniprot entires.
#
# #### Approach 2
#
# Given one third of the diseases have no OMIM identifiers, we should try to map those diseases to EFO then try to join with the uniprot evidence set.
#
# 1. Extract evidence from humsavar dataset where no OMIM identifiers availabe.
# 2. Generate associations.
# 3. Map diseases to EFO.
# 4. Join with Uniprot evidence based on uniprot id and EFO id.
#
# **Conclusion**:

# %%
# %%bash
#
# gsutil cp -r gs://otar011-uniprot/cttv011-11-10-2021.json.gz .
#
# ls -lah
#
# gzcat cttv011-11-10-2021.json.gz | head -n1 | jq
# Out:
# total 32216
# drwxr-xr-x   7 dsuveges  384566875   224B 21 Dec 23:37 .
# drwxrwxr-x  65 dsuveges  384566875   2.0K 20 Dec 22:33 ..
# drwxr-xr-x   3 dsuveges  384566875    96B 20 Dec 22:33 .ipynb_checkpoints
# -rw-r--r--   1 dsuveges  384566875    55K 21 Dec 23:36 Untitled.ipynb
# -rw-r--r--   1 dsuveges  384566875   703K 21 Dec 23:37 cttv011-11-10-2021.json.gz
# -rw-r--r--   1 dsuveges  384566875   7.5M 29 Sep 01:00 humsavar-2021-12-20.txt
# -rw-r--r--   1 dsuveges  384566875   7.5M 21 Dec 00:26 humsavar.txt
# {
#   "datasourceId": "uniprot_literature",
#   "datatypeId": "genetic_literature",
#   "diseaseFromSource": "Ectodermal dysplasia and immunodeficiency 1",
#   "diseaseFromSourceId": "OMIM:300291",
#   "confidence": "high",
#   "diseaseFromSourceMappedId": "MONDO_0020740",
#   "literature": [
#     "21606507",
#     "16547522",
#     "11224521",
#     "14651848",
#     "19185524",
#     "11242109",
#     "11047757",
#     "15100680",
#     "12045264"
#   ],
#   "targetFromSourceId": "Q9Y6K9",
#   "targetModulation": "up_or_down"
# }
# Copying gs://otar011-uniprot/cttv011-11-10-2021.json.gz...
# - [1 files][702.7 KiB/702.7 KiB]
# Operation completed over 1 objects/702.7 KiB.

# %%
# %%bash
#
# # Fetching data from uniprot:
# # wget https://www.uniprot.org/docs/humsavar.txt -O humsavar-2021-12-20.txt
# wc -l humsavar-2021-12-20.txt
#
# head -47 humsavar-2021-12-20.txt
# echo "... 80k sor.."
# tail -15 humsavar-2021-12-20.txt
# Out:
#    80179 humsavar-2021-12-20.txt
# --------------------------------------------------------------------------------
#         UniProt - Swiss-Prot Protein Knowledgebase
#         SIB Swiss Institute of Bioinformatics; Geneva, Switzerland
#         European Bioinformatics Institute (EBI); Hinxton, United Kingdom
#         Protein Information Resource (PIR); Washington DC, USA
# --------------------------------------------------------------------------------
#
# Description: Index of human variants curated from literature reports
# Name:        humsavar.txt
# Release:     2021_04 of 29-Sep-2021
#
# --------------------------------------------------------------------------------
# This file lists all missense variants annotated in UniProtKB/Swiss-Prot human
# entries. It provides a variant classification which is intended for research
# purposes only, not for clinical and diagnostic use.
#
#  - The column 'Variant category' shows the classification of the variant using
#    the American College of Medical Genetics and Genomics/Association for
#    Molecular Pathology (ACMG/AMP) terminology (Richards et al. PubMed:25741868)
#    into the following categories:
#
#    LP/P = likely pathogenic or pathogenic
#    LB/B = likely benign or benign
#    US   = uncertain significance
#
#    These categories are assigned based on the variant annotation in the
#    corresponding UniProtKB/Swiss-Prot entries that is curated from literature
#    reports. The classification may change over time and must not be considered
#    as a definitive statement about the pathogenic role of a variant.
#
#  - The column 'Disease name' shows the name of the disease or the disease sample
#    in which variants have been found. Names are only provided for diseases
#    catalogued in OMIM and for cancer samples.
#
# Statistics for single amino acid variants:
#
#              LP/P:  31479
#              LB/B:  39578
#              US:    9073
#              Total: 80130
#
# Main      Swiss-Prot             AA             Variant
# gene name AC         FTId        change         category dbSNP          Disease name
# _________ __________ ___________ ______________ ________ ______________ _____________________
# A1BG      P04217     VAR_018369  p.His52Arg     LB/B     rs893184       -
# A1BG      P04217     VAR_018370  p.His395Arg    LB/B     rs2241788      -
# A1CF      Q9NQ94     VAR_052201  p.Val555Met    LB/B     rs9073         -
# ... 80k sor..
# -         Q6ZVL8     VAR_043712  p.Cys136Ser    LB/B     rs8055382      -
# -         Q8IYB0     VAR_044325  p.Asp129Tyr    US       -              A colorectal cancer sample
# -         Q8N2B8     VAR_043938  p.Arg127Gln    US       -              A colorectal cancer sample
# -         Q8N402     VAR_042673  p.Pro97Leu     LB/B     rs12169718     -
# -         Q8N402     VAR_042674  p.Thr114Ser    LB/B     rs6519443      -
# -         Q8N402     VAR_042675  p.Thr131Pro    LB/B     rs6519442      -
# -         Q96M66     VAR_039178  p.Arg37His     LB/B     rs350229       -
# -         Q96M66     VAR_039179  p.Arg171Ser    LB/B     rs11648228     -
# -         Q9N2K0     VAR_017799  p.Val81Leu     LB/B     -              -
# -         Q9N2K0     VAR_017800  p.Phe150Leu    LB/B     -              -
#
# --------------------------------------------------------------------------------
# Copyrighted by the UniProt Consortium, see https://www.uniprot.org/terms
# Distributed under the Creative Commons Attribution (CC BY 4.0) License
# --------------------------------------------------------------------------------

# %%
import pandas as pd
import re
from ontoma import OnToma

# Initialize ontoma:
otmap = OnToma()

# Data read directly from the web:
humsavar_url = 'https://www.uniprot.org/docs/humsavar.txt'

# Column names are not inferred from the data:
humsavar_columns = [
    'gene', 
    'uniprotId', 
    'variantId', 
    'aaChange', 
    'severity',
    'rsId',
    'disease'
]

# Sinificant terms are mapped:
significant_map = {
    "LP/P": "pathogenic",
    "LB/B": "benign",
    "US": "uncertain significance"
}

# Humsavar disease annotation needs to be mapped at first:
def parse_disease(disease:str)-> str:
    """Returning with the parsed diese + OMIM"""
    
    return_dict = {
        'disease': disease,
        'diseaseMappedId': None,
        'diseaseMappedLabel': None,
        'omimId': None
    }

    if disease == '-':
        return return_dict
    
    elif '[MIM' not in disease:
        disease_label = disease

    else:
    
        # The OMIM needs to be extracted:
        m = re.match(r'(.+?) \[(MIM:\d+)', disease)

        # Do we have OMIM:
        if m:
            return_dict['omimId'] = m[2].replace('MIM', 'OMIM')
            disease_label = m[1]
        else:
            m = re.match(r'(.+?) \(', disease)
            disease_label = m[1]

    # Mapping label:
    mapping = otmap.find_term(disease_label)
    
    if len(mapping) > 0:
        return_dict['diseaseMappedId'] = mapping[0].id_normalised
        return_dict['diseaseMappedLabel'] = mapping[0].label

    elif return_dict['omimId']:
        mapping = otmap.find_term(return_dict['omimId'], code=True)
        if len(mapping) > 0:
            return_dict['diseaseMappedId'] = mapping[0].id_normalised
            return_dict['diseaseMappedLabel'] = mapping[0].label

    return return_dict

# Reading data as dataframe:
humsavar_data = (
    
    # Reading file:
    pd.read_fwf(humsavar_url, header=None, names=humsavar_columns, skiprows=44, skipfooter=6)
    
    # mapping severity significance:
    .assign(severity = lambda df: df.severity.map(significant_map))
    
    # Filtering out rows where no disease is given:
    .query('disease != "-"')
)

# Get the unique list of diseases and try to map to efo using ontoma:
efo_mapping = pd.DataFrame(
    pd.Series(
        humsavar_data.disease.unique()
    ).apply(parse_disease)
    .to_list()
)

# Joining humsavar data with disease mapping:
humsavar_data = (
    humsavar_data
    
    # Merging with efo:
    .merge(efo_mapping, on='disease', how='left')
    
    # Dropping unused columns:
    .drop(['gene', 'variantId'], axis=1)
)
# Out:
# WARNING  - ontoma.interface - EFO cache directory is not specified. Created temporary directory to store the cache: /var/folders/gr/q7cf7ljx2ss8b5cgvycxn9yxz2wxjr/T/tmpm_pr1ics. We recommend that you specify the cache directory to speed up subsequent OnToma runs.
# INFO     - ontoma.interface - Created EFO cache directory /var/folders/gr/q7cf7ljx2ss8b5cgvycxn9yxz2wxjr/T/tmpm_pr1ics.
# INFO     - ontoma.interface - Downloading EFO cache to /var/folders/gr/q7cf7ljx2ss8b5cgvycxn9yxz2wxjr/T/tmpm_pr1ics.
# /Users/dsuveges/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/pronto/parsers/rdfxml.py:113: SyntaxWarning: unknown element in `owl:ObjectProperty`: <Element '{http://purl.obolibrary.org/obo/}IAO_0000111' at 0x10bdf6d60>
#   self._extract_object_property(prop, curies)
# /Users/dsuveges/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/pronto/parsers/rdfxml.py:113: SyntaxWarning: unknown element in `owl:ObjectProperty`: <Element '{http://purl.obolibrary.org/obo/}IAO_0000111' at 0x10bdf6e00>
#   self._extract_object_property(prop, curies)
# /Users/dsuveges/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/pronto/parsers/rdfxml.py:113: SyntaxWarning: unknown element in `owl:ObjectProperty`: <Element '{http://purl.obolibrary.org/obo/}IAO_0000112' at 0x10bdf6ea0>
#   self._extract_object_property(prop, curies)
# /Users/dsuveges/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/pronto/parsers/rdfxml.py:113: SyntaxWarning: unknown element in `owl:ObjectProperty`: <Element '{http://purl.obolibrary.org/obo/}IAO_0000112' at 0x10bdf6ef0>
#   self._extract_object_property(prop, curies)
# /Users/dsuveges/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/pronto/parsers/rdfxml.py:113: SyntaxWarning: unknown element in `owl:ObjectProperty`: <Element '{http://purl.obolibrary.org/obo/}IAO_0000112' at 0x10bdf6f40>
#   self._extract_object_property(prop, curies)
# /Users/dsuveges/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/pronto/parsers/rdfxml.py:113: SyntaxWarning: unknown element in `owl:ObjectProperty`: <Element '{http://purl.obolibrary.org/obo/}IAO_0000112' at 0x10bdf6f90>
#   self._extract_object_property(prop, curies)
# /Users/dsuveges/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/pronto/parsers/rdfxml.py:113: SyntaxWarning: unknown element in `owl:ObjectProperty`: <Element '{http://purl.obolibrary.org/obo/}IAO_0000112' at 0x10bc11040>
#   self._extract_object_property(prop, curies)
# /Users/dsuveges/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/pronto/parsers/rdfxml.py:113: SyntaxWarning: unknown element in `owl:ObjectProperty`: <Element '{http://purl.obolibrary.org/obo/}IAO_0000112' at 0x10bc11090>
#   self._extract_object_property(prop, curies)
# /Users/dsuveges/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/pronto/parsers/rdfxml.py:113: SyntaxWarning: unknown element in `owl:ObjectProperty`: <Element '{http://purl.obolibrary.org/obo/}IAO_0000116' at 0x10bc11360>
#   self._extract_object_property(prop, curies)
# /Users/dsuveges/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/pronto/parsers/rdfxml.py:113: SyntaxWarning: unknown element in `owl:ObjectProperty`: <Element '{http://purl.obolibrary.org/obo/}IAO_0000116' at 0x10bc113b0>
#   self._extract_object_property(prop, curies)
# /Users/dsuveges/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/pronto/parsers/rdfxml.py:113: SyntaxWarning: unknown element in `owl:ObjectProperty`: <Element '{http://purl.obolibrary.org/obo/}IAO_0000116' at 0x10bc11400>
#   self._extract_object_property(prop, curies)
# /Users/dsuveges/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/pronto/parsers/rdfxml.py:113: SyntaxWarning: unknown element in `owl:ObjectProperty`: <Element '{http://purl.obolibrary.org/obo/}IAO_0000116' at 0x10bc11450>
#   self._extract_object_property(prop, curies)
# /Users/dsuveges/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/pronto/parsers/rdfxml.py:113: SyntaxWarning: unknown element in `owl:ObjectProperty`: <Element '{http://purl.obolibrary.org/obo/}IAO_0000116' at 0x10bc114a0>
#   self._extract_object_property(prop, curies)
# /Users/dsuveges/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/pronto/parsers/rdfxml.py:113: SyntaxWarning: unknown element in `owl:ObjectProperty`: <Element '{http://purl.obolibrary.org/obo/}IAO_0000116' at 0x10bc114f0>
#   self._extract_object_property(prop, curies)
# /Users/dsuveges/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/pronto/parsers/rdfxml.py:113: SyntaxWarning: unknown element in `owl:ObjectProperty`: <Element '{http://purl.obolibrary.org/obo/}IAO_0000116' at 0x10bc11540>
#   self._extract_object_property(prop, curies)
# /Users/dsuveges/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/pronto/parsers/rdfxml.py:113: SyntaxWarning: unknown element in `owl:ObjectProperty`: <Element '{http://purl.obolibrary.org/obo/}IAO_0000116' at 0x10bc11590>
#   self._extract_object_property(prop, curies)
# /Users/dsuveges/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/pronto/parsers/rdfxml.py:113: SyntaxWarning: unknown element in `owl:ObjectProperty`: <Element '{http://purl.obolibrary.org/obo/}IAO_0000118' at 0x10bc11630>
#   self._extract_object_property(prop, curies)
# /Users/dsuveges/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/pronto/parsers/rdfxml.py:113: SyntaxWarning: unknown element in `owl:ObjectProperty`: <Element '{http://purl.obolibrary.org/obo/}IAO_0000118' at 0x10bc11680>
#   self._extract_object_property(prop, curies)
# /Users/dsuveges/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/pronto/parsers/rdfxml.py:113: SyntaxWarning: unknown element in `owl:ObjectProperty`: <Element '{http://www.ebi.ac.uk/efo/}EFO_URI' at 0x10bc11a40>
#   self._extract_object_property(prop, curies)
# /Users/dsuveges/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/pronto/parsers/rdfxml.py:113: SyntaxWarning: unknown element in `owl:ObjectProperty`: <Element '{http://www.w3.org/2000/01/rdf-schema#}seeAlso' at 0x10bc0a2c0>
#   self._extract_object_property(prop, curies)
# /Users/dsuveges/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/pronto/parsers/rdfxml.py:113: SyntaxWarning: several names found for 'part_of', using 'part of'
#   self._extract_object_property(prop, curies)
# /Users/dsuveges/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/pronto/ontology.py:283: NotImplementedWarning: cannot process plain `owl:AnnotationProperty`
#   cls(self).parse_from(_handle)  # type: ignore
# /Users/dsuveges/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/pronto/parsers/rdfxml.py:117: SyntaxWarning: unknown element in `owl:Class`: {http://purl.obolibrary.org/obo/}IAO_0000117
#   self._extract_term(class_, curies)
# /Users/dsuveges/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/pronto/parsers/rdfxml.py:117: SyntaxWarning: could not extract ID from `IAO:0100001` annotation
#   self._extract_term(class_, curies)
# /Users/dsuveges/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/pronto/parsers/rdfxml.py:117: SyntaxWarning: unknown element in `owl:Class`: {http://www.ebi.ac.uk/efo/}obsoleted_in_version
#   self._extract_term(class_, curies)
# /Users/dsuveges/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/pronto/parsers/rdfxml.py:117: SyntaxWarning: unknown element in `owl:Class`: {http://www.ebi.ac.uk/efo/}organizational_class
#   self._extract_term(class_, curies)
# /Users/dsuveges/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/pronto/parsers/rdfxml.py:117: SyntaxWarning: unknown element in `owl:Class`: {http://www.ebi.ac.uk/efo/}reason_for_obsolescence
#   self._extract_term(class_, curies)
# /Users/dsuveges/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/pronto/parsers/rdfxml.py:117: SyntaxWarning: unknown element in `owl:Class`: {http://www.ebi.ac.uk/efo/}EFO_URI
#   self._extract_term(class_, curies)
# /Users/dsuveges/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/pronto/ontology.py:283: SyntaxWarning: could not extract ID from `oboInOwl:consider` annotation
#   cls(self).parse_from(_handle)  # type: ignore
# /Users/dsuveges/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/pronto/parsers/rdfxml.py:117: SyntaxWarning: unknown element in `owl:Class`: {http://www.ebi.ac.uk/efo/}gwas_trait
#   self._extract_term(class_, curies)
# /Users/dsuveges/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/pronto/parsers/rdfxml.py:117: SyntaxWarning: unknown element in `owl:Class`: {http://purl.obolibrary.org/obo/}IAO_0000112
#   self._extract_term(class_, curies)
# /Users/dsuveges/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/pronto/parsers/rdfxml.py:117: SyntaxWarning: unknown element in `owl:Class`: {http://www.ebi.ac.uk/efo/}definition_citation
#   self._extract_term(class_, curies)
# /Users/dsuveges/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/pronto/parsers/rdfxml.py:117: SyntaxWarning: unknown element in `owl:Class`: {http://www.w3.org/2000/01/rdf-schema#}seeAlso
#   self._extract_term(class_, curies)
# /Users/dsuveges/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/pronto/parsers/rdfxml.py:117: SyntaxWarning: unknown element in `owl:Class`: {http://purl.obolibrary.org/obo/}IAO_0000589
#   self._extract_term(class_, curies)
# /Users/dsuveges/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/pronto/parsers/rdfxml.py:117: SyntaxWarning: unknown element in `owl:Class`: {http://purl.obolibrary.org/obo/}IAO_0000231
#   self._extract_term(class_, curies)
# /Users/dsuveges/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/pronto/parsers/rdfxml.py:117: SyntaxWarning: unknown element in `owl:Class`: {http://purl.obolibrary.org/obo/}IAO_0006012
#   self._extract_term(class_, curies)
# /Users/dsuveges/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/pronto/parsers/rdfxml.py:117: SyntaxWarning: unknown element in `owl:Class`: {http://purl.obolibrary.org/obo/mondo#}excluded_synonym
#   self._extract_term(class_, curies)
# /Users/dsuveges/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/pronto/parsers/rdfxml.py:117: SyntaxWarning: unknown element in `owl:Class`: {http://purl.obolibrary.org/obo/}IAO_0000111
#   self._extract_term(class_, curies)
# /Users/dsuveges/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/pronto/parsers/rdfxml.py:117: SyntaxWarning: unknown element in `owl:Class`: {http://purl.obolibrary.org/obo/}IAO_0000118
#   self._extract_term(class_, curies)
# /Users/dsuveges/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/pronto/parsers/rdfxml.py:117: SyntaxWarning: unknown element in `owl:Class`: {http://purl.obolibrary.org/obo/}IAO_0000119
#   self._extract_term(class_, curies)
# /Users/dsuveges/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/pronto/parsers/rdfxml.py:117: SyntaxWarning: unknown element in `owl:Class`: {http://purl.obolibrary.org/obo/}OBI_0001886
#   self._extract_term(class_, curies)
# /Users/dsuveges/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/pronto/parsers/rdfxml.py:117: SyntaxWarning: unknown element in `owl:Class`: {http://purl.org/dc/elements/1.1/}source
#   self._extract_term(class_, curies)
# /Users/dsuveges/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/pronto/parsers/rdfxml.py:117: SyntaxWarning: several names found for 'OBI:0001620', using 'latitude'
#   self._extract_term(class_, curies)
# /Users/dsuveges/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/pronto/parsers/rdfxml.py:117: SyntaxWarning: several names found for 'OBI:0001621', using 'longitude'
#   self._extract_term(class_, curies)
# /Users/dsuveges/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/pronto/parsers/rdfxml.py:117: SyntaxWarning: several names found for 'OBI:1110021', using 'infect'
#   self._extract_term(class_, curies)
# /Users/dsuveges/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/pronto/parsers/rdfxml.py:117: SyntaxWarning: several names found for 'OBI:1110122', using 'pathologic process'
#   self._extract_term(class_, curies)
# /Users/dsuveges/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/pronto/parsers/rdfxml.py:117: SyntaxWarning: unknown element in `owl:Class`: {http://purl.obolibrary.org/obo/}UBPROP_0000001
#   self._extract_term(class_, curies)
# /Users/dsuveges/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/pronto/parsers/rdfxml.py:117: SyntaxWarning: unknown element in `owl:Class`: {http://purl.obolibrary.org/obo/}UBPROP_0000003
#   self._extract_term(class_, curies)
# /Users/dsuveges/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/pronto/parsers/rdfxml.py:117: SyntaxWarning: unknown element in `owl:Class`: {http://purl.obolibrary.org/obo/}UBPROP_0000007
#   self._extract_term(class_, curies)
# /Users/dsuveges/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/pronto/parsers/rdfxml.py:117: SyntaxWarning: unknown element in `owl:Class`: {http://purl.obolibrary.org/obo/}UBPROP_0000008
#   self._extract_term(class_, curies)
# /Users/dsuveges/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/pronto/parsers/rdfxml.py:117: SyntaxWarning: unknown element in `owl:Class`: {http://purl.obolibrary.org/obo/}UBPROP_0000011
#   self._extract_term(class_, curies)
# /Users/dsuveges/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/pronto/parsers/rdfxml.py:117: SyntaxWarning: unknown element in `owl:Class`: {http://purl.obolibrary.org/obo/}IAO_0000232
#   self._extract_term(class_, curies)
# /Users/dsuveges/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/pronto/parsers/rdfxml.py:117: SyntaxWarning: unknown element in `owl:Class`: {http://purl.obolibrary.org/obo/}UBPROP_0000012
#   self._extract_term(class_, curies)
# /Users/dsuveges/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/pronto/parsers/rdfxml.py:117: SyntaxWarning: unknown element in `owl:Class`: {http://purl.obolibrary.org/obo/}IAO_0000116
#   self._extract_term(class_, curies)
# /Users/dsuveges/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/pronto/parsers/rdfxml.py:117: SyntaxWarning: unknown element in `owl:Class`: {http://purl.obolibrary.org/obo/}UBPROP_0000010
#   self._extract_term(class_, curies)
# /Users/dsuveges/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/pronto/parsers/rdfxml.py:117: SyntaxWarning: unknown element in `owl:Class`: {http://purl.obolibrary.org/obo/}UBPROP_0000009
#   self._extract_term(class_, curies)
# /Users/dsuveges/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/pronto/parsers/rdfxml.py:117: SyntaxWarning: unknown element in `owl:Class`: {http://purl.obolibrary.org/obo/}UBPROP_0000013
#   self._extract_term(class_, curies)
# /Users/dsuveges/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/pronto/parsers/rdfxml.py:117: SyntaxWarning: unknown element in `owl:Class`: {http://purl.obolibrary.org/obo/}UBPROP_0000002
#   self._extract_term(class_, curies)
# /Users/dsuveges/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/pronto/parsers/rdfxml.py:117: SyntaxWarning: unknown element in `owl:Class`: {http://purl.obolibrary.org/obo/}RO_0002175
#   self._extract_term(class_, curies)
# /Users/dsuveges/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/pronto/parsers/rdfxml.py:117: SyntaxWarning: unknown element in `owl:Class`: {http://purl.org/dc/elements/1.1/}description
#   self._extract_term(class_, curies)
# /Users/dsuveges/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/pronto/parsers/rdfxml.py:117: SyntaxWarning: unknown element in `owl:Class`: {http://purl.obolibrary.org/obo/}UBPROP_0000005
#   self._extract_term(class_, curies)
# /Users/dsuveges/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/pronto/parsers/rdfxml.py:117: SyntaxWarning: unknown element in `owl:Class`: {http://purl.obolibrary.org/obo/}UBPROP_0000004
#   self._extract_term(class_, curies)
# /Users/dsuveges/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/pronto/parsers/rdfxml.py:117: SyntaxWarning: could not extract target IRI from `owl:Restriction`
#   self._extract_term(class_, curies)
# /Users/dsuveges/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/pronto/parsers/rdfxml.py:117: SyntaxWarning: several names found for 'http://www.ebi.ac.uk/efo/EFO_0000722', concatenating
#   self._extract_term(class_, curies)
# /Users/dsuveges/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/pronto/parsers/rdfxml.py:117: SyntaxWarning: cannot process `rdfs:subClassOf` in this context
#   self._extract_term(class_, curies)
# /Users/dsuveges/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/pronto/parsers/rdfxml.py:117: SyntaxWarning: unknown element in `owl:Class`: {http://www.ebi.ac.uk/efo/}branch_class
#   self._extract_term(class_, curies)
# /Users/dsuveges/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/pronto/parsers/rdfxml.py:117: SyntaxWarning: unknown element in `owl:Class`: {http://www.ebi.ac.uk/efo/}primary_source
#   self._extract_term(class_, curies)
# /Users/dsuveges/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/pronto/parsers/rdfxml.py:117: SyntaxWarning: unknown element in `owl:Class`: {http://www.w3.org/2002/07/owl#}incompatibleWith
#   self._extract_term(class_, curies)
# /Users/dsuveges/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/pronto/parsers/rdfxml.py:117: SyntaxWarning: several names found for 'http://www.ebi.ac.uk/efo/EFO_0004813', concatenating
#   self._extract_term(class_, curies)
# /Users/dsuveges/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/pronto/parsers/rdfxml.py:117: SyntaxWarning: several names found for 'EFO:0004911', concatenating
#   self._extract_term(class_, curies)
# /Users/dsuveges/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/pronto/parsers/rdfxml.py:117: SyntaxWarning: unknown element in `owl:Class`: {http://www.co-ode.org/patterns#}createdBy
#   self._extract_term(class_, curies)
# /Users/dsuveges/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/pronto/parsers/rdfxml.py:117: SyntaxWarning: several names found for 'EFO:0005769', concatenating
#   self._extract_term(class_, curies)
# /Users/dsuveges/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/pronto/parsers/rdfxml.py:117: SyntaxWarning: several names found for 'EFO:0005772', concatenating
#   self._extract_term(class_, curies)
# /Users/dsuveges/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/pronto/parsers/rdfxml.py:117: SyntaxWarning: unknown element in `owl:Class`: {http://www.w3.org/2000/01/rdf-schema#}comment
#   self._extract_term(class_, curies)
# /Users/dsuveges/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/pronto/parsers/rdfxml.py:117: SyntaxWarning: several names found for 'EFO:0007409', using 'Ornithine transcarbamylase deficiency'
#   self._extract_term(class_, curies)
# /Users/dsuveges/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/pronto/parsers/rdfxml.py:117: SyntaxWarning: several names found for 'EFO:0007532', concatenating
#   self._extract_term(class_, curies)
# /Users/dsuveges/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/pronto/ontology.py:283: SyntaxWarning: could not extract synonym value in 'http://www.ebi.ac.uk/efo/EFO_0008451'
#   cls(self).parse_from(_handle)  # type: ignore
# /Users/dsuveges/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/pronto/parsers/rdfxml.py:117: SyntaxWarning: unknown element in `owl:Class`: {http://purl.obolibrary.org/obo/mondo#}related
#   self._extract_term(class_, curies)
# /Users/dsuveges/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/pronto/parsers/rdfxml.py:117: SyntaxWarning: several names found for 'EFO:1000013', concatenating
#   self._extract_term(class_, curies)
# /Users/dsuveges/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/pronto/parsers/rdfxml.py:117: SyntaxWarning: unknown element in `owl:Class`: {http://www.w3.org/2004/02/skos/core#}prefLabel
#   self._extract_term(class_, curies)
# /Users/dsuveges/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/pronto/parsers/rdfxml.py:117: SyntaxWarning: unknown element in `owl:Class`: {http://purl.obolibrary.org/obo/mondo#}pathogenesis
#   self._extract_term(class_, curies)
# /Users/dsuveges/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/pronto/ontology.py:283: SyntaxWarning: unknown axiom property: 'http://www.w3.org/2000/01/rdf-schema#comment'
#   cls(self).parse_from(_handle)  # type: ignore
# /Users/dsuveges/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/pronto/ontology.py:283: SyntaxWarning: `oboInOwl:hasDbXref` element has no text
#   cls(self).parse_from(_handle)  # type: ignore
# /Users/dsuveges/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/pronto/ontology.py:283: SyntaxWarning: unknown axiom property: 'http://www.geneontology.org/formats/oboInOwl#inSubset'
#   cls(self).parse_from(_handle)  # type: ignore
# /Users/dsuveges/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/pronto/ontology.py:283: SyntaxWarning: unknown axiom property: 'http://www.w3.org/2000/01/rdf-schema#seeAlso'
#   cls(self).parse_from(_handle)  # type: ignore
# /Users/dsuveges/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/pronto/ontology.py:283: SyntaxWarning: unknown axiom property: 'http://purl.obolibrary.org/obo/mondo#excluded_subClassOf'
#   cls(self).parse_from(_handle)  # type: ignore
# /Users/dsuveges/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/pronto/ontology.py:283: SyntaxWarning: unknown axiom property: 'http://purl.obolibrary.org/obo/mondo#excluded_synonym'
#   cls(self).parse_from(_handle)  # type: ignore
# /Users/dsuveges/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/pronto/ontology.py:283: SyntaxWarning: unknown axiom property: 'http://www.geneontology.org/formats/oboInOwl#consider'
#   cls(self).parse_from(_handle)  # type: ignore
# /Users/dsuveges/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/pronto/ontology.py:283: SyntaxWarning: unknown axiom property: 'http://purl.obolibrary.org/obo/UBPROP_0000001'
#   cls(self).parse_from(_handle)  # type: ignore
# /Users/dsuveges/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/pronto/ontology.py:283: SyntaxWarning: unknown axiom property: 'http://purl.obolibrary.org/obo/UBPROP_0000003'
#   cls(self).parse_from(_handle)  # type: ignore
# /Users/dsuveges/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/pronto/ontology.py:283: SyntaxWarning: unknown axiom property: 'http://purl.obolibrary.org/obo/UBPROP_0000008'
#   cls(self).parse_from(_handle)  # type: ignore
# /Users/dsuveges/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/pronto/ontology.py:283: SyntaxWarning: unknown axiom property: 'http://purl.obolibrary.org/obo/RO_0002161'
#   cls(self).parse_from(_handle)  # type: ignore
# /Users/dsuveges/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/pronto/ontology.py:283: SyntaxWarning: unknown axiom property: 'http://purl.obolibrary.org/obo/UBPROP_0000012'
#   cls(self).parse_from(_handle)  # type: ignore
# /Users/dsuveges/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/pronto/ontology.py:283: SyntaxWarning: unknown axiom property: 'http://purl.obolibrary.org/obo/RO_0002175'
#   cls(self).parse_from(_handle)  # type: ignore
# /Users/dsuveges/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/pronto/ontology.py:283: SyntaxWarning: unknown axiom property: 'http://purl.obolibrary.org/obo/UBPROP_0000013'
#   cls(self).parse_from(_handle)  # type: ignore
# /Users/dsuveges/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/pronto/ontology.py:283: SyntaxWarning: unknown axiom property: 'http://purl.obolibrary.org/obo/IAO_0000116'
#   cls(self).parse_from(_handle)  # type: ignore
# /Users/dsuveges/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/pronto/ontology.py:283: SyntaxWarning: unknown axiom property: 'http://purl.obolibrary.org/obo/UBPROP_0000002'
#   cls(self).parse_from(_handle)  # type: ignore
# /Users/dsuveges/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/pronto/ontology.py:283: SyntaxWarning: unknown axiom property: 'http://purl.obolibrary.org/obo/RO_0002174'
#   cls(self).parse_from(_handle)  # type: ignore
# /Users/dsuveges/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/pronto/ontology.py:283: SyntaxWarning: unknown axiom property: 'http://purl.obolibrary.org/obo/IAO_0000232'
#   cls(self).parse_from(_handle)  # type: ignore
# /Users/dsuveges/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/pronto/ontology.py:283: SyntaxWarning: unknown axiom property: 'http://purl.obolibrary.org/obo/UBPROP_0000011'
#   cls(self).parse_from(_handle)  # type: ignore
# /Users/dsuveges/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/pronto/ontology.py:283: SyntaxWarning: unknown axiom property: 'http://purl.obolibrary.org/obo/UBPROP_0000009'
#   cls(self).parse_from(_handle)  # type: ignore
# /Users/dsuveges/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/pronto/ontology.py:283: SyntaxWarning: unknown axiom property: 'http://purl.obolibrary.org/obo/UBPROP_0000010'
#   cls(self).parse_from(_handle)  # type: ignore
# /Users/dsuveges/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/pronto/ontology.py:283: SyntaxWarning: unknown axiom property: 'http://purl.org/dc/elements/1.1/description'
#   cls(self).parse_from(_handle)  # type: ignore
# /Users/dsuveges/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/pronto/ontology.py:283: SyntaxWarning: unknown axiom property: 'http://purl.obolibrary.org/obo/UBPROP_0000005'
#   cls(self).parse_from(_handle)  # type: ignore
# /Users/dsuveges/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/pronto/ontology.py:283: SyntaxWarning: unknown axiom property: 'http://purl.obolibrary.org/obo/mondo#related'
#   cls(self).parse_from(_handle)  # type: ignore
# /Users/dsuveges/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/pronto/ontology.py:283: SyntaxWarning: could not parse Xref: 'doi: 10.1111/nmo.12871'
#   cls(self).parse_from(_handle)  # type: ignore
# /Users/dsuveges/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/pronto/ontology.py:283: SyntaxWarning: unknown axiom property: 'http://purl.obolibrary.org/obo/mondo#pathogenesis'
#   cls(self).parse_from(_handle)  # type: ignore
# /Users/dsuveges/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/pronto/ontology.py:283: SyntaxWarning: unknown axiom property: 'http://purl.obolibrary.org/obo/mondo#excluded_from_qc_check'
#   cls(self).parse_from(_handle)  # type: ignore
# INFO     - ontoma.interface - Using EFO cache from /var/folders/gr/q7cf7ljx2ss8b5cgvycxn9yxz2wxjr/T/tmpm_pr1ics.
# INFO:ontoma.interface:Using EFO cache from /var/folders/gr/q7cf7ljx2ss8b5cgvycxn9yxz2wxjr/T/tmpm_pr1ics.
# INFO     - ontoma.interface - Loaded 20322 terms, 92701 xrefs, and 67124 synonyms from EFO cache.
# INFO:ontoma.interface:Loaded 20322 terms, 92701 xrefs, and 67124 synonyms from EFO cache.
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-2-af0d6561ed2d> in <module>
#      87 # Get the unique list of diseases and try to map to efo using ontoma:
#      88 efo_mapping = pd.DataFrame(
# ---> 89     pd.Series(
#      90         humsavar_data.disease.unique()
#      91     ).apply(parse_disease)
#
# ~/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    4136             else:
#    4137                 values = self.astype(object)._values
# -> 4138                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4139
#    4140         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-2-af0d6561ed2d> in parse_disease(disease)
#      58
#      59     # Mapping label:
# ---> 60     mapping = otmap.find_term(disease_label)
#      61
#      62     if len(mapping) > 0:
#
# ~/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/ontoma/interface.py in find_term(self, query, code, suggest)
#     199                 or self.step06_owl_exact_synonym(normalised_string)
#     200                 or self.step07_manual_mapping(normalised_string)
# --> 201                 or self.step08_zooma_high_confidence(normalised_string)
#     202             )
#     203             if not result and suggest:
#
# ~/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/ontoma/interface.py in step08_zooma_high_confidence(self, normalised_string)
#     132
#     133     def step08_zooma_high_confidence(self, normalised_string):
# --> 134         zooma_mappings = {
#     135             ontology.normalise_ontology_identifier(mapping)
#     136             for mapping in self._zooma.search(normalised_string)
#
# ~/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/ontoma/interface.py in <setcomp>(.0)
#     132
#     133     def step08_zooma_high_confidence(self, normalised_string):
# --> 134         zooma_mappings = {
#     135             ontology.normalise_ontology_identifier(mapping)
#     136             for mapping in self._zooma.search(normalised_string)
#
# ~/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/ontoma/zooma.py in search(self, query_string)
#      31         }
#      32         url = f'{self.base}/services/annotate?propertyValue={query_string}'
# ---> 33         for zooma_result in requests.get(url, data=payload).json():
#      34             if zooma_result['confidence'] == 'HIGH':
#      35                 for semantic_tag in zooma_result['semanticTags']:
#
# ~/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/requests/models.py in json(self, **kwargs)
#     908                     # used.
#     909                     pass
# --> 910         return complexjson.loads(self.text, **kwargs)
#     911
#     912     @property
#
# ~/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/simplejson/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, use_decimal, **kw)
#     523             parse_constant is None and object_pairs_hook is None
#     524             and not use_decimal and not kw):
# --> 525         return _default_decoder.decode(s)
#     526     if cls is None:
#     527         cls = JSONDecoder
#
# ~/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/simplejson/decoder.py in decode(self, s, _w, _PY3)
#     368         if _PY3 and isinstance(s, bytes):
#     369             s = str(s, self.encoding)
# --> 370         obj, end = self.raw_decode(s)
#     371         end = _w(s, end).end()
#     372         if end != len(s):
#
# ~/opt/anaconda3/envs/jupyter3.9/lib/python3.9/site-packages/simplejson/decoder.py in raw_decode(self, s, idx, _w, _PY3)
#     398             elif ord0 == 0xef and s[idx:idx + 3] == '\xef\xbb\xbf':
#     399                 idx += 3
# --> 400         return self.scan_once(s, idx=_w(s, idx).end())
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
## Getting some stats:
print(f'Number of unique uniprot ids: {len(humsavar_data.uniprotId.unique())}')
print(f'Number of unique diseases: {len(humsavar_data.disease.unique())}')

print(f'\nNumber of evidence: {len(humsavar_data)}')
print(f'Number of associations: {len(humsavar_data[["uniprotId", "disease"]].drop_duplicates())}')

print(f'\nNumber of diseases with no mapping: {len(efo_mapping.loc[efo_mapping.diseaseMappedId.isna()])}')

humsavar_mapped = humsavar_data.loc[humsavar_data.diseaseMappedId.notna()]
humsavar_notmapped = humsavar_data.loc[humsavar_data.diseaseMappedId.isna()]

print(f'\nNumber of evidence w. mapping: {len(humsavar_mapped)}')
print(f'Number of associations w. mapping: {len(humsavar_mapped[["uniprotId", "diseaseMappedId"]].drop_duplicates())}')


print(f'\nNumber of evidence wo. mapping: {len(humsavar_notmapped)}')
print(f'Number of associations wo. mapping: {len(humsavar_notmapped[["uniprotId", "disease"]].drop_duplicates())}')


humsavar_df = spark.createDataFrame(humsavar_data).persist()
humsavar_df.show()
# Out:
# Number of unique uniprot ids: 4190
# Number of unique diseases: 4529
#
# Number of evidence: 38775
# Number of associations: 6318
#
# Number of diseases with no mapping: 874
#
# Number of evidence w. mapping: 31307
# Number of associations w. mapping: 3806
#
# Number of evidence wo. mapping: 7468
# Number of associations wo. mapping: 2404
# +---------+-----------+--------------------+------------+--------------------+---------------+--------------------+-----------+
# |uniprotId|   aaChange|            severity|        rsId|             disease|diseaseMappedId|  diseaseMappedLabel|     omimId|
# +---------+-----------+--------------------+------------+--------------------+---------------+--------------------+-----------+
# |   Q9NRG9| p.Gln15Lys|          pathogenic| rs121918549|Achalasia-addison...|       ORDO:869|   triple a syndrome|OMIM:231550|
# |   Q9NRG9|p.His160Arg|          pathogenic|rs1297831120|Achalasia-addison...|       ORDO:869|   triple a syndrome|OMIM:231550|
# |   Q9NRG9|p.Ser263Pro|          pathogenic| rs121918550|Achalasia-addison...|       ORDO:869|   triple a syndrome|OMIM:231550|
# |   P49588|p.Arg329His|          pathogenic| rs267606621|Charcot-Marie-Too...|    ORDO:228174|autosomal dominan...|OMIM:613287|
# |   P49588| p.Asn71Tyr|          pathogenic| rs387906792|Charcot-Marie-Too...|    ORDO:228174|autosomal dominan...|OMIM:613287|
# |   P49588| p.Lys81Thr|          pathogenic| rs786205157|Developmental and...|      ORDO:1934|early infantile e...|OMIM:616339|
# |   P49588|p.Arg751Gly|          pathogenic| rs143370729|Developmental and...|      ORDO:1934|early infantile e...|OMIM:616339|
# |   P49588|p.Gly913Asp|          pathogenic| rs369774476|Developmental and...|      ORDO:1934|early infantile e...|OMIM:616339|
# |   Q5JTZ9|p.Leu155Arg|          pathogenic| rs387907061|Combined oxidativ...|    ORDO:319504|combined oxidativ...|OMIM:614096|
# |   Q5JTZ9|p.Arg592Trp|          pathogenic| rs138119149|Combined oxidativ...|    ORDO:319504|combined oxidativ...|OMIM:614096|
# |   Q5JTZ9| p.Phe50Cys|          pathogenic| rs587777590|Leukoencephalopat...|           null|                null|OMIM:615889|
# |   Q5JTZ9|p.Glu405Lys|          pathogenic| rs587777592|Leukoencephalopat...|           null|                null|OMIM:615889|
# |   Q5JTZ9|p.Gly965Arg|          pathogenic| rs543267101|Leukoencephalopat...|           null|                null|OMIM:615889|
# |   Q6ZMQ8| p.Ser81Phe|uncertain signifi...|           -|An ovarian mucino...|           null|                null|       null|
# |   Q6ZMQ8| p.Leu97Val|uncertain signifi...|           -|A lung adenocarci...|           null|                null|       null|
# |   Q6ZMQ8|p.Met104Val|uncertain signifi...|rs1337040042|An ovarian mucino...|           null|                null|       null|
# |   P80404|p.Arg220Lys|          pathogenic| rs121434578|GABA transaminase...|      ORDO:2066|gamma-aminobutyri...|OMIM:613163|
# |   O95477|p.Arg587Trp|          pathogenic|   rs2853574|Tangier disease (...|     ORDO:31150|     tangier disease|OMIM:205400|
# |   O95477|p.Trp590Ser|          pathogenic| rs137854496|Tangier disease (...|     ORDO:31150|     tangier disease|OMIM:205400|
# |   O95477|p.Gln597Arg|          pathogenic|   rs2853578|Tangier disease (...|     ORDO:31150|     tangier disease|OMIM:205400|
# +---------+-----------+--------------------+------------+--------------------+---------------+--------------------+-----------+
# only showing top 20 rows

# %%
from pyspark.conf import SparkConf
from pyspark.sql import SparkSession
from pyspark.sql.functions import explode, col, concat, lit, lower, regexp_replace, split, udf
from pyspark import SparkFiles
from pyspark.sql.types import StringType

spark_conf = (
    SparkConf()
    .set('spark.driver.memory', '5g')
    .set('spark.executor.memory', '5g')
    .set('spark.driver.maxResultSize', '0')
    .set('spark.debug.maxToStringFields', '2000')
    .set('spark.sql.execution.arrow.maxRecordsPerBatch', '500000')
)
spark = (
    SparkSession.builder
    .config(conf=spark_conf)
    .config("spark.sql.broadcastTimeout", "36000")
    .master('local[*]')
    .getOrCreate()
)

uniprot_df = (
    spark.read.json('cttv011-11-10-2021.json.gz')
    .select('diseaseFromSource', 'diseaseFromSourceId', 'confidence', 'diseaseFromSourceMappedId', 'targetFromSourceId')
    .distinct()
    .persist()
)


print(uniprot_df.count())
print(uniprot_df.select('diseaseFromSourceMappedId', 'targetFromSourceId').distinct().count())
# Out:
# 7754
# 7396

# %%
# Prepare association from the humsavar evidence set:
humsavar_associations = (
    humsavar_df
    
    # Filtering for evidence where OMIM disease identifiers are available:
    .filter(col('omimId').isNotNull())
    .select('uniprotId', 'omimId')
    
    # Generate associations:
    .distinct()
    
    # Annotate source:
    .withColumn('humsavar', lit(True))
    .persist()
)

print(humsavar_associations.count()) # 4002
print(humsavar_associations.show())

# +---------+-----------+--------+
# |uniprotId|     omimId|humsavar|
# +---------+-----------+--------+
# |   Q9UPV0|OMIM:614845|    true|
# |   Q9Y259|OMIM:602541|    true|
# |   Q8TDJ6|OMIM:618663|    true|
# |   Q9NYP3|OMIM:617604|    true|
# |   Q04446|OMIM:232500|    true|
# |   P36382|OMIM:108770|    true|
# |   P29033|OMIM:602540|    true|
# |   Q5T442|OMIM:613206|    true|
# |   Q96IR7|OMIM:619027|    true|
# |   P78411|OMIM:611174|    true|
# |   Q96FE5|OMIM:618103|    true|
# |   P37287|OMIM:300818|    true|
# |   O00469|OMIM:609220|    true|
# |   P28340|OMIM:612591|    true|
# |   P78424|OMIM:601583|    true|
# |   Q9ULP9|OMIM:605021|    true|
# |   Q9NUM4|OMIM:617964|    true|
# |   Q9Y462|OMIM:300803|    true|
# |   P22557|OMIM:300751|    true|
# |   Q2TAA5|OMIM:613661|    true|
# +---------+-----------+--------+


# Prepare association from the uniprot evidence set:
uniprot_assoc = (
    uniprot_df
    
    # Selecting and renaming relevant columns:
    .select('diseaseFromSourceId', 'targetFromSourceId')
    .withColumnRenamed('targetFromSourceId', 'uniprotId')
    .withColumnRenamed('diseaseFromSourceId', 'omimId')

    # Generate associations:
    .distinct()
    
    # Annotate source:
    .withColumn('uniprot', lit(True))
    .persist()
)

print(uniprot_assoc.count()) # 5894
print(uniprot_assoc.show())

# +-----------+---------+-------+
# |     omimId|uniprotId|uniprot|
# +-----------+---------+-------+
# |OMIM:614935|   Q86X45|   true|
# |OMIM:264350|   P51168|   true|
# |OMIM:615833|   Q8NC96|   true|
# |OMIM:617613|   Q9BUE6|   true|
# |OMIM:612782|   Q96D31|   true|
# |OMIM:619051|   P14854|   true|
# |OMIM:609968|   P06213|   true|
# |OMIM:218330|   Q9HBG6|   true|
# |OMIM:607174|   Q969G3|   true|
# |OMIM:614250|   Q16653|   true|
# |OMIM:203780|   P53420|   true|
# |OMIM:242300|   P22735|   true|
# |OMIM:600195|   Q02763|   true|
# |OMIM:608812|   Q8IXK2|   true|
# |OMIM:310490|   O95831|   true|
# |OMIM:273250|   Q8IY37|   true|
# |OMIM:608516|   P08172|   true|
# |OMIM:309520|   Q93074|   true|
# |OMIM:615558|   P04114|   true|
# |OMIM:300559|   P46020|   true|
# +-----------+---------+-------+


# Joining humsavar and uniprot datasets:
association_compare = (
    uniprot_assoc
    .join(humsavar_associations, on=['omimId', 'uniprotId'], how='outer')
    .persist()
)

print(association_compare.count()) # 6171
print(association_compare.show())

# +-----------+---------+-------+--------+
# |     omimId|uniprotId|uniprot|humsavar|
# +-----------+---------+-------+--------+
# |OMIM:149200|   P29033|   true|    true|
# |OMIM:203780|   P53420|   true|    true|
# |OMIM:218330|   Q9HBG6|   true|    true|
# |OMIM:242300|   P22735|   true|    true|
# |OMIM:264350|   P51168|   true|    true|
# |OMIM:273250|   Q8IY37|   true|    true|
# |OMIM:300494|   Q9NZ94|   true|    true|
# |OMIM:300559|   P46020|   true|    true|
# |OMIM:300661|   P60891|   true|    null|
# |OMIM:309520|   Q93074|   true|    null|
# |OMIM:310490|   O95831|   true|    null|
# |OMIM:600195|   Q02763|   true|    true|
# |OMIM:605282|   Q86X52|   true|    true|
# |OMIM:605589|   Q71SY5|   true|    true|
# |OMIM:607174|   Q969G3|   true|    null|
# |OMIM:608516|   P08172|   true|    null|
# |OMIM:608812|   Q8IXK2|   true|    true|
# |OMIM:609968|   P06213|   true|    true|
# |OMIM:611291|   Q9H9Q4|   true|    null|
# |OMIM:612286|   Q06495|   true|    true|
# +-----------+---------+-------+--------+

# Number of associations found only in the uniprot dataset: 2169
print(
    association_compare
    .filter(
        col('uniprot').isNotNull() & 
        col('humsavar').isNull()
    )
    .count()
)

# Number of associations found only in the humsavar dataset: 187
print(
    association_compare
    .filter(
        col('uniprot').isNull() & 
        col('humsavar').isNotNull()
    )
    .count()
)

# Number of associations found in both dataset: 3815
print(
    association_compare
    .filter(
        col('uniprot').isNotNull() & 
        col('humsavar').isNotNull()
    )
    .count()
)
# Out:
# 4002
# +---------+-----------+--------+
# |uniprotId|     omimId|humsavar|
# +---------+-----------+--------+
# |   Q9UPV0|OMIM:614845|    true|
# |   Q9Y259|OMIM:602541|    true|
# |   Q8TDJ6|OMIM:618663|    true|
# |   Q9NYP3|OMIM:617604|    true|
# |   Q04446|OMIM:232500|    true|
# |   P36382|OMIM:108770|    true|
# |   P29033|OMIM:602540|    true|
# |   Q5T442|OMIM:613206|    true|
# |   Q96IR7|OMIM:619027|    true|
# |   P78411|OMIM:611174|    true|
# |   Q96FE5|OMIM:618103|    true|
# |   P37287|OMIM:300818|    true|
# |   O00469|OMIM:609220|    true|
# |   P28340|OMIM:612591|    true|
# |   P78424|OMIM:601583|    true|
# |   Q9ULP9|OMIM:605021|    true|
# |   Q9NUM4|OMIM:617964|    true|
# |   Q9Y462|OMIM:300803|    true|
# |   P22557|OMIM:300751|    true|
# |   Q2TAA5|OMIM:613661|    true|
# +---------+-----------+--------+
# only showing top 20 rows
#
# None
# 5984
# +-----------+---------+-------+
# |     omimId|uniprotId|uniprot|
# +-----------+---------+-------+
# |OMIM:614935|   Q86X45|   true|
# |OMIM:264350|   P51168|   true|
# |OMIM:615833|   Q8NC96|   true|
# |OMIM:617613|   Q9BUE6|   true|
# |OMIM:612782|   Q96D31|   true|
# |OMIM:619051|   P14854|   true|
# |OMIM:609968|   P06213|   true|
# |OMIM:218330|   Q9HBG6|   true|
# |OMIM:607174|   Q969G3|   true|
# |OMIM:614250|   Q16653|   true|
# |OMIM:203780|   P53420|   true|
# |OMIM:242300|   P22735|   true|
# |OMIM:600195|   Q02763|   true|
# |OMIM:608812|   Q8IXK2|   true|
# |OMIM:310490|   O95831|   true|
# |OMIM:273250|   Q8IY37|   true|
# |OMIM:608516|   P08172|   true|
# |OMIM:309520|   Q93074|   true|
# |OMIM:615558|   P04114|   true|
# |OMIM:300559|   P46020|   true|
# +-----------+---------+-------+
# only showing top 20 rows
#
# None

# %%
# Getting more insights on the associations which are not covered in the uniprot datasets: 
missing_assoc = (
    association_compare
    .filter(col('uniprot').isNull())
    .persist()
)

# Which is missing from the uniprot dataset exactly?
disease_not_in_uniprot = (
    missing_assoc
    .select("omimId")
    .distinct()
    .join((
        association_compare
        .filter(col('uniprot').isNotNull())
        .select('omimId')
        .distinct()
    ), on='omimId', how='inner')
)

target_not_in_uniprot = (
    missing_assoc
    .select("uniprotId")
    .distinct()
    .join((
        association_compare
        .filter(col('uniprot').isNotNull())
        .select('uniprotId')
        .distinct()
    ), on='uniprotId', how='inner')
)

print(f'Missing associations: {missing_assoc.count()}')
print(f'Number of diseases in the missing associations: {missing_assoc.select("omimId").distinct().count()} (not in Uniprot: {disease_not_in_uniprot.count()})')
print(f'Number of targets in the missing associations: {missing_assoc.select("uniprotId").distinct().count()} (not in Uniprot: {target_not_in_uniprot.count()})')
# Out:
# Missing associations: 187
# Number of diseases in the missing associations: 123 (not in Uniprot: 3)
# Number of targets in the missing associations: 182 (not in Uniprot: 159)

# %%
disease_not_in_uniprot.show()
target_not_in_uniprot.show()
# Out:
# +-----------+
# |     omimId|
# +-----------+
# |OMIM:608089|
# |OMIM:613659|
# |OMIM:146550|
# +-----------+
#
# +---------+
# |uniprotId|
# +---------+
# |   Q00796|
# |   O14656|
# |   Q02487|
# |   Q9UHD2|
# |   A2RRP1|
# |   O94886|
# |   P55268|
# |   Q9BY12|
# |   Q8WZ42|
# |   Q8NB90|
# |   Q5K651|
# |   Q8TE60|
# |   Q13228|
# |   Q8NBL1|
# |   O15047|
# |   P17612|
# |   P49589|
# |   Q8IVL5|
# |   P53701|
# |   Q8WVS4|
# +---------+
# only showing top 20 rows

# %%
humsavar_associations = (
    pd.read_fwf(humsavar_url, header=None, names=humsavar_columns, skiprows=44, skipfooter=6)
    
    # Extracting OMIM disease identifier:
    .assign(
        diseaseFromSourceId = lambda df: df.disease.str.extract(r'(MIM:\d+)').replace(regex=r'MIM', value='OMIM')
    )
    
    # Filtering for rows where OMIM identifiers are available:
    .query('diseaseFromSourceId.notnull()', engine='python')
    
    # Get unique disease/target associations from evidence:
    [['diseaseFromSourceId', 'uniprotId']]
    .drop_duplicates()
    .reset_index(drop=True)
)

humsavar_associations
# Out:
#      diseaseFromSourceId uniprotId
# 0            OMIM:231550    Q9NRG9
# 1            OMIM:613287    P49588
# 2            OMIM:616339    P49588
# 3            OMIM:614096    Q5JTZ9
# 4            OMIM:615889    Q5JTZ9
# ...                  ...       ...
# 3997         OMIM:616833    Q8N1G0
# 3998         OMIM:300803    Q9Y462
# 3999         OMIM:260565    Q15649
# 4000         OMIM:617712    P21754
# 4001         OMIM:603671    Q9HCJ5
#
# [4002 rows x 2 columns]

# %%
humsavar_associations = (
    pd.read_fwf(humsavar_url, header=None, names=humsavar_columns, skiprows=44, skipfooter=6)
    
    # Extracting OMIM disease identifier:
    .assign(
        diseaseFromSourceId = lambda df: df.disease.str.extract(r'(MIM:\d+)').replace(regex=r'MIM', value='OMIM')
    )
)

humsavar_associations.head()
# Out:
#    gene uniprotId   variantId     aaChange severity        rsId disease  \
# 0  A1BG    P04217  VAR_018369   p.His52Arg     LB/B    rs893184       -
# 1  A1BG    P04217  VAR_018370  p.His395Arg     LB/B   rs2241788       -
# 2  A1CF    Q9NQ94  VAR_052201  p.Val555Met     LB/B      rs9073       -
# 3  A1CF    Q9NQ94  VAR_059821  p.Ala558Ser     LB/B  rs11817448       -
# 4   A2M    P01023  VAR_000012  p.Arg704His     LB/B   rs1800434       -
#
#   diseaseFromSourceId
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN

# %%
# Numbber of evidence:
print(f'Number of evidence: {len(humsavar_associations)}')

# Number of evidence without gene or uniprot id:
missing_gene_uniprot = humsavar_associations.query('(gene == "-") & (uniprotId == "-")')
print(f'Number of evidence with no genes: {len(missing_gene_uniprot)}')

missing_gene = humsavar_associations.query('gene == "-"')
print(f'Number of evidence with no genes: {len(missing_gene)}')
missing_gene[['gene', 'uniprotId', 'rsId', 'disease']]

# Number of evidence without disease annotation:
missing_disease = humsavar_associations.query('disease == "-"')
genes_w_missing_disease = humsavar_associations.query('disease == "-"').uniprotId.unique()
print(f'Number of evidence with no disease annotation: {len(missing_disease)} (with {len(genes_w_missing_disease)} genes)')
w_disease = humsavar_associations.query('disease != "-"')
genes_w_disease = w_disease.query('disease == "-"').uniprotId.unique()
print(f'Number of evidence disease annotation: {len(w_disease)}')

# Number of associations with disease annotation:
associations = humsavar_associations[['uniprotId', 'disease']].query('disease != "-"').drop_duplicates()
print(f'Number of associations: {len(associations)}. genes: {len(associations.uniprotId.unique())}, diseases: {len(associations.disease.unique())}')

# Number of associations with MIM disease:
mim_assoc = (
    associations
    .assign(
        diseaseFromSourceId = lambda df: df.disease.str.extract(r'(MIM:\d+)').replace(regex=r'MIM', value='OMIM')
    )
    .query('diseaseFromSourceId.notnull()', engine='python')
)
print(f'Number of associations with MIM : {len(mim_assoc)}. genes: {len(mim_assoc.uniprotId.unique())}, diseases: {len(mim_assoc.disease.unique())}')

# Number of evidence without diease with OMIM identifier
# Out:
# Number of evidence: 80129
# Number of evidence with no genes: 0
# Number of evidence with no genes: 27
# Number of evidence with no disease annotation: 41354 (with 11855 genes)
# Number of evidence disease annotation: 38775
# Number of associations: 6318. genes: 4190, diseases: 4529
# Number of associations with MIM : 4062. genes: 2914, diseases: 3843

# %%
mim_assoc[['uniprotId', 'diseaseFromSourceId']].drop_duplicates()
# Out:
#       uniprotId diseaseFromSourceId
# 29       Q9NRG9         OMIM:231550
# 61       P49588         OMIM:613287
# 64       P49588         OMIM:616339
# 70       Q5JTZ9         OMIM:614096
# 72       Q5JTZ9         OMIM:615889
# ...         ...                 ...
# 79750    Q8N1G0         OMIM:616833
# 79783    Q9Y462         OMIM:300803
# 79999    Q15649         OMIM:260565
# 80016    P21754         OMIM:617712
# 80076    Q9HCJ5         OMIM:603671
#
# [4002 rows x 2 columns]

# %%
(
    association_compare
    .filter(col('uniprot').isNull())
    .select(col('uniprotId'))
    .distinct()
    .count()
)
# Disease: 123 -> found in uniprot: 3 (missing 120)
# Target: 182 -> found in uniprot: 159 (missing 23)
# Out:
# 182

# %%
(
    association_compare
    .filter(col('uniprot').isNotNull())
    .select(col('omimId'), ('uniprot'))
    .distinct()
    .join((
        association_compare
        .filter(col('uniprot').isNull())
        .select(col('omimId'))
        .distinct()
    ), on='omimId', how='inner')
    .count()
)
# Out:
# 3

# %%
efo_mapping.head()
# Out:
#                                              disease diseaseMappedId  \
# 0  Achalasia-addisonianism-alacrima syndrome (AAA...        ORDO:869
# 1  Charcot-Marie-Tooth disease 2N (CMT2N) [MIM:61...     ORDO:228174
# 2  Developmental and epileptic encephalopathy 29 ...       ORDO:1934
# 3  Combined oxidative phosphorylation deficiency ...     ORDO:319504
# 4  Leukoencephalopathy, progressive, with ovarian...            None
#
#                                   diseaseMappedLabel       omimId
# 0                                  triple a syndrome  OMIM:231550
# 1  autosomal dominant charcot-marie-tooth disease...  OMIM:613287
# 2           early infantile epileptic encephalopathy  OMIM:616339
# 3   combined oxidative phosphorylation defect type 8  OMIM:614096
# 4                                               None  OMIM:615889

# %% [markdown]
# ## Approach 2
#
# 1. Filter humsavar dataset for rows, where omim is not available + disease annotation is available.
# 2. Map disease annotation to EFO
# 3. Join with Uniprot dataset

# %%
import pandas as pd
import re
from ontoma import OnToma

# Initialize ontoma:
# otmap = OnToma()

# Data read directly from the web:
humsavar_url = 'https://www.uniprot.org/docs/humsavar.txt'

# Column names are not inferred from the data:
humsavar_columns = [
    'gene', 
    'uniprotId', 
    'variantId', 
    'aaChange', 
    'severity',
    'rsId',
    'disease'
]


# Reading data as dataframe:
humsavar_data = (
    
    # Reading file:
    pd.read_fwf(humsavar_url, header=None, names=humsavar_columns, skiprows=44, skipfooter=6)
    
    # mapping severity significance:
    .assign(severity = lambda df: df.severity.map(significant_map))
    
    # Filtering out rows where no disease is given:
    .query('disease != "-"')
    
    # Filtering for diseases where no OMIM is available:
    .loc[lambda df: ~ df.disease.str.contains(r'MIM')]
)

print(f'Number of evidence: {len(humsavar_data)}')
# Out:
# Number of evidence: 6261

# %%
# Restricting data for associations
associations = (
    humsavar_data
    [['uniprotId', 'disease']]
    .drop_duplicates()
)

print(f'Number of association: {len(associations)}')
print(associations.head())

diseases = pd.Series(associations.disease.unique())
print(f'Number of unique diseases: {len(diseases)}')
# Out:
# Number of association: 2193
#     uniprotId                                    disease
# 86     Q6ZMQ8       An ovarian mucinous carcinoma sample
# 87     Q6ZMQ8               A lung adenocarcinoma sample
# 132    O95477                 A colorectal cancer sample
# 189    Q86UK0  A pancreatic ductal adenocarcinoma sample
# 227    Q99758                     A breast cancer sample
# Number of unique diseases: 623

# %%
from json import JSONDecodeError

def map_disease(disease:str)-> str:
    """Returning with the parsed disease"""
    
    return_dict = {
        'disease': disease,
        'diseaseMappedId': None,
        'diseaseMappedLabel': None,
    }
    
    # Removing the string 'sample'
    disease = (
        disease
        .replace(' sample', '')
        .replace(r'An ', '')
        .replace(r'A ', '')
    )
        
    # Mapping label:
    try:
        mapping = otmap.find_term(disease)
    except:
        return return_dict
        
    
    if len(mapping) > 0:
        return_dict['diseaseMappedId'] = mapping[0].id_normalised
        return_dict['diseaseMappedLabel'] = mapping[0].label

    return return_dict


mapped_diseases = diseases.apply(map_disease)
# otmap.find_term('An ovarian mucinous carcinoma')
# Out:
# INFO     - ontoma.interface - Processed: ovarian mucinous carcinoma → [OnTomaResult(query='ovarian mucinous carcinoma', id_normalised='EFO:0006462', id_ot_schema='EFO_0006462', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0006462', label='ovarian mucinous adenocarcinoma')]
# INFO:ontoma.interface:Processed: ovarian mucinous carcinoma → [OnTomaResult(query='ovarian mucinous carcinoma', id_normalised='EFO:0006462', id_ot_schema='EFO_0006462', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0006462', label='ovarian mucinous adenocarcinoma')]
# INFO     - ontoma.interface - Processed: lung adenocarcinoma → [OnTomaResult(query='lung adenocarcinoma', id_normalised='EFO:0000571', id_ot_schema='EFO_0000571', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0000571', label='lung adenocarcinoma')]
# INFO:ontoma.interface:Processed: lung adenocarcinoma → [OnTomaResult(query='lung adenocarcinoma', id_normalised='EFO:0000571', id_ot_schema='EFO_0000571', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0000571', label='lung adenocarcinoma')]
# INFO     - ontoma.interface - Processed: colorectal cancer → [OnTomaResult(query='colorectal cancer', id_normalised='EFO:0005842', id_ot_schema='EFO_0005842', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0005842', label='colorectal cancer')]
# INFO:ontoma.interface:Processed: colorectal cancer → [OnTomaResult(query='colorectal cancer', id_normalised='EFO:0005842', id_ot_schema='EFO_0005842', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0005842', label='colorectal cancer')]
# INFO     - ontoma.interface - Processed: pancreatic ductal adenocarcinoma → [OnTomaResult(query='pancreatic ductal adenocarcinoma', id_normalised='EFO:0002517', id_ot_schema='EFO_0002517', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0002517', label='pancreatic ductal adenocarcinoma')]
# INFO:ontoma.interface:Processed: pancreatic ductal adenocarcinoma → [OnTomaResult(query='pancreatic ductal adenocarcinoma', id_normalised='EFO:0002517', id_ot_schema='EFO_0002517', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0002517', label='pancreatic ductal adenocarcinoma')]
# INFO     - ontoma.interface - Processed: breast cancer → [OnTomaResult(query='breast cancer', id_normalised='MONDO:0007254', id_ot_schema='MONDO_0007254', id_full_uri='http://purl.obolibrary.org/obo/MONDO_0007254', label='breast cancer')]
# INFO:ontoma.interface:Processed: breast cancer → [OnTomaResult(query='breast cancer', id_normalised='MONDO:0007254', id_ot_schema='MONDO_0007254', id_full_uri='http://purl.obolibrary.org/obo/MONDO_0007254', label='breast cancer')]
# INFO     - ontoma.interface - Processed: lung large cell carcinoma → [OnTomaResult(query='lung large cell carcinoma', id_normalised='EFO:0003050', id_ot_schema='EFO_0003050', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0003050', label='large cell lung carcinoma')]
# INFO:ontoma.interface:Processed: lung large cell carcinoma → [OnTomaResult(query='lung large cell carcinoma', id_normalised='EFO:0003050', id_ot_schema='EFO_0003050', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0003050', label='large cell lung carcinoma')]
# INFO     - ontoma.interface - Processed: melanoma → [OnTomaResult(query='melanoma', id_normalised='EFO:0000756', id_ot_schema='EFO_0000756', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0000756', label='melanoma')]
# INFO:ontoma.interface:Processed: melanoma → [OnTomaResult(query='melanoma', id_normalised='EFO:0000756', id_ot_schema='EFO_0000756', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0000756', label='melanoma')]
# INFO     - ontoma.interface - Processed: Cardiomyopathy, familial hypertrophic 23, with or without left ventricular → []
# INFO:ontoma.interface:Processed: Cardiomyopathy, familial hypertrophic 23, with or without left ventricular → []
# INFO     - ontoma.interface - Processed: lung squamous cell carcinoma → [OnTomaResult(query='lung squamous cell carcinoma', id_normalised='EFO:0000708', id_ot_schema='EFO_0000708', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0000708', label='squamous cell lung carcinoma')]
# INFO:ontoma.interface:Processed: lung squamous cell carcinoma → [OnTomaResult(query='lung squamous cell carcinoma', id_normalised='EFO:0000708', id_ot_schema='EFO_0000708', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0000708', label='squamous cell lung carcinoma')]
# INFO     - ontoma.interface - Processed: gastric adenocarcinoma → [OnTomaResult(query='gastric adenocarcinoma', id_normalised='EFO:0000503', id_ot_schema='EFO_0000503', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0000503', label='gastric adenocarcinoma')]
# INFO:ontoma.interface:Processed: gastric adenocarcinoma → [OnTomaResult(query='gastric adenocarcinoma', id_normalised='EFO:0000503', id_ot_schema='EFO_0000503', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0000503', label='gastric adenocarcinoma')]
# INFO     - ontoma.interface - Processed: Severe combined immunodeficiency autosomal recessive T-cell-negative/B-cell → []
# INFO:ontoma.interface:Processed: Severe combined immunodeficiency autosomal recessive T-cell-negative/B-cell → []
# INFO     - ontoma.interface - Processed: melanoma cell line → []
# INFO:ontoma.interface:Processed: melanoma cell line → []
# INFO     - ontoma.interface - Processed: Neurodevelopmental disorder with hypotonia, microcephaly, and seizures (NED → []
# INFO:ontoma.interface:Processed: Neurodevelopmental disorder with hypotonia, microcephaly, and seizures (NED → []
# INFO     - ontoma.interface - Processed: glioblastoma cell line → []
# INFO:ontoma.interface:Processed: glioblastoma cell line → []
# INFO     - ontoma.interface - Processed: lung cancer cell line → []
# INFO:ontoma.interface:Processed: lung cancer cell line → []
# INFO     - ontoma.interface - Processed: glioblastoma multiforme → [OnTomaResult(query='glioblastoma multiforme', id_normalised='EFO:0000519', id_ot_schema='EFO_0000519', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0000519', label='glioblastoma multiforme')]
# INFO:ontoma.interface:Processed: glioblastoma multiforme → [OnTomaResult(query='glioblastoma multiforme', id_normalised='EFO:0000519', id_ot_schema='EFO_0000519', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0000519', label='glioblastoma multiforme')]
# INFO     - ontoma.interface - Processed: Melanoma → [OnTomaResult(query='Melanoma', id_normalised='EFO:0000756', id_ot_schema='EFO_0000756', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0000756', label='melanoma')]
# INFO:ontoma.interface:Processed: Melanoma → [OnTomaResult(query='Melanoma', id_normalised='EFO:0000756', id_ot_schema='EFO_0000756', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0000756', label='melanoma')]
# INFO     - ontoma.interface - Processed: ovarian serous carcinoma → [OnTomaResult(query='ovarian serous carcinoma', id_normalised='EFO:1001516', id_ot_schema='EFO_1001516', id_full_uri='http://www.ebi.ac.uk/efo/EFO_1001516', label='ovarian serous carcinoma')]
# INFO:ontoma.interface:Processed: ovarian serous carcinoma → [OnTomaResult(query='ovarian serous carcinoma', id_normalised='EFO:1001516', id_ot_schema='EFO_1001516', id_full_uri='http://www.ebi.ac.uk/efo/EFO_1001516', label='ovarian serous carcinoma')]
# INFO     - ontoma.interface - Processed: ovarian undifferentiated carcinoma → [OnTomaResult(query='ovarian undifferentiated carcinoma', id_normalised='EFO:1000605', id_ot_schema='EFO_1000605', id_full_uri='http://www.ebi.ac.uk/efo/EFO_1000605', label='undifferentiated ovarian carcinoma')]
# INFO:ontoma.interface:Processed: ovarian undifferentiated carcinoma → [OnTomaResult(query='ovarian undifferentiated carcinoma', id_normalised='EFO:1000605', id_ot_schema='EFO_1000605', id_full_uri='http://www.ebi.ac.uk/efo/EFO_1000605', label='undifferentiated ovarian carcinoma')]
# INFO     - ontoma.interface - Processed: melanoma metastatic → []
# INFO:ontoma.interface:Processed: melanoma metastatic → []
# INFO     - ontoma.interface - Processed: metastatic melanoma → [OnTomaResult(query='metastatic melanoma', id_normalised='EFO:0002617', id_ot_schema='EFO_0002617', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0002617', label='metastatic melanoma')]
# INFO:ontoma.interface:Processed: metastatic melanoma → [OnTomaResult(query='metastatic melanoma', id_normalised='EFO:0002617', id_ot_schema='EFO_0002617', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0002617', label='metastatic melanoma')]
# INFO     - ontoma.interface - Processed: Midface hypoplasia, hearing impairment, elliptocytosis, and nephrocalcinosi → []
# INFO:ontoma.interface:Processed: Midface hypoplasia, hearing impairment, elliptocytosis, and nephrocalcinosi → []
# INFO     - ontoma.interface - Processed: lung neuroendocrine carcinoma → []
# INFO:ontoma.interface:Processed: lung neuroendocrine carcinoma → []
# INFO     - ontoma.interface - Processed: Colorectal carcinoma → [OnTomaResult(query='Colorectal carcinoma', id_normalised='EFO:1001951', id_ot_schema='EFO_1001951', id_full_uri='http://www.ebi.ac.uk/efo/EFO_1001951', label='colorectal carcinoma')]
# INFO:ontoma.interface:Processed: Colorectal carcinoma → [OnTomaResult(query='Colorectal carcinoma', id_normalised='EFO:1001951', id_ot_schema='EFO_1001951', id_full_uri='http://www.ebi.ac.uk/efo/EFO_1001951', label='colorectal carcinoma')]
# INFO     - ontoma.interface - Processed: Colorectal tumor → [OnTomaResult(query='Colorectal tumor', id_normalised='EFO:0004142', id_ot_schema='EFO_0004142', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0004142', label='colorectal neoplasm')]
# INFO:ontoma.interface:Processed: Colorectal tumor → [OnTomaResult(query='Colorectal tumor', id_normalised='EFO:0004142', id_ot_schema='EFO_0004142', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0004142', label='colorectal neoplasm')]
# INFO     - ontoma.interface - Processed: Prostate cancer → [OnTomaResult(query='Prostate cancer', id_normalised='MONDO:0008315', id_ot_schema='MONDO_0008315', id_full_uri='http://purl.obolibrary.org/obo/MONDO_0008315', label='prostate cancer')]
# INFO:ontoma.interface:Processed: Prostate cancer → [OnTomaResult(query='Prostate cancer', id_normalised='MONDO:0008315', id_ot_schema='MONDO_0008315', id_full_uri='http://purl.obolibrary.org/obo/MONDO_0008315', label='prostate cancer')]
# INFO     - ontoma.interface - Processed: Breast cancer → [OnTomaResult(query='Breast cancer', id_normalised='MONDO:0007254', id_ot_schema='MONDO_0007254', id_full_uri='http://purl.obolibrary.org/obo/MONDO_0007254', label='breast cancer')]
# INFO:ontoma.interface:Processed: Breast cancer → [OnTomaResult(query='Breast cancer', id_normalised='MONDO:0007254', id_ot_schema='MONDO_0007254', id_full_uri='http://purl.obolibrary.org/obo/MONDO_0007254', label='breast cancer')]
# INFO     - ontoma.interface - Processed: colorectal adenocarcinoma → [OnTomaResult(query='colorectal adenocarcinoma', id_normalised='EFO:0000365', id_ot_schema='EFO_0000365', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0000365', label='colorectal adenocarcinoma')]
# INFO:ontoma.interface:Processed: colorectal adenocarcinoma → [OnTomaResult(query='colorectal adenocarcinoma', id_normalised='EFO:0000365', id_ot_schema='EFO_0000365', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0000365', label='colorectal adenocarcinoma')]
# INFO     - ontoma.interface - Processed: Facial dysmorphism, lens dislocation, anterior segment abnormalities, and s → []
# INFO:ontoma.interface:Processed: Facial dysmorphism, lens dislocation, anterior segment abnormalities, and s → []
# INFO     - ontoma.interface - Processed: B-cell chronic lymphocytic leukemia → [OnTomaResult(query='B-cell chronic lymphocytic leukemia', id_normalised='EFO:0000095', id_ot_schema='EFO_0000095', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0000095', label='chronic lymphocytic leukemia')]
# INFO:ontoma.interface:Processed: B-cell chronic lymphocytic leukemia → [OnTomaResult(query='B-cell chronic lymphocytic leukemia', id_normalised='EFO:0000095', id_ot_schema='EFO_0000095', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0000095', label='chronic lymphocytic leukemia')]
# INFO     - ontoma.interface - Processed: T-prolymphocytic leukemia → []
# INFO:ontoma.interface:Processed: T-prolymphocytic leukemia → []
# INFO     - ontoma.interface - Processed: Mantle cell lymphoma → [OnTomaResult(query='Mantle cell lymphoma', id_normalised='EFO:1001469', id_ot_schema='EFO_1001469', id_full_uri='http://www.ebi.ac.uk/efo/EFO_1001469', label='mantle cell lymphoma')]
# INFO:ontoma.interface:Processed: Mantle cell lymphoma → [OnTomaResult(query='Mantle cell lymphoma', id_normalised='EFO:1001469', id_ot_schema='EFO_1001469', id_full_uri='http://www.ebi.ac.uk/efo/EFO_1001469', label='mantle cell lymphoma')]
# INFO     - ontoma.interface - Processed: renal papillary cancer → []
# INFO:ontoma.interface:Processed: renal papillary cancer → []
# INFO     - ontoma.interface - Processed: renal clear cell carcinoma → [OnTomaResult(query='renal clear cell carcinoma', id_normalised='EFO:0000349', id_ot_schema='EFO_0000349', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0000349', label='clear cell renal carcinoma')]
# INFO:ontoma.interface:Processed: renal clear cell carcinoma → [OnTomaResult(query='renal clear cell carcinoma', id_normalised='EFO:0000349', id_ot_schema='EFO_0000349', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0000349', label='clear cell renal carcinoma')]
# INFO     - ontoma.interface - Processed: Congenital hypotonia, epilepsy, developmental delay, and digital anomalies → [OnTomaResult(query='Congenital hypotonia, epilepsy, developmental delay, and digital anomalies', id_normalised='MONDO:0032781', id_ot_schema='MONDO_0032781', id_full_uri='http://purl.obolibrary.org/obo/MONDO_0032781', label='congenital hypotonia, epilepsy, developmental delay, and digital anomalies')]
# INFO:ontoma.interface:Processed: Congenital hypotonia, epilepsy, developmental delay, and digital anomalies → [OnTomaResult(query='Congenital hypotonia, epilepsy, developmental delay, and digital anomalies', id_normalised='MONDO:0032781', id_ot_schema='MONDO_0032781', id_full_uri='http://purl.obolibrary.org/obo/MONDO_0032781', label='congenital hypotonia, epilepsy, developmental delay, and digital anomalies')]
# INFO     - ontoma.interface - Processed: Muscular dystrophy-dystroglycanopathy congenital with brain and eye anomali → []
# INFO:ontoma.interface:Processed: Muscular dystrophy-dystroglycanopathy congenital with brain and eye anomali → []
# INFO     - ontoma.interface - Processed: lung cancer → [OnTomaResult(query='lung cancer', id_normalised='MONDO:0008903', id_ot_schema='MONDO_0008903', id_full_uri='http://purl.obolibrary.org/obo/MONDO_0008903', label='lung cancer')]
# INFO:ontoma.interface:Processed: lung cancer → [OnTomaResult(query='lung cancer', id_normalised='MONDO:0008903', id_ot_schema='MONDO_0008903', id_full_uri='http://purl.obolibrary.org/obo/MONDO_0008903', label='lung cancer')]
# INFO     - ontoma.interface - Processed: ovarian clear cell adenocarcinoma → [OnTomaResult(query='ovarian clear cell adenocarcinoma', id_normalised='EFO:1000042', id_ot_schema='EFO_1000042', id_full_uri='http://www.ebi.ac.uk/efo/EFO_1000042', label='ovarian clear cell adenocarcinoma')]
# INFO:ontoma.interface:Processed: ovarian clear cell adenocarcinoma → [OnTomaResult(query='ovarian clear cell adenocarcinoma', id_normalised='EFO:1000042', id_ot_schema='EFO_1000042', id_full_uri='http://www.ebi.ac.uk/efo/EFO_1000042', label='ovarian clear cell adenocarcinoma')]
# INFO     - ontoma.interface - Processed: uterine cancer → [OnTomaResult(query='uterine cancer', id_normalised='MONDO:0002715', id_ot_schema='MONDO_0002715', id_full_uri='http://purl.obolibrary.org/obo/MONDO_0002715', label='uterine cancer')]
# INFO:ontoma.interface:Processed: uterine cancer → [OnTomaResult(query='uterine cancer', id_normalised='MONDO:0002715', id_ot_schema='MONDO_0002715', id_full_uri='http://purl.obolibrary.org/obo/MONDO_0002715', label='uterine cancer')]
# INFO     - ontoma.interface - Processed: Burkitt lymphoma → [OnTomaResult(query='Burkitt lymphoma', id_normalised='EFO:0000309', id_ot_schema='EFO_0000309', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0000309', label='burkitts lymphoma')]
# INFO:ontoma.interface:Processed: Burkitt lymphoma → [OnTomaResult(query='Burkitt lymphoma', id_normalised='EFO:0000309', id_ot_schema='EFO_0000309', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0000309', label='burkitts lymphoma')]
# INFO     - ontoma.interface - Processed: Non-Hodgkin lymphoma → [OnTomaResult(query='Non-Hodgkin lymphoma', id_normalised='EFO:0005952', id_ot_schema='EFO_0005952', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0005952', label='non-hodgkins lymphoma')]
# INFO:ontoma.interface:Processed: Non-Hodgkin lymphoma → [OnTomaResult(query='Non-Hodgkin lymphoma', id_normalised='EFO:0005952', id_ot_schema='EFO_0005952', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0005952', label='non-hodgkins lymphoma')]
# INFO     - ontoma.interface - Processed: bladder transitional cell carcinoma → [OnTomaResult(query='bladder transitional cell carcinoma', id_normalised='EFO:0006544', id_ot_schema='EFO_0006544', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0006544', label='bladder transitional cell carcinoma')]
# INFO:ontoma.interface:Processed: bladder transitional cell carcinoma → [OnTomaResult(query='bladder transitional cell carcinoma', id_normalised='EFO:0006544', id_ot_schema='EFO_0006544', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0006544', label='bladder transitional cell carcinoma')]
# INFO     - ontoma.interface - Processed: Neurodevelopmental disorder with dysmorphic facies and distal limb anomalie → []
# INFO:ontoma.interface:Processed: Neurodevelopmental disorder with dysmorphic facies and distal limb anomalie → []
# INFO     - ontoma.interface - Processed: colorectal cancer cell line → []
# INFO:ontoma.interface:Processed: colorectal cancer cell line → []
# INFO     - ontoma.interface - Processed: Colon cancer → [OnTomaResult(query='Colon cancer', id_normalised='MONDO:0021063', id_ot_schema='MONDO_0021063', id_full_uri='http://purl.obolibrary.org/obo/MONDO_0021063', label='malignant colon neoplasm'), OnTomaResult(query='Colon cancer', id_normalised='EFO:1001950', id_ot_schema='EFO_1001950', id_full_uri='http://www.ebi.ac.uk/efo/EFO_1001950', label='colon carcinoma')]
# INFO:ontoma.interface:Processed: Colon cancer → [OnTomaResult(query='Colon cancer', id_normalised='MONDO:0021063', id_ot_schema='MONDO_0021063', id_full_uri='http://purl.obolibrary.org/obo/MONDO_0021063', label='malignant colon neoplasm'), OnTomaResult(query='Colon cancer', id_normalised='EFO:1001950', id_ot_schema='EFO_1001950', id_full_uri='http://www.ebi.ac.uk/efo/EFO_1001950', label='colon carcinoma')]
# INFO     - ontoma.interface - Processed: Ovarian cancer → [OnTomaResult(query='Ovarian cancer', id_normalised='MONDO:0008170', id_ot_schema='MONDO_0008170', id_full_uri='http://purl.obolibrary.org/obo/MONDO_0008170', label='ovarian cancer')]
# INFO:ontoma.interface:Processed: Ovarian cancer → [OnTomaResult(query='Ovarian cancer', id_normalised='MONDO:0008170', id_ot_schema='MONDO_0008170', id_full_uri='http://purl.obolibrary.org/obo/MONDO_0008170', label='ovarian cancer')]
# INFO     - ontoma.interface - Processed: Renal cancer → [OnTomaResult(query='Renal cancer', id_normalised='EFO:0002890', id_ot_schema='EFO_0002890', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0002890', label='renal carcinoma'), OnTomaResult(query='Renal cancer', id_normalised='EFO:0003865', id_ot_schema='EFO_0003865', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0003865', label='kidney neoplasm')]
# INFO:ontoma.interface:Processed: Renal cancer → [OnTomaResult(query='Renal cancer', id_normalised='EFO:0002890', id_ot_schema='EFO_0002890', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0002890', label='renal carcinoma'), OnTomaResult(query='Renal cancer', id_normalised='EFO:0003865', id_ot_schema='EFO_0003865', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0003865', label='kidney neoplasm')]
# INFO     - ontoma.interface - Processed: Lung cancer → [OnTomaResult(query='Lung cancer', id_normalised='MONDO:0008903', id_ot_schema='MONDO_0008903', id_full_uri='http://purl.obolibrary.org/obo/MONDO_0008903', label='lung cancer')]
# INFO:ontoma.interface:Processed: Lung cancer → [OnTomaResult(query='Lung cancer', id_normalised='MONDO:0008903', id_ot_schema='MONDO_0008903', id_full_uri='http://purl.obolibrary.org/obo/MONDO_0008903', label='lung cancer')]
# INFO     - ontoma.interface - Processed: Pancreas cancer → [OnTomaResult(query='Pancreas cancer', id_normalised='EFO:1000359', id_ot_schema='EFO_1000359', id_full_uri='http://www.ebi.ac.uk/efo/EFO_1000359', label='malignant pancreatic neoplasm')]
# INFO:ontoma.interface:Processed: Pancreas cancer → [OnTomaResult(query='Pancreas cancer', id_normalised='EFO:1000359', id_ot_schema='EFO_1000359', id_full_uri='http://www.ebi.ac.uk/efo/EFO_1000359', label='malignant pancreatic neoplasm')]
# INFO     - ontoma.interface - Processed: Bladder cancer → [OnTomaResult(query='Bladder cancer', id_normalised='EFO:0000292', id_ot_schema='EFO_0000292', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0000292', label='bladder carcinoma')]
# INFO:ontoma.interface:Processed: Bladder cancer → [OnTomaResult(query='Bladder cancer', id_normalised='EFO:0000292', id_ot_schema='EFO_0000292', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0000292', label='bladder carcinoma')]
# INFO     - ontoma.interface - Processed: Colorectal cancer → [OnTomaResult(query='Colorectal cancer', id_normalised='EFO:0005842', id_ot_schema='EFO_0005842', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0005842', label='colorectal cancer')]
# INFO:ontoma.interface:Processed: Colorectal cancer → [OnTomaResult(query='Colorectal cancer', id_normalised='EFO:0005842', id_ot_schema='EFO_0005842', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0005842', label='colorectal cancer')]
# INFO     - ontoma.interface - Processed: Pancreatic cancer → [OnTomaResult(query='Pancreatic cancer', id_normalised='EFO:0003860', id_ot_schema='EFO_0003860', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0003860', label='pancreatic neoplasm'), OnTomaResult(query='Pancreatic cancer', id_normalised='EFO:1000359', id_ot_schema='EFO_1000359', id_full_uri='http://www.ebi.ac.uk/efo/EFO_1000359', label='malignant pancreatic neoplasm')]
# INFO:ontoma.interface:Processed: Pancreatic cancer → [OnTomaResult(query='Pancreatic cancer', id_normalised='EFO:0003860', id_ot_schema='EFO_0003860', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0003860', label='pancreatic neoplasm'), OnTomaResult(query='Pancreatic cancer', id_normalised='EFO:1000359', id_ot_schema='EFO_1000359', id_full_uri='http://www.ebi.ac.uk/efo/EFO_1000359', label='malignant pancreatic neoplasm')]
# INFO     - ontoma.interface - Processed: Mental retardation and microcephaly with pontine and cerebellar hypoplasia → [OnTomaResult(query='Mental retardation and microcephaly with pontine and cerebellar hypoplasia', id_normalised='ORDO:163937', id_ot_schema='Orphanet_163937', id_full_uri='http://www.orpha.net/ORDO/Orphanet_163937', label='x-linked intellectual disability, najm type')]
# INFO:ontoma.interface:Processed: Mental retardation and microcephaly with pontine and cerebellar hypoplasia → [OnTomaResult(query='Mental retardation and microcephaly with pontine and cerebellar hypoplasia', id_normalised='ORDO:163937', id_ot_schema='Orphanet_163937', id_full_uri='http://www.orpha.net/ORDO/Orphanet_163937', label='x-linked intellectual disability, najm type')]
# INFO     - ontoma.interface - Processed: Intellectual developmental disorder with hypertelorism and distinctive faci → []
# INFO:ontoma.interface:Processed: Intellectual developmental disorder with hypertelorism and distinctive faci → []
# INFO     - ontoma.interface - Processed: gastric cancer → [OnTomaResult(query='gastric cancer', id_normalised='MONDO:0001056', id_ot_schema='MONDO_0001056', id_full_uri='http://purl.obolibrary.org/obo/MONDO_0001056', label='gastric cancer')]
# INFO:ontoma.interface:Processed: gastric cancer → [OnTomaResult(query='gastric cancer', id_normalised='MONDO:0001056', id_ot_schema='MONDO_0001056', id_full_uri='http://purl.obolibrary.org/obo/MONDO_0001056', label='gastric cancer')]
# INFO     - ontoma.interface - Processed: diffuse gastric cancer → []
# INFO:ontoma.interface:Processed: diffuse gastric cancer → []
# INFO     - ontoma.interface - Processed: Lobular breast carcinoma → [OnTomaResult(query='Lobular breast carcinoma', id_normalised='EFO:0008509', id_ot_schema='EFO_0008509', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0008509', label='lobular breast carcinoma')]
# INFO:ontoma.interface:Processed: Lobular breast carcinoma → [OnTomaResult(query='Lobular breast carcinoma', id_normalised='EFO:0008509', id_ot_schema='EFO_0008509', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0008509', label='lobular breast carcinoma')]
# INFO     - ontoma.interface - Processed: gastric carcinoma → [OnTomaResult(query='gastric carcinoma', id_normalised='EFO:0000178', id_ot_schema='EFO_0000178', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0000178', label='gastric carcinoma')]
# INFO:ontoma.interface:Processed: gastric carcinoma → [OnTomaResult(query='gastric carcinoma', id_normalised='EFO:0000178', id_ot_schema='EFO_0000178', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0000178', label='gastric carcinoma')]
# INFO     - ontoma.interface - Processed: thyroid cancer → [OnTomaResult(query='thyroid cancer', id_normalised='MONDO:0002108', id_ot_schema='MONDO_0002108', id_full_uri='http://purl.obolibrary.org/obo/MONDO_0002108', label='thyroid cancer')]
# INFO:ontoma.interface:Processed: thyroid cancer → [OnTomaResult(query='thyroid cancer', id_normalised='MONDO:0002108', id_ot_schema='MONDO_0002108', id_full_uri='http://purl.obolibrary.org/obo/MONDO_0002108', label='thyroid cancer')]
# INFO     - ontoma.interface - Processed: ovarian carcinoma → [OnTomaResult(query='ovarian carcinoma', id_normalised='EFO:0001075', id_ot_schema='EFO_0001075', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0001075', label='ovarian carcinoma')]
# INFO:ontoma.interface:Processed: ovarian carcinoma → [OnTomaResult(query='ovarian carcinoma', id_normalised='EFO:0001075', id_ot_schema='EFO_0001075', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0001075', label='ovarian carcinoma')]
# INFO     - ontoma.interface - Processed: ovarian mucinous carcinoma → [OnTomaResult(query='ovarian mucinous carcinoma', id_normalised='EFO:0006462', id_ot_schema='EFO_0006462', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0006462', label='ovarian mucinous adenocarcinoma')]
# INFO:ontoma.interface:Processed: ovarian mucinous carcinoma → [OnTomaResult(query='ovarian mucinous carcinoma', id_normalised='EFO:0006462', id_ot_schema='EFO_0006462', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0006462', label='ovarian mucinous adenocarcinoma')]
# INFO     - ontoma.interface - Processed: ovarian papillary serous adenocarcinoma → [OnTomaResult(query='ovarian papillary serous adenocarcinoma', id_normalised='EFO:0002917', id_ot_schema='EFO_0002917', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0002917', label='ovarian serous adenocarcinoma')]
# INFO:ontoma.interface:Processed: ovarian papillary serous adenocarcinoma → [OnTomaResult(query='ovarian papillary serous adenocarcinoma', id_normalised='EFO:0002917', id_ot_schema='EFO_0002917', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0002917', label='ovarian serous adenocarcinoma')]
# INFO     - ontoma.interface - Processed: Intrauterine growth retardation, metaphyseal dysplasia, adrenal hypoplasia → []
# INFO:ontoma.interface:Processed: Intrauterine growth retardation, metaphyseal dysplasia, adrenal hypoplasia → []
# INFO     - ontoma.interface - Processed: familial melanoma → [OnTomaResult(query='familial melanoma', id_normalised='ORDO:618', id_ot_schema='Orphanet_618', id_full_uri='http://www.orpha.net/ORDO/Orphanet_618', label='familial melanoma')]
# INFO:ontoma.interface:Processed: familial melanoma → [OnTomaResult(query='familial melanoma', id_normalised='ORDO:618', id_ot_schema='Orphanet_618', id_full_uri='http://www.orpha.net/ORDO/Orphanet_618', label='familial melanoma')]
# INFO     - ontoma.interface - Processed: lung tumor → [OnTomaResult(query='lung tumor', id_normalised='MONDO:0021117', id_ot_schema='MONDO_0021117', id_full_uri='http://purl.obolibrary.org/obo/MONDO_0021117', label='lung neoplasm')]
# INFO:ontoma.interface:Processed: lung tumor → [OnTomaResult(query='lung tumor', id_normalised='MONDO:0021117', id_ot_schema='MONDO_0021117', id_full_uri='http://purl.obolibrary.org/obo/MONDO_0021117', label='lung neoplasm')]
# INFO     - ontoma.interface - Processed: melanoma → [OnTomaResult(query='melanoma', id_normalised='EFO:0000756', id_ot_schema='EFO_0000756', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0000756', label='melanoma')]
# INFO:ontoma.interface:Processed: melanoma → [OnTomaResult(query='melanoma', id_normalised='EFO:0000756', id_ot_schema='EFO_0000756', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0000756', label='melanoma')]
# INFO     - ontoma.interface - Processed: pancreas tumor → [OnTomaResult(query='pancreas tumor', id_normalised='EFO:0003860', id_ot_schema='EFO_0003860', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0003860', label='pancreatic neoplasm')]
# INFO:ontoma.interface:Processed: pancreas tumor → [OnTomaResult(query='pancreas tumor', id_normalised='EFO:0003860', id_ot_schema='EFO_0003860', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0003860', label='pancreatic neoplasm')]
# INFO     - ontoma.interface - Processed: Pancreas carcinoma → [OnTomaResult(query='Pancreas carcinoma', id_normalised='EFO:0002618', id_ot_schema='EFO_0002618', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0002618', label='pancreatic carcinoma')]
# INFO:ontoma.interface:Processed: Pancreas carcinoma → [OnTomaResult(query='Pancreas carcinoma', id_normalised='EFO:0002618', id_ot_schema='EFO_0002618', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0002618', label='pancreatic carcinoma')]
# INFO     - ontoma.interface - Processed: Non-small cell lung carcinoma → [OnTomaResult(query='Non-small cell lung carcinoma', id_normalised='EFO:0003060', id_ot_schema='EFO_0003060', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0003060', label='non-small cell lung carcinoma')]
# INFO:ontoma.interface:Processed: Non-small cell lung carcinoma → [OnTomaResult(query='Non-small cell lung carcinoma', id_normalised='EFO:0003060', id_ot_schema='EFO_0003060', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0003060', label='non-small cell lung carcinoma')]
# INFO     - ontoma.interface - Processed: esophagus tumor → [OnTomaResult(query='esophagus tumor', id_normalised='MONDO:0021355', id_ot_schema='MONDO_0021355', id_full_uri='http://purl.obolibrary.org/obo/MONDO_0021355', label='neoplasm of esophagus')]
# INFO:ontoma.interface:Processed: esophagus tumor → [OnTomaResult(query='esophagus tumor', id_normalised='MONDO:0021355', id_ot_schema='MONDO_0021355', id_full_uri='http://purl.obolibrary.org/obo/MONDO_0021355', label='neoplasm of esophagus')]
# INFO     - ontoma.interface - Processed: bladder tumor → [OnTomaResult(query='bladder tumor', id_normalised='EFO:0000294', id_ot_schema='EFO_0000294', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0000294', label='bladder tumor')]
# INFO:ontoma.interface:Processed: bladder tumor → [OnTomaResult(query='bladder tumor', id_normalised='EFO:0000294', id_ot_schema='EFO_0000294', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0000294', label='bladder tumor')]
# INFO     - ontoma.interface - Processed: Neck tumor → [OnTomaResult(query='Neck tumor', id_normalised='MONDO:0021351', id_ot_schema='MONDO_0021351', id_full_uri='http://purl.obolibrary.org/obo/MONDO_0021351', label='neoplasm of neck')]
# INFO:ontoma.interface:Processed: Neck tumor → [OnTomaResult(query='Neck tumor', id_normalised='MONDO:0021351', id_ot_schema='MONDO_0021351', id_full_uri='http://purl.obolibrary.org/obo/MONDO_0021351', label='neoplasm of neck')]
# INFO     - ontoma.interface - Processed: Leukemia → [OnTomaResult(query='Leukemia', id_normalised='EFO:0000565', id_ot_schema='EFO_0000565', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0000565', label='leukemia')]
# INFO:ontoma.interface:Processed: Leukemia → [OnTomaResult(query='Leukemia', id_normalised='EFO:0000565', id_ot_schema='EFO_0000565', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0000565', label='leukemia')]
# INFO     - ontoma.interface - Processed: Squamous cell carcinoma → [OnTomaResult(query='Squamous cell carcinoma', id_normalised='EFO:0000707', id_ot_schema='EFO_0000707', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0000707', label='squamous cell carcinoma')]
# INFO:ontoma.interface:Processed: Squamous cell carcinoma → [OnTomaResult(query='Squamous cell carcinoma', id_normalised='EFO:0000707', id_ot_schema='EFO_0000707', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0000707', label='squamous cell carcinoma')]
# INFO     - ontoma.interface - Processed: Lung adenocarcinoma → [OnTomaResult(query='Lung adenocarcinoma', id_normalised='EFO:0000571', id_ot_schema='EFO_0000571', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0000571', label='lung adenocarcinoma')]
# INFO:ontoma.interface:Processed: Lung adenocarcinoma → [OnTomaResult(query='Lung adenocarcinoma', id_normalised='EFO:0000571', id_ot_schema='EFO_0000571', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0000571', label='lung adenocarcinoma')]
# INFO     - ontoma.interface - Processed: osteogenic sarcoma → [OnTomaResult(query='osteogenic sarcoma', id_normalised='EFO:0000637', id_ot_schema='EFO_0000637', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0000637', label='osteosarcoma')]
# INFO:ontoma.interface:Processed: osteogenic sarcoma → [OnTomaResult(query='osteogenic sarcoma', id_normalised='EFO:0000637', id_ot_schema='EFO_0000637', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0000637', label='osteosarcoma')]
# INFO     - ontoma.interface - Processed: Multiple cancers → []
# INFO:ontoma.interface:Processed: Multiple cancers → []
# INFO     - ontoma.interface - Processed: Myasthenic syndrome, congenital, 3C, associated with acetylcholine receptor → []
# INFO:ontoma.interface:Processed: Myasthenic syndrome, congenital, 3C, associated with acetylcholine receptor → []
# INFO     - ontoma.interface - Processed: Low molecular weight proteinuria with hypercalciuria and nephrocalcinosis ( → []
# INFO:ontoma.interface:Processed: Low molecular weight proteinuria with hypercalciuria and nephrocalcinosis ( → []
# INFO     - ontoma.interface - Processed: Intellectual developmental disorder with speech delay, autism and dysmorphi → []
# INFO:ontoma.interface:Processed: Intellectual developmental disorder with speech delay, autism and dysmorphi → []
# INFO     - ontoma.interface - Processed: Breast cancers → [OnTomaResult(query='Breast cancers', id_normalised='EFO:0000305', id_ot_schema='EFO_0000305', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0000305', label='breast carcinoma')]
# INFO:ontoma.interface:Processed: Breast cancers → [OnTomaResult(query='Breast cancers', id_normalised='EFO:0000305', id_ot_schema='EFO_0000305', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0000305', label='breast carcinoma')]
# INFO     - ontoma.interface - Processed: lung carcinoma → [OnTomaResult(query='lung carcinoma', id_normalised='EFO:0001071', id_ot_schema='EFO_0001071', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0001071', label='lung carcinoma')]
# INFO:ontoma.interface:Processed: lung carcinoma → [OnTomaResult(query='lung carcinoma', id_normalised='EFO:0001071', id_ot_schema='EFO_0001071', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0001071', label='lung carcinoma')]
# INFO     - ontoma.interface - Processed: Wilms' tumor → [OnTomaResult(query="Wilms' tumor", id_normalised='ORDO:654', id_ot_schema='Orphanet_654', id_full_uri='http://www.orpha.net/ORDO/Orphanet_654', label='nephroblastoma')]
# INFO:ontoma.interface:Processed: Wilms' tumor → [OnTomaResult(query="Wilms' tumor", id_normalised='ORDO:654', id_ot_schema='Orphanet_654', id_full_uri='http://www.orpha.net/ORDO/Orphanet_654', label='nephroblastoma')]
# INFO     - ontoma.interface - Processed: breast tumor → [OnTomaResult(query='breast tumor', id_normalised='EFO:0003869', id_ot_schema='EFO_0003869', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0003869', label='breast neoplasm')]
# INFO:ontoma.interface:Processed: breast tumor → [OnTomaResult(query='breast tumor', id_normalised='EFO:0003869', id_ot_schema='EFO_0003869', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0003869', label='breast neoplasm')]
# INFO     - ontoma.interface - Processed: prostate tumor → [OnTomaResult(query='prostate tumor', id_normalised='MONDO:0021259', id_ot_schema='MONDO_0021259', id_full_uri='http://purl.obolibrary.org/obo/MONDO_0021259', label='prostate neoplasm')]
# INFO:ontoma.interface:Processed: prostate tumor → [OnTomaResult(query='prostate tumor', id_normalised='MONDO:0021259', id_ot_schema='MONDO_0021259', id_full_uri='http://purl.obolibrary.org/obo/MONDO_0021259', label='prostate neoplasm')]
# INFO     - ontoma.interface - Processed: Hepatocellular carcinoma → [OnTomaResult(query='Hepatocellular carcinoma', id_normalised='EFO:0000182', id_ot_schema='EFO_0000182', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0000182', label='hepatocellular carcinoma')]
# INFO:ontoma.interface:Processed: Hepatocellular carcinoma → [OnTomaResult(query='Hepatocellular carcinoma', id_normalised='EFO:0000182', id_ot_schema='EFO_0000182', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0000182', label='hepatocellular carcinoma')]
# INFO     - ontoma.interface - Processed: Granulomatous disease, chronic, cytochrome-b-negative, autosomal recessive → []
# INFO:ontoma.interface:Processed: Granulomatous disease, chronic, cytochrome-b-negative, autosomal recessive → []
# INFO     - ontoma.interface - Processed: Leukoencephalopathy with brainstem and spinal cord involvement and lactate → []
# INFO:ontoma.interface:Processed: Leukoencephalopathy with brainstem and spinal cord involvement and lactate → []
# INFO     - ontoma.interface - Processed: esophageal carcinoma → [OnTomaResult(query='esophageal carcinoma', id_normalised='EFO:0002916', id_ot_schema='EFO_0002916', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0002916', label='esophageal carcinoma')]
# INFO:ontoma.interface:Processed: esophageal carcinoma → [OnTomaResult(query='esophageal carcinoma', id_normalised='EFO:0002916', id_ot_schema='EFO_0002916', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0002916', label='esophageal carcinoma')]
# INFO     - ontoma.interface - Processed: colorectal carcinoma → [OnTomaResult(query='colorectal carcinoma', id_normalised='EFO:1001951', id_ot_schema='EFO_1001951', id_full_uri='http://www.ebi.ac.uk/efo/EFO_1001951', label='colorectal carcinoma')]
# INFO:ontoma.interface:Processed: colorectal carcinoma → [OnTomaResult(query='colorectal carcinoma', id_normalised='EFO:1001951', id_ot_schema='EFO_1001951', id_full_uri='http://www.ebi.ac.uk/efo/EFO_1001951', label='colorectal carcinoma')]
# INFO     - ontoma.interface - Processed: cancer → [OnTomaResult(query='cancer', id_normalised='EFO:0000311', id_ot_schema='EFO_0000311', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0000311', label='cancer')]
# INFO:ontoma.interface:Processed: cancer → [OnTomaResult(query='cancer', id_normalised='EFO:0000311', id_ot_schema='EFO_0000311', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0000311', label='cancer')]
# INFO     - ontoma.interface - Processed: Neurodevelopmental disorder with seizures and speech and walking impairment → [OnTomaResult(query='Neurodevelopmental disorder with seizures and speech and walking impairment', id_normalised='MONDO:0000508', id_ot_schema='MONDO_0000508', id_full_uri='http://purl.obolibrary.org/obo/MONDO_0000508', label='syndromic intellectual disability')]
# INFO:ontoma.interface:Processed: Neurodevelopmental disorder with seizures and speech and walking impairment → [OnTomaResult(query='Neurodevelopmental disorder with seizures and speech and walking impairment', id_normalised='MONDO:0000508', id_ot_schema='MONDO_0000508', id_full_uri='http://purl.obolibrary.org/obo/MONDO_0000508', label='syndromic intellectual disability')]
# INFO     - ontoma.interface - Processed: Neurodevelopmental disorder with severe motor impairment and absent languag → []
# INFO:ontoma.interface:Processed: Neurodevelopmental disorder with severe motor impairment and absent languag → []
# INFO     - ontoma.interface - Processed: glioma → [OnTomaResult(query='glioma', id_normalised='EFO:0005543', id_ot_schema='EFO_0005543', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0005543', label='glioma')]
# INFO:ontoma.interface:Processed: glioma → [OnTomaResult(query='glioma', id_normalised='EFO:0005543', id_ot_schema='EFO_0005543', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0005543', label='glioma')]
# INFO     - ontoma.interface - Processed: glioma cell line → []
# INFO:ontoma.interface:Processed: glioma cell line → []
# INFO     - ontoma.interface - Processed: lung small cell carcinoma → [OnTomaResult(query='lung small cell carcinoma', id_normalised='EFO:0000702', id_ot_schema='EFO_0000702', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0000702', label='small cell lung carcinoma')]
# INFO:ontoma.interface:Processed: lung small cell carcinoma → [OnTomaResult(query='lung small cell carcinoma', id_normalised='EFO:0000702', id_ot_schema='EFO_0000702', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0000702', label='small cell lung carcinoma')]
# INFO     - ontoma.interface - Processed: Muscular dystrophy-dystroglycanopathy congenital with impaired intellectual → []
# INFO:ontoma.interface:Processed: Muscular dystrophy-dystroglycanopathy congenital with impaired intellectual → []
# INFO     - ontoma.interface - Processed: Cardiomyopathy, dilated, with woolly hair, keratoderma, and tooth agenesis → [OnTomaResult(query='Cardiomyopathy, dilated, with woolly hair, keratoderma, and tooth agenesis', id_normalised='ORDO:65282', id_ot_schema='Orphanet_65282', id_full_uri='http://www.orpha.net/ORDO/Orphanet_65282', label='woolly hair-palmoplantar keratoderma-dilated cardiomyopathy syndrome')]
# INFO:ontoma.interface:Processed: Cardiomyopathy, dilated, with woolly hair, keratoderma, and tooth agenesis → [OnTomaResult(query='Cardiomyopathy, dilated, with woolly hair, keratoderma, and tooth agenesis', id_normalised='ORDO:65282', id_ot_schema='Orphanet_65282', id_full_uri='http://www.orpha.net/ORDO/Orphanet_65282', label='woolly hair-palmoplantar keratoderma-dilated cardiomyopathy syndrome')]
# INFO     - ontoma.interface - Processed: Spinal muscular atrophy, lower extremity-predominant 1, autosomal dominant → []
# INFO:ontoma.interface:Processed: Spinal muscular atrophy, lower extremity-predominant 1, autosomal dominant → []
# INFO     - ontoma.interface - Processed: Neurodevelopmental disorder with microcephaly and structural brain anomalie → []
# INFO:ontoma.interface:Processed: Neurodevelopmental disorder with microcephaly and structural brain anomalie → []
# INFO     - ontoma.interface - Processed: Ectodermal dysplasia 10B, hypohidrotic/hair/tooth type, autosomal recessive → []
# INFO:ontoma.interface:Processed: Ectodermal dysplasia 10B, hypohidrotic/hair/tooth type, autosomal recessive → []
# INFO     - ontoma.interface - Processed: Ectodermal dysplasia 10A, hypohidrotic/hair/nail type, autosomal dominant ( → []
# INFO:ontoma.interface:Processed: Ectodermal dysplasia 10A, hypohidrotic/hair/nail type, autosomal dominant ( → []
# INFO     - ontoma.interface - Processed: Ectodermal dysplasia 11B, hypohidrotic/hair/tooth type, autosomal recessive → [OnTomaResult(query='Ectodermal dysplasia 11B, hypohidrotic/hair/tooth type, autosomal recessive', id_normalised='ORDO:238468', id_ot_schema='Orphanet_238468', id_full_uri='http://www.orpha.net/ORDO/Orphanet_238468', label='hypohidrotic ectodermal dysplasia'), OnTomaResult(query='Ectodermal dysplasia 11B, hypohidrotic/hair/tooth type, autosomal recessive', id_normalised='ORDO:248', id_ot_schema='Orphanet_248', id_full_uri='http://www.orpha.net/ORDO/Orphanet_248', label='autosomal recessive hypohidrotic ectodermal dysplasia')]
# INFO:ontoma.interface:Processed: Ectodermal dysplasia 11B, hypohidrotic/hair/tooth type, autosomal recessive → [OnTomaResult(query='Ectodermal dysplasia 11B, hypohidrotic/hair/tooth type, autosomal recessive', id_normalised='ORDO:238468', id_ot_schema='Orphanet_238468', id_full_uri='http://www.orpha.net/ORDO/Orphanet_238468', label='hypohidrotic ectodermal dysplasia'), OnTomaResult(query='Ectodermal dysplasia 11B, hypohidrotic/hair/tooth type, autosomal recessive', id_normalised='ORDO:248', id_ot_schema='Orphanet_248', id_full_uri='http://www.orpha.net/ORDO/Orphanet_248', label='autosomal recessive hypohidrotic ectodermal dysplasia')]
# INFO     - ontoma.interface - Processed: Ichthyotic keratoderma, spasticity, hypomyelination, and dysmorphic facies → []
# INFO:ontoma.interface:Processed: Ichthyotic keratoderma, spasticity, hypomyelination, and dysmorphic facies → []
# INFO     - ontoma.interface - Processed: pancreatic cancer → [OnTomaResult(query='pancreatic cancer', id_normalised='EFO:0003860', id_ot_schema='EFO_0003860', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0003860', label='pancreatic neoplasm'), OnTomaResult(query='pancreatic cancer', id_normalised='EFO:1000359', id_ot_schema='EFO_1000359', id_full_uri='http://www.ebi.ac.uk/efo/EFO_1000359', label='malignant pancreatic neoplasm')]
# INFO:ontoma.interface:Processed: pancreatic cancer → [OnTomaResult(query='pancreatic cancer', id_normalised='EFO:0003860', id_ot_schema='EFO_0003860', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0003860', label='pancreatic neoplasm'), OnTomaResult(query='pancreatic cancer', id_normalised='EFO:1000359', id_ot_schema='EFO_1000359', id_full_uri='http://www.ebi.ac.uk/efo/EFO_1000359', label='malignant pancreatic neoplasm')]
# INFO     - ontoma.interface - Processed: bladder carcinoma NOS → []
# INFO:ontoma.interface:Processed: bladder carcinoma NOS → []
# INFO     - ontoma.interface - Processed: hepatocellular carcinoma → [OnTomaResult(query='hepatocellular carcinoma', id_normalised='EFO:0000182', id_ot_schema='EFO_0000182', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0000182', label='hepatocellular carcinoma')]
# INFO:ontoma.interface:Processed: hepatocellular carcinoma → [OnTomaResult(query='hepatocellular carcinoma', id_normalised='EFO:0000182', id_ot_schema='EFO_0000182', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0000182', label='hepatocellular carcinoma')]
# INFO     - ontoma.interface - Processed: Erythroleukemia → [OnTomaResult(query='Erythroleukemia', id_normalised='EFO:1001955', id_ot_schema='EFO_1001955', id_full_uri='http://www.ebi.ac.uk/efo/EFO_1001955', label='erythroleukemia')]
# INFO:ontoma.interface:Processed: Erythroleukemia → [OnTomaResult(query='Erythroleukemia', id_normalised='EFO:1001955', id_ot_schema='EFO_1001955', id_full_uri='http://www.ebi.ac.uk/efo/EFO_1001955', label='erythroleukemia')]
# INFO     - ontoma.interface - Processed: Deafness, autosomal recessive, 36, with or without vestibular involvement ( → []
# INFO:ontoma.interface:Processed: Deafness, autosomal recessive, 36, with or without vestibular involvement ( → []
# INFO     - ontoma.interface - Processed: Infections, recurrent, associated with encephalopathy, hepatic dysfunction → []
# INFO:ontoma.interface:Processed: Infections, recurrent, associated with encephalopathy, hepatic dysfunction → []
# INFO     - ontoma.interface - Processed: Poikiloderma, hereditary fibrosing, with tendon contractures, myopathy, and → []
# INFO:ontoma.interface:Processed: Poikiloderma, hereditary fibrosing, with tendon contractures, myopathy, and → []
# INFO     - ontoma.interface - Processed: Intellectual developmental disorder with dysmorphic facies and behavioral a → []
# INFO:ontoma.interface:Processed: Intellectual developmental disorder with dysmorphic facies and behavioral a → []
# INFO     - ontoma.interface - Processed: Esophagus cancer → [OnTomaResult(query='Esophagus cancer', id_normalised='MONDO:0007576', id_ot_schema='MONDO_0007576', id_full_uri='http://purl.obolibrary.org/obo/MONDO_0007576', label='esophageal cancer')]
# INFO:ontoma.interface:Processed: Esophagus cancer → [OnTomaResult(query='Esophagus cancer', id_normalised='MONDO:0007576', id_ot_schema='MONDO_0007576', id_full_uri='http://purl.obolibrary.org/obo/MONDO_0007576', label='esophageal cancer')]
# INFO     - ontoma.interface - Processed: acute lymphoblastic leukemia cell line → []
# INFO:ontoma.interface:Processed: acute lymphoblastic leukemia cell line → []
# ...
# INFO:ontoma.interface:Processed: non-small cell lung cancer cell line → []
# INFO     - ontoma.interface - Processed: Neurodevelopmental disorder with or without anomalies of the brain, eye, or → []
# INFO:ontoma.interface:Processed: Neurodevelopmental disorder with or without anomalies of the brain, eye, or → []
# INFO     - ontoma.interface - Processed: Thyroid carcinoma → [OnTomaResult(query='Thyroid carcinoma', id_normalised='EFO:0002892', id_ot_schema='EFO_0002892', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0002892', label='thyroid carcinoma')]
# INFO:ontoma.interface:Processed: Thyroid carcinoma → [OnTomaResult(query='Thyroid carcinoma', id_normalised='EFO:0002892', id_ot_schema='EFO_0002892', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0002892', label='thyroid carcinoma')]
# INFO     - ontoma.interface - Processed: Intellectual developmental disorder with or without epilepsy or cerebellar → []
# INFO:ontoma.interface:Processed: Intellectual developmental disorder with or without epilepsy or cerebellar → []
# INFO     - ontoma.interface - Processed: Colorectal adenocarcinomas cell line → []
# INFO:ontoma.interface:Processed: Colorectal adenocarcinomas cell line → []
# INFO     - ontoma.interface - Processed: Optic atrophy 10 with or without ataxia, mental retardation, and seizures ( → []
# INFO:ontoma.interface:Processed: Optic atrophy 10 with or without ataxia, mental retardation, and seizures ( → []
# INFO     - ontoma.interface - Processed: Ventricular tachycardia, catecholaminergic polymorphic, 1, with or without → []
# INFO:ontoma.interface:Processed: Ventricular tachycardia, catecholaminergic polymorphic, 1, with or without → []
# INFO     - ontoma.interface - Processed: rhabdomyosarcoma → [OnTomaResult(query='rhabdomyosarcoma', id_normalised='EFO:0002918', id_ot_schema='EFO_0002918', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0002918', label='rhabdomyosarcoma')]
# INFO:ontoma.interface:Processed: rhabdomyosarcoma → [OnTomaResult(query='rhabdomyosarcoma', id_normalised='EFO:0002918', id_ot_schema='EFO_0002918', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0002918', label='rhabdomyosarcoma')]
# INFO     - ontoma.interface - Processed: Metabolic crises, recurrent, with variable encephalomyopathic features and → []
# INFO:ontoma.interface:Processed: Metabolic crises, recurrent, with variable encephalomyopathic features and → []
# INFO     - ontoma.interface - Processed: colorectal carcinoma → [OnTomaResult(query='colorectal carcinoma', id_normalised='EFO:1001951', id_ot_schema='EFO_1001951', id_full_uri='http://www.ebi.ac.uk/efo/EFO_1001951', label='colorectal carcinoma')]
# INFO:ontoma.interface:Processed: colorectal carcinoma → [OnTomaResult(query='colorectal carcinoma', id_normalised='EFO:1001951', id_ot_schema='EFO_1001951', id_full_uri='http://www.ebi.ac.uk/efo/EFO_1001951', label='colorectal carcinoma')]
# INFO     - ontoma.interface - Processed: Pancreatic carcinoma → [OnTomaResult(query='Pancreatic carcinoma', id_normalised='EFO:0002618', id_ot_schema='EFO_0002618', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0002618', label='pancreatic carcinoma')]
# INFO:ontoma.interface:Processed: Pancreatic carcinoma → [OnTomaResult(query='Pancreatic carcinoma', id_normalised='EFO:0002618', id_ot_schema='EFO_0002618', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0002618', label='pancreatic carcinoma')]
# INFO     - ontoma.interface - Processed: Developmental and epileptic encephalopathy 85 with or without midline brain → []
# INFO:ontoma.interface:Processed: Developmental and epileptic encephalopathy 85 with or without midline brain → []
# INFO     - ontoma.interface - Processed: Basal cell carcinoma → [OnTomaResult(query='Basal cell carcinoma', id_normalised='EFO:0004193', id_ot_schema='EFO_0004193', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0004193', label='basal cell carcinoma')]
# INFO:ontoma.interface:Processed: Basal cell carcinoma → [OnTomaResult(query='Basal cell carcinoma', id_normalised='EFO:0004193', id_ot_schema='EFO_0004193', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0004193', label='basal cell carcinoma')]
# INFO     - ontoma.interface - Processed: Basal cell carcinomas → []
# INFO:ontoma.interface:Processed: Basal cell carcinomas → []
# INFO     - ontoma.interface - Processed: Neurodevelopmental disorder with microcephaly, arthrogryposis, and structur → []
# INFO:ontoma.interface:Processed: Neurodevelopmental disorder with microcephaly, arthrogryposis, and structur → []
# INFO     - ontoma.interface - Processed: Cervical cancer → [OnTomaResult(query='Cervical cancer', id_normalised='MONDO:0002974', id_ot_schema='MONDO_0002974', id_full_uri='http://purl.obolibrary.org/obo/MONDO_0002974', label='cervical cancer')]
# INFO:ontoma.interface:Processed: Cervical cancer → [OnTomaResult(query='Cervical cancer', id_normalised='MONDO:0002974', id_ot_schema='MONDO_0002974', id_full_uri='http://purl.obolibrary.org/obo/MONDO_0002974', label='cervical cancer')]
# INFO     - ontoma.interface - Processed: Cervical carcinoma → [OnTomaResult(query='Cervical carcinoma', id_normalised='EFO:0001061', id_ot_schema='EFO_0001061', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0001061', label='cervical carcinoma')]
# INFO:ontoma.interface:Processed: Cervical carcinoma → [OnTomaResult(query='Cervical carcinoma', id_normalised='EFO:0001061', id_ot_schema='EFO_0001061', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0001061', label='cervical carcinoma')]
# INFO     - ontoma.interface - Processed: Ovarian carcinoma → [OnTomaResult(query='Ovarian carcinoma', id_normalised='EFO:0001075', id_ot_schema='EFO_0001075', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0001075', label='ovarian carcinoma')]
# INFO:ontoma.interface:Processed: Ovarian carcinoma → [OnTomaResult(query='Ovarian carcinoma', id_normalised='EFO:0001075', id_ot_schema='EFO_0001075', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0001075', label='ovarian carcinoma')]
# INFO     - ontoma.interface - Processed: Gastric carcinoma → [OnTomaResult(query='Gastric carcinoma', id_normalised='EFO:0000178', id_ot_schema='EFO_0000178', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0000178', label='gastric carcinoma')]
# INFO:ontoma.interface:Processed: Gastric carcinoma → [OnTomaResult(query='Gastric carcinoma', id_normalised='EFO:0000178', id_ot_schema='EFO_0000178', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0000178', label='gastric carcinoma')]
# INFO     - ontoma.interface - Processed: ovarian clear cell carcinoma → []
# INFO:ontoma.interface:Processed: ovarian clear cell carcinoma → []
# INFO     - ontoma.interface - Processed: Metabolic crises, recurrent, with rhabdomyolysis, cardiac arrhythmias, and → []
# INFO:ontoma.interface:Processed: Metabolic crises, recurrent, with rhabdomyolysis, cardiac arrhythmias, and → []
# INFO     - ontoma.interface - Processed: Encephalopathy, progressive, early-onset, with brain atrophy and thin corpu → []
# INFO:ontoma.interface:Processed: Encephalopathy, progressive, early-onset, with brain atrophy and thin corpu → []
# INFO     - ontoma.interface - Processed: Ischiocoxopodopatellar syndrome with or without pulmonary arterial hyperten → []
# INFO:ontoma.interface:Processed: Ischiocoxopodopatellar syndrome with or without pulmonary arterial hyperten → []
# INFO     - ontoma.interface - Processed: pancreatic carcinoma → [OnTomaResult(query='pancreatic carcinoma', id_normalised='EFO:0002618', id_ot_schema='EFO_0002618', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0002618', label='pancreatic carcinoma')]
# INFO:ontoma.interface:Processed: pancreatic carcinoma → [OnTomaResult(query='pancreatic carcinoma', id_normalised='EFO:0002618', id_ot_schema='EFO_0002618', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0002618', label='pancreatic carcinoma')]
# INFO     - ontoma.interface - Processed: Acute myeloid leukemias → []
# INFO:ontoma.interface:Processed: Acute myeloid leukemias → []
# INFO     - ontoma.interface - Processed: Chronic myelomonocytic leukemia → [OnTomaResult(query='Chronic myelomonocytic leukemia', id_normalised='EFO:1001779', id_ot_schema='EFO_1001779', id_full_uri='http://www.ebi.ac.uk/efo/EFO_1001779', label='chronic myelomonocytic leukemia')]
# INFO:ontoma.interface:Processed: Chronic myelomonocytic leukemia → [OnTomaResult(query='Chronic myelomonocytic leukemia', id_normalised='EFO:1001779', id_ot_schema='EFO_1001779', id_full_uri='http://www.ebi.ac.uk/efo/EFO_1001779', label='chronic myelomonocytic leukemia')]
# INFO     - ontoma.interface - Processed: chronic myelomonocytic leukemia → [OnTomaResult(query='chronic myelomonocytic leukemia', id_normalised='EFO:1001779', id_ot_schema='EFO_1001779', id_full_uri='http://www.ebi.ac.uk/efo/EFO_1001779', label='chronic myelomonocytic leukemia')]
# INFO:ontoma.interface:Processed: chronic myelomonocytic leukemia → [OnTomaResult(query='chronic myelomonocytic leukemia', id_normalised='EFO:1001779', id_ot_schema='EFO_1001779', id_full_uri='http://www.ebi.ac.uk/efo/EFO_1001779', label='chronic myelomonocytic leukemia')]
# INFO     - ontoma.interface - Processed: Chronic myelomonocytic leukemias → [OnTomaResult(query='Chronic myelomonocytic leukemias', id_normalised='EFO:1001779', id_ot_schema='EFO_1001779', id_full_uri='http://www.ebi.ac.uk/efo/EFO_1001779', label='chronic myelomonocytic leukemia')]
# INFO:ontoma.interface:Processed: Chronic myelomonocytic leukemias → [OnTomaResult(query='Chronic myelomonocytic leukemias', id_normalised='EFO:1001779', id_ot_schema='EFO_1001779', id_full_uri='http://www.ebi.ac.uk/efo/EFO_1001779', label='chronic myelomonocytic leukemia')]
# INFO     - ontoma.interface - Processed: secondary acute myeloid leukemia → [OnTomaResult(query='secondary acute myeloid leukemia', id_normalised='MONDO:0019457', id_ot_schema='MONDO_0019457', id_full_uri='http://purl.obolibrary.org/obo/MONDO_0019457', label='therapy related acute myeloid leukemia and myelodysplastic syndrome')]
# INFO:ontoma.interface:Processed: secondary acute myeloid leukemia → [OnTomaResult(query='secondary acute myeloid leukemia', id_normalised='MONDO:0019457', id_ot_schema='MONDO_0019457', id_full_uri='http://purl.obolibrary.org/obo/MONDO_0019457', label='therapy related acute myeloid leukemia and myelodysplastic syndrome')]
# INFO     - ontoma.interface - Processed: Neurodevelopmental disorder with microcephaly, cortical malformations, and → []
# INFO:ontoma.interface:Processed: Neurodevelopmental disorder with microcephaly, cortical malformations, and → []
# INFO     - ontoma.interface - Processed: Microcephaly, growth restriction, and increased sister chromatid exchange 2 → [OnTomaResult(query='Microcephaly, growth restriction, and increased sister chromatid exchange 2', id_normalised='MONDO:0020628', id_ot_schema='MONDO_0020628', id_full_uri='http://purl.obolibrary.org/obo/MONDO_0020628', label='microcephaly, growth restriction, and increased sister chromatid exchange 2')]
# INFO:ontoma.interface:Processed: Microcephaly, growth restriction, and increased sister chromatid exchange 2 → [OnTomaResult(query='Microcephaly, growth restriction, and increased sister chromatid exchange 2', id_normalised='MONDO:0020628', id_ot_schema='MONDO_0020628', id_full_uri='http://purl.obolibrary.org/obo/MONDO_0020628', label='microcephaly, growth restriction, and increased sister chromatid exchange 2')]
# INFO     - ontoma.interface - Processed: Kidney cancer → [OnTomaResult(query='Kidney cancer', id_normalised='MONDO:0002367', id_ot_schema='MONDO_0002367', id_full_uri='http://purl.obolibrary.org/obo/MONDO_0002367', label='kidney cancer')]
# INFO:ontoma.interface:Processed: Kidney cancer → [OnTomaResult(query='Kidney cancer', id_normalised='MONDO:0002367', id_ot_schema='MONDO_0002367', id_full_uri='http://purl.obolibrary.org/obo/MONDO_0002367', label='kidney cancer')]
# INFO     - ontoma.interface - Processed: Neck cancer → [OnTomaResult(query='Neck cancer', id_normalised='MONDO:0021310', id_ot_schema='MONDO_0021310', id_full_uri='http://purl.obolibrary.org/obo/MONDO_0021310', label='malignant tumor of neck')]
# INFO:ontoma.interface:Processed: Neck cancer → [OnTomaResult(query='Neck cancer', id_normalised='MONDO:0021310', id_ot_schema='MONDO_0021310', id_full_uri='http://purl.obolibrary.org/obo/MONDO_0021310', label='malignant tumor of neck')]
# INFO     - ontoma.interface - Processed: Encephalopathy, progressive, early-onset, with brain atrophy and spasticity → []
# INFO:ontoma.interface:Processed: Encephalopathy, progressive, early-onset, with brain atrophy and spasticity → []
# INFO     - ontoma.interface - Processed: Ventricular tachycardia, catecholaminergic polymorphic, 5, with or without → []
# INFO:ontoma.interface:Processed: Ventricular tachycardia, catecholaminergic polymorphic, 5, with or without → []
# INFO     - ontoma.interface - Processed: Papillary cancer → []
# INFO:ontoma.interface:Processed: Papillary cancer → []
# INFO     - ontoma.interface - Processed: bladder carcinoma → [OnTomaResult(query='bladder carcinoma', id_normalised='EFO:0000292', id_ot_schema='EFO_0000292', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0000292', label='bladder carcinoma')]
# INFO:ontoma.interface:Processed: bladder carcinoma → [OnTomaResult(query='bladder carcinoma', id_normalised='EFO:0000292', id_ot_schema='EFO_0000292', id_full_uri='http://www.ebi.ac.uk/efo/EFO_0000292', label='bladder carcinoma')]
# INFO     - ontoma.interface - Processed: Wilms tumor → [OnTomaResult(query='Wilms tumor', id_normalised='MONDO:0019004', id_ot_schema='MONDO_0019004', id_full_uri='http://purl.obolibrary.org/obo/MONDO_0019004', label='kidney wilms tumor'), OnTomaResult(query='Wilms tumor', id_normalised='ORDO:654', id_ot_schema='Orphanet_654', id_full_uri='http://www.orpha.net/ORDO/Orphanet_654', label='nephroblastoma')]
# INFO:ontoma.interface:Processed: Wilms tumor → [OnTomaResult(query='Wilms tumor', id_normalised='MONDO:0019004', id_ot_schema='MONDO_0019004', id_full_uri='http://purl.obolibrary.org/obo/MONDO_0019004', label='kidney wilms tumor'), OnTomaResult(query='Wilms tumor', id_normalised='ORDO:654', id_ot_schema='Orphanet_654', id_full_uri='http://www.orpha.net/ORDO/Orphanet_654', label='nephroblastoma')]
# INFO     - ontoma.interface - Processed: Neck squamous cell carcinoma → []
# INFO:ontoma.interface:Processed: Neck squamous cell carcinoma → []
# INFO     - ontoma.interface - Processed: Amyotrophic lateral sclerosis 22, with or without frontotemporal dementia ( → []
# INFO:ontoma.interface:Processed: Amyotrophic lateral sclerosis 22, with or without frontotemporal dementia ( → []
# INFO     - ontoma.interface - Processed: Pachygyria, microcephaly, developmental delay, and dysmorphic facies, with → []
# INFO:ontoma.interface:Processed: Pachygyria, microcephaly, developmental delay, and dysmorphic facies, with → []
# INFO     - ontoma.interface - Processed: Amyotrophic lateral sclerosis 15, with or without frontotemporal dementia ( → []
# INFO:ontoma.interface:Processed: Amyotrophic lateral sclerosis 15, with or without frontotemporal dementia ( → []
# INFO     - ontoma.interface - Processed: Neurodevelopmental disorder, mitochondrial, with abnormal movements and lac → []
# INFO:ontoma.interface:Processed: Neurodevelopmental disorder, mitochondrial, with abnormal movements and lac → []
# INFO     - ontoma.interface - Processed: Burkitt lymphoma cell line → []
# INFO:ontoma.interface:Processed: Burkitt lymphoma cell line → []
# INFO     - ontoma.interface - Processed: Neurodevelopmental disorder with impaired speech and hyperkinetic movements → [OnTomaResult(query='Neurodevelopmental disorder with impaired speech and hyperkinetic movements', id_normalised='MONDO:0000508', id_ot_schema='MONDO_0000508', id_full_uri='http://purl.obolibrary.org/obo/MONDO_0000508', label='syndromic intellectual disability')]
# INFO:ontoma.interface:Processed: Neurodevelopmental disorder with impaired speech and hyperkinetic movements → [OnTomaResult(query='Neurodevelopmental disorder with impaired speech and hyperkinetic movements', id_normalised='MONDO:0000508', id_ot_schema='MONDO_0000508', id_full_uri='http://purl.obolibrary.org/obo/MONDO_0000508', label='syndromic intellectual disability')]

# %%
# Get the unique list of diseases and try to map to efo using ontoma:
efo_mapping = pd.DataFrame(
    mapped_diseases
    .to_list()
)


# Joining humsavar data with disease mapping:
humsavar_associations_mapped = (
    associations
    
    # Merging with efo:
    .merge(efo_mapping, on='disease', how='left')
    
    # Selecting only mapped associations
    .loc[lambda df: df.diseaseMappedId.notna()]
    
    # Update disease id:
    .assign(diseaseMappedId = lambda df: df.diseaseMappedId.str.replace(':', '_'))
    
    # Get unique list of associations:
    [['uniprotId', 'diseaseMappedId']]
    .drop_duplicates()
    .assign(humsavar = True)
)

print(f'Number of unique associations with mapped diseases: {len(humsavar_associations_mapped)}')
print(f'Number of unique mapped diseases: {len(humsavar_associations_mapped.diseaseMappedId.unique())}')


# Convert it to spark df:
hs_mapped_df = spark.createDataFrame(humsavar_associations_mapped).persist()
hs_mapped_df.show()
# Out:
# Number of unique associations with mapped diseases: 1567
# Number of unique mapped diseases: 93
# +---------+---------------+--------+
# |uniprotId|diseaseMappedId|humsavar|
# +---------+---------------+--------+
# |   Q6ZMQ8|    EFO_0006462|    true|
# |   Q6ZMQ8|    EFO_0000571|    true|
# |   O95477|    EFO_0005842|    true|
# |   Q86UK0|    EFO_0002517|    true|
# |   Q99758|  MONDO_0007254|    true|
# |   P78363|  MONDO_0007254|    true|
# |   P08183|    EFO_0005842|    true|
# |   Q9NRK6|  MONDO_0007254|    true|
# |   Q2M3G0|    EFO_0005842|    true|
# |   Q2M3G0|    EFO_0002517|    true|
# |   Q9NP58|  MONDO_0007254|    true|
# |   Q9NUT2|  MONDO_0007254|    true|
# |   Q9UBJ2|    EFO_0002517|    true|
# |   Q7Z5M8|  MONDO_0007254|    true|
# |   P00519|    EFO_0003050|    true|
# |   P00519|    EFO_0000756|    true|
# |   Q6H8Q1|    EFO_0002517|    true|
# |   Q13085|    EFO_0005842|    true|
# |   O00763|    EFO_0002517|    true|
# |   P11310|  MONDO_0007254|    true|
# +---------+---------------+--------+
# only showing top 20 rows

# %% [markdown]
# Join this mapped dataset with our uniprot associations:

# %%
uniprot_df = (
    spark.read.json('cttv011-11-10-2021.json.gz')
    .select('diseaseFromSource', 'diseaseFromSourceId', 'confidence', 'diseaseFromSourceMappedId', 'targetFromSourceId')
    .distinct()
    .persist()
)


print(uniprot_df.count())
print(uniprot_df.select('diseaseFromSourceMappedId', 'targetFromSourceId').distinct().count())


uniprot_assoc = (
    uniprot_df
    
    # Selecting and renaming relevant columns:
    .select('diseaseFromSourceMappedId', 'targetFromSourceId')
    .withColumnRenamed('targetFromSourceId', 'uniprotId')
    .withColumnRenamed('diseaseFromSourceMappedId', 'diseaseMappedId')

    # Generate associations:
    .distinct()
    
    # Annotate source:
    .withColumn('uniprot', lit(True))
    .persist()
)

uniprot_assoc.show()
# Out:
# 7754
# 7396
# +---------------+---------+-------+
# |diseaseMappedId|uniprotId|uniprot|
# +---------------+---------+-------+
# |    EFO_0009070|   P55201|   true|
# |  MONDO_0032910|   A1L188|   true|
# |  Orphanet_3337|   Q06495|   true|
# |Orphanet_169446|   P29597|   true|
# | Orphanet_79351|   O43175|   true|
# |  Orphanet_1934|   Q8NC96|   true|
# |   Orphanet_610|   P12111|   true|
# | Orphanet_95716|   P07202|   true|
# | Orphanet_63454|   Q16644|   true|
# |   Orphanet_154|   P49810|   true|
# |Orphanet_166081|   P04275|   true|
# |   Orphanet_791|   Q9NZN9|   true|
# |   Orphanet_334|   Q8IWT1|   true|
# |  Orphanet_1020|   P49810|   true|
# |   Orphanet_822|   P16157|   true|
# |           null|   Q9C0K0|   true|
# |   Orphanet_740|   P02545|   true|
# |Orphanet_314689|   Q13043|   true|
# |  MONDO_0029134|   Q6F5E8|   true|
# |    EFO_0000279|   Q8TBY8|   true|
# +---------------+---------+-------+
# only showing top 20 rows

# %%
get_sources = udf(
    lambda humsavar, uniprot: 'both' if humsavar and uniprot else 'uniprot' if uniprot else 'humsavar',
    StringType()
)

joined_df = (
    hs_mapped_df
    .join(uniprot_assoc, on = ['diseaseMappedId', 'uniprotId'], how='outer')
    .withColumn('source', get_sources(col('humsavar'), col('uniprot')))
    .persist()
)

print(
    joined_df
    .groupBy('source')
    .count()
    .toPandas()
    .to_markdown(index=False)
)

joined_df.show()
# Out:
# | source   |   count |
# |:---------|--------:|
# | humsavar |    1557 |
# | both     |      10 |
# | uniprot  |    7386 |
# +---------------+---------+--------+-------+--------+
# |diseaseMappedId|uniprotId|humsavar|uniprot|  source|
# +---------------+---------+--------+-------+--------+
# |           null|   Q9C0K0|    null|   true| uniprot|
# |           null|   Q9NP91|    null|   true| uniprot|
# |    EFO_0000279|   Q8TBY8|    null|   true| uniprot|
# |    EFO_0000712|   P24723|    null|   true| uniprot|
# |    EFO_0002517|   O75078|    true|   null|humsavar|
# |    EFO_0003105|   Q8TEW0|    null|   true| uniprot|
# |    EFO_0003105|   Q9H2D1|    null|   true| uniprot|
# |    EFO_0005842|   P50749|    true|   null|humsavar|
# |    EFO_0005842|   Q9Y286|    true|   null|humsavar|
# |    EFO_0009070|   P55201|    null|   true| uniprot|
# |  MONDO_0007254|   P15090|    true|   null|humsavar|
# |  MONDO_0007254|   P24557|    true|   null|humsavar|
# |  MONDO_0007254|   Q86UW6|    true|   null|humsavar|
# |  MONDO_0008572|   Q8WVP7|    null|   true| uniprot|
# |  MONDO_0014512|   Q00577|    null|   true| uniprot|
# |  MONDO_0029134|   Q6F5E8|    null|   true| uniprot|
# |  MONDO_0032910|   A1L188|    null|   true| uniprot|
# |  MONDO_0033482|   Q14671|    null|   true| uniprot|
# |Orphanet_101085|   P07196|    null|   true| uniprot|
# |  Orphanet_1020|   P49810|    null|   true| uniprot|
# +---------------+---------+--------+-------+--------+
# only showing top 20 rows

# %% [markdown]
# Why do we have such a poor overlap??

# %%
(
    humsavar_data
    .query('uniprotId == "O75078"')
    .head(50)
)
# Out:
#         gene uniprotId   variantId     aaChange                severity rsId  \
# 2273  ADAM11    O75078  VAR_062669  p.Ser693Arg  uncertain significance    -
#
#                                         disease
# 2273  A pancreatic ductal adenocarcinoma sample

# %%
hs_all = spark.createDataFrame(humsavar_data).persist()

(
    joined_df
    .filter(col('source') == 'humsavar')
    .select('diseaseMappedId', 'uniprotId')
    .join(hs_all, on = 'uniprotId', how='left')
    .select('uniprotId', 'disease')
    .distinct()
    .show(truncate=False)
)
# Out:
# +---------+---------------------------------------------------------------------------+
# |uniprotId|disease                                                                    |
# +---------+---------------------------------------------------------------------------+
# |O75643   |A colorectal cancer sample                                                 |
# |P35222   |Hepatocellular carcinoma                                                   |
# |P35222   |Neurodevelopmental disorder with spastic diplegia and visual defects (NEDSD|
# |P51812   |A breast cancer sample                                                     |
# |P51812   |A gastric adenocarcinoma sample                                            |
# |P51812   |A glioblastoma multiforme sample                                           |
# |Q00341   |A breast cancer sample                                                     |
# |Q15477   |A breast cancer sample                                                     |
# |Q15477   |A colorectal cancer sample                                                 |
# |Q15746   |An ovarian mucinous carcinoma sample                                       |
# |Q9C0K0   |A colorectal cancer sample                                                 |
# |Q9UM73   |A breast pleomorphic lobular carcinoma sample                              |
# |Q9UM73   |An ovarian serous carcinoma sample                                         |
# |O60828   |A colorectal cancer sample                                                 |
# |P04275   |A breast cancer sample                                                     |
# |Q13795   |A breast cancer sample                                                     |
# |Q96JA3   |A breast cancer sample                                                     |
# |Q96QS6   |A lung adenocarcinoma sample                                               |
# |Q9BXU1   |A lung neuroendocrine carcinoma sample                                     |
# |Q9BXU1   |A lung small cell carcinoma sample                                         |
# +---------+---------------------------------------------------------------------------+
# only showing top 20 rows

# %%
(
    hs_mapped_df
    .filter(col('uniprotId') == 'Q8N2K0')
    .show()
)
# Out:
# +---------+---------------+--------+
# |uniprotId|diseaseMappedId|humsavar|
# +---------+---------------+--------+
# +---------+---------------+--------+
