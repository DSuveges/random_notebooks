# %% [markdown]
# # TEP parser
#
# TEP () are pulled from SGC website from here: `https://www.thesgc.org/tep`

# %%
import requests
from bs4 import BeautifulSoup, UnicodeDammit
import pandas as pd

def get_gene(row):
    genes = row.findAll('td')[0].text
    return genes.split('/')

def get_gene_name(row):
    return row.findAll('td')[1].text


def get_url(row):
    gene_cell = row.findAll('td')[0]
    tep_url = gene_cell.find('a').get('href')
    
    if not tep_url.startswith('http'):
        tep_url = 'https://www.thesgc.org' + tep_url
        
    return tep_url


def get_therapeutic_area(row):
    therapeutic_area = row.findAll('td')[2].text
    return therapeutic_area


def hgnc_alias_lookup(gene_label):
    
    endpoints = ['alias_name','alias_symbol','prev_symbol',"symbol","name"]
    
    # Initialize values:
    gene_name, gene_id = None, None
    
    for endpoint in endpoints:  
        url = f'http://rest.genenames.org/fetch/{endpoint}/{gene_label}'
        print(url)
        headers = {'Accept': 'application/json'} 
        r = requests.get(url, headers=headers)
        data = r.json()
    
        if data['response']['numFound'] == 0:
            continue

        elif data['response']['numFound'] == 1:
            docs = data['response']['docs'][0]
            print(f'Gene symbol found in HGNC {endpoint}')
            gene_name, gene_id =  docs['symbol'], docs['ensembl_gene_id']
            break
        else:
            docs = data['response']['docs'][0]
            print(f'Gene symbol found in HGNC {endpoint}')
            print(f'Warning! Multiple genes found for {gene_name}')
            gene_name, gene_id =  docs['symbol'], docs['ensembl_gene_id']
            break

    if gene_id is None:
        print(f'Gene not found in HGNC: {gene_label}')
    return gene_id, gene_name

def gene_name_lookup(gene_name):
    ensembl_url = f'http://rest.ensembl.org/lookup/symbol/homo_sapiens/{gene_name}?content-type=application/json'
    r = requests.get(ensembl_url)
    
    data = r.json()
    
    if 'error' in data:
        print(f'Gene not found in Ensembl: {gene_name}')
        return hgnc_alias_lookup(gene_name)
    
    # Parse data:
    return data['id'], data['display_name']
    
    
    
url = 'https://www.thesgc.org/tep'

response = requests.get(url)

html = response.text
uhtml = UnicodeDammit(html)

soup = BeautifulSoup(uhtml.unicode_markup, features="html.parser")

TEP_table = soup.findAll('table')[-1]

TEP_raw_data = []

for row in TEP_table.find('tbody').findAll('tr'):
    TEP_raw_data.append({
        "genes": get_gene(row),
        "TEP_url": get_url(row),
        "disease": get_therapeutic_area(row),
        "description": get_gene_name(row)
    })
    
TEP_raw_df = pd.DataFrame(TEP_raw_data)
TEP_raw_df = TEP_raw_df.explode('genes')

gene_ids = TEP_raw_df.genes.apply(gene_name_lookup)
gene_df = pd.DataFrame(gene_ids.tolist(), columns=['gene_id','gene_symbol'])
gene_df.head()
# Out:
# Gene not found in Ensembl: Moesin
# http://rest.genenames.org/fetch/alias_name/Moesin
# Gene symbol found in HGNC alias_name
# Gene not found in Ensembl: hFBG-C
# http://rest.genenames.org/fetch/alias_name/hFBG-C
# http://rest.genenames.org/fetch/alias_symbol/hFBG-C
# http://rest.genenames.org/fetch/prev_symbol/hFBG-C
# http://rest.genenames.org/fetch/symbol/hFBG-C
# http://rest.genenames.org/fetch/name/hFBG-C
# Gene not found in HGNC: None
# Gene not found in Ensembl: TASK1
# http://rest.genenames.org/fetch/alias_name/TASK1
# http://rest.genenames.org/fetch/alias_symbol/TASK1
# Gene symbol found in HGNC alias_symbol
# Gene not found in Ensembl: TMEM16K
# http://rest.genenames.org/fetch/alias_name/TMEM16K
# http://rest.genenames.org/fetch/alias_symbol/TMEM16K
# http://rest.genenames.org/fetch/prev_symbol/TMEM16K
# Gene symbol found in HGNC prev_symbol
# Gene not found in Ensembl: PfBDP4
# http://rest.genenames.org/fetch/alias_name/PfBDP4
# http://rest.genenames.org/fetch/alias_symbol/PfBDP4
# http://rest.genenames.org/fetch/prev_symbol/PfBDP4
# http://rest.genenames.org/fetch/symbol/PfBDP4
# http://rest.genenames.org/fetch/name/PfBDP4
# Gene not found in HGNC: None
#            gene_id gene_symbol
# 0  ENSG00000124067     SLC12A4
# 1  ENSG00000140199     SLC12A6
# 2  ENSG00000082397     EPB41L3
# 3  ENSG00000168918      INPP5D
# 4  ENSG00000186575         NF2

# %%
TEP_raw_df.reset_index(drop=True, inplace=True)
gene_df.reset_index(drop=True, inplace=True)

final_df = pd.concat( [gene_df, TEP_raw_df], axis=1) 
final_df
# Out:
#             gene_id gene_symbol    genes  \
# 0   ENSG00000124067     SLC12A4  SLC12A4
# 1   ENSG00000140199     SLC12A6  SLC12A6
# 2   ENSG00000082397     EPB41L3  EPB41L3
# 3   ENSG00000168918      INPP5D   INPP5D
# 4   ENSG00000186575         NF2   Moesin
# 5              None        None   hFBG-C
# 6   ENSG00000164181      ELOVL7   ELOVL7
# 7   ENSG00000181192      DHTKD1   DHTKD1
# 8   ENSG00000152457     DCLRE1C  DCLRE1C
# 9   ENSG00000164458        TBXT     TBXT
# 10  ENSG00000118007       STAG1    STAG1
# 11  ENSG00000177000       MTHFR    MTHFR
# 12  ENSG00000158578       ALAS2    ALAS2
# 13  ENSG00000213930        GALT     GALT
# 14  ENSG00000108479       GALK1    GALK1
# 15  ENSG00000160145       KALRN    KALRN
# 16  ENSG00000136238        RAC1     RAC1
# 17  ENSG00000079999       KEAP1    KEAP1
# 18  ENSG00000076321      KLHL20   KLHL20
# 19  ENSG00000130382       MLLT1    MLLT1
# 20  ENSG00000171303       KCNK3    TASK1
# 21  ENSG00000160746       ANO10  TMEM16K
# 22  ENSG00000138622        HCN4     HCN4
# 23  ENSG00000140876       NUDT7    NUDT7
# 24  ENSG00000173193      PARP14   PARP14
# 25  ENSG00000104312       RIPK2    RIPK2
# 26  ENSG00000101323        HAO1     HAO1
# 27  ENSG00000168143      FAM83B   FAM83B
# 28  ENSG00000106683       LIMK1    LIMK1
# 29  ENSG00000198924     DCLRE1A  DCLRE1A
# 30  ENSG00000172269      DPAGT1   DPAGT1
# 31  ENSG00000008311        AASS     AASS
# 32  ENSG00000196632        WNK3     WNK3
# 33  ENSG00000094631       HDAC6    HDAC6
# 34  ENSG00000120733       KDM3B    KDM3B
# 35  ENSG00000186280       KDM4D    KDM4D
# 36  ENSG00000146247        PHIP     PHIP
# 37             None        None   PfBDP4
# 38  ENSG00000108469      RECQL5   RECQL5
# 39  ENSG00000143379      SETDB1   SETDB1
# 40  ENSG00000167258       CDK12    CDK12
#
#                                       TEP_url  \
# 0   https://www.thesgc.org/tep/slc12a4slc12a6
# 1   https://www.thesgc.org/tep/slc12a4slc12a6
# 2          https://www.thesgc.org/tep/epb41l3
# 3           https://www.thesgc.org/tep/inpp5d
# 4           https://www.thesgc.org/tep/moesin
# 5           https://www.thesgc.org/tep/hfbg-c
# 6           https://www.thesgc.org/tep/elovl7
# 7           https://www.thesgc.org/tep/dhtkd1
# 8          https://www.thesgc.org/tep/dclre1c
# 9             https://www.thesgc.org/tep/tbxt
# 10           https://www.thesgc.org/tep/stag1
# 11           https://www.thesgc.org/tep/mthfr
# 12           https://www.thesgc.org/tep/alas2
# 13            https://www.thesgc.org/tep/galt
# 14            https://www.thesgc.org/tep/galt
# 15       https://www.thesgc.org/tep/kalrnrac1
# 16       https://www.thesgc.org/tep/kalrnrac1
# 17           https://www.thesgc.org/tep/keap1
# 18          https://www.thesgc.org/tep/klhl20
# 19           https://www.thesgc.org/tep/mllt1
# 20           https://www.thesgc.org/tep/task1
# 21         https://www.thesgc.org/tep/tmem16k
# 22            https://www.thesgc.org/tep/HCN4
# 23           https://www.thesgc.org/tep/NUDT7
# 24          https://www.thesgc.org/tep/PARP14
# 25           https://www.thesgc.org/tep/RIPK2
# 26            https://www.thesgc.org/tep/HAO1
# 27          https://www.thesgc.org/tep/FAM83B
# 28           https://www.thesgc.org/tep/LIMK1
# 29         https://www.thesgc.org/tep/DCLRE1A
# 30          https://www.thesgc.org/tep/DPAGT1
# 31            https://www.thesgc.org/tep/AASS
# 32            https://www.thesgc.org/tep/WNK3
# 33           https://www.thesgc.org/tep/HDAC6
# 34           https://www.thesgc.org/tep/KDM3B
# 35           https://www.thesgc.org/tep/KDM4D
# 36            https://www.thesgc.org/tep/PHIP
# 37          https://www.thesgc.org/tep/PfBDP4
# 38          https://www.thesgc.org/tep/RECQL5
# 39          https://www.thesgc.org/tep/SETDB1
# 40           https://www.thesgc.org/tep/CDK12
#
#                                         disease  \
# 0       Sickle cell disease (SCD), Neurological
# 1       Sickle cell disease (SCD), Neurological
# 2                             Neurodegeneration
# 3                        Neurological Disorders
# 4                           Alzheimer’s disease
# 5                         Inflammatory diseases
# 6                            Metabolic diseases
# 7                            Metabolic diseases
# 8                                      Oncology
# 9                                        Cancer
# 10                                       Cancer
# 11                  Metabolic disorders, Cancer
# 12                           Metabolic diseases
# 13                           Metabolic diseases
# 14                           Metabolic diseases
# 15                       Neurological Disorders
# 16                       Neurological Disorders
# 17                              Neuropsychiatry
# 18                      Cancer, Neuropsychiatry
# 19                                       Cancer
# 20                       Neurological Disorders
# 21                       Neurological Disorders
# 22      Cardiovascular, Inflammation, and Neuro
# 23                           Metabolic diseases
# 24                         Cancer, Inflammation
# 25                        Inflammatory diseases
# 26                          Metabolic disorders
# 27                                       Cancer
# 28                              Neuropsychiatry
# 29                                       Cancer
# 30  Neuropsychiatry and neuro genetic disorders
# 31           Metabolic & Neurological disorders
# 32                           Metabolic diseases
# 33                                     Oncology
# 34                                       Cancer
# 35                                       Cancer
# 36                                       Cancer
# 37                                      Malaria
# 38                                       Cancer
# 39                                     Oncology
# 40                                     Oncology
#
#                                           description
# 0   Potassium/Chloride Co-transporter 1 and 3 (KCC...
# 1   Potassium/Chloride Co-transporter 1 and 3 (KCC...
# 2                                             EPB41L3
# 3                                      INPP5D (SHIP1)
# 4                                        MSN (Moesin)
# 5   Fibrinogen-like globe domain of human Tenascin...
# 6   Elongation of very long chain fatty acids prot...
# 7   Dehydrogenase E1 and transketolase domain-cont...
# 8                        \nArtemis (DCLRE1C, SNM1C)\n
# 9   \nHuman T-box transcription factor T (Brachyur...
# 10  \nHuman Stromal Antigen 1 (STAG1) Cohesin Subu...
# 11   \nMethylene-Tetrahydrofolate Reductase (MTHFR)\n
# 12  \nHuman 5'-Aminolevulinate synthase, erythoid-...
# 13  \nHuman Galactose- 1-phosphate uridylyltransfe...
# 14  \nHuman Galactose- 1-phosphate uridylyltransfe...
# 15  Human Kalrin/RAC1 GEF/GTPase Complex (KARLN/RAC1)
# 16  Human Kalrin/RAC1 GEF/GTPase Complex (KARLN/RAC1)
# 17  \nHuman Kelch-like ECH Associated Protein 1 (K...
# 18           \nHuman Kelch-like protein 20 (KLHL20)\n
# 19  Human Mixed-Lineage Leukemia, Translocated to ...
# 20  \nHuman TWIK-Related Acid-Sensitive K+ Channel...
# 21                          \nHuman TMEM16K (ANO10)\n
# 22  Human Hyperpolarization Activated Cyclic Nucle...
# 23  Human Peroxisomal Coenzyme A Diphosphatase NUD...
# 24  Human Poly (ADP-ribose) Polymerase Family Memb...
# 25  Human Receptor-Interacting Serine/Threonine-Pr...
# 26                   Human Hydroxyacid Oxidase (HAO1)
# 27  Human Family With Sequence Similarity 83 Membe...
# 28   Human LIM Domain Kinase 1 (LIMK1), Kinase Domain
# 29    Human DNA Cross-Link Repair 1A (DCLRE1A, SNM1A)
# 30  Human Dolichyl-Phosphate Alpha-N-Acetyl glucos...
# 31  Human Alpha-Aminoadipic Semialdehyde Synthase ...
# 32               Human With No Lysine Kinase 3 (WNK3)
# 33                Human Histone Deacetylase 6 (HDAC6)
# 34                  Lysine Demethylase JMJD1B (KDM3B)
# 35                  Lysine Demethylase JMJD2D (KDM4D)
# 36  Human Pleckstrin Homology Domain Interacting P...
# 37                      Plasmodium bormodomain PfBDP4
# 38                              Human RECQL5 helicase
# 39  Human SET domain bifurcated 1 (SETDB1), Tudor ...
# 40  Human Cyclin-Dependent Kinase 12 (CDK12), Kina...

# %%
data
# Out:
# {'responseHeader': {'status': 0, 'QTime': 0},
#  'response': {'numFound': 1,
#   'start': 0,
#   'docs': [{'hgnc_id': 'HGNC:7773',
#     'symbol': 'NF2',
#     'name': 'neurofibromin 2',
#     'status': 'Approved',
#     'locus_type': 'gene with protein product',
#     'prev_name': ['neurofibromin 2 (bilateral acoustic neuroma)',
#      'neurofibromin 2 (merlin)'],
#     'alias_symbol': ['merlin', 'ACN', 'SCH', 'BANF', 'merlin-1'],
#     'alias_name': ['moesin-ezrin-radixin like',
#      'schwannomin',
#      'bilateral acoustic neurofibromatosis'],
#     'location': '22q12.2',
#     'date_approved_reserved': '1992-01-01T00:00:00Z',
#     'date_modified': '2021-01-09T00:00:00Z',
#     'date_name_changed': '2016-07-04T00:00:00Z',
#     'ena': ['L11353'],
#     'entrez_id': '4771',
#     'mgd_id': ['MGI:97307'],
#     'cosmic': 'NF2',
#     'orphanet': 123774,
#     'pubmed_id': [10591208],
#     'refseq_accession': ['NM_000268'],
#     'gene_group': ['A-kinase anchoring proteins', 'FERM domain containing'],
#     'vega_id': 'OTTHUMG00000030727',
#     'lsdb': ['Neurofibromatosis 2 (NF2) mutation database|http://www.hgmd.cf.ac.uk/nf2/',
#      'LRG_511|http://ftp.ebi.ac.uk/pub/databases/lrgex/LRG_511.xml'],
#     'ensembl_gene_id': 'ENSG00000186575',
#     'ccds_id': ['CCDS13865',
#      'CCDS13863',
#      'CCDS54516',
#      'CCDS13861',
#      'CCDS13862',
#      'CCDS13864'],
#     'locus_group': 'protein-coding gene',
#     'omim_id': ['607379'],
#     'uniprot_ids': ['P35240'],
#     'ucsc_id': 'uc003age.5',
#     'rgd_id': ['RGD:3169'],
#     'gene_group_id': [396, 1293],
#     'location_sortable': '22q12.2',
#     'agr': 'HGNC:7773',
#     'symbol_report_tag': ['Stable symbol'],
#     'uuid': '35c4c140-8cf4-4e6d-b9a6-f410a5072348',
#     '_version_': 1689385055268372482}]}}

# %%
url = 'https://www.thesgc.org/tep'

response = requests.get(url)

html = response.text
uhtml = UnicodeDammit(html)

soup = BeautifulSoup(uhtml.unicode_markup, features="html.parser")

TEP_table = soup.findAll('table')[-1]

TEP_raw_data = []

for row in TEP_table.find('tbody').findAll('tr'):
    TEP_raw_data.append({
        "genes": get_gene(row),
        "TEP_url": get_url(row),
        "disease": get_therapeutic_area(row),
        "description": get_gene_name(row)
    })
# Out:
# <tr>
# <td><a href="/tep/CDK12">CDK12</a></td>
# <td>Human Cyclin-Dependent Kinase 12 (CDK12), Kinase Domain</td>
# <td>Oncology</td>
# <td>Version 7</td>
# <td>2016</td>
# </tr>

# %%
URL = get_url(row)
URL= 'https://www.thesgc.org/tep/galtgalk1'

# %%
r = requests.get(URL)
html = r.text
uhtml = UnicodeDammit(html)

soup = BeautifulSoup(uhtml.unicode_markup, features="html.parser")

# %%
for a in soup.findAll('a'):
    url = a.get('href')
    try:
        if 'uniprot' in url:
            print(url)
    except TypeError:
        continue
# Out:
# http://www.uniprot.org/uniprot/P07902
# http://www.uniprot.org/uniprot/P51570

# %%
data = [ 
            {'ENSG00000094631': {
                'id': 'ENSG00000094631',
                'symbol': 'HDAC6',
                'link': 'https://www.thesgc.org/tep/hdac6'
            }},
            {'ENSG00000120733': {
                'id': 'ENSG00000120733',
                'symbol': 'KDM3B',
                'link': 'https://www.thesgc.org/tep/kdm3b'
            }},
            {'ENSG00000186280': {
                'id': 'ENSG00000186280',
                'symbol': 'KDM4D',
                'link': 'https://www.thesgc.org/tep/kdm4d'
            }},
            {'ENSG00000146247': {
                'id': 'ENSG00000146247',
                'symbol': 'PHIP',
                'link': 'https://www.thesgc.org/tep/phip'
            }}]

# %%
{row['genes']:{'urls': row['TEP_url']} for i, row in TEP_raw_df.iterrows()}
# Out:
# {'SLC12A4': {'urls': 'https://www.thesgc.org/tep/slc12a4slc12a6'},
#  'SLC12A6': {'urls': 'https://www.thesgc.org/tep/slc12a4slc12a6'},
#  'EPB41L3': {'urls': 'https://www.thesgc.org/tep/epb41l3'},
#  'INPP5D': {'urls': 'https://www.thesgc.org/tep/inpp5d'},
#  'Moesin': {'urls': 'https://www.thesgc.org/tep/moesin'},
#  'hFBG-C': {'urls': 'https://www.thesgc.org/tep/hfbg-c'},
#  'ELOVL7': {'urls': 'https://www.thesgc.org/tep/elovl7'},
#  'DHTKD1': {'urls': 'https://www.thesgc.org/tep/dhtkd1'},
#  'DCLRE1C': {'urls': 'https://www.thesgc.org/tep/dclre1c'},
#  'TBXT': {'urls': 'https://www.thesgc.org/tep/tbxt'},
#  'STAG1': {'urls': 'https://www.thesgc.org/tep/stag1'},
#  'MTHFR': {'urls': 'https://www.thesgc.org/tep/mthfr'},
#  'ALAS2': {'urls': 'https://www.thesgc.org/tep/alas2'},
#  'GALT': {'urls': 'https://www.thesgc.org/tep/galt'},
#  'GALK1': {'urls': 'https://www.thesgc.org/tep/galt'},
#  'KALRN': {'urls': 'https://www.thesgc.org/tep/kalrnrac1'},
#  'RAC1': {'urls': 'https://www.thesgc.org/tep/kalrnrac1'},
#  'KEAP1': {'urls': 'https://www.thesgc.org/tep/keap1'},
#  'KLHL20': {'urls': 'https://www.thesgc.org/tep/klhl20'},
#  'MLLT1': {'urls': 'https://www.thesgc.org/tep/mllt1'},
#  'TASK1': {'urls': 'https://www.thesgc.org/tep/task1'},
#  'TMEM16K': {'urls': 'https://www.thesgc.org/tep/tmem16k'},
#  'HCN4': {'urls': 'https://www.thesgc.org/tep/HCN4'},
#  'NUDT7': {'urls': 'https://www.thesgc.org/tep/NUDT7'},
#  'PARP14': {'urls': 'https://www.thesgc.org/tep/PARP14'},
#  'RIPK2': {'urls': 'https://www.thesgc.org/tep/RIPK2'},
#  'HAO1': {'urls': 'https://www.thesgc.org/tep/HAO1'},
#  'FAM83B': {'urls': 'https://www.thesgc.org/tep/FAM83B'},
#  'LIMK1': {'urls': 'https://www.thesgc.org/tep/LIMK1'},
#  'DCLRE1A': {'urls': 'https://www.thesgc.org/tep/DCLRE1A'},
#  'DPAGT1': {'urls': 'https://www.thesgc.org/tep/DPAGT1'},
#  'AASS': {'urls': 'https://www.thesgc.org/tep/AASS'},
#  'WNK3': {'urls': 'https://www.thesgc.org/tep/WNK3'},
#  'HDAC6': {'urls': 'https://www.thesgc.org/tep/HDAC6'},
#  'KDM3B': {'urls': 'https://www.thesgc.org/tep/KDM3B'},
#  'KDM4D': {'urls': 'https://www.thesgc.org/tep/KDM4D'},
#  'PHIP': {'urls': 'https://www.thesgc.org/tep/PHIP'},
#  'PfBDP4': {'urls': 'https://www.thesgc.org/tep/PfBDP4'},
#  'RECQL5': {'urls': 'https://www.thesgc.org/tep/RECQL5'},
#  'SETDB1': {'urls': 'https://www.thesgc.org/tep/SETDB1'},
#  'CDK12': {'urls': 'https://www.thesgc.org/tep/CDK12'}}

# %%
for i, row in TEP_raw_df.iterrows():
    print(row)
# Out:
# genes                                                    SLC12A4
# TEP_url                https://www.thesgc.org/tep/slc12a4slc12a6
# disease                  Sickle cell disease (SCD), Neurological
# description    Potassium/Chloride Co-transporter 1 and 3 (KCC...
# Name: 0, dtype: object
# genes                                                    SLC12A6
# TEP_url                https://www.thesgc.org/tep/slc12a4slc12a6
# disease                  Sickle cell disease (SCD), Neurological
# description    Potassium/Chloride Co-transporter 1 and 3 (KCC...
# Name: 1, dtype: object
# genes                                     EPB41L3
# TEP_url        https://www.thesgc.org/tep/epb41l3
# disease                         Neurodegeneration
# description                               EPB41L3
# Name: 2, dtype: object
# genes                                     INPP5D
# TEP_url        https://www.thesgc.org/tep/inpp5d
# disease                   Neurological Disorders
# description                       INPP5D (SHIP1)
# Name: 3, dtype: object
# genes                                     Moesin
# TEP_url        https://www.thesgc.org/tep/moesin
# disease                      Alzheimer’s disease
# description                         MSN (Moesin)
# Name: 4, dtype: object
# genes                                                     hFBG-C
# TEP_url                        https://www.thesgc.org/tep/hfbg-c
# disease                                    Inflammatory diseases
# description    Fibrinogen-like globe domain of human Tenascin...
# Name: 5, dtype: object
# genes                                                     ELOVL7
# TEP_url                        https://www.thesgc.org/tep/elovl7
# disease                                       Metabolic diseases
# description    Elongation of very long chain fatty acids prot...
# Name: 6, dtype: object
# genes                                                     DHTKD1
# TEP_url                        https://www.thesgc.org/tep/dhtkd1
# disease                                       Metabolic diseases
# description    Dehydrogenase E1 and transketolase domain-cont...
# Name: 7, dtype: object
# genes                                     DCLRE1C
# TEP_url        https://www.thesgc.org/tep/dclre1c
# disease                                  Oncology
# description          \nArtemis (DCLRE1C, SNM1C)\n
# Name: 8, dtype: object
# genes                                                       TBXT
# TEP_url                          https://www.thesgc.org/tep/tbxt
# disease                                                   Cancer
# description    \nHuman T-box transcription factor T (Brachyur...
# Name: 9, dtype: object
# genes                                                      STAG1
# TEP_url                         https://www.thesgc.org/tep/stag1
# disease                                                   Cancer
# description    \nHuman Stromal Antigen 1 (STAG1) Cohesin Subu...
# Name: 10, dtype: object
# genes                                                     MTHFR
# TEP_url                        https://www.thesgc.org/tep/mthfr
# disease                             Metabolic disorders, Cancer
# description    \nMethylene-Tetrahydrofolate Reductase (MTHFR)\n
# Name: 11, dtype: object
# genes                                                      ALAS2
# TEP_url                         https://www.thesgc.org/tep/alas2
# disease                                       Metabolic diseases
# description    \nHuman 5'-Aminolevulinate synthase, erythoid-...
# Name: 12, dtype: object
# genes                                                       GALT
# TEP_url                          https://www.thesgc.org/tep/galt
# disease                                       Metabolic diseases
# description    \nHuman Galactose- 1-phosphate uridylyltransfe...
# Name: 13, dtype: object
# genes                                                      GALK1
# TEP_url                          https://www.thesgc.org/tep/galt
# disease                                       Metabolic diseases
# description    \nHuman Galactose- 1-phosphate uridylyltransfe...
# Name: 14, dtype: object
# genes                                                      KALRN
# TEP_url                     https://www.thesgc.org/tep/kalrnrac1
# disease                                   Neurological Disorders
# description    Human Kalrin/RAC1 GEF/GTPase Complex (KARLN/RAC1)
# Name: 15, dtype: object
# genes                                                       RAC1
# TEP_url                     https://www.thesgc.org/tep/kalrnrac1
# disease                                   Neurological Disorders
# description    Human Kalrin/RAC1 GEF/GTPase Complex (KARLN/RAC1)
# Name: 16, dtype: object
# genes                                                      KEAP1
# TEP_url                         https://www.thesgc.org/tep/keap1
# disease                                          Neuropsychiatry
# description    \nHuman Kelch-like ECH Associated Protein 1 (K...
# Name: 17, dtype: object
# genes                                            KLHL20
# TEP_url               https://www.thesgc.org/tep/klhl20
# disease                         Cancer, Neuropsychiatry
# description    \nHuman Kelch-like protein 20 (KLHL20)\n
# Name: 18, dtype: object
# genes                                                      MLLT1
# TEP_url                         https://www.thesgc.org/tep/mllt1
# disease                                                   Cancer
# description    Human Mixed-Lineage Leukemia, Translocated to ...
# Name: 19, dtype: object
# genes                                                      TASK1
# TEP_url                         https://www.thesgc.org/tep/task1
# disease                                   Neurological Disorders
# description    \nHuman TWIK-Related Acid-Sensitive K+ Channel...
# Name: 20, dtype: object
# genes                                     TMEM16K
# TEP_url        https://www.thesgc.org/tep/tmem16k
# disease                    Neurological Disorders
# description             \nHuman TMEM16K (ANO10)\n
# Name: 21, dtype: object
# genes                                                       HCN4
# TEP_url                          https://www.thesgc.org/tep/HCN4
# disease                  Cardiovascular, Inflammation, and Neuro
# description    Human Hyperpolarization Activated Cyclic Nucle...
# Name: 22, dtype: object
# genes                                                      NUDT7
# TEP_url                         https://www.thesgc.org/tep/NUDT7
# disease                                       Metabolic diseases
# description    Human Peroxisomal Coenzyme A Diphosphatase NUD...
# Name: 23, dtype: object
# genes                                                     PARP14
# TEP_url                        https://www.thesgc.org/tep/PARP14
# disease                                     Cancer, Inflammation
# description    Human Poly (ADP-ribose) Polymerase Family Memb...
# Name: 24, dtype: object
# genes                                                      RIPK2
# TEP_url                         https://www.thesgc.org/tep/RIPK2
# disease                                    Inflammatory diseases
# description    Human Receptor-Interacting Serine/Threonine-Pr...
# Name: 25, dtype: object
# genes                                      HAO1
# TEP_url         https://www.thesgc.org/tep/HAO1
# disease                     Metabolic disorders
# description    Human Hydroxyacid Oxidase (HAO1)
# Name: 26, dtype: object
# genes                                                     FAM83B
# TEP_url                        https://www.thesgc.org/tep/FAM83B
# disease                                                   Cancer
# description    Human Family With Sequence Similarity 83 Membe...
# Name: 27, dtype: object
# genes                                                     LIMK1
# TEP_url                        https://www.thesgc.org/tep/LIMK1
# disease                                         Neuropsychiatry
# description    Human LIM Domain Kinase 1 (LIMK1), Kinase Domain
# Name: 28, dtype: object
# genes                                                  DCLRE1A
# TEP_url                     https://www.thesgc.org/tep/DCLRE1A
# disease                                                 Cancer
# description    Human DNA Cross-Link Repair 1A (DCLRE1A, SNM1A)
# Name: 29, dtype: object
# genes                                                     DPAGT1
# TEP_url                        https://www.thesgc.org/tep/DPAGT1
# disease              Neuropsychiatry and neuro genetic disorders
# description    Human Dolichyl-Phosphate Alpha-N-Acetyl glucos...
# Name: 30, dtype: object
# genes                                                       AASS
# TEP_url                          https://www.thesgc.org/tep/AASS
# disease                       Metabolic & Neurological disorders
# description    Human Alpha-Aminoadipic Semialdehyde Synthase ...
# Name: 31, dtype: object
# genes                                          WNK3
# TEP_url             https://www.thesgc.org/tep/WNK3
# disease                          Metabolic diseases
# description    Human With No Lysine Kinase 3 (WNK3)
# Name: 32, dtype: object
# genes                                        HDAC6
# TEP_url           https://www.thesgc.org/tep/HDAC6
# disease                                   Oncology
# description    Human Histone Deacetylase 6 (HDAC6)
# Name: 33, dtype: object
# genes                                      KDM3B
# TEP_url         https://www.thesgc.org/tep/KDM3B
# disease                                   Cancer
# description    Lysine Demethylase JMJD1B (KDM3B)
# Name: 34, dtype: object
# genes                                      KDM4D
# TEP_url         https://www.thesgc.org/tep/KDM4D
# disease                                   Cancer
# description    Lysine Demethylase JMJD2D (KDM4D)
# Name: 35, dtype: object
# genes                                                       PHIP
# TEP_url                          https://www.thesgc.org/tep/PHIP
# disease                                                   Cancer
# description    Human Pleckstrin Homology Domain Interacting P...
# Name: 36, dtype: object
# genes                                     PfBDP4
# TEP_url        https://www.thesgc.org/tep/PfBDP4
# disease                                  Malaria
# description        Plasmodium bormodomain PfBDP4
# Name: 37, dtype: object
# genes                                     RECQL5
# TEP_url        https://www.thesgc.org/tep/RECQL5
# disease                                   Cancer
# description                Human RECQL5 helicase
# Name: 38, dtype: object
# genes                                                     SETDB1
# TEP_url                        https://www.thesgc.org/tep/SETDB1
# disease                                                 Oncology
# description    Human SET domain bifurcated 1 (SETDB1), Tudor ...
# Name: 39, dtype: object
# genes                                                      CDK12
# TEP_url                         https://www.thesgc.org/tep/CDK12
# disease                                                 Oncology
# description    Human Cyclin-Dependent Kinase 12 (CDK12), Kina...
# Name: 40, dtype: object

# %%
import pandas as pd

# %%
dfs = pd.read_html('https://www.thesgc.org/tep')
tep_df = (
    dfs[1]
    .assign(
        genes = lambda df: df.Gene.str.split('/')
    )
    .explode('genes')
    .drop(['Gene', 'Vers'])
)
tep_df.head()
# Out:
#               Gene                                        Description  \
# 0  SLC12A4/SLC12A6  Potassium/Chloride Co-transporter 1 and 3 (KCC...
# 0  SLC12A4/SLC12A6  Potassium/Chloride Co-transporter 1 and 3 (KCC...
# 1          EPB41L3                                            EPB41L3
# 2           INPP5D                                     INPP5D (SHIP1)
# 3           Moesin                                       MSN (Moesin)
#
#                           Therapeutic Area    Version  Date    genes
# 0  Sickle cell disease (SCD), Neurological  Version 1  2020  SLC12A4
# 0  Sickle cell disease (SCD), Neurological  Version 1  2020  SLC12A6
# 1                        Neurodegeneration  Version 1  2020  EPB41L3
# 2                   Neurological Disorders  Version 1  2020   INPP5D
# 3                      Alzheimer’s disease  Version 1  2020   Moesin

# %%
import requests
from bs4 import BeautifulSoup, UnicodeDammit
import pandas as pd
import logging


def retrieve_tep_list():

    def get_description(row):
        return row.findAll('td')[1].text.strip()

    def get_url(row):
        gene_cell = row.findAll('td')[0]
        tep_url = gene_cell.find('a').get('href')
        
        if not tep_url.startswith('http'):
            tep_url = 'https://www.thesgc.org' + tep_url
            
        return tep_url
        
    def get_therapeutic_area(row):
        therapeutic_area = row.findAll('td')[2].text
        return therapeutic_area
    
    def get_genes(row):
        genes = row.findAll('td')[0].text
        return genes.split('/')


    url = 'https://www.thesgc.org/tep'

    response = requests.get(url)

    html = response.text
    uhtml = UnicodeDammit(html)

    soup = BeautifulSoup(uhtml.unicode_markup, features="html.parser")

    TEP_table = soup.findAll('table')[-1]

    TEP_raw_data = []

    for row in TEP_table.find('tbody').findAll('tr'):
        TEP_raw_data.append({
            "genes": get_genes(row),
            "TEP_url": get_url(row),
            "disease": get_therapeutic_area(row),
            "description": get_description(row)
        })
        
    return (
        pd.DataFrame(TEP_raw_data)
        .explode('genes')
        .rename(columns={'genes': 'targetFromSource'})
    )


tep_list = retrieve_tep_list()
tep_list.to_json('tep-2021-09-07.json.gz', compression='infer', lines=True, orient='records')

# %%
# %%bash
#
# gzcat tep-2021-09-07.json.gz | head -n1 | jq
# Out:
# {
#   "targetFromSource": "SLC12A4",
#   "TEP_url": "https://www.thesgc.org/tep/slc12a4slc12a6",
#   "disease": "Sickle cell disease (SCD), Neurological",
#   "description": "Potassium/Chloride Co-transporter 1 and 3 (KCC1/KCC3; SLC12A4/SLC12A6)"
# }

# %%
tep_list.targetFromSource.duplicated().any()
# Out:
# False

# %%
import json

def id_lookup(ensembl_ids):

    headers={ "Content-Type" : "application/json", "Accept" : "application/json"}
    r = requests.post('http://rest.ensembl.org/lookup/id', headers=headers, data=json.dumps({ "ids" : ensembl_ids }))

    try:
        decoded = r.json()
    except:
        print(r.content)

    # Parse response:
    parsed = []
    for gene_id, data in decoded.items():
        parsed.append({
            'gene_id': gene_id,
            'symbol': data['display_name']
            })

    return pd.DataFrame(parsed)


def uniprot_lookup(uniprot_id):
    url = f'http://rest.ensembl.org/xrefs/symbol/homo_sapiens/{uniprot_id}?content-type=application/json'
    r = requests.get(url)
    data = r.json()

    # Parse gene id:
    for item in data:
        if item['type']:
            return item['id']

    # If gene id is not found:
    logging.info(f'Failed to retrieve Ensembl id for: {uniprot_id}')
    return None


# tep_list = ( 
#     tep_list
#     .assign(ensembl_id = lambda df: df.targetFromSource.apply(uniprot_lookup))
# )

tep_list.loc[tep_list.ensembl_id.notna()].ensembl_id.duplicated()
# Out:
# 0     False
# 0     False
# 1     False
# 2     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 12    False
# 13    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 35    False
# 36    False
# 37    False
# Name: ensembl_id, dtype: bool
