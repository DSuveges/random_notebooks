# %% [markdown]
# OK, there is a problem:
# 1. Due to some messing around in the GWAS Catalog, the study table is not properly exported, a handful of studies are now missing.
# 2. Once the issue was fixed Jack generated the study table again, however the manual mappings were not added for the finngen and ukbb studies.
# 3. Things are now needs to be sorted out before the platform pipelines are run.
#
# Steps:
# * Fetch old and new study table.
# * join tables together.
# * Verify table content.
# * Start up cluster.
# * Generate evidence
# * Validate evidence

# %%
# %%bash
#
# DESC='/Users/dsuveges/project_data/genetics/study_tables'
#
# # Create folder for study files:
# mkdir -p ${DESC}
# rm -rf ${DESC}/*
#
# OLD='gs://genetics-portal-dev-staging/v2d/210601/studies.parquet'
# NEW='gs://genetics-portal-dev-staging/v2d/210922/studies.parquet'
#
# # Fetch first dataset:
# gsutil cp -r $OLD $DESC/studies_old.parquet
# gsutil cp -r $NEW $DESC/studies_new.parquet
#
# ls -la $DESC
# Out:
# total 6656
# drwxr-xr-x  4 dsuveges  384566875      128  7 Nov 23:24 .
# drwxr-xr-x  4 dsuveges  384566875      128  7 Nov 21:43 ..
# -rw-r--r--  1 dsuveges  384566875  1746889  7 Nov 23:24 studies_new.parquet
# -rw-r--r--  1 dsuveges  384566875  1657489  7 Nov 23:24 studies_old.parquet
# Copying gs://genetics-portal-dev-staging/v2d/210601/studies.parquet...
# -
# Operation completed over 1 objects/1.6 MiB.
# Copying gs://genetics-portal-dev-staging/v2d/210922/studies.parquet...
# / [1 files][  1.7 MiB/  1.7 MiB]
# Operation completed over 1 objects/1.7 MiB.

# %%
import pyspark.sql
from pyspark.sql.types import *
from pyspark.sql.functions import *
from pyspark import SparkContext
import re

global spark

# SparkContext.setSystemProperty('spark.executor.memory', '20g')

spark = (pyspark.sql.SparkSession
    .builder
    .appName("phenodigm_parser")
    .config("spark.executor.memory", '10g')
     .config("spark.driver.bindAddress", "localhost")
    .config("spark.driver.memory", '10g')
    .getOrCreate()
)

# %%
old_file = '/Users/dsuveges/project_data/genetics/study_tables/studies_old.parquet'
new_file = '/Users/dsuveges/project_data/genetics/study_tables/studies_new.parquet'
merged_file = '/Users/dsuveges/project_data/genetics/study_tables/studies_merged.parquet'

old_df = spark.read.parquet(old_file).persist()
new_df = spark.read.parquet(new_file).persist()

print(f'Old study count: {old_df.count()}')
print(f'New study count: {new_df.count()}')
# Out:
# Old study count: 33781
# New study count: 36395

# %%
# 
merged_data = (
    new_df
    # Dropping rows from the new dataset with missing phenotype annotation
    .filter(col('trait_efos').isNotNull())
    
    # Joining with old dataset to complement the old dataset:
    .union(old_df)
    
    # Drop duplicated lines:
    .distinct()
    .coalesce(1)
    .persist()
)

merged_data.write.format('parquet').mode('overwrite').save(merged_file)

# %%
merged_data.count()
# Out:
# 36402

# %%
merged_data.filter(col('trait_efos').isNull()).count()
# Out:
# 0

# %% [markdown]
# Uploading the merged dataset to the google buckets we have:

# %%
# %%bash
#
# MERGED='/Users/dsuveges/project_data/genetics/study_tables/studies_merged.parquet'
#
# gsutil cp -r $MERGED gs://genetics-portal-dev-staging/v2d/210922/
#
# gsutil ls -la gs://genetics-portal-dev-staging/v2d/210922/
# Out:
#   18596009  2021-09-28T07:43:18Z  gs://genetics-portal-dev-staging/v2d/210922/ld_analysis_input.tsv#1632814998129248  metageneration=1
#   74041364  2021-09-28T07:43:18Z  gs://genetics-portal-dev-staging/v2d/210922/locus_overlap.parquet#1632814998973176  metageneration=1
#    1737179  2021-11-05T13:20:09Z  gs://genetics-portal-dev-staging/v2d/210922/prev_studies.parquet#1636118409652139  metageneration=1
#    1746889  2021-11-05T16:09:39Z  gs://genetics-portal-dev-staging/v2d/210922/studies.parquet#1636128579763206  metageneration=1
#    8632246  2021-09-28T07:43:18Z  gs://genetics-portal-dev-staging/v2d/210922/toploci.parquet#1632814998077861  metageneration=1
#     860630  2021-10-25T12:34:18Z  gs://genetics-portal-dev-staging/v2d/210922/trait_efo-2021-10-25.parquet#1635165258148742  metageneration=1
#     860657  2021-11-05T18:55:38Z  gs://genetics-portal-dev-staging/v2d/210922/trait_efo-2021-11-05.parquet#1636138538105813  metageneration=1
#                                  gs://genetics-portal-dev-staging/v2d/210922/finemapping.parquet/
#                                  gs://genetics-portal-dev-staging/v2d/210922/ld.parquet/
#                                  gs://genetics-portal-dev-staging/v2d/210922/studies_merged.parquet/
# TOTAL: 7 objects, 106474974 bytes (101.54 MiB)
# Copying file:///Users/dsuveges/project_data/genetics/study_tables/studies_merged.parquet/._SUCCESS.crc [Content-Type=application/octet-stream]...
# Copying file:///Users/dsuveges/project_data/genetics/study_tables/studies_merged.parquet/part-00000-ba9d2827-0e36-46d1-b4df-8a697531086a-c000.snappy.parquet [Content-Type=application/octet-stream]...
# Copying file:///Users/dsuveges/project_data/genetics/study_tables/studies_merged.parquet/.part-00000-ba9d2827-0e36-46d1-b4df-8a697531086a-c000.snappy.parquet.crc [Content-Type=application/octet-stream]...
# Copying file:///Users/dsuveges/project_data/genetics/study_tables/studies_merged.parquet/_SUCCESS [Content-Type=application/octet-stream]...
# | [4 files][  2.2 MiB/  2.2 MiB]   78.4 KiB/s
# Operation completed over 4 objects/2.2 MiB.

# %%
# %%bash
#
# gcloud dataproc clusters create \
#   genetics-evidence-generation \
#   --image-version=1.4 \
#   --properties=spark:spark.debug.maxToStringFields=100,spark:spark.executor.cores=31,spark:spark.executor.instances=1 \
#   --master-machine-type=n1-standard-32 \
#   --master-boot-disk-size=1TB \
#   --zone=europe-west1-d \
#   --single-node \
#   --max-idle=5m \
#   --region=europe-west1 \
#   --project=open-targets-genetics-dev
# Out:
# Waiting on operation [projects/open-targets-genetics-dev/regions/europe-west1/operations/6c5e0291-e401-35d9-ac00-64ae1c80d49d].
# Waiting for cluster creation operation...
# .................................................................................................................................................................................................................................................................................................................................................................................................................................................................done.
# Created [https://dataproc.googleapis.com/v1/projects/open-targets-genetics-dev/regions/europe-west1/clusters/genetics-evidence-generation] Cluster placed in zone [europe-west1-d].

# %%
# %%ding
# %%bash
#
#
# # Set Genetics Portal envidence source files:
# export timeStamp='2021-10-25'
#
# L2G_FILE="gs://genetics-portal-dev-staging/l2g/211015/predictions/l2g.full.211015.parquet"
# STUDY_FILE="gs://genetics-portal-dev-staging/v2d/210922/studies_merged.parquet"
# TOPLOCI_FILE="gs://genetics-portal-dev-staging/v2d/210922/toploci.parquet"
# VARIANTINDEX="gs://genetics-portal-staging/variant-annotation/190129/variant-annotation.parquet"
# ECO_CODES="gs://genetics-portal-data/lut/vep_consequences.tsv"
# OUT_FILE="gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-${timeStamp}"
#
# SCRIPT_DIR='/Users/dsuveges/repositories/evidence_datasource_parsers/'
#
# gcloud dataproc jobs submit pyspark \
#   --cluster=genetics-evidence-generation \
#   --project=open-targets-genetics-dev \
#   --region=europe-west1 \
#   ${SCRIPT_DIR}/modules/GeneticsPortal.py -- \
#   --locus2gene ${L2G_FILE} \
#   --toploci ${TOPLOCI_FILE} \
#   --study ${STUDY_FILE} \
#   --threshold 0.05 \
#   --variantIndex ${VARIANTINDEX}  \
#   --ecoCodes ${ECO_CODES} \
#   --outputFile ${OUT_FILE}

# %%
# %%ding
# %%bash
#
# OUTFILE='gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25'
# TEMP_DIR='/Users/dsuveges/project_data/genetics/evid'
#
# mkdir -p $TEMP_DIR
#
# gsutil cp -r $OUTFILE $TEMP_DIR
# Out:
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/_SUCCESS...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00000-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00001-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# - [3 files][576.2 KiB/576.2 KiB]
# ==> NOTE: You are performing a sequence of gsutil operations that may
# run significantly faster if you instead use gsutil -m cp ... Please
# see the -m section under "gsutil help options" for further information
# about when gsutil -m can be advantageous.
#
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00002-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00003-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00004-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00005-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00006-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00007-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00008-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00009-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00010-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00011-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00012-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00013-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00014-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00015-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00016-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00017-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00018-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00019-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00020-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00021-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00022-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00023-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00024-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00025-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00026-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00027-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00028-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00029-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00030-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00031-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00032-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00033-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00034-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00035-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00036-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00037-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00038-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00039-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00040-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00041-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00042-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00043-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00044-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00045-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00046-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00047-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00048-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00049-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00050-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00051-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00052-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00053-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00054-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00055-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00056-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00057-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00058-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00059-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00060-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00061-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00062-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00063-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00064-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00065-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00066-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00067-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00068-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00069-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00070-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00071-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00072-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00073-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00074-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00075-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00076-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00077-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00078-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00079-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00080-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00081-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00082-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00083-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00084-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00085-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00086-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00087-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00088-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00089-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00090-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00091-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00092-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00093-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00094-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00095-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00096-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00097-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00098-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00099-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00100-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00101-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00102-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00103-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00104-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00105-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00106-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00107-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00108-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00109-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00110-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00111-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00112-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00113-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00114-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00115-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00116-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00117-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00118-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00119-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00120-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00121-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00122-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00123-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00124-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00125-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00126-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00127-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00128-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00129-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00130-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00131-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00132-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00133-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00134-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00135-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00136-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00137-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00138-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00139-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00140-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00141-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00142-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00143-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00144-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00145-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00146-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00147-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00148-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00149-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00150-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00151-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00152-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00153-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00154-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00155-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00156-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00157-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00158-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00159-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00160-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00161-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00162-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00163-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00164-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00165-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00166-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00167-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00168-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00169-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00170-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00171-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00172-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00173-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00174-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00175-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00176-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00177-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00178-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00179-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00180-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00181-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00182-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00183-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00184-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00185-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00186-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00187-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00188-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00189-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00190-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00191-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00192-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00193-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00194-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00195-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00196-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00197-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00198-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# Copying gs://genetics-portal-analysis/l2g-platform-export/data/genetics_portal-2021-10-25/part-00199-ad727899-d556-4607-abfa-6d3b4cdc97ed-c000.json.gz...
# \ [201 files][ 56.9 MiB/ 56.9 MiB]    1.1 MiB/s
# ==> NOTE: You are performing a sequence of gsutil operations that may
# run significantly faster if you instead use gsutil -m cp ... Please
# see the -m section under "gsutil help options" for further information
# about when gsutil -m can be advantageous.
#
#
# Operation completed over 201 objects/56.9 MiB.

# %%
(
    merged_data
    .filter(col('study_id') == 'NEALE2_30270_raw')
    .show(1, vertical=True, truncate=False)
)
# Out:
# -RECORD 0----------------------------------------
#  study_id             | NEALE2_30270_raw
#  pmid                 |
#  pub_date             | 2018-08-01
#  pub_journal          |
#  pub_title            |
#  pub_author           | UKB Neale v2
#  trait_reported       | Mean sphered cell volume
#  trait_efos           | []
#  ancestry_initial     | [European=344729]
#  ancestry_replication | []
#  n_initial            | 344729
#  n_replication        | 0
#  n_cases              | null
#  trait_category       | Uncategorised
#  num_assoc_loci       | 494
#  has_sumstats         | true

# %%
(
    new_df
    .filter(col('study_id') == 'NEALE2_30270_raw')
    .show(1, vertical=True, truncate=False)
)
# Out:
# -RECORD 0----------------------------------------
#  study_id             | NEALE2_30270_raw
#  pmid                 |
#  pub_date             | 2018-08-01
#  pub_journal          |
#  pub_title            |
#  pub_author           | UKB Neale v2
#  trait_reported       | Mean sphered cell volume
#  trait_efos           | []
#  ancestry_initial     | [European=344729]
#  ancestry_replication | []
#  n_initial            | 344729
#  n_replication        | 0
#  n_cases              | null
#  trait_category       | Uncategorised
#  num_assoc_loci       | 494
#  has_sumstats         | true

# %%
(
    new_df
    .filter((size(col("trait_efos")) != 0) & (~col('study_id').startswith('GCST')))
    .select('study_id', 'trait_reported', 'trait_efos')
    .show(truncate=False)
    
)
# Out:
# +----------------------------------------+-----------------------------------------------------------+---------------------------------------+
# |study_id                                |trait_reported                                             |trait_efos                             |
# +----------------------------------------+-----------------------------------------------------------+---------------------------------------+
# |FINNGEN_R5_AB1_AMOEBIASIS               |Amoebiasis                                                 |[EFO_0007144]                          |
# |FINNGEN_R5_AB1_ANOGENITAL_HERPES_SIMPLEX|Anogenital herpesviral [herpes simplex] infection          |[EFO_0007282]                          |
# |FINNGEN_R5_AB1_ARTHROPOD                |Arthropod-borne viral fevers and viral haemorrhagic fevers |[EFO_0000763, MONDO_0018087]           |
# |FINNGEN_R5_AB1_ASPERGILLOSIS            |Aspergillosis                                              |[EFO_0007157]                          |
# |FINNGEN_R5_AB1_ATYPICAL_CNS_VIRUS       |Atypical virus infections of central nervous system        |[MONDO_0024318]                        |
# |FINNGEN_R5_AB1_BACTINF_NOS              |"Bacterial infection, other or unspecified"                |[EFO_0000771]                          |
# |FINNGEN_R5_AB1_BACT_BIR_OTHER_INF_AGENTS|"Bacterial, viral and other infectious agents"             |[EFO_0000771, EFO_0000763, EFO_0005741]|
# |FINNGEN_R5_AB1_BACT_INTEST_OTH          |Other bacterial intestinal infections                      |[EFO_0000771]                          |
# |FINNGEN_R5_AB1_CANDIDIASIS              |Candidiasis                                                |[MONDO_0002026]                        |
# |FINNGEN_R5_AB1_CHLAMYDIA_OTHER          |Other sexually transmitted chlamydial diseases             |[MONDO_0021681, EFO_1001288]           |
# |FINNGEN_R5_AB1_CMV                      |Cytomegaloviral disease                                    |[EFO_0001062]                          |
# |FINNGEN_R5_AB1_DERMATOPHYTOSIS          |Dermatophytosis                                            |[MONDO_0004678]                        |
# |FINNGEN_R5_AB1_EARLY_SYPHILIS           |Early syphilis                                             |[EFO_0007504]                          |
# |FINNGEN_R5_AB1_EBV                      |Infectious mononucleosis                                   |[EFO_0007326]                          |
# |FINNGEN_R5_AB1_ERYSIPELAS               |Erysipelas                                                 |[EFO_1001462]                          |
# |FINNGEN_R5_AB1_GASTROENTERITIS_NOS      |Diarrhoea and gastroenteritis of presumed infectious origin|[MONDO_0045031]                        |
# |FINNGEN_R5_AB1_GHLAMY_OTHER             |Other diseases caused by chlamydiae                        |[EFO_1001288]                          |
# |FINNGEN_R5_AB1_GONOCOCCAL               |Gonococcal infection                                       |[DOID_7551]                            |
# |FINNGEN_R5_AB1_HELMINTIASES             |Helminthiases                                              |[EFO_0007245, EFO_1001342]             |
# |FINNGEN_R5_AB1_HEPATITIS_OTHER_VIRAL    |Other  viral hepatitis                                     |[EFO_0004196]                          |
# +----------------------------------------+-----------------------------------------------------------+---------------------------------------+
# only showing top 20 rows

# %%
(
    new_df
    .filter(size(col("trait_efos")) == 0)
    .select('trait_category')
    .distinct()
    .show(truncate=False)
    
)
# Out:
# +--------------+
# |trait_category|
# +--------------+
# |Uncategorised |
# +--------------+
