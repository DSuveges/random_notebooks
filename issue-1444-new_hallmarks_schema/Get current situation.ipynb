# %% [markdown]
# Current schema:
#
#
# ```
# root
#  |-- hallmarks: struct (nullable = true)
#  |    |-- attributes: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- pmid: long (nullable = true)
#  |    |    |    |-- attribute_name: string (nullable = true)
#  |    |    |    |-- description: string (nullable = true)
#  |    |-- cancer_hallmarks: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- pmid: long (nullable = true)
#  |    |    |    |-- description: string (nullable = true)
#  |    |    |    |-- label: string (nullable = true)
#  |    |    |    |-- promote: boolean (nullable = true)
#  |    |    |    |-- suppress: boolean (nullable = true)
#  |    |-- function_summary: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- pmid: long (nullable = true)
#  |    |    |    |-- description: string (nullable = true)
#  ```
#
#  Cosmic team uploads the hallmarks data to google bucket: [gs://otar007-cosmic/archives/CTTV007-10-02-2021_v94_hallmarks.tsv.gz](gs://otar007-cosmic/archives/CTTV007-10-02-2021_v94_hallmarks.tsv.gz)
#
#
# Graph QL address: [https://api-beta-dot-open-targets-eu-dev.appspot.com/api/v4/graphql/browser](https://api-beta-dot-open-targets-eu-dev.appspot.com/api/v4/graphql/browser)
#
# Query:
#
# ```
# query OpenTargetsGeneticsQuery {
#   target(ensemblId: "ENSG00000136754") {
#     hallmarks {
#       attributes {
#         name
#         reference {
#           pubmedId
#           description
#         }
#       }
#       rows {
#         promote
#         suppress
#         label
#       }
#       functions{
#         description
#         pubmedId
#       }
#     }
#   }
# }
# ```

# %%
# %%bash
#
# DATA_DIR='~/project_data/ot/hallmarks'
#
# # Create directory:
# mkdir -p ${DATA_DIR}
#
# # Fetching data:
# gsutil cp -r gs://otar007-cosmic/archives/CTTV007-10-02-2021_v94_hallmarks.tsv.gz ${DATA_DIR}
#
# gzcat "${DATA_DIR}/CTTV007-10-02-2021_v94_hallmarks.tsv.gz" | head -3 | column -t
#
# gzcat "${DATA_DIR}/CTTV007-10-02-2021_v94_hallmarks.tsv.gz" | wc -l
# Out:
# GENE_SYMBOL  CELL_TYPE       PUBMED_PMID  HALLMARK  IMPACT         DESCRIPTION  CELL_LINE
# ABI1         hepatocellular  carcinoma    28339046  proliferative  signalling   promotes    overexpression  of              ABI1  increases  and        KD   decreases  cell       proliferation  HepG2      and  MHCC97H
# ABI1         hepatocellular  carcinoma    28339046  invasion       and          metastasis  promotes        overexpression  of    ABI1       increases  and  KD         decreases  cell           migration  and  invasion  HepG2  and  MHCC97H
#     3716

# %% [markdown]
# So there are 3716 rows in the hallmark file. Let's read it in a pandas dataframe

# %%
import pandas as pd
import json
import gzip

hallmark_file = '/Users/dsuveges/project_data/ot/hallmarks/CTTV007-10-02-2021_v94_hallmarks.tsv.gz'

hallmark_df = pd.read_csv(hallmark_file, sep='\t', compression='gzip', encoding='cp1252', dtype=str)

print(hallmark_df.head())
len(hallmark_df)
# Out:
#   GENE_SYMBOL                 CELL_TYPE PUBMED_PMID                  HALLMARK  \
# 0        ABI1  hepatocellular carcinoma    28339046  proliferative signalling
# 1        ABI1  hepatocellular carcinoma    28339046   invasion and metastasis
# 2        ABI1                       NaN    16025998            role in cancer
# 3        ABI1                       NaN     9694699            role in cancer
# 4        ABI1                       NaN    23552839            role in cancer
#
#      IMPACT                                        DESCRIPTION  \
# 0  promotes  overexpression of ABI1 increases and KD decrea...
# 1  promotes  overexpression of ABI1 increases and KD decrea...
# 2       TSG                                                TSG
# 3    fusion                                             fusion
# 4       TSG                                                TSG
#
#            CELL_LINE
# 0  HepG2 and MHCC97H
# 1  HepG2 and MHCC97H
# 2                NaN
# 3                NaN
# 4                NaN
# 3715

# %%
hallmark_df.loc[hallmark_df.GENE_SYMBOL == 'ABI1']
# hallmark_df.loc[hallmark_df.HALLMARK.isna()] # -> zero rows
# Out:
#    GENE_SYMBOL                 CELL_TYPE PUBMED_PMID  \
# 0         ABI1  hepatocellular carcinoma    28339046
# 1         ABI1  hepatocellular carcinoma    28339046
# 2         ABI1                       NaN    16025998
# 3         ABI1                       NaN     9694699
# 4         ABI1                       NaN    23552839
# 5         ABI1                       NaN     9010225
# 6         ABI1                       NaN     9694699
# 7         ABI1                       AML     9694699
# 8         ABI1              mouse pre-B     18453543
# 9         ABI1                       NaN    23552839
# 10        ABI1              glioblastoma    26473374
# 11        ABI1                       NaN    10499589
# 12        ABI1         colorectal cancer    24913355
# 13        ABI1             breast cancer    17951403
# 14        ABI1             breast cancer    17951403
# 15        ABI1  hepatocellular carcinoma    28339046
#
#                     HALLMARK      IMPACT  \
# 0   proliferative signalling    promotes
# 1    invasion and metastasis    promotes
# 2             role in cancer         TSG
# 3             role in cancer      fusion
# 4             role in cancer         TSG
# 5      suppression of growth    promotes
# 6           function summary         NaN
# 7             fusion partner         NaN
# 8    invasion and metastasis    promotes
# 9                mouse model         NaN
# 10   invasion and metastasis  suppresses
# 11          function summary         NaN
# 12   invasion and metastasis    promotes
# 13   invasion and metastasis    promotes
# 14  proliferative signalling    promotes
# 15            role in cancer    oncogene
#
#                                           DESCRIPTION          CELL_LINE
# 0   overexpression of ABI1 increases and KD decrea...  HepG2 and MHCC97H
# 1   overexpression of ABI1 increases and KD decrea...  HepG2 and MHCC97H
# 2                                                 TSG                NaN
# 3                                              fusion                NaN
# 4                                                 TSG                NaN
# 5   fibroblasts overexpressing e3B1 have reduced g...                NaN
# 6                     Abl-interacting adaptor protein                NaN
# 7                                               KMT2A                NaN
# 8   KD inhibits the Bcr-Abl-stimulated abnormal cy...               baf3
# 9   development of prostatic intraepithelial neopl...                NaN
# 10  loss of the Abi1 gene enhances the Crk Tyr251 ...                NaN
# 11  participates in the transduction of signals fr...                NaN
# 12  promotes tumour cell adhesion, extracellular m...                NaN
# 13  KD decreases invasiveness and migration abilit...         MDA-MB-231
# 14                    KD decreases cell proliferation         MDA-MB-231
# 15                                           oncogene  HepG2 and MHCC97H

# %%
hallmark_df.HALLMARK.unique()
# Out:
# array(['proliferative signalling', 'invasion and metastasis',
#        'role in cancer', 'suppression of growth', 'function summary',
#        'fusion partner', 'mouse model', 'angiogenesis',
#        'differentiation and development',
#        'global regulation of gene expression',
#        'change of cellular energetics',
#        'genome instability and mutations',
#        'escaping programmed cell death', 'types of alteration in cancer',
#        'clinical impact', 'impact of mutation on function',
#        'cell division control', 'tumour promoting inflammation',
#        'cell replicative immortality', 'senescence',
#        'escaping immune response to cancer', 'interaction with pathogen'],
#       dtype=object)

# %%
hallmark_annotations = ['proliferative signalling', 'invasion and metastasis',
       'suppression of growth',
        'angiogenesis','change of cellular energetics',
       'genome instability and mutations',
       'escaping programmed cell death',
       'tumour promoting inflammation',
       'cell replicative immortality', 
       'escaping immune response to cancer']

hallmarks_only = hallmark_df.loc[hallmark_df.HALLMARK.isin(hallmark_annotations)]

# Is this 
print(
    hallmarks_only.loc[hallmarks_only.GENE_SYMBOL == 'ABI1',['HALLMARK', 'IMPACT']]
    .drop_duplicates()
)


print(
    hallmark_df.loc[(hallmark_df.GENE_SYMBOL == 'ABI1') & (~hallmark_df.IMPACT.isin(['promotes','suppresses']))]
    .drop_duplicates()
)
# Out:
#                     HALLMARK      IMPACT
# 0   proliferative signalling    promotes
# 1    invasion and metastasis    promotes
# 5      suppression of growth    promotes
# 10   invasion and metastasis  suppresses
#    GENE_SYMBOL                 CELL_TYPE PUBMED_PMID          HALLMARK  \
# 2         ABI1                       NaN    16025998    role in cancer
# 3         ABI1                       NaN     9694699    role in cancer
# 4         ABI1                       NaN    23552839    role in cancer
# 6         ABI1                       NaN     9694699  function summary
# 7         ABI1                       AML     9694699    fusion partner
# 9         ABI1                       NaN    23552839       mouse model
# 11        ABI1                       NaN    10499589  function summary
# 15        ABI1  hepatocellular carcinoma    28339046    role in cancer
#
#       IMPACT                                        DESCRIPTION  \
# 2        TSG                                                TSG
# 3     fusion                                             fusion
# 4        TSG                                                TSG
# 6        NaN                    Abl-interacting adaptor protein
# 7        NaN                                              KMT2A
# 9        NaN  development of prostatic intraepithelial neopl...
# 11       NaN  participates in the transduction of signals fr...
# 15  oncogene                                           oncogene
#
#             CELL_LINE
# 2                 NaN
# 3                 NaN
# 4                 NaN
# 6                 NaN
# 7                 NaN
# 9                 NaN
# 11                NaN
# 15  HepG2 and MHCC97H

# %%
print(
    hallmark_df.loc[(hallmark_df.GENE_SYMBOL == 'ABI1') & (hallmark_df.IMPACT.isin(['promotes','suppresses']))]
    .drop_duplicates()
)
# Out:
#    GENE_SYMBOL                 CELL_TYPE PUBMED_PMID  \
# 0         ABI1  hepatocellular carcinoma    28339046
# 1         ABI1  hepatocellular carcinoma    28339046
# 5         ABI1                       NaN     9010225
# 8         ABI1              mouse pre-B     18453543
# 10        ABI1              glioblastoma    26473374
# 12        ABI1         colorectal cancer    24913355
# 13        ABI1             breast cancer    17951403
# 14        ABI1             breast cancer    17951403
#
#                     HALLMARK      IMPACT  \
# 0   proliferative signalling    promotes
# 1    invasion and metastasis    promotes
# 5      suppression of growth    promotes
# 8    invasion and metastasis    promotes
# 10   invasion and metastasis  suppresses
# 12   invasion and metastasis    promotes
# 13   invasion and metastasis    promotes
# 14  proliferative signalling    promotes
#
#                                           DESCRIPTION          CELL_LINE
# 0   overexpression of ABI1 increases and KD decrea...  HepG2 and MHCC97H
# 1   overexpression of ABI1 increases and KD decrea...  HepG2 and MHCC97H
# 5   fibroblasts overexpressing e3B1 have reduced g...                NaN
# 8   KD inhibits the Bcr-Abl-stimulated abnormal cy...               baf3
# 10  loss of the Abi1 gene enhances the Crk Tyr251 ...                NaN
# 12  promotes tumour cell adhesion, extracellular m...                NaN
# 13  KD decreases invasiveness and migration abilit...         MDA-MB-231
# 14                    KD decreases cell proliferation         MDA-MB-231

# %%
hallmark_df.loc[(hallmark_df.GENE_SYMBOL == 'ABI1') & (hallmark_df.HALLMARK == 'role in cancer')]
# Out:
#    GENE_SYMBOL                 CELL_TYPE PUBMED_PMID        HALLMARK  \
# 2         ABI1                       NaN    16025998  role in cancer
# 3         ABI1                       NaN     9694699  role in cancer
# 4         ABI1                       NaN    23552839  role in cancer
# 15        ABI1  hepatocellular carcinoma    28339046  role in cancer
#
#       IMPACT DESCRIPTION          CELL_LINE
# 2        TSG         TSG                NaN
# 3     fusion      fusion                NaN
# 4        TSG         TSG                NaN
# 15  oncogene    oncogene  HepG2 and MHCC97H

# %%
hallmark_df.loc[(hallmark_df.GENE_SYMBOL == 'ABI1') & (~hallmark_df.HALLMARK.isin(hallmark_annotations))]
# Out:
#    GENE_SYMBOL                 CELL_TYPE PUBMED_PMID          HALLMARK  \
# 2         ABI1                       NaN    16025998    role in cancer
# 3         ABI1                       NaN     9694699    role in cancer
# 4         ABI1                       NaN    23552839    role in cancer
# 6         ABI1                       NaN     9694699  function summary
# 7         ABI1                       AML     9694699    fusion partner
# 9         ABI1                       NaN    23552839       mouse model
# 11        ABI1                       NaN    10499589  function summary
# 15        ABI1  hepatocellular carcinoma    28339046    role in cancer
#
#       IMPACT                                        DESCRIPTION  \
# 2        TSG                                                TSG
# 3     fusion                                             fusion
# 4        TSG                                                TSG
# 6        NaN                    Abl-interacting adaptor protein
# 7        NaN                                              KMT2A
# 9        NaN  development of prostatic intraepithelial neopl...
# 11       NaN  participates in the transduction of signals fr...
# 15  oncogene                                           oncogene
#
#             CELL_LINE
# 2                 NaN
# 3                 NaN
# 4                 NaN
# 6                 NaN
# 7                 NaN
# 9                 NaN
# 11                NaN
# 15  HepG2 and MHCC97H

# %%
not_known = (
    pd.Series(
        hallmark_df
        .HALLMARK
        .unique()
    )
    .rename('cica')
    .to_frame()
    .loc[ lambda x: ~x.cica.isin(hallmark_annotations + ['function summary', 'role in cancer', 'fusion partner', 'mouse model'])]
    .cica
    .tolist()
)

# %%
hallmark_df.loc[hallmark_df.HALLMARK.isin(not_known)].HALLMARK.value_counts()
# Out:
# types of alteration in cancer           369
# impact of mutation on function          217
# differentiation and development         171
# clinical impact                         125
# cell division control                    90
# global regulation of gene expression     51
# senescence                               33
# interaction with pathogen                 9
# Name: HALLMARK, dtype: int64

# %%
hallmark_df.loc[(hallmark_df.GENE_SYMBOL == 'ABI1') &
                (hallmark_df.HALLMARK != 'role in cancer') &
               (~hallmark_df.HALLMARK.isin(hallmark_annotations))]
# Out:
#    GENE_SYMBOL CELL_TYPE PUBMED_PMID          HALLMARK IMPACT  \
# 6         ABI1       NaN     9694699  function summary    NaN
# 7         ABI1       AML     9694699    fusion partner    NaN
# 9         ABI1       NaN    23552839       mouse model    NaN
# 11        ABI1       NaN    10499589  function summary    NaN
#
#                                           DESCRIPTION CELL_LINE
# 6                     Abl-interacting adaptor protein       NaN
# 7                                               KMT2A       NaN
# 9   development of prostatic intraepithelial neopl...       NaN
# 11  participates in the transduction of signals fr...       NaN

# %%
hallmark_df.loc[(hallmark_df.HALLMARK == 'function summary')]
# Out:
#      GENE_SYMBOL             CELL_TYPE PUBMED_PMID          HALLMARK IMPACT  \
# 6           ABI1                   NaN     9694699  function summary    NaN
# 11          ABI1                   NaN    10499589  function summary    NaN
# 17          ABL1                   NaN    23316053  function summary    NaN
# 20          ABL1                   NaN    25999467  function summary    NaN
# 33         ACKR3  vascular endothelium    26119946  function summary    NaN
# ...          ...                   ...         ...               ...    ...
# 3526      PTPN11                   NaN    12826400  function summary    NaN
# 3598       PTPRB                   NaN    19451274  function summary    NaN
# 3629       FOXL2                   NaN    24049064  function summary    NaN
# 3657      ACVR2A     colorectal cancer    26497569  function summary    NaN
# 3658      ACVR2A                   NaN    11815670  function summary    NaN
#
#                                             DESCRIPTION CELL_LINE
# 6                       Abl-interacting adaptor protein       NaN
# 11    participates in the transduction of signals fr...       NaN
# 17    protein-tyrosine kinase, plays a prominent rol...       NaN
# 20    phosphorylates RAS proteins to allosterically ...       NaN
# 33              scavenger receptor for chemokine CXCL12       NaN
# ...                                                 ...       ...
# 3526  Src homology-2 domain-containing protein tyros...       NaN
# 3598  a receptor-type tyrosine phosphatase involved ...       NaN
# 3629  a forkhead type transcription factor involved ...       NaN
# 3657  Activin ACVR2A signaling stabilises p21 via SMAD4     SW480
# 3658  transmembrane, constitutively active serine-th...       NaN
#
# [427 rows x 7 columns]

# %%
(
    hallmark_df
    .groupby(['HALLMARK'])
    .agg(
        {
            "CELL_LINE": lambda x: x.dropna().unique().tolist(),
            "CELL_TYPE": lambda x: x.dropna().unique().tolist(),
        }
    )
)
# Out:
#                                                                               CELL_LINE  \
# HALLMARK
# angiogenesis                          [HepG2, PDVC57, MCF-7, BGC-823 and MKN-28, RH3...
# cell division control                 [Hela and U2OS, NIH-3T3, KMS11, KMM1, Cal27, S...
# cell replicative immortality                                         [HONE1, BJ, U87MG]
# change of cellular energetics         [Raji, MCF-7, RPMI-8826, MCF7, SK-OV-3, 3AO, H...
# clinical impact                       [A549, H1993, HCC827, H1975, A549, Pc9, Pc9 GR...
# differentiation and development       [32D.C10, NB4-55 ,HL-60, U-937, NB-39-nu, NGP,...
# escaping immune response to cancer    [FO-1, HepG2/C3A, SNU-423,  SK-HEP-1, PLC/PRF/...
# escaping programmed cell death        [SW480 and HT-29, MiaPaCa-2, H460, HCT-15, and...
# function summary                                   [LNCaP , MCF-7, HeLa, HEK293, SW480]
# fusion partner                                     [UACC812, ZR-75-30, Karpas 231, VAL]
# genome instability and mutations      [Tramp-C1, JHH4, MDA-MB-468, T24, NIH 3T3, HCT...
# global regulation of gene expression  [OCI-Ly-19, WSU-DLCL2, Karpas422, LNCaP, MCF-7...
# impact of mutation on function        [NIH3T3, K562, Ba/F3, Jurkat T, NIH 3T3, Ba/F3...
# interaction with pathogen                                                  [AGS, COS-7]
# invasion and metastasis               [HepG2 and MHCC97H, baf3, MDA-MB-231, HCCLM3, ...
# mouse model                                           [LLC, B16F10, A549, Panc02, T241]
# proliferative signalling              [HepG2 and MHCC97H, MDA-MB-231, EC109, TF-1, S...
# role in cancer                        [HepG2 and MHCC97H, H1703, Jurkat T, MCF-7, B1...
# senescence                            [MKN28, AGS, WI-38, GTL-16, MKN-45, SNU-5, MIP...
# suppression of growth                 [T47D, GES1, Raji, MCF10A, HepG2, PLC and Huh7...
# tumour promoting inflammation                                [MCF10A, TE1, HCT116, KGN]
# types of alteration in cancer         [DU-145, ACCM, MDA-MB453, HCT116, SW48, DLD1, ...
#
#                                                                               CELL_TYPE
# HALLMARK
# angiogenesis                          [hepatocellular carcinoma, papillary thyroid c...
# cell division control                 [mouse brain, mouse, mouse fibroblasts, endoth...
# cell replicative immortality          [haematopoietic stem cells, triple negative br...
# change of cellular energetics         [prostate cancer, adipocytes and L6 myotubes, ...
# clinical impact                       [GBM, gallbladder cancer, renal cell carcinoma...
# differentiation and development       [mouse, murine myeloid, sensory dorsal root ga...
# escaping immune response to cancer    [melanoma, colorectal cancer, pancreatic ducta...
# escaping programmed cell death        [colorectal cancer, glioma-initiating cells, m...
# function summary                      [vascular endothelium, lung cancer, Ewing sarc...
# fusion partner                        [AML, CML, lipoma, prostate cancer, ALL, papil...
# genome instability and mutations      [murine prostate cancer, ovarian cancer, hepat...
# global regulation of gene expression  [colorectal cancer, colon carcinoma, oligodend...
# impact of mutation on function        [papillary thyroid carcinoma, neuroblastoma, m...
# interaction with pathogen                                           [gastric carcinoma]
# invasion and metastasis               [hepatocellular carcinoma, mouse pre-B , gliob...
# mouse model                           [mouse, breast cancer, mouse embryos, chronic ...
# proliferative signalling              [hepatocellular carcinoma, breast cancer, oeso...
# role in cancer                        [hepatocellular carcinoma, breast cancer, lipo...
# senescence                            [gastric cancer, endometrial cancer , mouse ke...
# suppression of growth                 [breast cancer, gastric epithelium, hepatocell...
# tumour promoting inflammation         [breast cancer, mouse model of lung cancer, GB...
# types of alteration in cancer         [breast cancer, prostate cancer, ER- breast ca...

# %%
len(hallmark_df.loc[hallmark_df.HALLMARK == 'function summary'])
# Out:
# 3715

# %%
(
    hallmark_df
    .groupby('GENE_SYMBOL')
    .agg({'HALLMARK': lambda x: len(x.loc[x == 'function summary'])})
    .value_counts('HALLMARK')
)
# Out:
# HALLMARK
# 1    217
# 2     73
# 3     14
# 0      8
# 4      3
# 5      2
# dtype: int64

# %%
print('\n'.join(hallmark_df.loc[hallmark_df.GENE_SYMBOL == 'NPM1'].HALLMARK.unique()))
# Out:
# impact of mutation on function
# types of alteration in cancer
# interaction with pathogen
# fusion partner
# cell division control
# differentiation and development
# function summary
# genome instability and mutations
# escaping programmed cell death
# proliferative signalling
# invasion and metastasis
# change of cellular energetics
# suppression of growth
# senescence
# role in cancer
# clinical impact

# %%
hallmark_df.loc[(hallmark_df.GENE_SYMBOL == 'NPM1') & (hallmark_df.HALLMARK == 'role in cancer')]
# Out:
#      GENE_SYMBOL              CELL_TYPE PUBMED_PMID        HALLMARK  \
# 2353        NPM1      mouse fibroblasts    19033198  role in cancer
# 2354        NPM1  lymphoid malignancies    18212245  role in cancer
# 2355        NPM1                    NaN    21278791  role in cancer
# 2356        NPM1                   ALCL     8122112  role in cancer
#
#                      IMPACT            DESCRIPTION CELL_LINE
# 2353               oncogene               oncogene      MEFs
# 2354                    TSG                    TSG       NaN
# 2355  oncogene, TSG, fusion  oncogene, TSG, fusion       NaN
# 2356                    NaN                 fusion       NaN

# %%
hallmark_df.loc[(hallmark_df.GENE_SYMBOL == 'NPM1')]
# Out:
#      GENE_SYMBOL                                          CELL_TYPE  \
# 2324        NPM1                                                AML
# 2325        NPM1            salivary gland adenoid cystic carcinoma
# 2326        NPM1                                                NaN
# 2327        NPM1                                        MDS and AML
# 2328        NPM1                                                APL
# 2329        NPM1                                               ALCL
# 2330        NPM1                                  colorectal cancer
# 2331        NPM1                                   mouse fibroblast
# 2332        NPM1                            acute myeloid leukaemia
# 2333        NPM1                                                AML
# 2334        NPM1                                  colorectal cancer
# 2335        NPM1                                                NaN
# 2336        NPM1                                   mouse fibroblast
# 2337        NPM1                                    cervical cancer
# 2338        NPM1                                                AML
# 2339        NPM1                                                NaN
# 2340        NPM1  bone osteosarcoma, cervical cancer, breast cancer
# 2341        NPM1            salivary gland adenoid cystic carcinoma
# 2342        NPM1                            cervical cancer and AML
# 2343        NPM1               breast, cervical, and gastric cancer
# 2344        NPM1                                                NaN
# 2345        NPM1            salivary gland adenoid cystic carcinoma
# 2346        NPM1                                   mouse fibroblast
# 2347        NPM1                                                NaN
# 2348        NPM1                                                AML
# 2349        NPM1                            acute myeloid leukaemia
# 2350        NPM1                                  bone osteosarcoma
# 2351        NPM1                                 osteogenic sarcoma
# 2352        NPM1                                  colorectal cancer
# 2353        NPM1                                  mouse fibroblasts
# 2354        NPM1                              lymphoid malignancies
# 2355        NPM1                                                NaN
# 2356        NPM1                                               ALCL
# 2357        NPM1                                                AML
# 2358        NPM1                           hepatocellular carcinoma
# 2359        NPM1                                      solid tumours
# 2360        NPM1                                      breast cancer
# 2361        NPM1                                                APL
#
#      PUBMED_PMID                          HALLMARK                 IMPACT  \
# 2324    16455950    impact of mutation on function                    NaN
# 2325    27501253     types of alteration in cancer                    NaN
# 2326    23271972         interaction with pathogen                    NaN
# 2327     8570204                    fusion partner                    NaN
# 2328     8562957                    fusion partner                    NaN
# 2329     8122112                    fusion partner                    NaN
# 2330    23536448             cell division control               promotes
# 2331    11051553             cell division control                    NaN
# 2332    27669739   differentiation and development             suppresses
# 2333    28111462     types of alteration in cancer                    NaN
# 2334    23536448     types of alteration in cancer                    NaN
# 2335    27553022                  function summary                    NaN
# 2336    19033198                  function summary               promotes
# 2337    18332108                  function summary                    NaN
# 2338    28111462                  function summary                    NaN
# 2339    24576674                  function summary                    NaN
# 2340    20713529  genome instability and mutations             suppresses
# 2341    27501253    escaping programmed cell death               promotes
# 2342    20606168    escaping programmed cell death               promotes
# 2343    19734942    escaping programmed cell death               promotes
# 2344    17951246    escaping programmed cell death               promotes
# 2345    27501253          proliferative signalling               promotes
# 2346    19033198          proliferative signalling               promotes
# 2347    17951246          proliferative signalling               promotes
# 2348    26884713           invasion and metastasis               promotes
# 2349    28740552     change of cellular energetics               promotes
# 2350    12080348             suppression of growth               promotes
# 2351    15144954             suppression of growth               promotes
# 2352    23536448                        senescence             suppresses
# 2353    19033198                    role in cancer               oncogene
# 2354    18212245                    role in cancer                    TSG
# 2355    21278791                    role in cancer  oncogene, TSG, fusion
# 2356     8122112                    role in cancer                    NaN
# 2357    28370403                   clinical impact                    NaN
# 2358    28259962                   clinical impact                    NaN
# 2359    30126359                   clinical impact                    NaN
# 2360    21689627                   clinical impact                    NaN
# 2361    24183235    impact of mutation on function                    NaN
#
#                                             DESCRIPTION            CELL_LINE
# 2324  most common forms of NPM1 mutation in exon 12 ...                  NaN
# 2325  frequently overexpressed and higher levels ass...                 ACCM
# 2326  escorts an Epstein-Barr Virus nuclear antigen ...                  NaN
# 2327                                               MLF1                  NaN
# 2328                                               RARA                  NaN
# 2329                                                ALK                  NaN
# 2330  KD results in block of cell cycle progression ...  MIP101, RKO, HCT116
# 2331  binds to unduplicated centrosomes, dissociates...            swiss 3T3
# 2332  W288fs mutant inhibits myeloid differentiation...             OCI-AML3
# 2333  patients with frameshift mutation in NPM1 have...                  NaN
# 2334                           frequently overexpressed                  NaN
# 2335  a histone chaperone with functions in DNA repa...                  NaN
# 2336  binds to and regulates transcriptional activit...                  NaN
# 2337  associates directly with rRNA gene chromatin a...                 HeLa
# 2338  one of the most commonly mutated genes in AML,...                  NaN
# 2339  specifically recognizes and binds to DNA G-qua...                  NaN
# 2340  recruited to DNA DSB after phosphorylation at ...     HeLa, U2OS, MCF7
# 2341                               KD induces apoptosis                 SACC
# 2342  c-terminal W288fs mutations result in cytoplas...          HeLa, HL-60
# 2343  after oligomerisation, negatively regulates TP...  MCF7, HeLa, SGC7901
# 2344  suppresses apoptosis through interaction with ...                  NaN
# 2345                          KD inhibits proliferation                 ACCM
# 2346  regulates transcriptional activity of Myc over...                 MEFs
# 2347  interacts with PA2G4 (EBP1) isoforms and promo...   PC12, HEK293, HeLa
# 2348  W288fs mutant promotes adhesion, migration and...                THP-1
# 2349  W288fs mutant enhances autophagy and increases...             OCI-AML3
# 2350  promotes growth arrest on overexpression by di...                 U2OS
# 2351  promotes growth arrest by interaction with MDM...               SaOS-2
# 2352                             KD promotes senescence  MIP101, RKO, HCT116
# 2353                                           oncogene                 MEFs
# 2354                                                TSG                  NaN
# 2355                              oncogene, TSG, fusion                  NaN
# 2356                                             fusion                  NaN
# 2357  NPM1 mutations in de novo AML lacking recurren...                  NaN
# 2358  KD in cell lines with established multi drug r...      HepG2, SMMC7721
# 2359  higher protein level expression is associated ...                  NaN
# 2360  decreased level of expression associated with ...                  NaN
# 2361  NPM1-RARA fusion protein produced from t(5;17)...                 U937

# %%
annotation_examples = (
    hallmark_df
    .groupby(['HALLMARK'])
    .agg({
        "GENE_SYMBOL": lambda x: x.iloc[0], # Select first
        "DESCRIPTION": lambda x: x.iloc[0] # Select first
    })
    .reset_index()
    .assign(ANNOT_TYPE = lambda df: df.HALLMARK.apply(lambda x: "hallmark" if x in hallmark_annotations else 'function summary' if x == 'function summary' else 'other annotation'))
    .sort_values('ANNOT_TYPE')
    .to_markdown()
)

#row = annotation_examples.iloc[1]
#row['DESCRIPTION']
print(annotation_examples)
# Out:
# |    | HALLMARK                             | GENE_SYMBOL   | DESCRIPTION                                                                                                                                                                                                                   | ANNOT_TYPE       |
# |---:|:-------------------------------------|:--------------|:------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|:-----------------|
# |  8 | function summary                     | ABI1          | Abl-interacting adaptor protein                                                                                                                                                                                               | function summary |
# |  0 | angiogenesis                         | ABL1          | loss of Abl kinases leads to increased endothelial cell apoptosis both in vitro and in vivo, contributing to vascular dysfunction, infarction, and tissue damage                                                              | hallmark         |
# | 19 | suppression of growth                | ABI1          | fibroblasts overexpressing e3B1 have reduced growth compared to matched controls                                                                                                                                              | hallmark         |
# | 16 | proliferative signalling             | ABI1          | overexpression of ABI1 increases and KD decreases cell proliferation                                                                                                                                                          | hallmark         |
# | 14 | invasion and metastasis              | ABI1          | overexpression of ABI1 increases and KD decreases cell migration and invasion                                                                                                                                                 | hallmark         |
# | 20 | tumour promoting inflammation        | APOBEC3B      | deletion is associated with immune activation                                                                                                                                                                                 | hallmark         |
# |  7 | escaping programmed cell death       | ABL1          | positively regulates DNA damage-induced apoptosis                                                                                                                                                                             | hallmark         |
# | 10 | genome instability and mutations     | ABL1          | interacts constitutively with Rad51 and phosphorylates Rad51 on Tyr-54 upon treatment with ionising radiation to inhibit the binding of Rad51 to DNA and the function of Rad51 in ATP-dependent DNA strand exchange reactions | hallmark         |
# |  3 | change of cellular energetics        | ABL1          | regulates autophagy by promoting the trafficking and function of lysosomal components                                                                                                                                         | hallmark         |
# |  2 | cell replicative immortality         | ARID1A        | ARID1A deficiency compromises ES cell pluripotency, severely inhibits self-renewal, and promotes differentiation into primitive endoderm-like cells                                                                           | hallmark         |
# |  6 | escaping immune response to cancer   | B2M           | inactivating mutations in 5' region of the gene lead to impaired expression of HLA class I antigen, thus helping tumour to avoid the immune destruction                                                                       | hallmark         |
# |  5 | differentiation and development      | ABL1          | promotes adipocyte differentiation                                                                                                                                                                                            | other annotation |
# |  9 | fusion partner                       | ABI1          | KMT2A                                                                                                                                                                                                                         | other annotation |
# |  4 | clinical impact                      | ACKR3         | high expression predicts poor survival                                                                                                                                                                                        | other annotation |
# | 11 | global regulation of gene expression | ABL1          | induces stabilisation of histone deacetylase 1 (HDAC1) in a kinase activity-dependent manner                                                                                                                                  | other annotation |
# | 12 | impact of mutation on function       | ACSL3         | provides androgen upregulated promoter in fusion with ETV1                                                                                                                                                                    | other annotation |
# | 13 | interaction with pathogen            | BRD4          | cellular corepressor that inhibits the expression of HPV-encoded E6 and E7 oncoproteins which antagonise p53 and pRB tumour suppressor activity                                                                               | other annotation |
# | 15 | mouse model                          | ABI1          | development of prostatic intraepithelial neoplasia was observed in 8-month-old Abi1 knockout mice, but no progression beyond PIN was observed in mice as old as 12 months                                                     | other annotation |
# | 17 | role in cancer                       | ABI1          | TSG                                                                                                                                                                                                                           | other annotation |
# | 18 | senescence                           | ATM           | inactivation of ATM overcomes replication stress-induced senescence                                                                                                                                                           | other annotation |
# |  1 | cell division control                | APC           | regulates mitotic spindle assembly and orientation and chromosome segregation                                                                                                                                                 | other annotation |
# | 21 | types of alteration in cancer        | ACKR3         | overexpressed                                                                                                                                                                                                                 | other annotation |

# %%
annotation_examples.DESCRIPTION.apply(lambda x: "hallmark" if x in hallmark_annotations else 'function summary' if x == 'function summary' else 'other annotation')
# Out:
# HALLMARK
# angiogenesis                            other annotation
# cell division control                   other annotation
# cell replicative immortality            other annotation
# change of cellular energetics           other annotation
# clinical impact                         other annotation
# differentiation and development         other annotation
# escaping immune response to cancer      other annotation
# escaping programmed cell death          other annotation
# function summary                        other annotation
# fusion partner                          other annotation
# genome instability and mutations        other annotation
# global regulation of gene expression    other annotation
# impact of mutation on function          other annotation
# interaction with pathogen               other annotation
# invasion and metastasis                 other annotation
# mouse model                             other annotation
# proliferative signalling                other annotation
# role in cancer                          other annotation
# senescence                              other annotation
# suppression of growth                   other annotation
# tumour promoting inflammation           other annotation
# types of alteration in cancer           other annotation
# Name: DESCRIPTION, dtype: object

# %%
annotation_examples.index.to_series().apply(lambda x: "hallmark" if x in hallmark_annotations else 'function summary' if x == 'function summary' else 'other annotation')
# Out:
# HALLMARK
# angiogenesis                                    hallmark
# cell division control                   other annotation
# cell replicative immortality                    hallmark
# change of cellular energetics                   hallmark
# clinical impact                         other annotation
# differentiation and development         other annotation
# escaping immune response to cancer              hallmark
# escaping programmed cell death                  hallmark
# function summary                        function summary
# fusion partner                          other annotation
# genome instability and mutations                hallmark
# global regulation of gene expression    other annotation
# impact of mutation on function          other annotation
# interaction with pathogen               other annotation
# invasion and metastasis                         hallmark
# mouse model                             other annotation
# proliferative signalling                        hallmark
# role in cancer                          other annotation
# senescence                              other annotation
# suppression of growth                           hallmark
# tumour promoting inflammation                   hallmark
# types of alteration in cancer           other annotation
# Name: HALLMARK, dtype: object

# %%
print(
    hallmark_df
    .head()
    .to_markdown(index=False)
)
# Out:
# | GENE_SYMBOL   | CELL_TYPE                |   PUBMED_PMID | HALLMARK                 | IMPACT   | DESCRIPTION                                                                   | CELL_LINE         |
# |:--------------|:-------------------------|--------------:|:-------------------------|:---------|:------------------------------------------------------------------------------|:------------------|
# | ABI1          | hepatocellular carcinoma |      28339046 | proliferative signalling | promotes | overexpression of ABI1 increases and KD decreases cell proliferation          | HepG2 and MHCC97H |
# | ABI1          | hepatocellular carcinoma |      28339046 | invasion and metastasis  | promotes | overexpression of ABI1 increases and KD decreases cell migration and invasion | HepG2 and MHCC97H |
# | ABI1          | nan                      |      16025998 | role in cancer           | TSG      | TSG                                                                           | nan               |
# | ABI1          | nan                      |       9694699 | role in cancer           | fusion   | fusion                                                                        | nan               |
# | ABI1          | nan                      |      23552839 | role in cancer           | TSG      | TSG                                                                           | nan               |

# %%
def describe_column(colname):
    
    # Narrowing the df to the non-na values:
    s = hallmark_df[colname].loc[lambda x: x.notna()]
    
    print(f'Not null values: {len(s)}')
    print(f'Unique values: {len(s.unique())}')
    
    
colname = 'DESCRIPTION'
describe_column(colname)
# Out:
# Not null values: 3715
# Unique values: 2966

# %%
hallmark_df.GENE_SYMBOL.value_counts()
# Out:
# PTPN11      73
# CEBPA       56
# MET         51
# CYLD        49
# GATA1       41
#             ..
# ARHGEF12     1
# SNX9         1
# XPA          1
# ABL2         1
# CDX2         1
# Name: GENE_SYMBOL, Length: 317, dtype: int64

# %%
ensembl_id = 'ENSG00000179295'
# Out:
# 3715

# %%
import json

data = '''
{
  "data": {
    "target": {
      "hallmarks": {
        "attributes": [
          {
            "name": "senescence",
            "reference": {
              "pubmedId": 29505847,
              "description": "hepatocyte-specific KD induces hepatocyte senescence in mice with oncogene-driven hepatocellular carcinoma"
            }
          },
          {
            "name": "senescence",
            "reference": {
              "pubmedId": 25736378,
              "description": "KD induces senescence in mammospheres"
            }
          },
          {
            "name": "role in cancer",
            "reference": {
              "pubmedId": 25865556,
              "description": "oncogene"
            }
          },
          {
            "name": "role in cancer",
            "reference": {
              "pubmedId": 15710330,
              "description": "oncogene"
            }
          },
          {
            "name": "role in cancer",
            "reference": {
              "pubmedId": 28814887,
              "description": "oncogene"
            }
          },
          {
            "name": "role in cancer",
            "reference": {
              "pubmedId": 26622699,
              "description": "oncogene"
            }
          },
          {
            "name": "role in cancer",
            "reference": {
              "pubmedId": 27582544,
              "description": "TSG"
            }
          },
          {
            "name": "role in cancer",
            "reference": {
              "pubmedId": 27582544,
              "description": "oncogene"
            }
          },
          {
            "name": "role in cancer",
            "reference": {
              "pubmedId": 21575863,
              "description": "TSG"
            }
          },
          {
            "name": "clinical impact",
            "reference": {
              "pubmedId": 32944401,
              "description": "elevated expression is associated with reduced survival"
            }
          },
          {
            "name": "clinical impact",
            "reference": {
              "pubmedId": 25865556,
              "description": "high expression is associated with reduced survival"
            }
          },
          {
            "name": "clinical impact",
            "reference": {
              "pubmedId": 24297342,
              "description": "high expression is associated with reduced survival"
            }
          },
          {
            "name": "clinical impact",
            "reference": {
              "pubmedId": 26622699,
              "description": "elevated expression correlates with lymph node metastasis at presentation"
            }
          },
          {
            "name": "mouse model",
            "reference": {
              "pubmedId": 29323748,
              "description": "p.E76K conditional knock-in promotes colitis-associated colorectal cancer development"
            }
          },
          {
            "name": "types of alteration in cancer",
            "reference": {
              "pubmedId": 25865556,
              "description": "frequently increased expression (typically poorly differentiated tumours)"
            }
          },
          {
            "name": "types of alteration in cancer",
            "reference": {
              "pubmedId": 30371878,
              "description": "missense mutation in 42% of tumours, the most common being p.E76K"
            }
          },
          {
            "name": "types of alteration in cancer",
            "reference": {
              "pubmedId": 24297342,
              "description": "frequently increased expression"
            }
          },
          {
            "name": "types of alteration in cancer",
            "reference": {
              "pubmedId": 30371878,
              "description": "missense mutations in 9% of tumours"
            }
          },
          {
            "name": "types of alteration in cancer",
            "reference": {
              "pubmedId": 28814887,
              "description": "frequently increased expression"
            }
          },
          {
            "name": "types of alteration in cancer",
            "reference": {
              "pubmedId": 26622699,
              "description": "frequently increased expression"
            }
          },
          {
            "name": "global regulation of gene expression",
            "reference": {
              "pubmedId": 12425940,
              "description": "acts as a negative regulator of LIF signalling-mediated neuronal gene expression"
            }
          },
          {
            "name": "differentiation and development",
            "reference": {
              "pubmedId": 30764849,
              "description": "downregulation enhances cell differentiation via SRC and CTNNB1"
            }
          },
          {
            "name": "differentiation and development",
            "reference": {
              "pubmedId": 29659837,
              "description": "differentiation of primary chondrocytes from mice heterozygous for D61G mutation is impaired via ERK activation"
            }
          },
          {
            "name": "differentiation and development",
            "reference": {
              "pubmedId": 21670473,
              "description": "KD inhibits myeloid and erythroid differentiation of CD34 positive cells"
            }
          },
          {
            "name": "differentiation and development",
            "reference": {
              "pubmedId": 32751109,
              "description": "involved in the regulation of several processes central to embryo development"
            }
          },
          {
            "name": "cell division control",
            "reference": {
              "pubmedId": 32944401,
              "description": "KD delays cell G1 to S phase transition via PI3K/AKT/GSK3_ pathway-mediated degradation of cyclin D"
            }
          },
          {
            "name": "cell division control",
            "reference": {
              "pubmedId": 31807022,
              "description": "overexpression increases cell transition from G1 to S, a larger effect is observed for a E76K mutation-containing gene"
            }
          },
          {
            "name": "cell division control",
            "reference": {
              "pubmedId": 18640765,
              "description": "D61Y and E76K gain of function mutations promote cell progression to S and G2, in association with cyclin D upregulation and downregulation of p27 and p21"
            }
          },
          {
            "name": "interaction with pathogen",
            "reference": {
              "pubmedId": 11743164,
              "description": "activation by sh2 domain binding of tyrosine phosphorylated Helicobacter pylori protein CagA is required for CagA-induced gastric carcinoma-associated morphological changes"
            }
          },
          {
            "name": "impact of mutation on function",
            "reference": {
              "pubmedId": 31807022,
              "description": "E76K mutation enhances cell proliferation, migration and invasion effects effected by overexpression"
            }
          },
          {
            "name": "impact of mutation on function",
            "reference": {
              "pubmedId": 30375388,
              "description": "most commonly reported cancer mutation E76K changes basal autoinhibited conformation to open substrate accessible state"
            }
          }
        ],
        "rows": [
          {
            "promote": true,
            "suppress": false,
            "label": "genome instability and mutations"
          },
          {
            "promote": false,
            "suppress": true,
            "label": "genome instability and mutations"
          },
          {
            "promote": false,
            "suppress": true,
            "label": "angiogenesis"
          },
          {
            "promote": true,
            "suppress": false,
            "label": "angiogenesis"
          },
          {
            "promote": true,
            "suppress": false,
            "label": "angiogenesis"
          },
          {
            "promote": true,
            "suppress": false,
            "label": "angiogenesis"
          },
          {
            "promote": false,
            "suppress": true,
            "label": "escaping programmed cell death"
          },
          {
            "promote": true,
            "suppress": false,
            "label": "escaping programmed cell death"
          },
          {
            "promote": false,
            "suppress": true,
            "label": "escaping programmed cell death"
          },
          {
            "promote": true,
            "suppress": false,
            "label": "escaping programmed cell death"
          },
          {
            "promote": true,
            "suppress": false,
            "label": "escaping programmed cell death"
          },
          {
            "promote": false,
            "suppress": true,
            "label": "escaping programmed cell death"
          },
          {
            "promote": true,
            "suppress": false,
            "label": "escaping programmed cell death"
          },
          {
            "promote": true,
            "suppress": false,
            "label": "escaping programmed cell death"
          },
          {
            "promote": true,
            "suppress": false,
            "label": "escaping programmed cell death"
          },
          {
            "promote": true,
            "suppress": false,
            "label": "proliferative signalling"
          },
          {
            "promote": true,
            "suppress": false,
            "label": "proliferative signalling"
          },
          {
            "promote": true,
            "suppress": false,
            "label": "proliferative signalling"
          },
          {
            "promote": true,
            "suppress": false,
            "label": "proliferative signalling"
          },
          {
            "promote": true,
            "suppress": false,
            "label": "proliferative signalling"
          },
          {
            "promote": true,
            "suppress": false,
            "label": "proliferative signalling"
          },
          {
            "promote": true,
            "suppress": false,
            "label": "invasion and metastasis"
          },
          {
            "promote": true,
            "suppress": false,
            "label": "invasion and metastasis"
          },
          {
            "promote": true,
            "suppress": false,
            "label": "invasion and metastasis"
          },
          {
            "promote": true,
            "suppress": false,
            "label": "invasion and metastasis"
          },
          {
            "promote": true,
            "suppress": false,
            "label": "invasion and metastasis"
          },
          {
            "promote": true,
            "suppress": false,
            "label": "invasion and metastasis"
          },
          {
            "promote": true,
            "suppress": false,
            "label": "tumour promoting inflammation"
          },
          {
            "promote": true,
            "suppress": false,
            "label": "tumour promoting inflammation"
          },
          {
            "promote": false,
            "suppress": true,
            "label": "tumour promoting inflammation"
          },
          {
            "promote": false,
            "suppress": false,
            "label": "change of cellular energetics"
          },
          {
            "promote": false,
            "suppress": false,
            "label": "change of cellular energetics"
          },
          {
            "promote": true,
            "suppress": false,
            "label": "suppression of growth"
          },
          {
            "promote": true,
            "suppress": false,
            "label": "suppression of growth"
          },
          {
            "promote": true,
            "suppress": false,
            "label": "suppression of growth"
          },
          {
            "promote": true,
            "suppress": false,
            "label": "proliferative signalling"
          },
          {
            "promote": true,
            "suppress": false,
            "label": "escaping immune response to cancer"
          },
          {
            "promote": true,
            "suppress": false,
            "label": "escaping immune response to cancer"
          },
          {
            "promote": true,
            "suppress": false,
            "label": "escaping immune response to cancer"
          },
          {
            "promote": true,
            "suppress": false,
            "label": "escaping immune response to cancer"
          }
        ],
        "functions": [
          {
            "description": "WT and E76K mutant PTPN11 dephosphorylates SRC phosphorylated KRAS WT and G12V mutant, thereby enhancing RAF binding to RAS",
            "pubmedId": 30644389
          },
          {
            "description": "Src homology-2 domain-containing protein tyrosine phosphatase involved in growth factor and cytokine-dependent intracellular signal transduction regulating multiple processes",
            "pubmedId": 12826400
          }
        ]
      }
    }
  }
}
'''

d = json.loads(data)
d
# Out:
# {'data': {'target': {'hallmarks': {'attributes': [{'name': 'senescence',
#       'reference': {'pubmedId': 29505847,
#        'description': 'hepatocyte-specific KD induces hepatocyte senescence in mice with oncogene-driven hepatocellular carcinoma'}},
#      {'name': 'senescence',
#       'reference': {'pubmedId': 25736378,
#        'description': 'KD induces senescence in mammospheres'}},
#      {'name': 'role in cancer',
#       'reference': {'pubmedId': 25865556, 'description': 'oncogene'}},
#      {'name': 'role in cancer',
#       'reference': {'pubmedId': 15710330, 'description': 'oncogene'}},
#      {'name': 'role in cancer',
#       'reference': {'pubmedId': 28814887, 'description': 'oncogene'}},
#      {'name': 'role in cancer',
#       'reference': {'pubmedId': 26622699, 'description': 'oncogene'}},
#      {'name': 'role in cancer',
#       'reference': {'pubmedId': 27582544, 'description': 'TSG'}},
#      {'name': 'role in cancer',
#       'reference': {'pubmedId': 27582544, 'description': 'oncogene'}},
#      {'name': 'role in cancer',
#       'reference': {'pubmedId': 21575863, 'description': 'TSG'}},
#      {'name': 'clinical impact',
#       'reference': {'pubmedId': 32944401,
#        'description': 'elevated expression is associated with reduced survival'}},
#      {'name': 'clinical impact',
#       'reference': {'pubmedId': 25865556,
#        'description': 'high expression is associated with reduced survival'}},
#      {'name': 'clinical impact',
#       'reference': {'pubmedId': 24297342,
#        'description': 'high expression is associated with reduced survival'}},
#      {'name': 'clinical impact',
#       'reference': {'pubmedId': 26622699,
#        'description': 'elevated expression correlates with lymph node metastasis at presentation'}},
#      {'name': 'mouse model',
#       'reference': {'pubmedId': 29323748,
#        'description': 'p.E76K conditional knock-in promotes colitis-associated colorectal cancer development'}},
#      {'name': 'types of alteration in cancer',
#       'reference': {'pubmedId': 25865556,
#        'description': 'frequently increased expression (typically poorly differentiated tumours)'}},
#      {'name': 'types of alteration in cancer',
#       'reference': {'pubmedId': 30371878,
#        'description': 'missense mutation in 42% of tumours, the most common being p.E76K'}},
#      {'name': 'types of alteration in cancer',
#       'reference': {'pubmedId': 24297342,
#        'description': 'frequently increased expression'}},
#      {'name': 'types of alteration in cancer',
#       'reference': {'pubmedId': 30371878,
#        'description': 'missense mutations in 9% of tumours'}},
#      {'name': 'types of alteration in cancer',
#       'reference': {'pubmedId': 28814887,
#        'description': 'frequently increased expression'}},
#      {'name': 'types of alteration in cancer',
#       'reference': {'pubmedId': 26622699,
#        'description': 'frequently increased expression'}},
#      {'name': 'global regulation of gene expression',
#       'reference': {'pubmedId': 12425940,
#        'description': 'acts as a negative regulator of LIF signalling-mediated neuronal gene expression'}},
#      {'name': 'differentiation and development',
#       'reference': {'pubmedId': 30764849,
#        'description': 'downregulation enhances cell differentiation via SRC and CTNNB1'}},
#      {'name': 'differentiation and development',
#       'reference': {'pubmedId': 29659837,
#        'description': 'differentiation of primary chondrocytes from mice heterozygous for D61G mutation is impaired via ERK activation'}},
#      {'name': 'differentiation and development',
#       'reference': {'pubmedId': 21670473,
#        'description': 'KD inhibits myeloid and erythroid differentiation of CD34 positive cells'}},
#      {'name': 'differentiation and development',
#       'reference': {'pubmedId': 32751109,
#        'description': 'involved in the regulation of several processes central to embryo development'}},
#      {'name': 'cell division control',
#       'reference': {'pubmedId': 32944401,
#        'description': 'KD delays cell G1 to S phase transition via PI3K/AKT/GSK3_ pathway-mediated degradation of cyclin D'}},
#      {'name': 'cell division control',
#       'reference': {'pubmedId': 31807022,
#        'description': 'overexpression increases cell transition from G1 to S, a larger effect is observed for a E76K mutation-containing gene'}},
#      {'name': 'cell division control',
#       'reference': {'pubmedId': 18640765,
#        'description': 'D61Y and E76K gain of function mutations promote cell progression to S and G2, in association with cyclin D upregulation and downregulation of p27 and p21'}},
#      {'name': 'interaction with pathogen',
#       'reference': {'pubmedId': 11743164,
#        'description': 'activation by sh2 domain binding of tyrosine phosphorylated Helicobacter pylori protein CagA is required for CagA-induced gastric carcinoma-associated morphological changes'}},
#      {'name': 'impact of mutation on function',
#       'reference': {'pubmedId': 31807022,
#        'description': 'E76K mutation enhances cell proliferation, migration and invasion effects effected by overexpression'}},
#      {'name': 'impact of mutation on function',
#       'reference': {'pubmedId': 30375388,
#        'description': 'most commonly reported cancer mutation E76K changes basal autoinhibited conformation to open substrate accessible state'}}],
#     'rows': [{'promote': True,
#       'suppress': False,
#       'label': 'genome instability and mutations'},
#      {'promote': False,
#       'suppress': True,
#       'label': 'genome instability and mutations'},
#      {'promote': False, 'suppress': True, 'label': 'angiogenesis'},
#      {'promote': True, 'suppress': False, 'label': 'angiogenesis'},
#      {'promote': True, 'suppress': False, 'label': 'angiogenesis'},
#      {'promote': True, 'suppress': False, 'label': 'angiogenesis'},
#      {'promote': False,
#       'suppress': True,
#       'label': 'escaping programmed cell death'},
#      {'promote': True,
#       'suppress': False,
#       'label': 'escaping programmed cell death'},
#      {'promote': False,
#       'suppress': True,
#       'label': 'escaping programmed cell death'},
#      {'promote': True,
#       'suppress': False,
#       'label': 'escaping programmed cell death'},
#      {'promote': True,
#       'suppress': False,
#       'label': 'escaping programmed cell death'},
#      {'promote': False,
#       'suppress': True,
#       'label': 'escaping programmed cell death'},
#      {'promote': True,
#       'suppress': False,
#       'label': 'escaping programmed cell death'},
#      {'promote': True,
#       'suppress': False,
#       'label': 'escaping programmed cell death'},
#      {'promote': True,
#       'suppress': False,
#       'label': 'escaping programmed cell death'},
#      {'promote': True, 'suppress': False, 'label': 'proliferative signalling'},
#      {'promote': True, 'suppress': False, 'label': 'proliferative signalling'},
#      {'promote': True, 'suppress': False, 'label': 'proliferative signalling'},
#      {'promote': True, 'suppress': False, 'label': 'proliferative signalling'},
#      {'promote': True, 'suppress': False, 'label': 'proliferative signalling'},
#      {'promote': True, 'suppress': False, 'label': 'proliferative signalling'},
#      {'promote': True, 'suppress': False, 'label': 'invasion and metastasis'},
#      {'promote': True, 'suppress': False, 'label': 'invasion and metastasis'},
#      {'promote': True, 'suppress': False, 'label': 'invasion and metastasis'},
#      {'promote': True, 'suppress': False, 'label': 'invasion and metastasis'},
#      {'promote': True, 'suppress': False, 'label': 'invasion and metastasis'},
#      {'promote': True, 'suppress': False, 'label': 'invasion and metastasis'},
#      {'promote': True,
#       'suppress': False,
#       'label': 'tumour promoting inflammation'},
#      {'promote': True,
#       'suppress': False,
#       'label': 'tumour promoting inflammation'},
#      {'promote': False,
#       'suppress': True,
#       'label': 'tumour promoting inflammation'},
#      {'promote': False,
#       'suppress': False,
#       'label': 'change of cellular energetics'},
#      {'promote': False,
#       'suppress': False,
#       'label': 'change of cellular energetics'},
#      {'promote': True, 'suppress': False, 'label': 'suppression of growth'},
#      {'promote': True, 'suppress': False, 'label': 'suppression of growth'},
#      {'promote': True, 'suppress': False, 'label': 'suppression of growth'},
#      {'promote': True, 'suppress': False, 'label': 'proliferative signalling'},
#      {'promote': True,
#       'suppress': False,
#       'label': 'escaping immune response to cancer'},
#      {'promote': True,
#       'suppress': False,
#       'label': 'escaping immune response to cancer'},
#      {'promote': True,
#       'suppress': False,
#       'label': 'escaping immune response to cancer'},
#      {'promote': True,
#       'suppress': False,
#       'label': 'escaping immune response to cancer'}],
#     'functions': [{'description': 'WT and E76K mutant PTPN11 dephosphorylates SRC phosphorylated KRAS WT and G12V mutant, thereby enhancing RAF binding to RAS',
#       'pubmedId': 30644389},
#      {'description': 'Src homology-2 domain-containing protein tyrosine phosphatase involved in growth factor and cytokine-dependent intracellular signal transduction regulating multiple processes',
#       'pubmedId': 12826400}]}}}}

# %%
pd.DataFrame(d['data']['target']['hallmarks']['rows']).label.unique()
# Out:
# array(['genome instability and mutations', 'angiogenesis',
#        'escaping programmed cell death', 'proliferative signalling',
#        'invasion and metastasis', 'tumour promoting inflammation',
#        'change of cellular energetics', 'suppression of growth',
#        'escaping immune response to cancer'], dtype=object)

# %%
from pyspark.sql import SparkSession
import pyspark.sql.functions as F

# establish spark connection
spark = (
    SparkSession.builder
    .master('local[*]')
    .getOrCreate()
)

# %%
target_file = '/Users/dsuveges/project_data/ot/target_index/target_21.04/targets'
###
### Getting the unique list of hallmark labels: it should be only 10, but there are more.
###
(
    spark.read.parquet(target_file)
    .select(
        F.explode(F.col('hallMarks.cancer_hallmarks')).alias('cancer_hallmarks')
    )
    .select(
        F.col('cancer_hallmarks.label')
    )
    .distinct()
    .show()
)
# Out:
# +--------------------+
# |               label|
# +--------------------+
# |tumour promoting ...|
# |cell replicative ...|
# |escaping immune r...|
# |genome instabilit...|
# |invasion and meta...|
# |proliferative sig...|
# |        angiogenesis|
# |escaping programm...|
# |change of cellula...|
# |suppression of gr...|
# +--------------------+

# %%
print(
    spark.read.parquet(target_file)
    .select(
        F.explode(F.col('hallMarks.attributes')).alias('attributes')
    )
    .select(
        F.col('attributes.attribute_name')
    )
    .distinct()
    .toPandas()
    .to_markdown(index=False)
)
# Out:
# | attribute_name                       |
# |:-------------------------------------|
# | fusion partner                       |
# | global regulation of gene expression |
# | differentiation and development      |
# | impact of mutation on function       |
# | cell division control                |
# | mouse model                          |
# | types of alteration in cancer        |
# | senescence                           |
# | clinical impact                      |
# | interaction with pathogen            |
# | role in cancer                       |

# %%
hallmark_df.loc[(hallmark_df.GENE_SYMBOL == 'PTPN11') & (hallmark_df.HALLMARK.isin(hallmark_annotations)),['HALLMARK','IMPACT','PUBMED_PMID']]
# Out:
#                                 HALLMARK      IMPACT PUBMED_PMID
# 3527    genome instability and mutations    promotes    26755576
# 3528    genome instability and mutations  suppresses    22890240
# 3529                        angiogenesis  suppresses    23065156
# 3530                        angiogenesis    promotes    26004555
# 3531                        angiogenesis    promotes    17962719
# 3532                        angiogenesis    promotes    19008228
# 3533      escaping programmed cell death  suppresses    12594211
# 3534      escaping programmed cell death    promotes    26004555
# 3535      escaping programmed cell death  suppresses    17330819
# 3536      escaping programmed cell death    promotes    29207183
# 3537      escaping programmed cell death    promotes    30104724
# 3538      escaping programmed cell death  suppresses    28947394
# 3539      escaping programmed cell death    promotes    28814887
# 3540      escaping programmed cell death    promotes    26622699
# 3541      escaping programmed cell death    promotes    17962719
# 3542            proliferative signalling    promotes    32944401
# 3543            proliferative signalling    promotes    31807022
# 3544            proliferative signalling    promotes    30355677
# 3545            proliferative signalling    promotes    29808006
# 3546            proliferative signalling    promotes    28814887
# 3547            proliferative signalling    promotes    27213290
# 3548             invasion and metastasis    promotes    30467378
# 3549             invasion and metastasis    promotes    29323748
# 3550             invasion and metastasis    promotes    31807022
# 3551             invasion and metastasis    promotes    26004555
# 3552             invasion and metastasis    promotes    25865556
# 3553             invasion and metastasis    promotes    28814887
# 3554       tumour promoting inflammation    promotes    30610104
# 3555       tumour promoting inflammation    promotes    23335101
# 3556       tumour promoting inflammation  suppresses    23530062
# 3557       change of cellular energetics         NaN    15520383
# 3558       change of cellular energetics         NaN    10514516
# 3559               suppression of growth    promotes    18757826
# 3560               suppression of growth    promotes    28947394
# 3561               suppression of growth    promotes    28085101
# 3562            proliferative signalling    promotes    17015617
# 3563  escaping immune response to cancer    promotes    29795405
# 3564  escaping immune response to cancer    promotes    27930879
# 3565  escaping immune response to cancer    promotes    24088816
# 3566  escaping immune response to cancer    promotes    19915046

# %%
hallmark_df.loc[(hallmark_df.HALLMARK == 'change of cellular energetics') & (hallmark_df.IMPACT.isna()),['GENE_SYMBOL', 'HALLMARK', 'IMPACT']]
# Out:
#      GENE_SYMBOL                       HALLMARK IMPACT
# 3557      PTPN11  change of cellular energetics    NaN
# 3558      PTPN11  change of cellular energetics    NaN

# %%
hallmark_df.loc[(hallmark_df.HALLMARK.isin(hallmark_annotations)) & (hallmark_df.IMPACT.isna()),['GENE_SYMBOL', 'HALLMARK', 'IMPACT', 'DESCRIPTION']]
# Out:
#      GENE_SYMBOL                        HALLMARK IMPACT  \
# 929         CYLD   tumour promoting inflammation    NaN
# 1496       FGFR2         invasion and metastasis    NaN
# 1978        LIFR         invasion and metastasis    NaN
# 2412        PAX5  escaping programmed cell death    NaN
# 2769      RABEP1         invasion and metastasis    NaN
# 2819    RAP1GDS1         invasion and metastasis    NaN
# 2849       RBM10  escaping programmed cell death    NaN
# 2850       RBM10  escaping programmed cell death    NaN
# 3557      PTPN11   change of cellular energetics    NaN
# 3558      PTPN11   change of cellular energetics    NaN
#
#                                             DESCRIPTION
# 929   liver-specific expression of deubiquitinase de...
# 1496  splice isoforms b and c, with preference for d...
# 1978  induction of LIFR confers a dormancy phenotype...
# 2412  suppression of B isoform of Pax5 leads to an i...
# 2769  disruption of Rabaptin-5 Ser407 phosphorylatio...
# 2819                               stimulates migration
# 2849  expression positively correlates with the expr...
# 2850  expression positively correlates with the expr...
# 3557  mice expressing a brain-specific exon 4 deleti...
# 3558  mice expressing protein tyrosine phosphatase d...

# %%
attributes_df = hallmark_df.loc[~hallmark_df.HALLMARK.isin(hallmark_annotations + ['functions'])]

# %%
for attribute in attributes_df.HALLMARK.unique():
    print(f'\nProcessing: {attribute}')
    print(attributes_df.loc[attributes_df.HALLMARK == attribute].drop(['CELL_TYPE','PUBMED_PMID','CELL_LINE'], axis=1).head())
# Out:
# Processing: role in cancer
#    GENE_SYMBOL        HALLMARK    IMPACT DESCRIPTION
# 2         ABI1  role in cancer       TSG         TSG
# 3         ABI1  role in cancer    fusion      fusion
# 4         ABI1  role in cancer       TSG         TSG
# 15        ABI1  role in cancer  oncogene    oncogene
# 28        ABL1  role in cancer    fusion      fusion
#
# Processing: function summary
#    GENE_SYMBOL          HALLMARK IMPACT  \
# 6         ABI1  function summary    NaN
# 11        ABI1  function summary    NaN
# 17        ABL1  function summary    NaN
# 20        ABL1  function summary    NaN
# 33       ACKR3  function summary    NaN
#
#                                           DESCRIPTION
# 6                     Abl-interacting adaptor protein
# 11  participates in the transduction of signals fr...
# 17  protein-tyrosine kinase, plays a prominent rol...
# 20  phosphorylates RAS proteins to allosterically ...
# 33            scavenger receptor for chemokine CXCL12
#
# Processing: fusion partner
#    GENE_SYMBOL        HALLMARK IMPACT DESCRIPTION
# 7         ABI1  fusion partner    NaN       KMT2A
# 16        ABL1  fusion partner    NaN         BCR
# 48       ACKR3  fusion partner    NaN       HMGA2
# 56       ACSL3  fusion partner    NaN        ETV1
# 57       ACSL6  fusion partner    NaN        ETV6
#
# Processing: mouse model
#     GENE_SYMBOL     HALLMARK IMPACT  \
# 9          ABI1  mouse model    NaN
# 220       ASXL1  mouse model    NaN
# 352        BCL9  mouse model    NaN
# 367       BCL9L  mouse model    NaN
# 411      BMPR1A  mouse model    NaN
#
#                                            DESCRIPTION
# 9    development of prostatic intraepithelial neopl...
# 220      loss of Asxl1 promotes myeloid transformation
# 352  knockdown significantly increases the survival...
# 367  overexpression in Apc-min+/- mouse model leads...
# 411  deletion in mice results in delayed mammary tu...
#
# Processing: differentiation and development
#     GENE_SYMBOL                         HALLMARK IMPACT  \
# 19         ABL1  differentiation and development    NaN
# 66        ACVR1  differentiation and development    NaN
# 69         AFF1  differentiation and development    NaN
# 80         AFF4  differentiation and development    NaN
# 154         APC  differentiation and development    NaN
#
#                                            DESCRIPTION
# 19                  promotes adipocyte differentiation
# 66      required for chondrogenesis during development
# 69          critical for normal lymphocyte development
# 80   depletion of AFF4 significantly inhibits the o...
# 154               involved in neuronal differentiation
#
# Processing: global regulation of gene expression
#     GENE_SYMBOL                              HALLMARK IMPACT  \
# 21         ABL1  global regulation of gene expression    NaN
# 184      ARID1A  global regulation of gene expression    NaN
# 222       ASXL1  global regulation of gene expression    NaN
# 278        ATRX  global regulation of gene expression    NaN
# 372        BCOR  global regulation of gene expression    NaN
#
#                                            DESCRIPTION
# 21   induces stabilisation of histone deacetylase 1...
# 184  ARID1A loss disrupts SWI/SNF targeting to enha...
# 222  part of polycomb-repressive deubiquitylase com...
# 278  regulator of DNA methylation, mutations result...
# 372  the BCOR complex contains Polycomb group prote...
#
# Processing: types of alteration in cancer
#    GENE_SYMBOL                       HALLMARK IMPACT  \
# 37       ACKR3  types of alteration in cancer    NaN
# 52       ACSL3  types of alteration in cancer    NaN
# 53       ACSL3  types of alteration in cancer    NaN
# 63       ACVR1  types of alteration in cancer    NaN
# 67       ACVR1  types of alteration in cancer    NaN
#
#                                          DESCRIPTION
# 37                                     overexpressed
# 52                                     downregulated
# 53                                    overexpressed
# 63                           recurrent GOF mutations
# 67  recurrent missense mutations G328V, G328E, R206H
#
# Processing: clinical impact
#     GENE_SYMBOL         HALLMARK IMPACT  \
# 38        ACKR3  clinical impact    NaN
# 45        ACKR3  clinical impact    NaN
# 47        ACKR3  clinical impact    NaN
# 395       BIRC3  clinical impact    NaN
# 409      BMPR1A  clinical impact    NaN
#
#                                            DESCRIPTION
# 38              high expression predicts poor survival
# 45              high expression predicts poor survival
# 47    high expression is associated with poor survival
# 395  lower expression levels of BIRC3 are associate...
# 409  decreased expression of BMPR1A is associated w...
#
# Processing: impact of mutation on function
#     GENE_SYMBOL                        HALLMARK IMPACT  \
# 55        ACSL3  impact of mutation on function    NaN
# 88        AKAP9  impact of mutation on function    NaN
# 110        AKT1  impact of mutation on function    NaN
# 123         ALK  impact of mutation on function    NaN
# 129         ALK  impact of mutation on function    NaN
#
#                                            DESCRIPTION
# 55   provides androgen upregulated promoter in fusi...
# 88   fusion protein lacks the autoinhibitory N-term...
# 110  Lys 17 alters the electrostatic interactions o...
# 123  regulatory domain is absent in fusion protein ...
# 129          F1174S causes ligand-independent activity
#
# Processing: cell division control
#     GENE_SYMBOL               HALLMARK IMPACT  \
# 150         APC  cell division control    NaN
# 246         ATM  cell division control    NaN
# 264         ATR  cell division control    NaN
# 265         ATR  cell division control    NaN
# 286        ATRX  cell division control    NaN
#
#                                            DESCRIPTION
# 150  regulates mitotic spindle assembly and orienta...
# 246   controls proper structure of the mitotic spindle
# 264                        controls S-phase checkpoint
# 265  deletion of ATR causes loss of DNA damage chec...
# 286  required for chromosome alignment and meiotic ...
#
# Processing: senescence
#     GENE_SYMBOL    HALLMARK    IMPACT  \
# 244         ATM  senescence       NaN
# 269         ATR  senescence  promotes
# 682      CDKN1A  senescence  promotes
# 687      CDKN2A  senescence  promotes
# 690      CDKN2A  senescence       NaN
#
#                                            DESCRIPTION
# 244  inactivation of ATM overcomes replication stre...
# 269  ectopic activation of ATR is sufficient to pro...
# 682                        induces cellular senescence
# 687                        induces cellular senescence
# 690  p16 induces senescence through the retinoblast...
#
# Processing: interaction with pathogen
#      GENE_SYMBOL                   HALLMARK IMPACT  \
# 459         BRD4  interaction with pathogen    NaN
# 904         CYLD  interaction with pathogen    NaN
# 918         CYLD  interaction with pathogen    NaN
# 1301        ESR1  interaction with pathogen    NaN
# 1566       FUBP1  interaction with pathogen    NaN
#
#                                             DESCRIPTION
# 459   cellular corepressor that inhibits the express...
# 904   negatively regulates the NF-kB-dependent infla...
# 918   negatively regulates the DDX58-mediated antivi...
# 1301  protects against HBV-associated hepatocellular...
# 1566  required for efficient replication of hepatiti...

# %%
hallmark_df.loc[ hallmark_df.HALLMARK == "interaction with pathogen"].DESCRIPTION.iloc[0]
# Out:
# 'cellular corepressor that inhibits the expression of HPV-encoded E6 and E7 oncoproteins which antagonise p53 and pRB tumour suppressor activity'

# %%
hallmark_df.loc[ (hallmark_df.HALLMARK == 'role in cancer') & (hallmark_df.DESCRIPTION != hallmark_df.IMPACT)]
# Out:
#      GENE_SYMBOL                    CELL_TYPE PUBMED_PMID        HALLMARK  \
# 882         CUX1                          NaN    25190083  role in cancer
# 1330       EWSR1                          NaN    17415412  role in cancer
# 1355        EZH2                          NaN    26845405  role in cancer
# 1465      FCGR2B                          NaN    11753646  role in cancer
# 2356        NPM1                         ALCL     8122112  role in cancer
# 2405        PAX5                          NaN    17851532  role in cancer
# 2474    PDCD1LG2                          NaN    24497532  role in cancer
# 3080       SMAD4  cholangiocellular carcinoma    16767220  role in cancer
# 3081       SMAD4              prostate cancer    21289624  role in cancer
# 3186        TET2  murine myeloid malignancies    21803851  role in cancer
# 3687    ARHGAP26                          NaN     8649427  role in cancer
#
#                 IMPACT                                        DESCRIPTION  \
# 882       TSG,oncogene                                      TSG, oncogene
# 1330  oncogene, fusion                                   fusion, oncogene
# 1355               NaN                                      oncogene, TSG
# 1465  oncogene, fusion                                   fusion, oncogene
# 2356               NaN                                             fusion
# 2405               TSG                              haploinsufficient TSG
# 2474  oncogene, fusion                                   fusion, oncogene
# 3080               NaN                                                TSG
# 3081               NaN                                                TSG
# 3186               TSG                                               TSG
# 3687               NaN  a GTPase activating protein that binds to foca...
#
#      CELL_LINE
# 882        NaN
# 1330       NaN
# 1355       NaN
# 1465       NaN
# 2356       NaN
# 2405       NaN
# 2474       NaN
# 3080       NaN
# 3081       NaN
# 3186       NaN
# 3687       NaN

# %%
hallmark_df.loc[ (hallmark_df.HALLMARK == 'role in cancer') & (hallmark_df.GENE_SYMBOL == 'ARHGAP26')]
# Out:
#      GENE_SYMBOL                         CELL_TYPE PUBMED_PMID  \
# 176     ARHGAP26                               NaN    10908648
# 3687    ARHGAP26                               NaN     8649427
# 3693    ARHGAP26                    gastric cancer    26146084
# 3694    ARHGAP26  infant acute monocytic leukaemia    15382263
# 3695    ARHGAP26                              JMML    10908648
# 3696    ARHGAP26                    ovarian cancer    31004081
#
#             HALLMARK  IMPACT  \
# 176   role in cancer     TSG
# 3687  role in cancer     NaN
# 3693  role in cancer  fusion
# 3694  role in cancer  fusion
# 3695  role in cancer  fusion
# 3696  role in cancer     TSG
#
#                                             DESCRIPTION CELL_LINE
# 176                                                 TSG       NaN
# 3687  a GTPase activating protein that binds to foca...       NaN
# 3693                                             fusion       NaN
# 3694                                             fusion       NaN
# 3695                                             fusion       NaN
# 3696                                                TSG       NaN

# %%
hallmark_df.loc[ (~hallmark_df.HALLMARK.isin(hallmark_annotations)) & (hallmark_df.DESCRIPTION.isna())]
# Out:
# Empty DataFrame
# Columns: [GENE_SYMBOL, CELL_TYPE, PUBMED_PMID, HALLMARK, IMPACT, DESCRIPTION, CELL_LINE]
# Index: []

# %%
hallmark_df.loc[hallmark_df.HALLMARK.isin(hallmark_annotations)]
# Out:
#      GENE_SYMBOL                              CELL_TYPE PUBMED_PMID  \
# 0           ABI1               hepatocellular carcinoma    28339046
# 1           ABI1               hepatocellular carcinoma    28339046
# 5           ABI1                                    NaN     9010225
# 8           ABI1                           mouse pre-B     18453543
# 10          ABI1                           glioblastoma    26473374
# ...          ...                                    ...         ...
# 3688    ARHGAP26  ductus arteriosus smooth muscle cells    30592323
# 3689    ARHGAP26                         ovarian cancer    31004081
# 3690    ARHGAP26                      colorectal cancer    28834752
# 3691    ARHGAP26  ductus arteriosus smooth muscle cells    30592323
# 3692    ARHGAP26                         ovarian cancer    31004081
#
#                       HALLMARK      IMPACT  \
# 0     proliferative signalling    promotes
# 1      invasion and metastasis    promotes
# 5        suppression of growth    promotes
# 8      invasion and metastasis    promotes
# 10     invasion and metastasis  suppresses
# ...                        ...         ...
# 3688  proliferative signalling    promotes
# 3689     suppression of growth    promotes
# 3690   invasion and metastasis  suppresses
# 3691   invasion and metastasis    promotes
# 3692   invasion and metastasis  suppresses
#
#                                             DESCRIPTION          CELL_LINE
# 0     overexpression of ABI1 increases and KD decrea...  HepG2 and MHCC97H
# 1     overexpression of ABI1 increases and KD decrea...  HepG2 and MHCC97H
# 5     fibroblasts overexpressing e3B1 have reduced g...                NaN
# 8     KD inhibits the Bcr-Abl-stimulated abnormal cy...               baf3
# 10    loss of the Abi1 gene enhances the Crk Tyr251 ...                NaN
# ...                                                 ...                ...
# 3688                    KD decreases cell proliferation                NaN
# 3689                KD leads to increased proliferation              SKOV3
# 3690  KD promotes membrane blebbing-based invasion a...              SW480
# 3691                        KD decreases cell migration                NaN
# 3692  KD leads to increased invasion and migration v...              SKOV3
#
# [1403 rows x 7 columns]

# %%
hallmark_df.loc[hallmark_df.HALLMARK=='role in cancer']
# Out:
#      GENE_SYMBOL                         CELL_TYPE PUBMED_PMID  \
# 2           ABI1                               NaN    16025998
# 3           ABI1                               NaN     9694699
# 4           ABI1                               NaN    23552839
# 15          ABI1          hepatocellular carcinoma    28339046
# 28          ABL1                               NaN    19260121
# ...          ...                               ...         ...
# 3687    ARHGAP26                               NaN     8649427
# 3693    ARHGAP26                    gastric cancer    26146084
# 3694    ARHGAP26  infant acute monocytic leukaemia    15382263
# 3695    ARHGAP26                              JMML    10908648
# 3696    ARHGAP26                    ovarian cancer    31004081
#
#             HALLMARK    IMPACT  \
# 2     role in cancer       TSG
# 3     role in cancer    fusion
# 4     role in cancer       TSG
# 15    role in cancer  oncogene
# 28    role in cancer    fusion
# ...              ...       ...
# 3687  role in cancer       NaN
# 3693  role in cancer    fusion
# 3694  role in cancer    fusion
# 3695  role in cancer    fusion
# 3696  role in cancer       TSG
#
#                                             DESCRIPTION          CELL_LINE
# 2                                                   TSG                NaN
# 3                                                fusion                NaN
# 4                                                   TSG                NaN
# 15                                             oncogene  HepG2 and MHCC97H
# 28                                               fusion                NaN
# ...                                                 ...                ...
# 3687  a GTPase activating protein that binds to foca...                NaN
# 3693                                             fusion                NaN
# 3694                                             fusion                NaN
# 3695                                             fusion                NaN
# 3696                                                TSG                NaN
#
# [503 rows x 7 columns]

# %%
hallmark_df.loc[hallmark_df.PUBMED_PMID=='9694699']
# Out:
#   GENE_SYMBOL CELL_TYPE PUBMED_PMID          HALLMARK  IMPACT  \
# 3        ABI1       NaN     9694699    role in cancer  fusion
# 6        ABI1       NaN     9694699  function summary     NaN
# 7        ABI1       AML     9694699    fusion partner     NaN
#
#                        DESCRIPTION CELL_LINE
# 3                           fusion       NaN
# 6  Abl-interacting adaptor protein       NaN
# 7                            KMT2A       NaN
