# %%
from pyspark.sql import functions as f, SparkSession, types as t
from pyspark.sql.window import Window

spark = SparkSession.builder.getOrCreate()

diseases = (
    spark.read.parquet('gs://open-targets-data-releases/22.11/output/etl/parquet/diseases/')
    .select(
        f.col('id').alias('diseaseId'), 
        f.col('name').alias('disaseName')
    )
)

drugs = (
    spark.read.parquet('gs://open-targets-data-releases/22.11/output/etl/parquet/molecule/')
    .select(
        f.col('id').alias('drugId'), 
        f.col('name').alias('drugName'),
        f.col('linkedDiseases.rows').alias('indications'),
        f.explode('linkedTargets.rows').alias('targetId')
    )
    .select(
        '*',
        f.explode('indications').alias('diseaseId')
    )
    .join(
        diseases, on='diseaseId', how='left'
    )
    .groupBy('drugId', 'drugName', 'targetId')
    .agg(f.collect_set(f.col('disaseName')).alias('indications'))
)

targets = (
    spark.read.parquet('gs://open-targets-data-releases/22.11/output/etl/parquet/targets/')
    .filter(f.col('biotype') == 'protein_coding')
    .select(
        f.col('genomicLocation.chromosome').alias('chromosome'),
        f.col('genomicLocation.start').alias('start'),
        f.col('genomicLocation.end').alias('end'),
        f.col('id').alias("targetId"), 
        f.col('approvedName').alias('targetName'), 
        f.col('approvedSymbol').alias('targetSymbol'),
    )
    .join(drugs, on='targetId', how='left')
    .persist()
)

targets.show()
# Out:
# [Stage 106:==================================================>  (192 + 8) / 200]
# +---------------+----------+---------+---------+--------------------+------------+-------------+----------------+--------------------+
# |       targetId|chromosome|    start|      end|          targetName|targetSymbol|       drugId|        drugName|         indications|
# +---------------+----------+---------+---------+--------------------+------------+-------------+----------------+--------------------+
# |ENSG00000059588|         1|234391313|234479179|TAR (HIV-1) RNA b...|      TARBP1|         null|            null|                null|
# |ENSG00000070182|        14| 64746283| 64879907|spectrin beta, er...|        SPTB|         null|            null|                null|
# |ENSG00000070366|        17|  2059839|  2303785|SMG6 nonsense med...|        SMG6|         null|            null|                null|
# |ENSG00000072071|        19| 14147743| 14206187|adhesion G protei...|      ADGRL1|         null|            null|                null|
# |ENSG00000073536|        17| 35128730| 35142304| notchless homolog 1|        NLE1|         null|            null|                null|
# |ENSG00000075290|        10|100463009|100483744|Wnt family member 8B|       WNT8B|         null|            null|                null|
# |ENSG00000083454|        17|  3672199|  3696240|purinergic recept...|       P2RX5|         null|            null|                null|
# |ENSG00000083782|        12| 90963682| 91005026|           epiphycan|        EPYC|         null|            null|                null|
# |ENSG00000086200|         5| 62403972| 62628582|         importin 11|       IPO11|         null|            null|                null|
# |ENSG00000087087|         7|100875103|100888664|serrate, RNA effe...|        SRRT|         null|            null|                null|
# |ENSG00000087502|        12| 29337352| 29381189|   ERGIC and golgi 2|      ERGIC2|         null|            null|                null|
# |ENSG00000092201|        14| 21351476| 21384019|SPT16 homolog, fa...|     SUPT16H|         null|            null|                null|
# |ENSG00000100567|        14| 58244843| 58272012|proteasome 20S su...|       PSMA3|CHEMBL2141296|        IXAZOMIB|[Mantle cell lymp...|
# |ENSG00000100567|        14| 58244843| 58272012|proteasome 20S su...|       PSMA3| CHEMBL451887|     CARFILZOMIB|[cancer, kidney c...|
# |ENSG00000100567|        14| 58244843| 58272012|proteasome 20S su...|       PSMA3| CHEMBL325041|      BORTEZOMIB|[refractory anemi...|
# |ENSG00000100567|        14| 58244843| 58272012|proteasome 20S su...|       PSMA3| CHEMBL371405|       MARIZOMIB|[lymphoma, cancer...|
# |ENSG00000100567|        14| 58244843| 58272012|proteasome 20S su...|       PSMA3|CHEMBL2103884|       OPROZOMIB|[cancer, hepatoce...|
# |ENSG00000100567|        14| 58244843| 58272012|proteasome 20S su...|       PSMA3|CHEMBL3545432|IXAZOMIB CITRATE|[Mantle cell lymp...|
# |ENSG00000101198|        20| 63240784| 63272694|sodium/potassium ...|      NKAIN4|         null|            null|                null|
# |ENSG00000102078|         X|130339888|130373361|solute carrier fa...|    SLC25A14|         null|            null|                null|
# +---------------+----------+---------+---------+--------------------+------------+-------------+----------------+--------------------+
# only showing top 20 rows

# %%
on_chr22 = targets.filter(f.col('chromosome') == '22').select('targetId').distinct().count()
on_chr22_w_drugs = (
    targets
    .filter(
        (f.col('chromosome') == '22') &
        (f.col('drugId').isNotNull()) &
        (f.col('indications').isNotNull())
    )
    .select('targetId')
    .distinct()
    .count()
)

print(f'Number of genes on chr22: {on_chr22}')
print(f'Number of genes on chr22 with drugs: {on_chr22_w_drugs}')
# Out:
# Number of genes on chr22: 447
# Number of genes on chr22 with drugs: 28

# %%
on_chr22_w_drugs = (
    targets
    .filter(
        (f.col('chromosome') == '22') &
        (f.col('drugId').isNotNull()) &
        (f.col('indications').isNotNull())
    )
    .distinct()
    .persist()
)
(
    on_chr22_w_drugs
    .groupBy('targetId','targetSymbol', 'targetName')
    .agg(
        f.count(f.col('targetId')).alias('drugCount')
    )
    .orderBy('drugCount', ascending=False)
    .show(30, truncate=False)
)
# Out:
# +---------------+------------+-------------------------------------------------------+---------+
# |targetId       |targetSymbol|targetName                                             |drugCount|
# +---------------+------------+-------------------------------------------------------+---------+
# |ENSG00000186951|PPARA       |peroxisome proliferator activated receptor alpha       |24       |
# |ENSG00000128271|ADORA2A     |adenosine A2a receptor                                 |22       |
# |ENSG00000100346|CACNA1I     |calcium voltage-gated channel subunit alpha1 I         |16       |
# |ENSG00000186716|BCR         |BCR activator of RhoGEF and GTPase                     |11       |
# |ENSG00000100429|HDAC10      |histone deacetylase 10                                 |9        |
# |ENSG00000100385|IL2RB       |interleukin 2 receptor subunit beta                    |8        |
# |ENSG00000166862|CACNG2      |calcium voltage-gated channel auxiliary subunit gamma 2|8        |
# |ENSG00000278195|SSTR3       |somatostatin receptor 3                                |7        |
# |ENSG00000100030|MAPK1       |mitogen-activated protein kinase 1                     |5        |
# |ENSG00000093010|COMT        |catechol-O-methyltransferase                           |4        |
# |ENSG00000100387|RBX1        |ring-box 1                                             |4        |
# |ENSG00000184983|NDUFA6      |NADH:ubiquinone oxidoreductase subunit A6              |3        |
# |ENSG00000100316|RPL3        |ribosomal protein L3                                   |3        |
# |ENSG00000198355|PIM3        |Pim-3 proto-oncogene, serine/threonine kinase          |3        |
# |ENSG00000213923|CSNK1E      |casein kinase 1 epsilon                                |2        |
# |ENSG00000100170|SLC5A1      |solute carrier family 5 member 1                       |2        |
# |ENSG00000183765|CHEK2       |checkpoint kinase 2                                    |2        |
# |ENSG00000100368|CSF2RB      |colony stimulating factor 2 receptor subunit beta      |2        |
# |ENSG00000100300|TSPO        |translocator protein                                   |2        |
# |ENSG00000185386|MAPK11      |mitogen-activated protein kinase 11                    |2        |
# |ENSG00000025708|TYMP        |thymidine phosphorylase                                |2        |
# |ENSG00000100311|PDGFB       |platelet derived growth factor subunit B               |1        |
# |ENSG00000100097|LGALS1      |galectin 1                                             |1        |
# |ENSG00000177663|IL17RA      |interleukin 17 receptor A                              |1        |
# |ENSG00000196236|XPNPEP3     |X-prolyl aminopeptidase 3                              |1        |
# |ENSG00000240972|MIF         |macrophage migration inhibitory factor                 |1        |
# |ENSG00000205560|CPT1B       |carnitine palmitoyltransferase 1B                      |1        |
# |ENSG00000159958|TNFRSF13C   |TNF receptor superfamily member 13C                    |1        |
# +---------------+------------+-------------------------------------------------------+---------+

# %%
diseases = (
    spark.read.parquet('gs://open-targets-data-releases/22.11/output/etl/parquet/diseases/')
    .select(
        f.col('id').alias('diseaseId'), 
        f.explode(f.col('therapeuticAreas')).alias('id')
    )
    .join(
        (
            spark.read.parquet('gs://open-targets-data-releases/22.11/output/etl/parquet/diseases/')
            .select(
                f.col('id'), 
                f.col('name').alias('diseaseName')
            )
        ), on='id', how='left'
    )
    .groupBy('diseaseId')
    .agg(
        f.collect_set('diseaseName').alias('therapeuticAreas')
    )
)

gwas_loci = (
    spark.read.json('gs://open-targets-data-releases/22.11/input/evidence-files/genetics-portal-evidences.json.gz')
    .filter(f.col('resourceScore')>=0.5)
    .select(
        f.col('targetFromSourceId').alias('targetId'),
        f.col("diseaseFromSourceMappedId").alias('diseaseId'),
    )
    .join(diseases, on='diseaseId')
    .drop('diseaseId')
    .select('targetId', f.explode('therapeuticAreas').alias('therapeuticArea'))
    .groupBy('targetId','therapeuticArea')
    .agg(f.count('*').alias('lociCount'))
    .groupBy('targetId')
    .agg(
        f.collect_list(
            f.struct(
                f.col('therapeuticArea'),
                f.col("lociCount")
            )
        ).alias('therapeuticAreas')
    )
    .persist()
)

gwas_loci.show()
# Out:
# [Stage 170:===============================================>    (183 + 16) / 200]
# +---------------+--------------------+
# |       targetId|    therapeuticAreas|
# +---------------+--------------------+
# |ENSG00000198870|[{urinary system ...|
# |ENSG00000173926|  [{measurement, 5}]|
# |ENSG00000182158|[{measurement, 35...|
# |ENSG00000188938|[{biological proc...|
# |ENSG00000070182|[{measurement, 59...|
# |ENSG00000070366|[{cancer or benig...|
# |ENSG00000153885|[{biological proc...|
# |ENSG00000224578|[{cardiovascular ...|
# |ENSG00000162377|  [{measurement, 1}]|
# |ENSG00000183032|[{measurement, 26...|
# |ENSG00000262655|[{measurement, 16...|
# |ENSG00000106012|[{musculoskeletal...|
# |ENSG00000087087|  [{measurement, 1}]|
# |ENSG00000143013|[{measurement, 22...|
# |ENSG00000177150|[{musculoskeletal...|
# |ENSG00000166046|[{measurement, 2}...|
# |ENSG00000163406|[{measurement, 37...|
# |ENSG00000120341|[{nervous system ...|
# |ENSG00000143198|  [{measurement, 5}]|
# |ENSG00000213079|[{respiratory or ...|
# +---------------+--------------------+
# only showing top 20 rows

# %%
chr22_w_gwas = (
    on_chr22_w_drugs
    .join(gwas_loci, on='targetId', how='left')
    .persist()
)

chr22_w_gwas.sample(0.2).select('targetName', 'indications', 'therapeuticAreas').show(vertical=True, truncate=False)
# Out:
# 22/12/24 00:54:16 WARN org.apache.spark.sql.execution.CacheManager: Asked to cache already cached data.
# -RECORD 0---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  targetName       | calcium voltage-gated channel subunit alpha1 I
#  indications      | [childhood absence epilepsy, epilepsy, irritable bowel syndrome, migraine disorder, neuropathic pain, complex regional pain syndrome, depressive disorder, Seizure]
#  therapeuticAreas | [{measurement, 12}, {genetic, familial or congenital disease, 3}, {psychiatric disorder, 27}, {nervous system disease, 27}, {biological process, 4}, {nutritional or metabolic disease, 1}]
# -RECORD 1---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  targetName       | calcium voltage-gated channel subunit alpha1 I
#  indications      | [Renal insufficiency, anxiety, generalized anxiety disorder]
#  therapeuticAreas | [{measurement, 12}, {genetic, familial or congenital disease, 3}, {psychiatric disorder, 27}, {nervous system disease, 27}, {biological process, 4}, {nutritional or metabolic disease, 1}]
# -RECORD 2---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  targetName       | calcium voltage-gated channel subunit alpha1 I
#  indications      | [sickle cell anemia, mucositis, scoliosis, cancer, opioid dependence, alcohol withdrawal, carpal tunnel syndrome, nicotine dependence, cicatricial alopecia, Seizure, Intervertebral disc degeneration, breast cancer, partial epilepsy, Low back pain, cannabis dependence, cirrhosis of liver, dyspepsia, multiple sclerosis, azoospermia, neuropathic pain, alcohol dependence, postherpetic neuralgia, alcohol drinking, Dementia, anxiety, reproductive system disease, delirium, diabetic neuropathy, insomnia, injury, Intervertebral Disc Displacement, Pruritus, spontaneous abortion, prostate cancer, urinary bladder carcinoma, head and neck malignant neoplasia, oropharynx cancer, fibromyalgia, depressive disorder, drug dependence, restless legs syndrome, Tinnitus, Vomiting, Herpes Zoster, Chronic pain, premature birth, schizophrenia, pain, Hot flashes, rotator cuff tear, post-operative sign or symptom, pelvic organ prolapse, epilepsy, post operative nausea and vomiting, psychosis, hyperemesis gravidarum, Tremor, neuralgia, autism spectrum disorder]
#  therapeuticAreas | [{measurement, 12}, {genetic, familial or congenital disease, 3}, {psychiatric disorder, 27}, {nervous system disease, 27}, {biological process, 4}, {nutritional or metabolic disease, 1}]
# -RECORD 3---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  targetName       | calcium voltage-gated channel subunit alpha1 I
#  indications      | [epilepsy, Seizure]
#  therapeuticAreas | [{measurement, 12}, {genetic, familial or congenital disease, 3}, {psychiatric disorder, 27}, {nervous system disease, 27}, {biological process, 4}, {nutritional or metabolic disease, 1}]
# -RECORD 4---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  targetName       | casein kinase 1 epsilon
#  indications      | [Mantle cell lymphoma, esophageal cancer, marginal zone B-cell lymphoma, chronic lymphocytic leukemia, Hodgkins lymphoma, gastrointestinal stromal tumor, rectum cancer, unspecified peripheral T-cell lymphoma, polycythemia vera, pancreatic carcinoma, follicular lymphoma, colorectal carcinoma, myelofibrosis, diffuse large B-cell lymphoma, gastric cancer]
#  therapeuticAreas | null
# -RECORD 5---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  targetName       | ring-box 1
#  indications      | [interstitial lung disease, sickle cell anemia, myeloproliferative disorder, Kaposi's sarcoma, Hodgkins lymphoma, primary myelofibrosis, Waldenstrom macroglobulinemia, medulloblastoma, soft tissue sarcoma, Castleman disease, graft versus host disease, plasmacytoma, hereditary hemorrhagic telangiectasia, myelofibrosis, AL amyloidosis, pulmonary fibrosis, systemic scleroderma, multiple myeloma, primary systemic amyloidosis, prostate cancer, immune system disease, neoplasm, polycythemia vera, pancreatic carcinoma, diffuse large B-cell lymphoma, plasma cell leukemia, small cell lung carcinoma, non-Hodgkins lymphoma]
#  therapeuticAreas | null
# ...
# -RECORD 18--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  targetName       | peroxisome proliferator activated receptor alpha
#  indications      | [cholestasis, Disorder of lipid metabolism, Hypercholesterolemia, cardiovascular disease, alcohol dependence, Combined hyperlipidemia, type 2 diabetes mellitus, coronary artery disease, Hypertriglyceridemia, medulloblastoma]
#  therapeuticAreas | [{disorder of visual system, 1}, {psychiatric disorder, 5}, {musculoskeletal or connective tissue disease, 1}, {measurement, 31}, {nervous system disease, 5}]
# -RECORD 19--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  targetName       | peroxisome proliferator activated receptor alpha
#  indications      | [Disorder of lipid metabolism, diabetes mellitus, type 2 diabetes mellitus]
#  therapeuticAreas | [{disorder of visual system, 1}, {psychiatric disorder, 5}, {musculoskeletal or connective tissue disease, 1}, {measurement, 31}, {nervous system disease, 5}]
# only showing top 20 rows

# %%
(
    chr22_w_gwas
    .withColumn('ta', f.explode('therapeuticAreas'))
    .select('targetId', f.col('ta.lociCount').alias('count'), f.col('ta.therapeuticArea').alias('therapeuticArea'))
    .distinct()
    .groupBy('targetId')
    .count()
    .orderBy('count', ascending=False)
    .show(39)
)
# Out:
# +---------------+-----+
# |       targetId|count|
# +---------------+-----+
# |ENSG00000183765|   11|
# |ENSG00000100385|    7|
# |ENSG00000100368|    7|
# |ENSG00000100311|    7|
# |ENSG00000100346|    6|
# |ENSG00000186951|    5|
# |ENSG00000100170|    5|
# |ENSG00000198355|    5|
# |ENSG00000186716|    5|
# |ENSG00000100030|    3|
# |ENSG00000093010|    2|
# |ENSG00000100300|    1|
# |ENSG00000177663|    1|
# |ENSG00000128271|    1|
# |ENSG00000159958|    1|
# |ENSG00000196236|    1|
# |ENSG00000240972|    1|
# +---------------+-----+

# %%
(
    spark.read.json('gs://open-targets-data-releases/22.11/input/evidence-files/genetics-portal-evidences.json.gz')
    .filter(
        (f.col('resourceScore')>=0.5) &
        (f.col('targetFromSourceId') == 'ENSG00000196236')
    )
    .show()
)
# Out:
# [Stage 298:>                                                        (0 + 1) / 1]
# +-------------------+---------------------------+---------------------------+------------------+-------------------+--------------------+-------------------------+----------+---------+--------------------------------+--------------------------------+--------------+--------------+---------+----------------------+---------------+------------------+------------+---------------+------------------+------------------------------+---------------+-----------+
# |               beta|betaConfidenceIntervalLower|betaConfidenceIntervalUpper|      datasourceId|         datatypeId|   diseaseFromSource|diseaseFromSourceMappedId|literature|oddsRatio|oddsRatioConfidenceIntervalLower|oddsRatioConfidenceIntervalUpper|pValueExponent|pValueMantissa|projectId|publicationFirstAuthor|publicationYear|     resourceScore|     studyId|studySampleSize|targetFromSourceId|variantFunctionalConsequenceId|      variantId|variantRsId|
# +-------------------+---------------------------+---------------------------+------------------+-------------------+--------------------+-------------------------+----------+---------+--------------------------------+--------------------------------+--------------+--------------+---------+----------------------+---------------+------------------+------------+---------------+------------------+------------------------------+---------------+-----------+
# |         -0.0113817|              -0.0153754156|        -0.0073879843999999|ot_genetics_portal|genetic_association|Apolipoprotein B ...|              EFO_0004615|[34226706]|     null|                            null|                            null|            -8|           2.1|     GCST|             Barton AR|           2021| 0.633899450302124|GCST90025952|         435744|   ENSG00000196236|                    SO_0001627|22_40876139_T_C|   rs138354|
# |             0.0128|         0.0082309456651447|         0.0173690543348552|ot_genetics_portal|genetic_association|Total cholesterol...|              EFO_0004574|[34594039]|     null|                            null|                            null|            -8|           4.0|     GCST|              Sakaue S|           2021|0.5001609921455383|GCST90018974|         480086|   ENSG00000196236|                    SO_0001627|22_40918008_C_T|  rs5758128|
# |-0.0123106999999999|              -0.0163648032|        -0.0082565967999999|ot_genetics_portal|genetic_association|Direct low densit...|              EFO_0004611|[34226706]|     null|                            null|                            null|            -9|           2.6|     GCST|             Barton AR|           2021|0.6304049491882324|GCST90025954|         437068|   ENSG00000196236|                    SO_0001627|22_40876139_T_C|   rs138354|
# |         -0.0123777|                -0.01642167|                -0.00833373|ot_genetics_portal|genetic_association|Total cholesterol...|              EFO_0004574|[34226706]|     null|                            null|                            null|            -9|           5.3|     GCST|             Barton AR|           2021|0.6455073356628418|GCST90025953|         437878|   ENSG00000196236|                    SO_0001627|22_40876139_T_C|   rs138354|
# +-------------------+---------------------------+---------------------------+------------------+-------------------+--------------------+-------------------------+----------+---------+--------------------------------+--------------------------------+--------------+--------------+---------+----------------------+---------------+------------------+------------+---------------+------------------+------------------------------+---------------+-----------+
